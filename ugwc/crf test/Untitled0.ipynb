# %%
# !pip install sklearn-crfsuite
# !pip install -U 'scikit-learn<0.24'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (4.64.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (0.8.10)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 5.0 MB/s
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.8 sklearn-crfsuite-0.3.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn<0.24
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 4.8 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.21.6)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.23.2 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.23.2 which is incompatible.
# Successfully installed scikit-learn-0.23.2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
# from sklearn.cross_validation import cross_val_score
# from sklearn.grid_search import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
nltk.download('conll2002')
# Out:
# [nltk_data] Downloading package conll2002 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2002.zip.
# True

# %%
nltk.corpus.conll2002.fileids()
# Out:
# ['esp.testa', 'esp.testb', 'esp.train', 'ned.testa', 'ned.testb', 'ned.train']

# %%
train_sents = list(nltk.corpus.conll2002.iob_sents('esp.train'))
test_sents = list(nltk.corpus.conll2002.iob_sents('esp.testb'))

# %%
train_sents[0]
# Out:
# [('Melbourne', 'NP', 'B-LOC'),
#  ('(', 'Fpa', 'O'),
#  ('Australia', 'NP', 'B-LOC'),
#  (')', 'Fpt', 'O'),
#  (',', 'Fc', 'O'),
#  ('25', 'Z', 'O'),
#  ('may', 'NC', 'O'),
#  ('(', 'Fpa', 'O'),
#  ('EFE', 'NC', 'B-ORG'),
#  (')', 'Fpt', 'O'),
#  ('.', 'Fp', 'O')]

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
sent2features(train_sents[0])[0]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'melbourne',
#  'word[-3:]': 'rne',
#  'word[-2:]': 'ne',
#  'word.isupper()': False,
#  'word.istitle()': True,
#  'word.isdigit()': False,
#  'postag': 'NP',
#  'postag[:2]': 'NP',
#  'BOS': True,
#  '+1:word.lower()': '(',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:postag': 'Fpa',
#  '+1:postag[:2]': 'Fp'}

# %%
train_sents
# Out:
# [[('Melbourne', 'NP', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Australia', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('Abogado', 'NC', 'B-PER'),
#   ('General', 'AQ', 'I-PER'),
#   ('del', 'SP', 'I-PER'),
#   ('Estado', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('Daryl', 'VMI', 'B-PER'),
#   ('Williams', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('subrayó', 'VMI', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('la', 'DA', 'O'),
#   ('necesidad', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('tomar', 'VMN', 'O'),
#   ('medidas', 'NC', 'O'),
#   ('para', 'SP', 'O'),
#   ('proteger', 'VMN', 'O'),
#   ('al', 'SP', 'O'),
#   ('sistema', 'NC', 'O'),
#   ('judicial', 'AQ', 'O'),
#   ('australiano', 'AQ', 'O'),
#   ('frente', 'RG', 'O'),
#   ('a', 'SP', 'O'),
#   ('una', 'DI', 'O'),
#   ('página', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('internet', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('imposibilita', 'VMI', 'O'),
#   ('el', 'DA', 'O'),
#   ('cumplimiento', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('principios', 'NC', 'O'),
#   ('básicos', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Ley', 'NC', 'B-MISC'),
#   ('.', 'Fp', 'O')],
#  [('La', 'DA', 'O'),
#   ('petición', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Abogado', 'NC', 'B-PER'),
#   ('General', 'AQ', 'I-PER'),
#   ('tiene', 'VMI', 'O'),
#   ('lugar', 'NC', 'O'),
#   ('después', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('que', 'CS', 'O'),
#   ('un', 'DI', 'O'),
#   ('juez', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Tribunal', 'NC', 'B-ORG'),
#   ('Supremo', 'AQ', 'I-ORG'),
#   ('del', 'SP', 'O'),
#   ('estado', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Victoria', 'NC', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Australia', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('se', 'P0', 'O'),
#   ('viera', 'VMS', 'O'),
#   ('forzado', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('disolver', 'VMN', 'O'),
#   ('un', 'DI', 'O'),
#   ('jurado', 'NC', 'O'),
#   ('popular', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('suspender', 'VMN', 'O'),
#   ('el', 'DA', 'O'),
#   ('proceso', 'NC', 'O'),
#   ('ante', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('argumento', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('defensa', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('que', 'CS', 'O'),
#   ('las', 'DA', 'O'),
#   ('personas', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('lo', 'PP', 'O'),
#   ('componían', 'VMI', 'O'),
#   ('podían', 'VMI', 'O'),
#   ('haber', 'VAN', 'O'),
#   ('obtenido', 'VMP', 'O'),
#   ('información', 'NC', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('acusado', 'VMP', 'O'),
#   ('a', 'SP', 'O'),
#   ('través', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('página', 'NC', 'O'),
#   ('CrimeNet', 'AQ', 'B-MISC'),
#   ('.', 'Fp', 'O')],
#  [('Esta', 'DD', 'O'),
#   ('página', 'NC', 'O'),
#   ('web', 'AQ', 'O'),
#   ('lleva', 'VMI', 'O'),
#   ('un', 'DI', 'O'),
#   ('mes', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('existencia', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('tiempo', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('sido', 'VSP', 'O'),
#   ('visitada', 'VMP', 'O'),
#   ('en', 'SP', 'O'),
#   ('más', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('millón', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('ocasiones', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('facilita', 'VMI', 'O'),
#   ('información', 'NC', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('miles', 'PN', 'O'),
#   ('de', 'SP', 'O'),
#   ('crímenes', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('criminales', 'VMM', 'O'),
#   ('ya', 'RG', 'O'),
#   ('enjuiciados', 'VMP', 'O'),
#   ('o', 'CC', 'O'),
#   ('aún', 'RG', 'O'),
#   ('perseguidos', 'VMM', 'O'),
#   (',', 'Fc', 'O'),
#   ('datos', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('salen', 'VMI', 'O'),
#   ('de', 'SP', 'O'),
#   ('artículos', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('periódicos', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('archivos', 'NC', 'O'),
#   ('judiciales', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Por', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('parte', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('el', 'DA', 'O'),
#   ('Abogado', 'NC', 'B-PER'),
#   ('General', 'AQ', 'I-PER'),
#   ('de', 'SP', 'O'),
#   ('Victoria', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('Rob', 'NC', 'B-PER'),
#   ('Hulls', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('indicó', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('no', 'RN', 'O'),
#   ('hay', 'VAI', 'O'),
#   ('nadie', 'PI', 'O'),
#   ('que', 'PR', 'O'),
#   ('controle', 'VMS', 'O'),
#   ('que', 'CS', 'O'),
#   ('las', 'DA', 'O'),
#   ('informaciones', 'NC', 'O'),
#   ('contenidas', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('CrimeNet', 'NC', 'B-MISC'),
#   ('son', 'VSI', 'O'),
#   ('veraces', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Hulls', 'NP', 'B-PER'),
#   ('señaló', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('sistema', 'NC', 'O'),
#   ('jurídico', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Commonwealth', 'NC', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('basa', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('justicia', 'NC', 'O'),
#   ('australiana', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('es', 'VSI', 'O'),
#   ('fundamental', 'AQ', 'O'),
#   ('que', 'PR', 'O'),
#   ('la', 'DA', 'O'),
#   ('persona', 'NC', 'O'),
#   ('sea', 'VSS', 'O'),
#   ('juzgada', 'VMP', 'O'),
#   ('únicamente', 'RG', 'O'),
#   ('teniendo', 'VMG', 'O'),
#   ('en', 'SP', 'O'),
#   ('cuenta', 'NC', 'O'),
#   ('las', 'DA', 'O'),
#   ('pruebas', 'NC', 'O'),
#   ('presentadas', 'AQ', 'O'),
#   ('ante', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('juez', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('La', 'DA', 'O'),
#   ('citada', 'AQ', 'O'),
#   ('página', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('internet', 'NC', 'O'),
#   ('se', 'P0', 'O'),
#   ('considera', 'VMI', 'O'),
#   ('también', 'RG', 'O'),
#   ('la', 'DA', 'O'),
#   ('causa', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('conclusión', 'NC', 'O'),
#   ('prematura', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('caso', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('asesinato', 'NC', 'O'),
#   ('juzgado', 'VMP', 'O'),
#   ('recientemente', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('ciudad', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Melbourne', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('capital', 'AQ', 'O'),
#   ('del', 'SP', 'O'),
#   ('estado', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Victoria', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('Santander', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Izquierda', 'NC', 'B-ORG'),
#   ('Unida', 'AQ', 'I-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Santander', 'NC', 'I-ORG'),
#   ('presentó', 'VMI', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('su', 'DP', 'O'),
#   ('nuevo', 'AQ', 'O'),
#   ('boletín', 'NC', 'O'),
#   ('trimestral', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Ciudad', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('una', 'DI', 'O'),
#   ('publicación', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('distribuirán', 'VMI', 'O'),
#   ('10.000', 'Z', 'O'),
#   ('ejemplares', 'NC', 'O'),
#   ('preferentemente', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('barrios', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('municipio', 'NC', 'O'),
#   ('donde', 'PR', 'O'),
#   ('la', 'DA', 'O'),
#   ('colación', 'NC', 'O'),
#   ('cuenta', 'VMI', 'O'),
#   ('con', 'SP', 'O'),
#   ('mayor', 'AQ', 'O'),
#   ('respaldo', 'NC', 'O'),
#   ('ciudadano', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('El', 'DA', 'O'),
#   ('portavoz', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Consejo', 'NC', 'B-ORG'),
#   ('Político', 'AQ', 'I-ORG'),
#   ('Municipal', 'AQ', 'I-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('IU', 'NC', 'I-ORG'),
#   ('en', 'SP', 'O'),
#   ('Santander', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('Ernesto', 'NC', 'B-PER'),
#   ('Gómez', 'NC', 'I-PER'),
#   ('de', 'SP', 'I-PER'),
#   ('la', 'DA', 'I-PER'),
#   ('Hera', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('explicó', 'VMI', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('conferencia', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('prensa', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('este', 'DD', 'O'),
#   ('boletín', 'NC', 'O'),
#   ('persigue', 'VMI', 'O'),
#   (',', 'Fc', 'O'),
#   ('más', 'RG', 'O'),
#   ('que', 'CS', 'O'),
#   ('informar', 'VMN', 'O'),
#   (',', 'Fc', 'O'),
#   ('abrir', 'VMN', 'O'),
#   ('espacios', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('debate', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('servir', 'VMN', 'O'),
#   ('como', 'CS', 'O'),
#   ('"', 'Fe', 'O'),
#   ('semilla', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('movilización', 'NC', 'O'),
#   ('política', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('ciudad', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Gómez', 'NC', 'B-PER'),
#   ('de', 'SP', 'I-PER'),
#   ('la', 'DA', 'I-PER'),
#   ('Hera', 'NC', 'I-PER'),
#   ('comentó', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('los', 'DA', 'O'),
#   ('contenidos', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('publicación', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Ciudad', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   ('responden', 'VMI', 'O'),
#   ('al', 'SP', 'O'),
#   ('programa', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('él', 'PP', 'O'),
#   ('encabezó', 'VMI', 'O'),
#   ('como', 'CS', 'O'),
#   ('candidato', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('elecciones', 'NC', 'O'),
#   ('municipales', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('1999', 'Z', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('IU', 'NC', 'B-ORG'),
#   ('perdió', 'VMI', 'O'),
#   ('su', 'DP', 'O'),
#   ('representación', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('Ayuntamiento', 'NC', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('confió', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('que', 'CS', 'O'),
#   ('su', 'DP', 'O'),
#   ('difusión', 'NC', 'O'),
#   ('sea', 'VSS', 'O'),
#   ('más', 'RG', 'O'),
#   ('amplia', 'AQ', 'O'),
#   ('una', 'DI', 'O'),
#   ('vez', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('la', 'DA', 'O'),
#   ('coalición', 'NC', 'O'),
#   ('resuelva', 'VMS', 'O'),
#   ('su', 'DP', 'O'),
#   ('crisis', 'NC', 'O'),
#   ('económica', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Por', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('momento', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Ciudad', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   ('será', 'VSI', 'O'),
#   ('repartida', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('forma', 'NC', 'O'),
#   ('preferencial', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('barrios', 'NC', 'O'),
#   ('con', 'SP', 'O'),
#   ('más', 'RG', 'O'),
#   ('electores', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('IU', 'NC', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('entre', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('el', 'DA', 'O'),
#   ('portavoz', 'NC', 'O'),
#   ('municipal', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('coalición', 'NC', 'O'),
#   ('citó', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('ladera', 'AQ', 'O'),
#   ('norte', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('calle', 'NC', 'B-LOC'),
#   ('Alta', 'AQ', 'I-LOC'),
#   (',', 'Fc', 'O'),
#   ('Cazoña', 'NC', 'B-LOC'),
#   ('y', 'CC', 'O'),
#   ('la', 'DA', 'O'),
#   ('zona', 'NC', 'O'),
#   ('comprendida', 'VMP', 'O'),
#   ('entre', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('calles', 'NC', 'O'),
#   ('Castilla', 'NC', 'B-LOC'),
#   ('y', 'CC', 'O'),
#   ('Hermida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('"', 'Fe', 'O'),
#   ('Ciudad', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('un', 'DI', 'O'),
#   ('boletín', 'NC', 'O'),
#   ('compuesto', 'AQ', 'O'),
#   ('por', 'SP', 'O'),
#   ('dos', 'DN', 'O'),
#   ('folios', 'NC', 'O'),
#   ('plegados', 'NC', 'O'),
#   ('por', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('mitad', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('sale', 'VMI', 'O'),
#   ('a', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('calle', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('primer', 'AO', 'O'),
#   ('número', 'NC', 'O'),
#   ('criticando', 'VMG', 'O'),
#   ('las', 'DA', 'O'),
#   ('obras', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('construcción', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('aparcamientos', 'NC', 'O'),
#   ('subterráneos', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('las', 'DA', 'O'),
#   ('molestias', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('están', 'VMI', 'O'),
#   ('causando', 'VMG', 'O'),
#   ('a', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('vecinos', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('el', 'DA', 'O'),
#   ('modo', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('que', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('explotarán', 'VMI', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Gómez', 'VMI', 'B-PER'),
#   ('de', 'SP', 'I-PER'),
#   ('la', 'DA', 'I-PER'),
#   ('Hera', 'NC', 'I-PER'),
#   ('considera', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('"', 'Fe', 'O'),
#   ('la', 'DA', 'O'),
#   ('política', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('PP', 'NC', 'B-ORG'),
#   ('de', 'SP', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('dinero', 'NC', 'O'),
#   ('absolutamente', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('todo', 'PI', 'O'),
#   ('y', 'CC', 'O'),
#   ('de', 'SP', 'O'),
#   ('que', 'CS', 'O'),
#   ('ese', 'DD', 'O'),
#   ('dinero', 'NC', 'O'),
#   ('se', 'P0', 'O'),
#   ('distribuya', 'VMS', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('todo', 'PI', 'O'),
#   ('para', 'SP', 'O'),
#   ('sus', 'DP', 'O'),
#   ('amigos', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('convertido', 'VMP', 'O'),
#   ('Santander', 'NC', 'B-LOC'),
#   ('en', 'SP', 'O'),
#   ('"', 'Fe', 'O'),
#   ('una', 'DI', 'O'),
#   ('trampa', 'NC', 'O'),
#   ('llena', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('agujeros', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('cuando', 'CS', 'O'),
#   ('todas', 'DI', 'O'),
#   ('las', 'DA', 'O'),
#   ('ciudades', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Europa', 'NC', 'B-LOC'),
#   ('occidental', 'AQ', 'O'),
#   ('están', 'VMI', 'O'),
#   ('tratando', 'VMG', 'O'),
#   ('de', 'SP', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('sus', 'DP', 'O'),
#   ('cascos', 'NC', 'O'),
#   ('urbanos', 'AQ', 'O'),
#   ('más', 'RG', 'O'),
#   ('habitables', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('A', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('juicio', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('las', 'DA', 'O'),
#   ('razones', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Ayuntamiento', 'NC', 'B-ORG'),
#   ('para', 'SP', 'O'),
#   ('llevar', 'VMN', 'O'),
#   ('adelante', 'RG', 'O'),
#   ('estas', 'DD', 'O'),
#   ('obras', 'NC', 'O'),
#   ('son', 'VSI', 'O'),
#   ('"', 'Fe', 'O'),
#   ('crematísticas', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('mercenarias', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('pero', 'CC', 'O'),
#   ('no', 'RN', 'O'),
#   ('tienen', 'VMI', 'O'),
#   ('nada', 'PI', 'O'),
#   ('que', 'PR', 'O'),
#   ('ver', 'VMN', 'O'),
#   ('con', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('futuro', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Santander', 'NC', 'B-LOC'),
#   ('ni', 'CC', 'O'),
#   ('con', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('bienestar', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('inmensa', 'AQ', 'O'),
#   ('mayoría', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('población', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('EFE', 'NC', 'B-ORG'),
#   ('-', 'Fg', 'O'),
#   ('Cantabria', 'VMI', 'B-LOC'),
#   ('Fráncfort', 'AQ', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('RFA', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFECOM', 'NP', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('grupo', 'NC', 'O'),
#   ('alemán', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('telefonía', 'NC', 'O'),
#   ('Deutsche', 'AQ', 'B-ORG'),
#   ('Telekom', 'NC', 'I-ORG'),
#   ('ha', 'VAI', 'O'),
#   ('adquirido', 'VMP', 'O'),
#   ('el', 'DA', 'O'),
#   ('50', 'Z', 'O'),
#   ('por', 'SP', 'O'),
#   ('ciento', 'DN', 'O'),
#   ('restante', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('operador', 'NC', 'O'),
#   ('suizo', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('telecomunicaciones', 'NC', 'O'),
#   ('Multilink', 'AQ', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('que', 'CS', 'O'),
#   ('hasta', 'SP', 'O'),
#   ('ahora', 'RG', 'O'),
#   ('poseía', 'VMI', 'O'),
#   ('France', 'AQ', 'B-ORG'),
#   ('Telecom', 'AQ', 'I-ORG'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('se', 'P0', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('convertido', 'VMP', 'O'),
#   ('en', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('único', 'AQ', 'O'),
#   ('propietario', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('informó', 'VMI', 'O'),
#   ('hoy,', 'AQ', 'O'),
#   ('jueves', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('la', 'DA', 'O'),
#   ('compañía', 'NC', 'O'),
#   ('germana', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Como', 'CS', 'O'),
#   ('contrapartida', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('Deutsche', 'NC', 'B-ORG'),
#   ('Telekom', 'NC', 'I-ORG'),
#   ('venderá', 'VMI', 'O'),
#   ('al', 'SP', 'O'),
#   ('consorcio', 'NC', 'O'),
#   ('francés', 'AQ', 'O'),
#   ('su', 'DP', 'O'),
#   ('participación', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('25', 'Z', 'O'),
#   ('por', 'SP', 'O'),
#   ('ciento', 'PN', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('empresa', 'NC', 'O'),
#   ('mixta', 'AQ', 'O'),
#   ('británica', 'AQ', 'O'),
#   ('MetroHoldings', 'NC', 'B-ORG'),
#   ('.', 'Fp', 'O')],
#  [('Multilink', 'NC', 'B-ORG'),
#   ('fue', 'VSI', 'O'),
#   ('creada', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('1998', 'Z', 'O'),
#   ('y', 'CC', 'O'),
#   ('ofrece', 'VMI', 'O'),
#   ('servicios', 'NC', 'O'),
#   ('telefónicos', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('de', 'SP', 'O'),
#   ('transmisión', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('datos', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('Suiza', 'NC', 'B-LOC'),
#   ('y', 'CC', 'O'),
#   ('el', 'DA', 'O'),
#   ('extranjero', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('además', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('tener', 'VMN', 'O'),
#   ('una', 'DI', 'O'),
#   ('red', 'NC', 'O'),
#   ('urbana', 'AQ', 'O'),
#   ('propia', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('fibra', 'NC', 'O'),
#   ('óptica', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Deutsche', 'VMI', 'B-ORG'),
#   ('Telekom', 'NC', 'I-ORG'),
#   ('calificó', 'VMI', 'O'),
#   ('esta', 'DD', 'O'),
#   ('compra', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('cuyo', 'PR', 'O'),
#   ('precio', 'VMI', 'O'),
#   ('no', 'RN', 'O'),
#   ('especificó', 'VMI', 'O'),
#   (',', 'Fc', 'O'),
#   ('como', 'CS', 'O'),
#   ('otro', 'DI', 'O'),
#   ('paso', 'NC', 'O'),
#   ('hacia', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('internacionalización', 'NC', 'O'),
#   ('mediante', 'SP', 'O'),
#   ('adquisiciones', 'NC', 'O'),
#   ('mayoritarias', 'AQ', 'O'),
#   ('destinadas', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('tener', 'VMN', 'O'),
#   ('el', 'DA', 'O'),
#   ('control', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('dirección', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('esas', 'DD', 'O'),
#   ('empresas', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('============================================================', 'Fz', 'O')],
#  [('Mérida', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('La', 'DA', 'O'),
#   ('Delegación', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('la', 'DA', 'I-ORG'),
#   ('Agencia', 'NC', 'I-ORG'),
#   ('EFE', 'NC', 'I-ORG'),
#   ('en', 'SP', 'O'),
#   ('Extremadura', 'NC', 'B-LOC'),
#   ('transmitirá', 'VMI', 'O'),
#   ('hoy,', 'NC', 'O'),
#   ('jueves,', 'AQ', 'O'),
#   ('día', 'NC', 'O'),
#   ('25', 'Z', 'O'),
#   (',', 'Fc', 'O'),
#   ('entre', 'SP', 'O'),
#   ('otras', 'PI', 'O'),
#   (',', 'Fc', 'O'),
#   ('las', 'DA', 'O'),
#   ('siguientes', 'AQ', 'O'),
#   ('informaciones', 'NC', 'O'),
#   (':', 'Fd', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('LASA', 'AQ', 'B-PER'),
#   ('ZABALA', 'NC', 'B-PER'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Mérida', 'NC', 'B-LOC'), ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('presidente', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Junta', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Extremadura', 'NC', 'I-ORG'),
#   (',', 'Fc', 'O'),
#   ('Juan', 'NC', 'B-PER'),
#   ('Carlos', 'AQ', 'I-PER'),
#   ('Rodríguez', 'NC', 'I-PER'),
#   ('Ibarra', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('recibirá', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('sede', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Presidencia', 'NC', 'B-ORG'),
#   ('del', 'SP', 'I-ORG'),
#   ('Gobierno', 'NC', 'I-ORG'),
#   ('extremeño', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('familiares', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('varios', 'PI', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('condenados', 'NC', 'O'),
#   ('por', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('proceso', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Lasa-Zabala', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('entre', 'SP', 'O'),
#   ('ellos', 'PP', 'O'),
#   ('a', 'SP', 'O'),
#   ('Lourdes', 'NC', 'B-PER'),
#   ('Díez', 'AQ', 'I-PER'),
#   ('Urraca', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('esposa', 'VMM', 'O'),
#   ('del', 'SP', 'O'),
#   ('ex', 'NC', 'O'),
#   ('gobernador', 'NC', 'O'),
#   ('civil', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('Guipúzcoa', 'NC', 'B-LOC'),
#   ('Julen', 'AQ', 'B-PER'),
#   ('Elgorriaga', 'AQ', 'I-PER'),
#   (';', 'Fx', 'O'),
#   ('y', 'CC', 'O'),
#   ('a', 'SP', 'O'),
#   ('Antonio', 'VMN', 'B-PER'),
#   ('Rodríguez', 'NC', 'I-PER'),
#   ('Galindo', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('hermano', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('general', 'AQ', 'O'),
#   ('Enrique', 'NC', 'B-PER'),
#   ('Rodríguez', 'NC', 'I-PER'),
#   ('Galindo', 'AQ', 'I-PER'),
#   ('.', 'Fp', 'O')],
#  [('(', 'Fpa', 'O'),
#   ('con', 'SP', 'O'),
#   ('fotografía', 'NC', 'O'),
#   (')', 'Fpt', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('PLENO', 'AQ', 'O'),
#   ('ASAMBLEA', 'NC', 'O'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Mérida', 'NC', 'B-LOC'), ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('Pleno', 'AQ', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('la', 'DA', 'I-ORG'),
#   ('Asamblea', 'NC', 'I-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Extremadura', 'NC', 'I-ORG'),
#   ('debatirá', 'VMI', 'O'),
#   (',', 'Fc', 'O'),
#   ('entre', 'SP', 'O'),
#   ('otras', 'PI', 'O'),
#   (',', 'Fc', 'O'),
#   ('una', 'DI', 'O'),
#   ('proposición', 'NC', 'O'),
#   ('no', 'RN', 'O'),
#   ('de', 'SP', 'O'),
#   ('ley', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('grupos', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('PSOE-NI', 'NC', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('PP', 'NC', 'B-ORG'),
#   ('y', 'CC', 'O'),
#   ('Mixto-Diputados', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('IU', 'NC', 'I-ORG'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('insta', 'VMI', 'O'),
#   ('al', 'SP', 'O'),
#   ('Gobierno', 'NC', 'B-ORG'),
#   ('central', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('promulgar', 'VMN', 'O'),
#   ('una', 'DI', 'O'),
#   ('Orden', 'NC', 'B-MISC'),
#   ('Ministerial', 'AQ', 'I-MISC'),
#   ('que', 'PR', 'O'),
#   ('recoja', 'VMS', 'O'),
#   ('la', 'DA', 'O'),
#   ('regionalización', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('superficie', 'NC', 'O'),
#   ('base', 'NC', 'O'),
#   ('para', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('cultivo', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('maíz', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('(', 'Fpa', 'O'),
#   ('EMPRENDEDORES', 'AQ', 'O'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Mérida', 'NC', 'B-LOC'), ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Economía,', 'NC', 'B-MISC'),
#   ('Industria.', 'AQ', 'I-MISC'),
#   ('Comercio', 'NC', 'I-MISC'),
#   (',', 'Fc', 'O'),
#   ('Manuel', 'AQ', 'B-PER'),
#   ('Amigo', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('los', 'DA', 'O'),
#   ('presidentes', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Caja', 'NC', 'B-ORG'),
#   ('Extremadura', 'AQ', 'I-ORG'),
#   ('y', 'CC', 'O'),
#   ('Caja', 'NC', 'B-ORG'),
#   ('Badajoz', 'AQ', 'I-ORG'),
#   (',', 'Fc', 'O'),
#   ('Jesús', 'I', 'B-PER'),
#   ('Medina', 'NC', 'I-PER'),
#   ('y', 'CC', 'O'),
#   ('José', 'NC', 'B-PER'),
#   ('Manuel', 'AQ', 'I-PER'),
#   ('Sánchez', 'NC', 'I-PER'),
#   ('Rojas', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('respectivamente', 'RG', 'O'),
#   (',', 'Fc', 'O'),
#   ('suscribirán', 'VMI', 'O'),
#   ('un', 'DI', 'O'),
#   ('convenio', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('colaboración', 'NC', 'O'),
#   ('para', 'SP', 'O'),
#   ('financiar', 'VMN', 'O'),
#   ('proyectos', 'NC', 'O'),
#   ('empresariales', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('jóvenes', 'NC', 'O'),
#   ('emprendedores', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('(', 'Fpa', 'O'),
#   ('CARLOS', 'AQ', 'B-PER'),
#   ('V', 'NC', 'I-PER'),
#   ('-', 'Fg', 'O'),
#   ('CONGRESO', 'NC', 'O'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Jaraíz', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Vera', 'NC', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Cáceres', 'NC', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('Instituto', 'NC', 'B-ORG'),
#   ('Histórico', 'AQ', 'I-ORG'),
#   ('"', 'Fe', 'I-ORG'),
#   ('Hoffmeyer', 'NC', 'I-ORG'),
#   ('"', 'Fe', 'I-ORG'),
#   ('acogerá', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('inauguración', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('primera', 'AO', 'O'),
#   ('sesión', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Congreso', 'NC', 'B-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('Historia', 'NC', 'I-MISC'),
#   ('Moderna', 'AQ', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   ('Carlos.', 'NC', 'B-MISC'),
#   ('y', 'CC', 'I-MISC'),
#   ('el', 'DA', 'I-MISC'),
#   ('fin', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('una', 'DI', 'I-MISC'),
#   ('época.', 'NC', 'I-MISC'),
#   ('1500-1558', 'Z', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('enmarca', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('actos', 'NC', 'O'),
#   ('conmemorativos', 'AQ', 'O'),
#   ('del', 'SP', 'O'),
#   ('V', 'NC', 'B-MISC'),
#   ('Centenario', 'AQ', 'I-MISC'),
#   ('del', 'SP', 'O'),
#   ('nacimiento', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('emperador', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Agenda', 'NC', 'O'),
#   ('informativa', 'AQ', 'O'),
#   (':', 'Fd', 'O'),
#   ('-', 'Fg', 'O'),
#   ('10:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('presidente', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Junta', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Extremadura', 'NC', 'I-ORG'),
#   (',', 'Fc', 'O'),
#   ('Juan', 'NC', 'B-PER'),
#   ('Carlos', 'AQ', 'I-PER'),
#   ('Rodríguez', 'NC', 'I-PER'),
#   ('Ibarra', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('recibirá', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('sede', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Presidencia', 'NC', 'B-ORG'),
#   ('del', 'SP', 'I-ORG'),
#   ('Gobierno', 'NC', 'I-ORG'),
#   ('extremeño', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('familiares', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('varios', 'PI', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('condenados', 'NC', 'O'),
#   ('por', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('proceso', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Lasa-Zabala', 'NC', 'B-MISC'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('10:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Economía,', 'NC', 'B-MISC'),
#   ('Industria.', 'AQ', 'I-MISC'),
#   ('Comercio', 'NC', 'I-MISC'),
#   (',', 'Fc', 'O'),
#   ('Manuel', 'AQ', 'B-PER'),
#   ('Amigo', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('los', 'DA', 'O'),
#   ('presidentes', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Caja', 'NC', 'B-ORG'),
#   ('Extremadura', 'AQ', 'I-ORG'),
#   ('y', 'CC', 'O'),
#   ('Caja', 'NC', 'B-ORG'),
#   ('Badajoz', 'AQ', 'I-ORG'),
#   (',', 'Fc', 'O'),
#   ('Jesús', 'I', 'B-ORG'),
#   ('Medina', 'NC', 'I-ORG'),
#   ('y', 'CC', 'O'),
#   ('José', 'NC', 'B-PER'),
#   ('Manuel', 'AQ', 'I-PER'),
#   ('Sánchez', 'NC', 'I-PER'),
#   ('Rojas', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('respectivamente', 'RG', 'O'),
#   (',', 'Fc', 'O'),
#   ('suscribirán', 'VMI', 'O'),
#   ('un', 'DI', 'O'),
#   ('convenio', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('colaboración', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('10:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Jaraíz', 'NC', 'B-LOC'),
#   ('de', 'SP', 'I-LOC'),
#   ('la', 'DA', 'I-LOC'),
#   ('Vera', 'NC', 'I-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Cáceres', 'NC', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Comenzará', 'VMI', 'O'),
#   ('el', 'DA', 'O'),
#   ('Congreso', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Carlos.', 'NC', 'B-MISC'),
#   ('y', 'CC', 'I-MISC'),
#   ('el', 'DA', 'I-MISC'),
#   ('fin', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('una', 'DI', 'I-MISC'),
#   ('época.', 'NC', 'I-MISC'),
#   ('1500-1558', 'Z', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('10:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Vivienda,', 'NC', 'B-MISC'),
#   ('Urbanismo.', 'AQ', 'I-MISC'),
#   ('Transportes', 'NC', 'I-MISC'),
#   (',', 'Fc', 'O'),
#   ('Javier', 'VMI', 'B-PER'),
#   ('Corominas', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('entregará', 'VMI', 'O'),
#   ('94', 'Z', 'O'),
#   ('viviendas', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('régimen', 'NC', 'O'),
#   ('especial', 'AQ', 'O'),
#   ('construidas', 'AQ', 'O'),
#   ('por', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('Grupo', 'NC', 'B-ORG'),
#   ('"', 'Fe', 'I-ORG'),
#   ('Magenta', 'AQ', 'I-ORG'),
#   ('"', 'Fe', 'I-ORG'),
#   ('en', 'SP', 'O'),
#   ('"', 'Fe', 'O'),
#   ('La', 'DA', 'B-LOC'),
#   ('Corchera', 'NC', 'I-LOC'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('10:30', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Plasencia', 'NC', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Cáceres', 'NC', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('alcalde', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('José', 'AQ', 'B-PER'),
#   ('Luis', 'NC', 'I-PER'),
#   ('Díez', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('hablará', 'VMI', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('diversas', 'DI', 'O'),
#   ('cuestiones', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('interés', 'NC', 'O'),
#   ('municipal', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('11:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Se', 'P0', 'O'),
#   ('celebrará', 'VMI', 'O'),
#   ('una', 'DI', 'O'),
#   ('sesión', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Pleno', 'AQ', 'B-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('la', 'DA', 'I-MISC'),
#   ('Asamblea', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('Extremadura', 'NC', 'I-MISC'),
#   ('.', 'Fp', 'O')],
#  [('12:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Montijo', 'NP', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Badajoz', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Cultura', 'NC', 'B-MISC'),
#   (',', 'Fc', 'O'),
#   ('Francisco', 'AQ', 'B-PER'),
#   ('Muñoz', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('inaugurará', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('IV', 'NC', 'B-MISC'),
#   ('Feria', 'VMM', 'I-MISC'),
#   ('del', 'SP', 'I-MISC'),
#   ('Libro', 'NC', 'I-MISC'),
#   ('local', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('12:00', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Azuaga', 'NP', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Badajoz', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Inauguración', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('XIX', 'AQ', 'B-MISC'),
#   ('Feria', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('Muestras', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('la', 'DA', 'I-MISC'),
#   ('Campiña', 'NC', 'I-MISC'),
#   ('Sur', 'AQ', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('Extremadura', 'NC', 'I-MISC'),
#   ('(', 'Fpa', 'O'),
#   ('FECSUR', 'NP', 'B-MISC'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('12:30', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('Pleno', 'AQ', 'B-ORG'),
#   ('del', 'SP', 'I-ORG'),
#   ('Ayuntamiento', 'NC', 'I-ORG'),
#   ('debatirá', 'VMI', 'O'),
#   ('cuestiones', 'NC', 'O'),
#   ('como', 'CS', 'O'),
#   ('la', 'DA', 'O'),
#   ('recalificación', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('terrenos', 'NC', 'O'),
#   ('aledaños', 'AQ', 'O'),
#   ('al', 'SP', 'O'),
#   ('Colegio', 'NC', 'B-LOC'),
#   ('"', 'Fe', 'I-LOC'),
#   ('Salesianos', 'AQ', 'I-LOC'),
#   ('"', 'Fe', 'I-LOC'),
#   ('.', 'Fp', 'O')],
#  [('20:30', 'Z', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Cáceres', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Cultura', 'NC', 'B-MISC'),
#   (',', 'Fc', 'O'),
#   ('Francisco', 'AQ', 'B-PER'),
#   ('Muñoz', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('asistirá', 'VMI', 'O'),
#   ('a', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('presentación', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('libro', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Seres.', 'AQ', 'B-MISC'),
#   ('Estrellas', 'NC', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('analiza', 'VMI', 'O'),
#   ('los', 'DA', 'O'),
#   ('orígenes', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('Universo', 'NC', 'B-MISC'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('datos', 'NC', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('proyecto', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('investigación', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Los', 'DA', 'B-MISC'),
#   ('Primeros', 'AO', 'I-MISC'),
#   ('Pobladores', 'NC', 'I-MISC'),
#   ('de', 'SP', 'I-MISC'),
#   ('Extremadura', 'NC', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [(':', 'Fd', 'O'),
#   ('-', 'Fg', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Mérida', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('La', 'DA', 'O'),
#   ('televisión', 'NC', 'O'),
#   ('pública', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('la', 'DA', 'O'),
#   ('sociedad', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('información', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('la', 'DA', 'O'),
#   ('financiación', 'NC', 'O'),
#   ('autonómica', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('los', 'DA', 'O'),
#   ('contenidos', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('jornada', 'NC', 'O'),
#   ('extraescolar', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('la', 'DA', 'O'),
#   ('creación', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('Consejo', 'NC', 'B-ORG'),
#   ('Consultivo', 'AQ', 'I-ORG'),
#   ('son', 'VSI', 'O'),
#   ('los', 'DA', 'O'),
#   ('primeros', 'AO', 'O'),
#   ('asuntos', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('negociarán', 'VMI', 'O'),
#   ('a', 'SP', 'O'),
#   ('partir', 'VMN', 'O'),
#   ('de', 'SP', 'O'),
#   ('mañana', 'NC', 'O'),
#   ('el', 'DA', 'O'),
#   ('PP', 'NC', 'B-ORG'),
#   ('y', 'CC', 'O'),
#   ('la', 'DA', 'O'),
#   ('Junta', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Extremadura', 'NC', 'I-ORG'),
#   ('para', 'SP', 'O'),
#   ('alcanzar', 'VMN', 'O'),
#   ('un', 'DI', 'O'),
#   ('pacto', 'NC', 'O'),
#   ('regional', 'AQ', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('13', 'Z', 'O'),
#   ('asuntos', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('interés', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [(':', 'Fd', 'O'),
#   ('-', 'Fg', 'O'),
#   ('h.', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('Cáceres', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Continuarán', 'VMI', 'O'),
#   ('las', 'DA', 'O'),
#   ('actividades', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Agora.', 'VMI', 'B-MISC'),
#   ('El', 'DA', 'I-MISC'),
#   ('debate', 'NC', 'I-MISC'),
#   ('peninsular', 'AQ', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Por', 'SP', 'O'),
#   ('Caius', 'NC', 'B-PER'),
#   ('Apicius', 'AQ', 'I-PER'),
#   ('Madrid', 'AQ', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Un', 'DI', 'O'),
#   ('vicio', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('no', 'RN', 'O'),
#   ('debe', 'VMI', 'O'),
#   ('incurrir', 'VMN', 'O'),
#   ('jamás', 'RG', 'O'),
#   ('quien', 'PR', 'O'),
#   ('se', 'P0', 'O'),
#   ('tenga', 'VMS', 'O'),
#   ('por', 'SP', 'O'),
#   ('gastrónomo', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('aspire', 'VMM', 'O'),
#   ('a', 'SP', 'O'),
#   ('ser', 'VSN', 'O'),
#   ('reconocido', 'VMP', 'O'),
#   ('como', 'CS', 'O'),
#   ('tal', 'PD', 'O'),
#   ('es', 'VSI', 'O'),
#   ('el', 'DA', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('patriotería', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('entendida', 'AQ', 'O'),
#   ('como', 'CS', 'O'),
#   ('el', 'DA', 'O'),
#   ('alarde', 'NC', 'O'),
#   ('excesivo', 'AQ', 'O'),
#   ('e', 'CC', 'O'),
#   ('inoportuno', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('patriotismo', 'NC', 'O'),
#   (':', 'Fd', 'O'),
#   ('el', 'DA', 'O'),
#   ('gastrónomo', 'NC', 'O'),
#   ('no', 'RN', 'O'),
#   ('es', 'VSI', 'O'),
#   ('apátrida', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('pero', 'CC', 'O'),
#   ('debe', 'VMI', 'O'),
#   ('huir', 'VMN', 'O'),
#   ('como', 'CS', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('peste', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('chovinismo', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Hace', 'VMI', 'O'),
#   ('años', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('uno', 'PI', 'O'),
#   ('de', 'SP', 'O'),
#   ('sus', 'DP', 'O'),
#   ('libros', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('viaje', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('el', 'DA', 'O'),
#   ('Nobel', 'NC', 'B-PER'),
#   ('de', 'SP', 'I-PER'),
#   ('Literatura', 'NC', 'I-PER'),
#   ('Camilo', 'AQ', 'I-PER'),
#   ('José', 'AQ', 'I-PER'),
#   ('Cela', 'NC', 'I-PER'),
#   ('afirmaba', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('el', 'DA', 'O'),
#   ('patriota', 'NC', 'O'),
#   ('es', 'VSI', 'O'),
#   ('quien', 'PR', 'O'),
#   ('está', 'VMI', 'O'),
#   ('orgulloso', 'AQ', 'O'),
#   ('del', 'SP', 'O'),
#   ('lugar', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('que', 'PR', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('nacido', 'VMP', 'O'),
#   ('y', 'CC', 'O'),
#   ('lo', 'PP', 'O'),
#   ('defiende', 'VMI', 'O'),
#   (',', 'Fc', 'O'),
#   ('actitud', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('tiene', 'VMI', 'O'),
#   ('razón', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('mientras', 'CS', 'O'),
#   ('que', 'CS', 'O'),
#   ('el', 'DA', 'O'),
#   ('patriotero', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('por', 'SP', 'O'),
#   ('entonces', 'RG', 'O'),
#   (',', 'Fc', 'O'),
#   ('Cela', 'NC', 'B-PER'),
#   ('usaba', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('palabra', 'NC', 'O'),
#   ("'", 'Fz', 'O'),
#   ('nacionalista', 'AQ', 'O'),
#   ("'", 'Fz', 'O'),
#   ('-', 'Fg', 'O'),
#   ('es', 'VSI', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('proclama', 'VMI', 'O'),
#   ('contra', 'SP', 'O'),
#   ('viento.', 'VMN', 'O'),
#   ('marea', 'NC', 'O'),
#   ('que', 'CS', 'O'),
#   ('su', 'DP', 'O'),
#   ('tierra', 'NC', 'O'),
#   ('natal', 'AQ', 'O'),
#   ('es', 'VSI', 'O'),
#   ('en', 'SP', 'O'),
#   ('todo', 'DI', 'O'),
#   ('superior', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('demás', 'PI', 'O'),
#   (',', 'Fc', 'O'),
#   ('cosa', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('que', 'CS', 'O'),
#   ('-', 'Fg', 'O'),
#   ('decía', 'VMI', 'O'),
#   ('Cela', 'NC', 'B-PER'),
#   ('-', 'Fg', 'O'),
#   ('bien', 'RG', 'O'),
#   ('pudiera', 'VMS', 'O'),
#   ('no', 'RN', 'O'),
#   ('tener', 'VMN', 'O'),
#   ('razón', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('En', 'SP', 'O'),
#   ('esto', 'PD', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('comida', 'NC', 'O'),
#   ('abunda', 'VMI', 'O'),
#   ('demasiado', 'RG', 'O'),
#   ('la', 'DA', 'O'),
#   ('patriotería', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Uno', 'PI', 'O'),
#   ('no', 'RN', 'O'),
#   ('tiene', 'VMI', 'O'),
#   ('ningún', 'DI', 'O'),
#   ('inconveniente', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('aceptar', 'VMN', 'O'),
#   ('que', 'CS', 'O'),
#   ('cada', 'DI', 'O'),
#   ('cual', 'PR', 'O'),
#   ('defienda', 'VMS', 'O'),
#   ('la', 'DA', 'O'),
#   ('cocina', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('los', 'DA', 'O'),
#   ('productos', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('tierra', 'NC', 'O'),
#   ('...', 'Fs', 'O'),
#   ('siempre', 'RG', 'O'),
#   ('que', 'CS', 'O'),
#   ('esa', 'DD', 'O'),
#   ('defensa', 'NC', 'O'),
#   ('no', 'RN', 'O'),
#   ('implique', 'VMS', 'O'),
#   ('el', 'DA', 'O'),
#   ('desprecio', 'NC', 'O'),
#   ('por', 'SP', 'O'),
#   ('cuanto', 'RG', 'O'),
#   ('es', 'VSI', 'O'),
#   ('ajeno', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('costumbres', 'NC', 'O'),
#   ('gastronómicas', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('solar', 'NC', 'O'),
#   ('patrio', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('En', 'SP', 'O'),
#   ('este', 'DD', 'O'),
#   ('caso', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('habrá', 'VAI', 'O'),
#   ('que', 'CS', 'O'),
#   ('pasar', 'VMN', 'O'),
#   ('de', 'SP', 'O'),
#   ('Cela', 'NC', 'B-PER'),
#   ('a', 'SP', 'O'),
#   ('Antonio', 'NC', 'B-PER'),
#   ('Machado', 'AQ', 'I-PER'),
#   ('y', 'CC', 'O'),
#   ('recordar', 'VMN', 'O'),
#   ('aquello', 'PD', 'O'),
#   ('de', 'SP', 'O'),
#   ('"', 'Fe', 'O'),
#   ('desprecia', 'VMM', 'O'),
#   ('cuanto', 'RG', 'O'),
#   ('ignora', 'VMI', 'O'),
#   ('...', 'Fs', 'O')],
#  [('"', 'Fe', 'O'),
#   ('El', 'DA', 'O'),
#   ('problema', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('patriotería', 'NC', 'O'),
#   ('gastronómica', 'AQ', 'O'),
#   ('-', 'Fg', 'O'),
#   ('y', 'CC', 'O'),
#   (',', 'Fc', 'O'),
#   ('no', 'RN', 'O'),
#   ('nos', 'PP', 'O'),
#   ('engañemos', 'VMS', 'O'),
#   (',', 'Fc', 'O'),
#   ('de', 'SP', 'O'),
#   ('cualquier', 'DI', 'O'),
#   ('otra', 'DI', 'O'),
#   ('-', 'Fg', 'O'),
#   ('es', 'VSI', 'O'),
#   ('ése', 'PD', 'O'),
#   ('justamente', 'RG', 'O'),
#   (':', 'Fd', 'O'),
#   ('la', 'DA', 'O'),
#   ('ignorancia', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Claro', 'RG', 'O'),
#   ('que', 'CS', 'O'),
#   ('esa', 'DD', 'O'),
#   ('misma', 'DI', 'O'),
#   ('ignorancia', 'NC', 'O'),
#   ('puede', 'VMI', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('caer', 'VMN', 'O'),
#   ('a', 'SP', 'O'),
#   ('muchos', 'PI', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('defecto', 'NC', 'O'),
#   ('contrario', 'AQ', 'O'),
#   (':', 'Fd', 'O'),
#   ('el', 'DA', 'O'),
#   (',', 'Fc', 'O'),
#   ('digamos', 'VMM', 'O'),
#   (',', 'Fc', 'O'),
#   ('papanatismo', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('hace', 'VMI', 'O'),
#   ('que', 'CS', 'O'),
#   ('para', 'SP', 'O'),
#   ('estos', 'DD', 'O'),
#   ('ciudadanos', 'NC', 'O'),
#   ('todo', 'DI', 'O'),
#   ('lo', 'DA', 'O'),
#   ('extranjero', 'NC', 'O'),
#   ('sea', 'VSS', 'O'),
#   ('mejor', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Pues', 'CS', 'O'),
#   ('...', 'Fs', 'O'),
#   ('tampoco', 'RG', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Un', 'DI', 'O'),
#   ('gastrónomo', 'NC', 'O'),
#   ('es', 'VSI', 'O'),
#   ('algo', 'PI', 'O'),
#   ('así', 'RG', 'O'),
#   ('como', 'CS', 'O'),
#   ('un', 'DI', 'O'),
#   ('viajero', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('pero', 'CC', 'O'),
#   ('viajero', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('no', 'RN', 'O'),
#   ('turista', 'AQ', 'O'),
#   (';', 'Fx', 'O'),
#   ('un', 'DI', 'O'),
#   ('viajero', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('digamos', 'VMM', 'O'),
#   (',', 'Fc', 'O'),
#   ('al', 'SP', 'O'),
#   ('estilo', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('siglo', 'NC', 'O'),
#   ('XIX', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('una', 'DI', 'O'),
#   ('persona', 'NC', 'O'),
#   ('llena', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('curiosidad', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('liberada', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('lo', 'DA', 'O'),
#   ('posible', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('de', 'SP', 'O'),
#   ('prejuicios', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('dispuesta', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('aceptar', 'VMN', 'O'),
#   ('las', 'DA', 'O'),
#   ('cosas', 'NC', 'O'),
#   ('buenas', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('demás', 'PI', 'O'),
#   ('sin', 'SP', 'O'),
#   ('por', 'SP', 'O'),
#   ('ello', 'PP', 'O'),
#   ('renegar', 'VMN', 'O'),
#   ('de', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('propias', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Pero', 'CC', 'O'),
#   ('esa', 'DD', 'O'),
#   ('universalidad', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('gastrónomo', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('los', 'DA', 'O'),
#   ('primeros', 'AO', 'O'),
#   ('que', 'PR', 'O'),
#   ('universalizaron', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('gastronomía', 'NC', 'O'),
#   ('fueron', 'VSI', 'O'),
#   ('los', 'DA', 'O'),
#   ('romanos', 'NC', 'O'),
#   ('-', 'Fg', 'O'),
#   ('no', 'RN', 'O'),
#   ('implica', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('renuncia', 'NC', 'O'),
#   ('a', 'SP', 'O'),
#   ('lo', 'DA', 'O'),
#   ('propio', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Mucho', 'RG', 'O'),
#   ('menos', 'RG', 'O'),
#   ('las', 'DA', 'O'),
#   ('mezcolanzas', 'NC', 'O'),
#   ('absurdas', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('esa', 'DD', 'O'),
#   ('cocina', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('llamamos', 'VMI', 'O'),
#   ("'", 'Fz', 'O'),
#   ('de', 'SP', 'O'),
#   ('fusión', 'NC', 'O'),
#   ("'", 'Fz', 'O'),
#   (',', 'Fc', 'O'),
#   ('muy', 'RG', 'O'),
#   ('defendible', 'AQ', 'O'),
#   ('siempre.', 'NC', 'O'),
#   ('cuando', 'CS', 'O'),
#   ('no', 'RN', 'O'),
#   ('derive', 'VMS', 'O'),
#   (',', 'Fc', 'O'),
#   ('como', 'CS', 'O'),
#   ('en', 'SP', 'O'),
#   ('tantos', 'DI', 'O'),
#   ('casos', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('cocina', 'NC', 'O'),
#   ("'", 'Fz', 'O'),
#   ('de', 'SP', 'O'),
#   ('confusión', 'NC', 'O'),
#   ("'", 'Fz', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Insistiremos', 'VMI', 'O'),
#   ('siempre', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('que', 'PR', 'O'),
#   ('una', 'DI', 'O'),
#   ('cocina', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('para', 'SP', 'O'),
#   ('ser', 'VSN', 'O'),
#   ('de', 'SP', 'O'),
#   ('verdad', 'NC', 'O'),
#   ('grande', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('de', 'SP', 'O'),
#   ('ser', 'VSN', 'O'),
#   ('fiel', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('tierra', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   ('también', 'RG', 'O'),
#   ('a', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('tiempo', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Pero', 'CC', 'O'),
#   ('debe', 'VMI', 'O'),
#   (',', 'Fc', 'O'),
#   ('cómo', 'PT', 'O'),
#   ('no', 'RN', 'O'),
#   (',', 'Fc', 'O'),
#   ('estar', 'VMN', 'O'),
#   ('abierta', 'AQ', 'O'),
#   ('a', 'SP', 'O'),
#   ('incorporaciones', 'NC', 'O'),
#   ('foráneas', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Qué', 'PT', 'O'),
#   ('sería', 'VSI', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('cocina', 'NC', 'O'),
#   ('europea', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('por', 'SP', 'O'),
#   ('ejemplo', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('sin', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('patatas', 'NC', 'O'),
#   (';', 'Fx', 'O'),
#   ('o', 'CC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('cocina', 'NC', 'O'),
#   ('mediterránea', 'AQ', 'O'),
#   ('sin', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('tomates', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('productos', 'NC', 'O'),
#   ('ambos', 'PN', 'O'),
#   ('que', 'PR', 'O'),
#   ('llegaron', 'VMI', 'O'),
#   ('al', 'SP', 'O'),
#   ('Viejo', 'AQ', 'B-MISC'),
#   ('Mundo', 'NC', 'I-MISC'),
#   ('hace', 'VMI', 'O'),
#   ('menos', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('cinco', 'DN', 'O'),
#   ('siglos', 'NC', 'O'),
#   ('...', 'Fs', 'O')],
#  [('Imagínense', 'VMM', 'O'),
#   ('ustedes', 'PP', 'O'),
#   ('que', 'CS', 'O'),
#   ('entre', 'SP', 'O'),
#   ('aquellos', 'DD', 'O'),
#   ('españoles', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('fueron', 'VSI', 'O'),
#   ('quienes', 'PR', 'O'),
#   ('llevaron', 'VMI', 'O'),
#   ('a', 'SP', 'O'),
#   ('Europa', 'VMN', 'B-LOC'),
#   ('esos', 'DD', 'O'),
#   ('dones', 'NC', 'O'),
#   ('americanos', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('se', 'P0', 'O'),
#   ('hubiera', 'VAS', 'O'),
#   ('impuesto', 'VMP', 'O'),
#   ('la', 'DA', 'O'),
#   ('patriotería', 'NC', 'O'),
#   ('gastronómica', 'AQ', 'O'),
#   (':', 'Fd', 'O'),
#   ('patatas', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('tomates', 'NC', 'O'),
#   ('se', 'P0', 'O'),
#   ('hubieran', 'VAS', 'O'),
#   ('quedado', 'VMP', 'O'),
#   ('en', 'SP', 'O'),
#   ('curiosidades', 'NC', 'O'),
#   ('botánicas', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('No', 'RN', 'O'),
#   ('hay', 'VAI', 'O'),
#   (',', 'Fc', 'O'),
#   ('no', 'RN', 'O'),
#   ('puede', 'VMI', 'O'),
#   ('haber', 'VAN', 'O'),
#   (',', 'Fc', 'O'),
#   ('una', 'DI', 'O'),
#   ('cocina', 'NC', 'O'),
#   ('universal', 'AQ', 'O'),
#   (';', 'Fx', 'O'),
#   ('recuerden', 'VMM', 'O'),
#   ('ustedes', 'PP', 'O'),
#   ('ese', 'DD', 'O'),
# ...
#   ('las', 'DA', 'O'),
#   ('declaraciones', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Mas', 'CC', 'B-PER'),
#   ('con', 'SP', 'O'),
#   ('una', 'DI', 'O'),
#   ('estrategia', 'NC', 'O'),
#   ('paralela', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('porque', 'CS', 'O'),
#   ('eso', 'PD', 'O'),
#   ('situaría', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('crisis', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('gobierno', 'NC', 'O'),
#   ('catalán', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('El', 'DA', 'O'),
#   ('consejero', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Gobernación', 'NC', 'B-MISC'),
#   ('y', 'CC', 'O'),
#   ('líder', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('UDC', 'NC', 'B-ORG'),
#   (',', 'Fc', 'O'),
#   ('Josep', 'NC', 'B-PER'),
#   ('Antoni', 'AQ', 'I-PER'),
#   ('Duran.', 'AQ', 'I-PER'),
#   ('Lleida', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('recibió', 'VMI', 'O'),
#   ('esta', 'DD', 'O'),
#   ('mañana', 'NC', 'O'),
#   ('por', 'SP', 'O'),
#   ('parte', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('gobierno', 'NC', 'O'),
#   ('chileno', 'AQ', 'O'),
#   ('la', 'DA', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Orden', 'NC', 'B-MISC'),
#   ('Bernardo', 'AQ', 'I-MISC'),
#   ("O'Higgins", 'NC', 'I-MISC'),
#   ('"', 'Fe', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('reconocimiento', 'NC', 'O'),
#   ('a', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('labor', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('cooperación', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('entendimiento', 'NC', 'O'),
#   ('con', 'SP', 'O'),
#   ('Chile', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('Duran.', 'VMI', 'B-PER'),
#   ('Lleida', 'NC', 'I-PER'),
#   ('no', 'RN', 'O'),
#   ('quiso', 'VMI', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('manifestaciones', 'NC', 'O'),
#   ('sobre', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('tema', 'NC', 'O'),
#   ('alegando', 'VMG', 'O'),
#   ('que', 'CS', 'O'),
#   ('"', 'Fe', 'O'),
#   ('el', 'DA', 'O'),
#   ('mejor', 'AQ', 'O'),
#   ('servicio', 'NC', 'O'),
#   ('público', 'AQ', 'O'),
#   ('que', 'PR', 'O'),
#   ('le', 'PP', 'O'),
#   ('puedo', 'VMI', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('a', 'SP', 'O'),
#   ('CiU', 'NC', 'B-ORG'),
#   ('y', 'CC', 'O'),
#   ('al', 'SP', 'O'),
#   ('futuro', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('gobierno', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Cataluña', 'NC', 'B-LOC'),
#   ('es', 'VSI', 'O'),
#   ('no', 'RN', 'O'),
#   ('hacer', 'VMN', 'O'),
#   ('declaraciones', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Sarajevo', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('23', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('Un', 'DI', 'O'),
#   ('total', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('16', 'Z', 'O'),
#   ('personas', 'NC', 'O'),
#   ('han', 'VAI', 'O'),
#   ('muerto', 'VMP', 'O'),
#   ('y', 'CC', 'O'),
#   ('una', 'DI', 'O'),
#   ('veintena', 'NC', 'O'),
#   ('han', 'VAI', 'O'),
#   ('resultado', 'VMP', 'O'),
#   ('heridas', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('lo', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('va', 'VMI', 'O'),
#   ('de', 'SP', 'O'),
#   ('año', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('Bosnia', 'NC', 'B-LOC'),
#   ('a', 'SP', 'O'),
#   ('causa', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('explosión', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('minas', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('informó', 'VMI', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('Sarajevo', 'VMN', 'B-LOC'),
#   ('una', 'DI', 'O'),
#   ('representante', 'NC', 'O'),
#   ('internacional', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Wendy', 'VMI', 'B-PER'),
#   ('Rappaport', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('portavoz', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('Alta', 'AQ', 'B-ORG'),
#   ('Comisaría', 'NC', 'I-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('las', 'DA', 'I-ORG'),
#   ('Naciones', 'NC', 'I-ORG'),
#   ('Unidas', 'AQ', 'I-ORG'),
#   ('para', 'SP', 'I-ORG'),
#   ('los', 'DA', 'I-ORG'),
#   ('Refugiados', 'NC', 'I-ORG'),
#   ('(', 'Fpa', 'O'),
#   ('ACNUR', 'NP', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   (',', 'Fc', 'O'),
#   ('recordó', 'VMI', 'O'),
#   ('el', 'DA', 'O'),
#   ('último', 'AO', 'O'),
#   ('caso', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('perdieron', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('vida', 'NC', 'O'),
#   ('dos', 'DN', 'O'),
#   ('niños', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('otros', 'DI', 'O'),
#   ('dos', 'PN', 'O'),
#   ('quedaron', 'VMI', 'O'),
#   ('gravemente', 'RG', 'O'),
#   ('heridos', 'AQ', 'O'),
#   ('cuando', 'CS', 'O'),
#   ('recogían', 'VMI', 'O'),
#   ('fresas', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('campo', 'NC', 'O'),
#   ('minado', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('término', 'NC', 'O'),
#   ('municipal', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('Malinjak', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('norte', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Bosnia', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('Según', 'SP', 'O'),
#   ('cálculos', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('los', 'DA', 'O'),
#   ('expertos', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('cuatro', 'DN', 'O'),
#   ('años.', 'NC', 'O'),
#   ('medio', 'RG', 'O'),
#   ('después', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('terminar', 'VMN', 'O'),
#   ('la', 'DA', 'O'),
#   ('guerra', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('todavía', 'RG', 'O'),
#   ('hay', 'VAI', 'O'),
#   ('en', 'SP', 'O'),
#   ('Bosnia', 'NC', 'B-LOC'),
#   ('un', 'DI', 'O'),
#   ('millón', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('estos', 'DD', 'O'),
#   ('artefactos', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Representantes', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('misión', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('ONU', 'NC', 'B-ORG'),
#   ('en', 'SP', 'O'),
#   ('Bosnia', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('encabeza', 'VMI', 'O'),
#   ('las', 'DA', 'O'),
#   ('operaciones', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('retirada', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('minas', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('han', 'VAI', 'O'),
#   ('denunciado', 'VMP', 'O'),
#   ('en', 'SP', 'O'),
#   ('varias', 'DI', 'O'),
#   ('ocasiones', 'NC', 'O'),
#   ('la', 'DA', 'O'),
#   ('falta', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('recursos', 'NC', 'O'),
#   ('financieros', 'AQ', 'O'),
#   ('para', 'SP', 'O'),
#   ('su', 'DP', 'O'),
#   ('trabajo', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('El', 'DA', 'O'),
#   ('portavoz', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('Fuerzas', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Estabilización', 'NC', 'I-ORG'),
#   ('(', 'Fpa', 'O'),
#   ('SFOR', 'NP', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('en', 'SP', 'O'),
#   ('Bosnia', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('comandante', 'NC', 'O'),
#   ('Yvon', 'AQ', 'B-PER'),
#   ('Desjardins', 'NC', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('indicó', 'VMI', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('que', 'CS', 'O'),
#   ('el', 'DA', 'O'),
#   ('Gobierno', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Noruega', 'NC', 'I-ORG'),
#   ('ha', 'VAI', 'O'),
#   ('decidido', 'VMP', 'O'),
#   ('aportar', 'VMN', 'O'),
#   ('unos', 'DI', 'O'),
#   ('225.000', 'Z', 'O'),
#   ('dólares', 'NC', 'O'),
#   ('para', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('eliminación', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('minas', 'NC', 'O'),
#   ('a', 'SP', 'O'),
#   ('partir', 'VMN', 'O'),
#   ('de', 'SP', 'O'),
#   ('julio', 'NC', 'O'),
#   ('próximo', 'AQ', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Barcelona', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('23', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  [('-', 'Fg', 'O')],
#  [('El', 'DA', 'O'),
#   ('fiscal', 'NC', 'O'),
#   ('ha', 'VAI', 'O'),
#   ('pedido', 'VMP', 'O'),
#   ('hoy', 'RG', 'O'),
#   ('54', 'Z', 'O'),
#   ('años', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('prisión', 'NC', 'O'),
#   ('en', 'SP', 'O'),
#   ('total', 'AQ', 'O'),
#   ('para', 'SP', 'O'),
#   ('dos', 'DN', 'O'),
#   ('prostitutas', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('un', 'DI', 'O'),
#   ('responsable', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('club', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('alterne', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Barcelona', 'NC', 'B-LOC'),
#   ('acusados', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('asesinar', 'VMN', 'O'),
#   ('a', 'SP', 'O'),
#   ('un', 'DI', 'O'),
#   ('empresario', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('poseía', 'VMI', 'O'),
#   ('diversas', 'DI', 'O'),
#   ('propiedades', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('que', 'PR', 'O'),
#   ('murió', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('playa', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('Castelldefels', 'NC', 'B-LOC'),
#   ('acuchillado', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('ahogado', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('orilla', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('La', 'DA', 'O'),
#   ('Audiencia', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Barcelona', 'NC', 'I-ORG'),
#   ('ha', 'VAI', 'O'),
#   ('iniciado', 'VMP', 'O'),
#   ('esta', 'DD', 'O'),
#   ('mañana', 'NC', 'O'),
#   ('el', 'DA', 'O'),
#   ('juicio', 'NC', 'O'),
#   ('con', 'SP', 'O'),
#   ('tribunal', 'NC', 'O'),
#   ('popular', 'AQ', 'O'),
#   ('contra', 'SP', 'O'),
#   ('E.', 'NC', 'B-PER'),
#   ('I.', 'AQ', 'I-PER'),
#   ('C.', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('M.', 'VMI', 'B-PER'),
#   ('W.', 'AQ', 'I-PER'),
#   ('W.', 'NC', 'I-PER'),
#   ('y', 'CC', 'O'),
#   ('P.', 'AQ', 'B-PER'),
#   ('B.', 'AQ', 'I-PER'),
#   ('H.', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('acusados', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('asesinar', 'VMN', 'O'),
#   ('a', 'SP', 'O'),
#   ('Pedro', 'VMN', 'B-PER'),
#   ('Corbella', 'NC', 'I-PER'),
#   ('Canturri', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('de', 'SP', 'O'),
#   ('62', 'Z', 'O'),
#   ('años', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('dueño', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('diversos', 'DI', 'O'),
#   ('comercios', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('empresas', 'NC', 'O'),
#   ('repartidas', 'AQ', 'O'),
#   ('por', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('comarca', 'NC', 'O'),
#   ('barcelonesa', 'AQ', 'O'),
#   ('del', 'SP', 'O'),
#   ('Maresme', 'NC', 'B-LOC'),
#   ('y', 'CC', 'O'),
#   ('ex', 'NC', 'O'),
#   ('propietario', 'AQ', 'O'),
#   ('del', 'SP', 'O'),
#   ('colegio', 'NC', 'O'),
#   ('privado', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('Mare', 'NC', 'B-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Déu', 'NC', 'I-ORG'),
#   ('de', 'SP', 'I-ORG'),
#   ('Núria', 'NC', 'I-ORG'),
#   ('"', 'Fe', 'O'),
#   ('de', 'SP', 'O'),
#   ('Barcelona', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('Los', 'DA', 'O'),
#   ('hechos', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('rodearon', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('muerte', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('empresario', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('estaba', 'VMI', 'O'),
#   ('separado', 'AQ', 'O'),
#   ('y', 'CC', 'O'),
#   ('tenía', 'VMI', 'O'),
#   ('una', 'DI', 'O'),
#   ('hija', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('tuvieron', 'VMI', 'O'),
#   ('lugar', 'NC', 'O'),
#   ('un', 'DI', 'O'),
#   ('mes', 'NC', 'O'),
#   ('después', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('que', 'PR', 'O'),
#   ('vendiera', 'VMS', 'O'),
#   ('el', 'DA', 'O'),
#   ('edificio', 'NC', 'O'),
#   ('donde', 'PR', 'O'),
#   ('estaba', 'VMI', 'O'),
#   ('ubicado', 'VMP', 'O'),
#   ('el', 'DA', 'O'),
#   ('citado', 'AQ', 'O'),
#   ('colegio', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('por', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('que', 'PR', 'O'),
#   ('obtuvo', 'VMI', 'O'),
#   ('la', 'DA', 'O'),
#   ('suma', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('100', 'Z', 'O'),
#   ('millones', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('pesetas', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Según', 'SP', 'O'),
#   ('coinciden', 'VMI', 'O'),
#   ('en', 'SP', 'O'),
#   ('señalar', 'VMN', 'O'),
#   ('el', 'DA', 'O'),
#   ('fiscal', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('diversos', 'DI', 'O'),
#   ('testigos', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('Corbella', 'NC', 'B-PER'),
#   ('disponía', 'VMI', 'O'),
#   ('de', 'SP', 'O'),
#   ('mucho', 'DI', 'O'),
#   ('dinero', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('le', 'PP', 'O'),
#   ('gustaba', 'VMI', 'O'),
#   ('gastarlo', 'VMN', 'O'),
#   ('de', 'SP', 'O'),
#   ('forma', 'NC', 'O'),
#   ('ostentosa', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('además', 'RG', 'O'),
#   ('de', 'SP', 'O'),
#   ('frecuentar', 'VMN', 'O'),
#   ('desde', 'SP', 'O'),
#   ('hacía', 'VMI', 'O'),
#   ('años', 'NC', 'O'),
#   ('clubes', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('alterne', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('prostitución', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   (',', 'Fc', 'O'),
#   ('entre', 'SP', 'O'),
#   ('ellos', 'PP', 'O'),
#   (',', 'Fc', 'O'),
#   ('el', 'DA', 'O'),
#   ('denominado', 'AQ', 'O'),
#   ('"', 'Fe', 'O'),
#   ('La', 'DA', 'B-LOC'),
#   ('vie', 'NC', 'I-LOC'),
#   ('en', 'SP', 'I-LOC'),
#   ('rose', 'VMS', 'I-LOC'),
#   ('"', 'Fe', 'O'),
#   ('de', 'SP', 'O'),
#   ('Barcelona', 'NC', 'B-LOC'),
#   ('.', 'Fp', 'O')],
#  [('En', 'SP', 'O'),
#   ('este', 'DD', 'O'),
#   ('club', 'NC', 'O'),
#   ('conoció', 'VMI', 'O'),
#   ('al', 'SP', 'O'),
#   ('acusado', 'VMP', 'O'),
#   ('E.', 'AQ', 'B-PER'),
#   ('I.', 'AQ', 'I-PER'),
#   ('C.', 'AQ', 'I-PER'),
#   (',', 'Fc', 'O'),
#   ('que', 'PR', 'O'),
#   ('ejercía', 'VMI', 'O'),
#   ('de', 'SP', 'O'),
#   ('Relaciones', 'NC', 'B-MISC'),
#   ('Públicas', 'AQ', 'I-MISC'),
#   ('del', 'SP', 'O'),
#   ('local', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('así', 'RG', 'O'),
#   ('como', 'CS', 'O'),
#   ('a', 'SP', 'O'),
#   ('la', 'DA', 'O'),
#   ('compañera', 'NC', 'O'),
#   ('sentimental', 'AQ', 'O'),
#   ('de', 'SP', 'O'),
#   ('éste', 'PD', 'O'),
#   ('y', 'CC', 'O'),
#   ('ex', 'NC', 'O'),
#   ('prostituta', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('la', 'DA', 'O'),
#   ('acusada', 'AQ', 'O'),
#   ('M.', 'VMI', 'B-PER'),
#   ('W.', 'AQ', 'I-PER'),
#   ('W.', 'NC', 'I-PER'),
#   ('Según', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('fiscal', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('Corbella', 'NC', 'B-PER'),
#   ('y', 'CC', 'O'),
#   ('E.', 'AQ', 'B-PER'),
#   ('I.', 'AQ', 'I-PER'),
#   ('C.', 'AQ', 'I-PER'),
#   ('entablaron', 'VMI', 'O'),
#   ('una', 'DI', 'O'),
#   ('"', 'Fe', 'O'),
#   ('relación', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('conveniencia', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('consistente', 'AQ', 'O'),
#   ('en', 'SP', 'O'),
#   ('que', 'CS', 'O'),
#   ('el', 'DA', 'O'),
#   ('empresario', 'NC', 'O'),
#   ('se', 'P0', 'O'),
#   ('gastaba', 'VMI', 'O'),
#   ('mucho', 'DI', 'O'),
#   ('dinero', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('tanto', 'RG', 'O'),
#   ('en', 'SP', 'O'),
#   ('drogas', 'NC', 'O'),
#   ('como', 'CS', 'O'),
#   ('en', 'SP', 'O'),
#   ('orgías', 'NC', 'O'),
#   ('sexuales', 'AQ', 'O'),
#   (',', 'Fc', 'O'),
#   ('y', 'CC', 'O'),
#   (',', 'Fc', 'O'),
#   ('a', 'SP', 'O'),
#   ('cambio', 'NC', 'O'),
#   (',', 'Fc', 'O'),
#   ('el', 'DA', 'O'),
#   ('acusado', 'NC', 'O'),
#   ('le', 'PP', 'O'),
#   ('proporcionaba', 'VMI', 'O'),
#   ('los', 'DA', 'O'),
#   ('contactos', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   ('amistades', 'NC', 'O'),
#   ('que', 'PR', 'O'),
#   ('solicitaba', 'VMI', 'O'),
#   ('el', 'DA', 'O'),
#   ('empresario', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  [('Hacia', 'SP', 'O'),
#   ('las', 'DA', 'O'),
#   ('22', 'Z', 'O'),
#   ('horas', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('día', 'NC', 'O'),
#   ('26', 'Z', 'O'),
#   ('de', 'SP', 'O'),
#   ('agosto', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('1997', 'Z', 'O'),
#   ('E.', 'NC', 'B-PER'),
#   ('I.', 'AQ', 'I-PER'),
#   ('C.', 'AQ', 'I-PER'),
#   ('y', 'CC', 'O'),
#   ('M.', 'VMI', 'B-PER'),
#   ('W.', 'AQ', 'I-PER'),
#   ('W.', 'NC', 'I-PER'),
#   ('se', 'P0', 'O'),
#   ('citaron', 'VMI', 'O'),
#   ('con', 'SP', 'O'),
#   ('Pedro', 'VMN', 'B-PER'),
#   ('Corbella', 'NC', 'I-PER'),
#   ('con', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('propósito', 'NC', 'O'),
#   ('de', 'SP', 'O'),
#   ('tomar', 'VMN', 'O'),
#   ('unas', 'DI', 'O'),
#   ('copas', 'NC', 'O'),
#   ('y', 'CC', 'O'),
#   (',', 'Fc', 'O'),
#   ('tras', 'SP', 'O'),
#   ('quedar', 'VMN', 'O'),
#   ('en', 'SP', 'O'),
#   ('lascercanías', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('pub', 'NC', 'O'),
#   ('"', 'Fe', 'O'),
#   ('La', 'DA', 'B-LOC'),
#   ('cama', 'NC', 'I-LOC'),
#   ('"', 'Fe', 'O'),
#   ('de', 'SP', 'O'),
#   ('Barcelona', 'NC', 'B-LOC'),
#   (',', 'Fc', 'O'),
#   ('los', 'DA', 'O'),
#   ('tres', 'PN', 'O'),
#   ('decidieron', 'VMI', 'O'),
#   ('desplazarse', 'VMN', 'O'),
#   ('a', 'SP', 'O'),
#   ('Castelldefels', 'NC', 'B-LOC'),
#   ('en', 'SP', 'O'),
#   ('el', 'DA', 'O'),
#   ('coche', 'NC', 'O'),
#   ('del', 'SP', 'O'),
#   ('acusado', 'NC', 'O'),
#   ('.', 'Fp', 'O')],
#  ...]

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.7964686316443963

# %%
# group B and I results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-LOC', 'I-LOC', 'B-MISC', 'I-MISC', 'B-ORG', 'I-ORG', 'B-PER', 'I-PER'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#               precision    recall  f1-score   support
#
#        B-LOC      0.810     0.784     0.797      1084
#        I-LOC      0.690     0.637     0.662       325
#       B-MISC      0.731     0.569     0.640       339
#       I-MISC      0.699     0.589     0.639       557
#        B-ORG      0.807     0.832     0.820      1400
#        I-ORG      0.852     0.786     0.818      1104
#        B-PER      0.850     0.884     0.867       735
#        I-PER      0.893     0.943     0.917       634
#
#    micro avg      0.813     0.787     0.799      6178
#    macro avg      0.791     0.753     0.770      6178
# weighted avg      0.809     0.787     0.796      6178
