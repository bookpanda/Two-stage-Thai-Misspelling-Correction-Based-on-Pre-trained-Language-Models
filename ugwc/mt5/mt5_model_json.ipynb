# %%
# !pip install transformers==4.15.0 sentencepiece
# !pip install datasets==1.17.0 
# !pip install pythainlp
# !pip install jiwer
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers==4.15.0 in /usr/local/lib/python3.7/dist-packages (4.15.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.97)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (0.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (4.12.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (1.21.6)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (0.10.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.15.0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.15.0) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.15.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.15.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.15.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.15.0) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.15.0) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.15.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.15.0) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets==1.17.0 in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (0.70.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (21.3)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (2022.7.1)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (6.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (4.12.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (3.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (1.3.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (0.9.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets==1.17.0) (3.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.17.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.17.0) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.17.0) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.17.0) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.17.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.17.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.17.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.17.0) (2022.6.15)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.17.0) (22.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets==1.17.0) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.17.0) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.17.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.17.0) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pythainlp in /usr/local/lib/python3.7/dist-packages (3.0.8)
# Requirement already satisfied: tinydb>=3.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (4.7.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2022.6.15)
# Requirement already satisfied: typing-extensions<5.0.0,>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from tinydb>=3.0->pythainlp) (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jiwer in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: levenshtein==0.20.2 in /usr/local/lib/python3.7/dist-packages (from jiwer) (0.20.2)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from levenshtein==0.20.2->jiwer) (2.6.1)
# Requirement already satisfied: jarowinkler<2.0.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from rapidfuzz<3.0.0,>=2.3.0->levenshtein==0.20.2->jiwer) (1.2.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.7/dist-packages (1.7.4)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (0.3.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (0.9.3)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.1.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.6)
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.12.1+cu113)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2022.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.17.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.47.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.35.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)

# %%
from transformers import (
    MT5ForConditionalGeneration,
    MT5TokenizerFast,
)
from transformers import AutoModelForMaskedLM, pipeline
from transformers import AutoTokenizer, BertForTokenClassification, AutoModel
import pandas as pd
import torch
import pickle
from tqdm import tqdm
from datasets import load_metric
from pythainlp.benchmarks import word_tokenization
from nltk.translate.gleu_score import sentence_gleu
from jiwer import cer
import os
import numpy as np
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from typing import Optional

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
# tokenizer = AutoTokenizer.from_pretrained('airesearch/wangchanberta-base-att-spm-uncased', model_max_length=512)
tokenizer_tag = pickle.load(open('drive/MyDrive/AIBuilders/json/tokenizer_json_15k.pkl', 'rb'))

# %%
class BertModel(torch.nn.Module):
    def __init__(self):
        super(BertModel, self).__init__()
        self.bert = BertForTokenClassification.from_pretrained('airesearch/wangchanberta-base-att-spm-uncased', num_labels=2)
        self.bert.resize_token_embeddings(len(tokenizer_tag))

    def forward(self, input_id, mask, label):
        output = self.bert(input_ids=input_id, attention_mask=mask, labels=label, return_dict=False)
        return output

# %%
tagging_model = BertModel()
# model = BertForTokenClassification.from_pretrained('airesearch/wangchanberta-base-att-spm-uncased', num_labels=2)
# model.resize_token_embeddings(len(tokenizer_th))

# FILE = "drive/MyDrive/AIBuilders/tagging.pth"
FILE = "drive/MyDrive/AIBuilders/json/tagging_json_400.pth"
tagging_model.load_state_dict(torch.load(FILE, map_location=torch.device('cpu')))
tagging_model.eval()
tagging_model.cuda()
# Out:
# You are using a model of type camembert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at airesearch/wangchanberta-base-att-spm-uncased were not used when initializing BertForTokenClassification: ['roberta.encoder.layer.5.output.dense.bias', 'roberta.encoder.layer.10.output.dense.weight', 'roberta.encoder.layer.6.intermediate.dense.weight', 'roberta.encoder.layer.4.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.weight', 'roberta.encoder.layer.9.attention.self.value.bias', 'roberta.encoder.layer.11.output.dense.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.9.attention.self.query.bias', 'roberta.encoder.layer.9.output.dense.weight', 'roberta.encoder.layer.7.attention.output.dense.bias', 'roberta.encoder.layer.11.output.LayerNorm.weight', 'roberta.encoder.layer.10.attention.output.dense.weight', 'roberta.encoder.layer.4.attention.self.value.bias', 'roberta.encoder.layer.6.attention.self.value.weight', 'roberta.encoder.layer.11.attention.output.dense.bias', 'roberta.encoder.layer.2.attention.self.key.weight', 'roberta.encoder.layer.9.attention.self.key.bias', 'roberta.encoder.layer.4.attention.self.value.weight', 'roberta.encoder.layer.10.attention.self.key.weight', 'roberta.encoder.layer.3.attention.self.query.bias', 'roberta.encoder.layer.7.output.LayerNorm.bias', 'roberta.encoder.layer.0.attention.output.dense.weight', 'roberta.encoder.layer.11.attention.self.value.bias', 'roberta.encoder.layer.5.output.dense.weight', 'roberta.encoder.layer.2.attention.output.dense.bias', 'roberta.encoder.layer.10.intermediate.dense.weight', 'roberta.encoder.layer.11.attention.output.LayerNorm.bias', 'roberta.encoder.layer.5.output.LayerNorm.weight', 'roberta.encoder.layer.0.attention.output.LayerNorm.weight', 'roberta.encoder.layer.8.attention.output.LayerNorm.bias', 'roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.6.attention.output.dense.weight', 'roberta.encoder.layer.5.output.LayerNorm.bias', 'roberta.encoder.layer.10.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.bias', 'roberta.encoder.layer.7.intermediate.dense.weight', 'lm_head.bias', 'roberta.encoder.layer.0.intermediate.dense.bias', 'roberta.encoder.layer.5.intermediate.dense.bias', 'roberta.encoder.layer.2.attention.self.query.bias', 'roberta.encoder.layer.10.attention.self.query.bias', 'roberta.encoder.layer.8.attention.self.key.bias', 'roberta.encoder.layer.4.attention.output.LayerNorm.bias', 'roberta.encoder.layer.4.attention.self.query.weight', 'roberta.encoder.layer.3.attention.output.dense.weight', 'roberta.encoder.layer.7.output.LayerNorm.weight', 'roberta.encoder.layer.3.intermediate.dense.bias', 'roberta.encoder.layer.9.attention.output.dense.bias', 'roberta.encoder.layer.5.attention.self.query.weight', 'roberta.encoder.layer.11.output.LayerNorm.bias', 'roberta.encoder.layer.9.attention.self.key.weight', 'roberta.encoder.layer.0.output.dense.bias', 'roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.8.attention.self.query.weight', 'roberta.encoder.layer.7.attention.self.key.bias', 'roberta.encoder.layer.9.output.LayerNorm.bias', 'roberta.encoder.layer.6.intermediate.dense.bias', 'roberta.encoder.layer.4.intermediate.dense.bias', 'roberta.encoder.layer.5.attention.output.dense.weight', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.encoder.layer.8.intermediate.dense.bias', 'roberta.encoder.layer.6.output.dense.weight', 'roberta.encoder.layer.1.attention.self.key.weight', 'roberta.encoder.layer.8.output.LayerNorm.weight', 'roberta.encoder.layer.8.attention.self.value.bias', 'lm_head.dense.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.query.bias', 'roberta.encoder.layer.1.attention.self.query.bias', 'roberta.encoder.layer.8.intermediate.dense.weight', 'roberta.encoder.layer.11.intermediate.dense.weight', 'roberta.encoder.layer.11.attention.self.key.weight', 'roberta. ...
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at airesearch/wangchanberta-base-att-spm-uncased and are newly initialized: ['encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.6.attention.self.key.bias', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.7.attention.self.value.bias', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.attention.self.key.bias', 'encoder.layer.4.output.dense.bias', 'encoder.layer.6.output.dense.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.8.attention.self.query.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.8.output.LayerNorm.bias', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.3.attention.self.value.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.8.attention.self.value.weight', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.3.output.dense.weight', 'encoder.layer.4.attention.self.value.bias', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.9.attention.output.LayerNorm.bias', 'encoder.layer.7.intermediate.dense.bias', 'embeddings.word_embeddings.weight', 'encoder.layer.10.output.dense.weight', 'encoder.layer.7.attention.output.dense.weight', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.7.attention.output.LayerNorm.weight', 'encoder.layer.8.output.dense.weight', 'encoder.layer.5.attention.self.key.weight', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.7.attention.self.key.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.3.attention.self.query.weight', 'encoder.layer.6.attention.output.LayerNorm.bias', 'encoder.layer.4.attention.self.value.weight', 'encoder.layer.8.intermediate.dense.bias', 'encoder.layer.9.output.dense.bias', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.9.attention.self.value.weight', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.2.output.dense.weight', 'encoder.layer.7.attention.self.value.weight', 'encoder.layer.3.attention.output.dense.bias', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.5.output.dense.bias', 'encoder.layer.9.intermediate.dense.bias', 'encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.6.attention.output.dense.bias', 'encoder.layer.6.attention.self.value.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.5.attention.output.LayerNorm.weight', 'embeddings.LayerNorm.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.4.attention.self.key.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.0.output.dense.weight', 'encoder.layer.4.attention.output.dense.bias', 'encoder.layer.9.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.4.output.dense.weight', 'encoder.layer.9.attention.self.k ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertModel(
#   (bert): BertForTokenClassification(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(25354, 768)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(1, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
ids_to_labels = {0: 'f', 1: 'i'}

def evaluate_one_text(model, sentence, mask):
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    input_id = torch.Tensor([sentence]).type(torch.int64)
    label_ids = []
    for i in sentence:
      if i == 1 or i == 5 or i == 6:
        label_ids.append(-100)
      else:
        label_ids.append(2)
    label_ids = torch.Tensor([label_ids]).type(torch.int64)
    mask = torch.Tensor([mask]).type(torch.int64)

    if use_cuda:
        model = model.cuda()
        input_id = input_id.cuda()
        mask = mask.cuda()
        label_ids = label_ids.cuda()

    logits = tagging_model(input_id, mask, None)
    logits_clean = logits[0][label_ids != -100]

    predictions = logits_clean.argmax(dim=1).tolist()
    prediction_label = [ids_to_labels[i] for i in predictions]
    return prediction_label

# %%
model_name="mt5-qg-epoch-4-train-loss-0.009-val-loss-0.2703"
mt5_model = MT5ForConditionalGeneration.from_pretrained(
    f"drive/MyDrive/mt5-thai-qg-json/{model_name}",
    return_dict=True,
)
tokenizer_mt5 = MT5TokenizerFast.from_pretrained(
    f"drive/MyDrive/mt5-thai-qg-json/{model_name}"
)

mt5_model.cuda()
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=250112, bias=False)
# )

# %%
ds_tag = pickle.load(open('drive/MyDrive/AIBuilders/json/ner_json_15k_2.pkl', 'rb'))
ds_mlm = pickle.load(open('drive/MyDrive/AIBuilders/json/mlm_json_15k_2.pkl', 'rb'))
test_df = pickle.load(open('drive/MyDrive/AIBuilders/json/test_mt5_no_split_json_15k.pkl', 'rb'))

# %%
ds_mlm = ds_mlm[10576:]
ds_tag = ds_tag[10576:]
NUM_SAMPLE = ds_mlm.shape[0]
NUM_SAMPLE
# Out:
# 5000

# %%
for i in range(10):
  a = ds_tag.iloc[i]['text']['input_ids'].squeeze(0).tolist()
  b = tokenizer_tag.convert_ids_to_tokens(a)
  print("".join(b))
# Out:
# <s>▁จําเป็นต้องเปิดบริการกับสาขาที่เปิดบัญชี▁มั๊ยครับ▁หรือสาขาไหนก็ได้</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁เมื่อวานก้ยังเข้าได้</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁ผมอยุ่ต่างประเทศครับ</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁พอไปสมัครที่ตุ้</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁แอฟมีปัญหาหรอค่ะตอนนี้</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁พี่คับผมอยากรุ้ว่า</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁แก้ไขปัญหาเปลี่ยนเบอร์มือถือได้อย่างไรคับ</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁ไม่ค่ะใช้เบอรเดิมค่ะ</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁เข้าไปโหลดตรงใหนครับ</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <s>▁จริงหรือไม่ถ้าอัพเดต▁k▁mobile▁banking▁ในแต่ละครั้งจะต้องเสียค่าธรรมเนียมและต้องเสียเท่าไหร่</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>

# %%
test_df
# Out:
#                                             source_text  \
# 0     แก้คำผิด:  จําเป็นต้องเปิดบริการกับสาขาที่เปิด...
# 1                   แก้คำผิด:  เมื่อวาน<mask>ยังเข้าได้
# 2                     แก้คำผิด:  ผม<mask>ต่างประเทศครับ
# 3                   แก้คำผิด:  พอไปสมัครที่<mask><mask>
# 4            แก้คำผิด:  <mask>มีปัญหา<mask><mask>ตอนนี้
# ...                                                 ...
# 4995  แก้คำผิด:  ไม่ทราบว่าทําการสมัครบริการซื้อสินค...
# 4996              แก้คำผิด:  จะ<mask><mask><mask><mask>
# 4997    แก้คำผิด:  อยาก<mask>ว่าจะเข้าระบบ <mask><mask>
# 4998             แก้คำผิด:  เข้าไม่ได้ <mask><mask>ครับ
# 4999  แก้คำผิด:  ช่วยดูทีครับจ่ายไม่<mask>มาจะสอง<ma...
#
#                                             target_text
# 0     จําเป็นต้องเปิดบริการกับสาขาที่เปิดบัญชี ไหมคร...
# 1                                 เมื่อวาน ก็ยังเข้าได้
# 2                                  ผมอยู่ต่างประเทศครับ
# 3                                       พอไปสมัครที่ตู้
# 4                                แอพมีปัญหาหรือคะตอนนี้
# ...                                                 ...
# 4995  ไม่ทราบว่าทําการสมัครบริการซื้อสินค้าทาง อินเท...
# 4996                                จะสมัคร อย่างไรครับ
# 4997                    อยาก รู้ว่าจะเข้าระบบ อย่างไรคะ
# 4998                          เข้าไม่ได้ เป็นอะ ไร ครับ
# 4999  ช่วยดูทีครับจ่ายไม่ได้มาจะสองอาทิตย์ แล้วรองหล...
#
# [5000 rows x 2 columns]

# %%
msp_type = pickle.load(open('drive/MyDrive/AIBuilders/json/msp_type.pkl', 'rb'))
msp_type = msp_type[10576:]
msp_word = pickle.load(open('drive/MyDrive/AIBuilders/json/msp_word.pkl', 'rb'))
msp_word = msp_word[10576:]
print(len(msp_type), len(msp_word))
# Out:
# 5000 5000

# %%
msp_word
# Out:
# [[[('มั๊ย', 'ไหม')]],
#  [[('ก้', 'ก็')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('ตุ้', 'ตู้')]],
#  [[('แอฟ', 'แอพ')], [('หรอ', 'หรือ'), ('ค่ะ', 'คะ')]],
#  [[('คับ', 'ครับ')], [('รุ้', 'รู้')]],
#  [[('คับ', 'ครับ')]],
#  [[('เบอร', 'เบอร์')]],
#  [[('ใหน', 'ไหน')]],
#  [[('อัพเดต', 'อัปเดต')]],
#  [[('เช้ค', 'เช็ค')]],
#  [[('เบอ', 'เบอร์')], [('คับ', 'ครับ')]],
#  [[('แอฟ', 'แอป')], [('อยาก', 'ยาก')]],
#  [[('แอพ', 'แอป')]],
#  [[('เชค', 'เช็ค')], [('ยังไง', 'อย่างไร')]],
#  [[('จ้า', 'จ้ะ')]],
#  [[('บัชชี', 'บัญชี')]],
#  [[('ยังใง', 'อย่างไร')]],
#  [[('คร้าบบ?', 'ครับ')]],
#  [[('ตัง', 'สตางค์')], [('เปน', 'เป็น')], [('ค่ะ', 'คะ')]],
#  [[('ยังงัย', 'ยังไง')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('อ่อ', 'อ๋อ'), ('คะ', 'ค่ะ')], [('คะ', 'ค่ะ')]],
#  [[('คร้า', 'ค่ะ')]],
#  [[('ใหม', 'ไหม')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ป่าว', 'เปล่า'), ('คัฟ', 'ครับ')]],
#  [[('อินเตอร์เน็ต', 'อินเทอร์เน็ต')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ก้', 'ก็')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่อ', 'อ๋อ')], [('มั้ย', 'ไหม')]],
#  [[('แอพ', 'แอป'), ('ไหม่', 'ใหม่'), ('หรอ', 'เหรอ'), ('คับ', 'ครับ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('แอพ', 'แอป')]],
#  [[('สมัค', 'สมัคร')], [('ยุ', 'อยู่')], [('สมัค', 'สมัคร')], [('ค่ะ', 'คะ')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('ยังไง', 'อย่างไร')], [('แอพ', 'แอป')]],
#  [[('สมัค', 'สมัคร')], [('คะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ไง', 'อย่างไร')]],
#  [[('อ่ะ', 'อะ'), ('ค่ะ', 'คะ')]],
#  [[('อะ', 'อะไร')], [('หรอ', 'เหรอ'), ('ค่ะ', 'คะ')]],
#  [[('ใด้', 'ได้')], [('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('แร้ว', 'แล้ว')], [('เรย', 'เลย'), ('คับ', 'ครับ')]],
#  [[('โทรศัพ', 'โทรศัพท์')], [('มั๊ย', 'ไหม')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('แอพ', 'แอป')]],
#  [[('คครับ', 'ครับ')]],
#  [[('แอพ', 'แอป')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ก้', 'ก็')], [('นี่', 'นี้')]],
#  [[('ตอ้ง', 'ต้อง')]],
#  [[('ตุ้', 'ตู้')], [('ก้อ', 'ก็')]],
#  [[('คับ', 'ครับ')],
#   [('รอง', 'ลอง'), ('สมัค', 'สมัคร')],
#   [('คับ', 'ครับ')],
#   [('แร้ว', 'แล้ว')],
#   [('ปะ', 'เปล่า'), ('คับ', 'ครับ')]],
#  [[('สัส', 'สัตว์')]],
#  [[('งัย', 'ไง'), ('ค่ะ', 'คะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('ที่อยุ่', 'ที่อยู่')], [('น่ะ', 'นะ'), ('ค่ะ', 'คะ')]],
#  [[('คับ', 'ครับ')]],
#  [[('เบอร์', 'หมายเลข')]],
#  [[('เบอร์', 'หมายเลข')]],
#  [[]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('โทสับ', 'โทรศัพท์')], [('แอฟ', 'แอป')], [('ออนไล', 'ออนไลน์')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('เค้า', 'เขา')]],
#  [[('ใหม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('มั๊ย', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ยังงัย', 'ยังไง'), ('ค่ะ', 'คะ')]],
#  [[('แอพ', 'แอป')], [('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('อ่อ', 'อ๋อ')], [('คับ', 'ครับ')]],
#  [[('ไม๊', 'ไหม')]],
#  [[('อะรัย', 'อะไร')], [('ค่ะ', 'คะ')]],
#  [[('สเตดเม้น', 'สเตทเม้นท์')]],
#  [[('ค่ะ', 'คะ')], [('ตัง', 'สตางค์'), ('อยุ่', 'อยู่')], [('ค่ะ', 'คะ')]],
#  [[('เปน', 'เป็น')],
#   [('เน็ต', 'อินเทอร์เน็ต')],
#   [('หรอ', 'หรือ'), ('ค่ะ', 'คะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('ตอ้ง', 'ต้อง')], [('อ่ะ', 'อะ')]],
#  [[('ค้ะ', 'ค่ะ')], [('บันชี', 'บัญชี')]],
#  [[('คับ', 'ครับ')]],
#  [[('โทรสับ', 'โทรศัพท์')], [('ไหม่', 'ใหม่')], [('คับ', 'ครับ')]],
#  [[('แอฟ', 'แอป')]],
#  [[('แอพ', 'แอป')]],
#  [[('เบอ', 'เบอร์')], [('คับ', 'ครับ')]],
#  [[('จิง', 'จริง')]],
#  [[('คับ', 'ครับ')]],
#  [[('แอพ', 'แอป')], [('รึป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('ยังงัย', 'ยังไง'), ('ค่ะ', 'คะ')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('เปน', 'เป็น')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใด้', 'ได้')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('คร้า', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ')], [('เน็ต', 'อินเทอร์เน็ต')]],
#  [[('แอพ', 'แอป')], [('ก้', 'ก็')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ยังงัย', 'ยังไง'), ('คับ', 'ครับ')]],
#  [[('ได่', 'ได้')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ต', 'ต'), (' ', '.')]],
#  [[('ก้', 'ก็')]],
#  [[('ก้อ', 'ก็')], [('เบอ', 'เบอร์')], [('แร้ว', 'แล้ว')]],
#  [[('ไม', 'ไหม')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ใด้', 'ได้')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('อ่ะ', 'อะ')], [('ค่าาา', 'ค่ะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('น่อย', 'หน่อย'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เรย', 'เลย'), ('อ่ะ', 'อะ')]],
#  [[('ไม', 'ไหม')]],
#  [[('โทรศัพ', 'โทรศัพท์')], [('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')], [('คะ', 'ค่ะ')]],
#  [[('ก้อ', 'ก็')], [('เรย', 'เลย'), ('คะ', 'ค่ะ')]],
#  [[('ม่', 'ไม่')], [], [('คับ', 'ครับ')]],
#  [[('ตัง', 'สตางค์')], [('กุ้', 'กู้')], [('มั้ย', 'ไหม')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('ใช้', 'ใช่'), ('ป่าว', 'เปล่า')]],
#  [[('แอป', 'แอพ')], [('อ้ะ', 'อะ')]],
#  [[('ว่ะ', 'วะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใด้', 'ได้'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('สมัค', 'สมัคร'), ('ใหม', 'ไหม')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ใหน', 'ไหน')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ได่', 'ได้')]],
#  [[('ใหน', 'ไหน'), ('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('คับ', 'ครับ')]],
#  [[('คับ', 'ครับ')], [('ไม', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('มั้ย', 'ไหม')], [('เปน', 'เป็น')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ป่ะ', 'เปล่า')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('นู๋', 'หนู')], [('ยังใง', 'ยังไง')], [('ค่ะ', 'คะ')]],
#  [[('แอฟ', 'แอป')], [('แต', 'แต่')], [('ม่', 'ไม่')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เบอยุแล้ว', 'เบอร์อยู่แล้ว')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ขอบคุน', 'ขอบคุณ')], [('ค้ะ', 'คะ')]],
#  [[('บช', 'บัญชี')]],
#  [[('เตอ', 'เจอ')]],
#  [[('ล๊อก', 'ล็อก')]],
#  [[('เรย', 'เลย'), ('ค้ะ', 'ค่ะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('บันชี', 'บัญชี')], [('อ้ะ', 'อะ'), ('ค้ะ', 'ค่ะ')]],
#  [[('หรัส', 'รหัส')]],
#  [[('ป่าว', 'เปล่า')]],
#  [[('เคาเตอร์', 'เคาน์เตอร์')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('บช', 'บัญชี')], [('สามรถ', 'สามารถ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('เค้า', 'เขา')], [('อ่ะ', 'อะ')]],
#  [[('คพ', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('เปน', 'เป็น')], [('เนต', 'อินเทอร์เน็ต')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('ใด้', 'ได้')]],
#  [[('ใม่', 'ไม่')]],
#  [[('ก้', 'ก็')]],
#  [[('ไง', 'อย่างไร'), ('ค่ะ', 'คะ')]],
#  [[]],
#  [[('เนต', 'อินเทอร์เน็ต')]],
#  [[('พิม', 'พิมพ์')], [('มั้ย', 'ไหม')]],
#  [[('สวัดดี', 'สวัสดี')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('เบอ', 'เบอร์')], [('คะ', 'ค่ะ')]],
#  [[('เชค', 'เช็ค')], [('รึป่าว', 'หรือเปล่า')]],
#  [[('รุ้', 'รู้')], [('ยุ่', 'อยู่')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('เนาะ', 'นะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('เด๋ว', 'เดี๋ยว')]],
#  [[('ก้', 'ก็')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่อ', 'อ๋อ')], [('คับ', 'ครับ')], [('คับ', 'ครับ')]],
#  [[('ก', 'ก'), (' ', '.')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('แอพ', 'แอป')]],
#  [[('ค่', 'คะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('รีไฟแนน', 'รีไฟแนนซ์')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('เบอ', 'เบอร์')], [('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ยังงัย', 'ยังไง')]],
#  [[('แอพ', 'แอป')]],
#  [[('อ่อ', 'อ๋อ')], [('ป่าว', 'เปล่า')]],
#  [[('ค่าาา', 'ค่ะ')]],
#  [[('มั้ย', 'ไหม'), ('คร้าบ', 'ครับ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('อ่อ', 'อ้อ'), ('คับ', 'ครับ')]],
#  [[('ไม', 'ไม่')], [('พิม', 'พิมพ์')]],
#  [[('โทรศัพ', 'โทรศัพท์')], [('หรอ', 'หรือ')]],
#  [[('ยังไง', 'อย่างไร')], [('คับ', 'ครับ')]],
#  [[('สมัค', 'สมัคร'), ('ใว้', 'ไว้')], [('คับ', 'ครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('โทรศัพย์', 'โทรศัพท์')]],
#  [[('อ่อ', 'อ๋อ')], [('คะ', 'ค่ะ')]],
#  [[('เคดิต', 'เครดิต')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อะ', 'อ่ะ')]],
#  [[('วีธี', 'วิธี')], [('ยังไง', 'อย่างไร')]],
#  [[('เด๋ว', 'เดี๋ยว')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ม่', 'ไม่')], [('ค่า', 'ค่ะ')]],
#  [[('ขอบคุน', 'ขอบคุณ')], [('คับ', 'ครับ')], [('ข้อมุล', 'ข้อมูล')]],
#  [[]],
#  [[('อ่ะ', 'อะ')]],
#  [[('บช', 'บัญชี')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('นู๋', 'หนู')]],
#  [[('ตังค์', 'สตางค์')], [('อ่ะ', 'อะ')]],
#  [[('คับ', 'ครับ')]],
#  [[('ม่', 'ไม่'), ('ด้', 'ได้'), ('คะ', 'ค่ะ')]],
#  [[]],
#  [[('ค่าาา', 'ค่ะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('แอพ', 'แอป')]],
#  [[('แอพ', 'แอป')]],
#  [[('เปลียน', 'เปลี่ยน')], [('โทสับ', 'โทรศัพท์')], [('คัฟ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('เคดิต', 'เครดิต')], [('อ่ะ', 'อะ')]],
#  [[('ไห้', 'ให้')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('เบอร', 'เบอร์')], [('ค่ะ', 'คะ')]],
#  [[('ขอโทด', 'ขอโทษ')]],
#  [[('ยุ่', 'อยู่')], [('ค่ะ', 'คะ')]],
#  [[('ใข่', 'ใช่')]],
#  [[('คับ', 'ครับ')]],
#  [[('ตัง', 'สตางค์')], [('อ่ะ', 'อะ')], [('ไทยพานิชย์', 'ไทยพาณิชย์')]],
#  [[('เปน', 'เป็น')]],
#  [[('ก้อ', 'ก็')]],
#  [[('เบอ', 'เบอร์')], [('ละ', 'ล่ะ')]],
#  [[('เนี้ย', 'เนี่ย')]],
#  [[('โทรสัพ', 'โทรศัพท์')]],
#  [[('ค่าาา', 'ค่ะ')]],
#  [[('ค่าาาาาาา', 'ค่ะ')]],
#  [[('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ')]],
#  [[('คะ', 'ค่ะ')], [('ลิ้ง', 'ลิงค์')]],
#  [[('ไง', 'อย่างไร')]],
#  [[('มั้ย', 'ไหม'), ('คพ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ตัง', 'สตางค์')]],
#  [[('เปน', 'เป็น')], [('มั้ย', 'ไหม')]],
#  [[('น่อย', 'หน่อย')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('บช', 'บัญชี')]],
#  [[('แอพ', 'แอป')], [('ไร', 'อะไร')]],
#  [[('ครัช', 'ครับ')]],
#  [[('ลิ้ง', 'ลิงค์')]],
#  [[('หรอ', 'หรือ'), ('ค้ะ', 'คะ')]],
#  [[('นี่', 'นี้')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ไห้', 'ให้')], [('คับ', 'ครับ')]],
#  [[('มั๊ย', 'ไหม')], [('เปิดบันชี', 'เปิดบัญชี')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ค่ะ', 'คะ'), ('ขอโทด', 'ขอโทษ')]],
#  [[('คร้าาา', 'ค่ะ')]],
#  [[('ไม', 'ไหม')]],
#  [[('เนต', 'อินเทอร์เน็ต')]],
#  [[('นู๋', 'หนู')]],
#  [[('เด๋วนี้', 'เดี๋ยวนี้')]],
#  [[('ค่ะ', 'คะ')], [('เบอ', 'เบอร์')]],
#  [[('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ครัช', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('เห้อ', 'เฮ้อ')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('แอพ', 'แอป')]],
#  [[('คับ', 'ครับ')], [('ไร', 'อะไร'), ('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ก้', 'ก็')]],
#  [[('ไหม่', 'ไหม')]],
#  [[('เปนไร', 'เป็นไร'), ('คับ', 'ครับ')],
#   [('แร้ว', 'แล้ว'), ('ก้อ', 'ก็')],
#   [('คับ', 'ครับ')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('ยังไง', 'อย่างไร'), ('คัฟ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เบอ', 'เบอร์')], [('คะ', 'ค่ะ')]],
#  [[('แอฟ', 'แอพ')], [('อยุ่', 'อยู่')]],
#  [[('ใด้', 'ได้')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('ใด้', 'ได้')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ให', 'ให้')]],
#  [[('คับ', 'ครับ')]],
#  [[('เบย', 'เลย'), ('คะ', 'ค่ะ')]],
#  [[('เน้ต', 'อินเทอร์เน็ต')]],
#  [[], [('พนง', 'พนักงาน')]],
#  [[]],
#  [[('แอพ', 'แอป')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('ม่', 'ไม่')],
#   [('ค้ะ', 'ค่ะ')],
#   [('เท่าไหร่', 'เท่าไร'), ('อ่ะ', 'อะ'), ('ค้ะ', 'ค่ะ')]],
#  [[('น่อย', 'หน่อย')]],
#  [[('เปน', 'เป็น')]],
#  [[('ไหม่', 'ใหม่'), ('อ่ะ', 'อะ')]],
#  [[('ที', 'ที่')]],
#  [[('โทรศัพ', 'โทรศัพท์')], [('คับ', 'ครับ')]],
#  [[('ม่', 'ไม่')]],
#  [[('ม่', 'ไม่')]],
#  [[('พนง', 'พนักงาน')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('เปน', 'เป็น')], [('คะ', 'ค่ะ')]],
#  [[('เปลียน', 'เปลี่ยน')], [('คับ', 'ครับ')]],
#  [[('ก้', 'ก็')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('มั้ย', 'ไหม')], [('แอพ', 'แอป')]],
#  [[('ยังงัย', 'อย่างไร')]],
#  [[('ขอโทด', 'ขอโทษ'), ('คร้าบ', 'ครับ')]],
#  [[('ร้องได้อ้ะ', 'ร้องได้อะ')]],
#  [[('เช็ค', 'เช็ก')], [('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ค๊ะ', 'คะ')]],
#  [[('ยุ', 'อยู่'), ('คับ', 'ครับ')]],
#  [[('ไร', 'อะไร'), ('ต่ะ', 'คะ')]],
#  [[('คระบ', 'ครับ')]],
#  [[('ไช่', 'ใช่')]],
#  [[('โทรศัพ', 'โทรศัพท์')], [('แอฟ', 'แอพ')]],
#  [[('ใข่', 'ใช่')]],
#  [[('อิก', 'อีก')]],
#  [[('สมัค', 'สมัคร')], [('คุน', 'คุณ'), ('ใด้', 'ได้'), ('ใหม', 'ไหม')]],
#  [[('เปน', 'เป็น')]],
#  [[('คนับ', 'ครับ')]],
#  [[('มี', 'มี'), (' ', '.'), ('ค', 'ค'), (' ', '.')]],
#  [[('ไม', 'ไหม')]],
#  [[('เวป', 'เว็บไซต์')], [('ดิ', 'สิ')]],
#  [[('อินเตอร์เน็ต', 'อินเทอร์เน็ต')]],
#  [[('โทรศัพย์', 'โทรศัพท์')], [('ยังไง', 'อย่างไร')]],
#  [[('k', 'k plus')], [('plusอ่ะคับ', 'อะครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('มะ', 'ไม่')]],
#  [[('ดิ', 'สิ')]],
#  [[('แอฟ', 'แอป')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('ไง', 'อย่างไร')], [('ค้ะ', 'คะ')]],
#  [[('เนี่ยยย', 'เนี่ย')]],
#  [[('กับ', 'กัน'), ('เรย', 'เลย')], [('มั้ย', 'ไหม'), ('ค้ะ', 'คะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('ม่', 'ไม่')]],
#  [[('อ่ะ', 'อะ')], [('โทรศัพ', 'โทรศัพท์')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('สมัค', 'สมัคร')], [('ค่ะ', 'คะ')]],
#  [[('มั๊ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('รึป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('แอฟ', 'แอพ')]],
#  [[('ใหม', 'ไหม')]],
#  [[('แอพ', 'แอป')]],
#  [[('ลิ้งค์', 'ลิงค์')], [('โทรศัพย์', 'โทรศัพท์')]],
#  [[('ได่', 'ได้')]],
#  [[('แอฟ', 'แอป')]],
#  [[('ใหม', 'ไหม')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('บันชี', 'บัญชี')]],
#  [[('ตัง', 'สตางค์'), ('หน่ะ', 'น่ะ')], [('มั้ย', 'ไหม')], [('ฮาาา', 'ฮา')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('คุน', 'คุณ')], [('เบอ', 'เบอร์')]],
#  [[('อินเตอร์เน็ต', 'อินเทอร์เน็ต')]],
#  [[('ตัง', 'สตางค์')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('ก้', 'ก็')]],
#  [[('สมัค', 'สมัคร')],
#   [('สมัค', 'สมัคร'), ('ยังไง', 'อย่างไร'), ('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('จร้า', 'จ้ะ')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('โดนจัย', 'โดนใจ')]],
#  [[('คับ', 'ครับ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('พิม', 'พิมพ์')]],
#  [[('ยังงัย', 'ยังไง'), ('ค่ะ', 'คะ')]],
#  [[('ก้', 'ก็')], [('พนง', 'พนักงาน')], [('โท', 'โทร')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('คีับ', 'ครับ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('กุ้', 'กู้')], [('ค่ะ', 'คะ')]],
#  [[('สมัค', 'สมัคร')], [('คอม', 'คอมพิวเตอร์')]],
#  [[('สมัค', 'สมัคร')], [('คับ', 'ครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ก้', 'ก็')], [('เปน', 'เป็น')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ไม', 'ไหม')]],
#  [[('ยังไง', 'อย่างไร'), ('อ่ะ', 'อะ')], [('อ่ะ', 'อะ')]],
#  [[('เรย', 'เลย'), ('น้ะ', 'นะ')]],
#  [[('สมัค', 'สมัคร')],
#   [('ใช่', 'ใช้')],
#   [('สมัค', 'สมัคร')],
#   [('คับ', 'ครับ')]],
#  [[('โทรศัพย์', 'โทรศัพท์')]],
#  [[('เคดิต', 'เครดิต')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('ม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('แอฟ', 'แอพ')], [('ค่ะ', 'คะ')]],
#  [[('ใด้', 'ได้'), ('คับ', 'ครับ')]],
#  [[('เรย', 'เลย')]],
#  [[('ใด้', 'ได้')]],
#  [[('เบอร', 'เบอร์')], [('ค่ะ', 'คะ')]],
#  [[('อ่อ', 'อ้อ'), ('ค่า', 'ค่ะ')]],
#  [[('เปี่ยน', 'เปลี่ยน'), ('เบอ', 'เบอร์')]],
#  [[('มี', 'มี'), (' ', '.'), ('ค', 'ค'), (' ', '.')]],
#  [[('บช', 'บัญชี')], [('ตัง', 'สตางค์')]],
#  [[('สมัค', 'สมัคร')], [('แอพ', 'application')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('บช', 'บัญชี')]],
#  [[('ใหม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('อะรัย', 'อะไร')]],
#  [[('เนต', 'อินเทอร์เน็ต')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('แอพ', 'แอป')], [('อ่ะ', 'อะ')]],
#  [[('แบงค์', 'แบงก์')], [('อ่ะ', 'อะ')]],
#  [[('เบอ', 'เบอร์')], [('ค่ะ', 'คะ')]],
#  [[('ไม่', 'ไหม'), ('ค่ะ', 'คะ')],
#   [('เบอ', 'เบอร์')],
#   [('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('รุ้', 'รู้')], [('ค่ะ', 'คะ')]],
#  [[('บันชี', 'บัญชี')], [('สมัค', 'สมัคร')]],
#  [[('คระบ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('รุ้', 'รู้')], [('ทา', 'มา')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('ก้', 'ก็')]],
#  [[('เคดิต', 'เครดิต')], [('ใช่', 'ใช้')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('เปน', 'เป็น')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('สาธุ จร้า', 'สาธุ จ้า')]],
#  [[('ไง', 'อย่างไร')], [('คับ', 'ครับ')], [('เบอร', 'เบอร์')]],
#  [[('เรย', 'เลย'), ('หรอ', 'เหรอ')]],
#  [[('รึยัง', 'หรือยัง')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('ไม', 'ไหม')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('พึ่ง', 'เพิ่ง')], [('มั๊ย', 'ไหม')]],
#  [[('ค่า', 'ค่ะ')], [('เด๋ว', 'เดี๋ยว')]],
#  [[('ไหม่', 'ใหม่')]],
#  [[('ตุ้', 'ตู้')]],
#  [[('รึป่าว', 'หรือเปล่า')]],
#  [[('ใด้', 'ได้')], [('กะตัง', 'สตางค์')]],
#  [[('เบอ', 'เบอร์')], [('ตุ้', 'ตู้')], [('หรอ', 'หรือ')]],
#  [[('โท', 'โทร')], [('อ่ะ', 'อะ')]],
#  [[('คระบ', 'ครับ')]],
#  [[('เปลียน', 'เปลี่ยน')], [('ใด้', 'ได้'), ('มัย', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('ยังไง', 'อย่างไร'), ('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('ยัตร', 'บัตร')]],
#  [[('แอฟ', 'แอพ')], [('ก้', 'ก็')]],
#  [[('เรย', 'เลย')]],
#  [[('แอพ', 'แอป')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('แอพ', 'แอป')], [('หรือป่าว', 'หรือเปล่า')]],
#  [[('แร้ว', 'แล้ว')], [('เรย', 'เลย')]],
#  [[('ก้', 'ก็')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใช่', 'ใช้'), ('เบอร', 'เบอร์')], [('หรอ', 'เหรอ'), ('ค่ะ', 'คะ')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ไม', 'ไม่')]],
#  [[('บช.', 'บัญชี')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('จร้า', 'จ้ะ')]],
#  [[('เบอ', 'เบอร์')], [('เบอ', 'เบอร์'), ('นึง', 'หนึ่ง')]],
#  [[('ใข่', 'ใช่'), ('ค้ะ', 'ค่ะ')]],
#  [[('เช้ค', 'เช็ค')]],
#  [[('ประมาน', 'ประมาณ')], [('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('พร้อมเพย์', 'พร้อมเพย์์')],
#   [('มั้ย', 'ไหม'), ('ค่ะ', 'คะ')],
#   [('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('คอลเซนเตอร์', 'คอลเซ็นเตอร์')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('พึ่ง', 'เพิ่ง')], [('โหลด', 'ดาวน์โหลด'), ('แอฟ', 'แอป')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('โทรสัพ', 'โทรศัพท์')], [('ตุ้', 'ตู้')], [('ค้ะ', 'ค่ะ')]],
#  [[('ไหม่', 'ใหม่')], [('หรอ', 'หรือ'), ('ค่ะ', 'คะ')]],
#  [[('ขอโทด', 'ขอโทษ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('บันชี', 'บัญชี')], [('สมัค', 'สมัคร')]],
#  [[('เบย', 'เลย')]],
#  [[('ค่าาา', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เบอ', 'เบอร์')], [('ใช่', 'ใช้')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('ใหม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เท่าไหร่', 'เท่าไร')]],
#  [[('ค้ะ', 'ค่ะ')], [('โทสับ', 'โทรศัพท์')], [('ไง', 'อย่างไร')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('เบอร', 'เบอร์')], [('ก้อ', 'ก็')], [('คัฟ', 'ครับ')]],
#  [[('คร้าบ', 'ครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('ไหม่', 'ใหม่'), ('เท่าไหร่', 'เท่าไร')]],
#  [[('แอฟ', 'แอป')]],
#  [[('แลัว', 'แล้ว')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('เห้น', 'เห็น')], [('ค่ะ', 'คะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('แอพ', 'แอป')], [('สมัค', 'สมัคร')]],
#  [[('บัชชี', 'บัญชี')]],
#  [[('ไม๊', 'ไหม')]],
#  [[('แอพ', 'แอป')], [('คับ', 'ครับ')]],
#  [[('ยุ่', 'อยู่')]],
#  [[('ธ', 'ธ'), (' ', '.')], [('ซัก', 'สัก')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('วัน', 'วัน'), ('พีช', 'พีซ')], [('แอพ', 'แอป')], [('มั้ย', 'ไหม')]],
#  [[('อ่ะ', 'อะ'), ('ค้ะ', 'ค่ะ')]],
#  [[('แอฟ', 'แอพ')]],
#  [[('หรือป่าว', 'หรือเปล่า')]],
#  [[('บันชี', 'บัญชี')], [('ก้', 'ก็')]],
#  [[('เบอ', 'เบอร์')], [('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('เปน', 'เป็น')], [('บันชี', 'บัญชี')], [('คะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('อยุ่', 'อยู่'), ('คับ', 'ครับ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ก้', 'ก็')], [('มั้ย', 'ไหม'), ('ค้ะ', 'คะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('ใม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('ฟัดดดด', 'ฟัด')]],
#  [[('ตัง', 'สตางค์')]],
#  [[('อะรัย', 'อะไร'), ('ค่ะ', 'คะ')]],
#  [[('ไม', 'ไหม')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ขอโทด', 'ขอโทษ')], [('ค่ะ', 'คะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('พนง', 'พนักงาน')], [('รุ้', 'รู้')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('อ่อ', 'อ๋อ')], [('คะ', 'ค่ะ')]],
#  [[('ดาวโหลด', 'ดาวน์โหลด')], [('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('โทร', 'โทรศัพท์')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('เค้า', 'เขา')]],
#  [[('เปลียน', 'เปลี่ยน')], [('คะ', 'ค่ะ')]],
#  [[('ป่ะ', 'เปล่า'), ('คับ', 'ครับ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('มั๊ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('เปน', 'เป็น')]],
#  [[('แอพ', 'แอป')], [('โหลด', 'ดาวน์โหลด')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('ก้', 'ก็')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('ใหม', 'ไหม')]],
#  [[('แอพ', 'แอป')], [('โหลด', 'ดาวน์โหลด')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใหน', 'ไหน'), ('ใด้', 'ได้')]],
#  [[('หรัส', 'รหัส'), ('คะ', 'ค่ะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('ขอโทด', 'ขอโทษ'), ('น้ะ', 'นะ'), ('ค้ะ', 'คะ')]],
#  [[('ใหม', 'ไหม')]],
#  [[('ล๊อก', 'ล็อก')]],
#  [[('อ่ะ', 'อะ')], [('โทรศัพ', 'โทรศัพท์')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('กุ', 'กู')], [('รุ้', 'รู้')]],
#  [[('บัญขี', 'บัญชี')], [('หมดดด', 'หมด')]],
#  [[('คับ', 'ครับ')]],
#  [[('แอพ', 'แอป')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ไหม่', 'ไหม')]],
#  [[('บช', 'บัญชี')], [('มั้ย', 'ไหม')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('ใด้', 'ได้')]],
#  [[('ตุ้', 'ตู้'), ('เเร้ว', 'แล้ว'), ('ต่ะ', 'ค่ะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('นิดนึง', 'นิดหนึ่ง')], [('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('เบอร', 'เบอร์'), ('คับ', 'ครับ')]],
#  [[('ขอบคุน', 'ขอบคุณ'), ('คร่', 'ค่ะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('แอฟ', 'แอป')]],
#  [[('งัย', 'ไง')], [('คับ', 'ครับ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('สามรถ', 'สามารถ')]],
#  [[('บันชี', 'บัญชี')], [('รุ้', 'รู้')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('ขอบคุน', 'ขอบคุณ')]],
#  [[('คึดถึง', 'คิดถึง')], [('เป่น', 'เป็น')]],
#  [[('เรย', 'เลย')], [('คับ', 'ครับ')]],
#  [[('ตัง', 'สตางค์')], [('ตัง', 'สตางค์')], [('ใหม', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('ไห้', 'ให้')], [('คร้า', 'คะ')]],
#  [[('หรือป่าว', 'หรือเปล่า'), ('ค้ะ', 'คะ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('แร้ว', 'แล้ว')], [('เรย', 'เลย')]],
#  [[('เรย', 'เลย')], [('คับ', 'ครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('แอฟ', 'แอป')], [('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('เคดิต', 'เครดิต'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ไทยพานิชย์', 'ไทยพาณิชย์')]],
#  [[('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('ป่ะ', 'ปะ')]],
#  [[('มั้ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('เปลียน', 'เปลี่ยน')], [('แอฟ', 'แอป')]],
#  [[('เบอร', 'เบอร์')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[]],
#  [[('แลัว', 'แล้ว')], [('ค่ะ', 'คะ')]],
#  [[('หรอ', 'หรือ')]],
#  [[('อะรัย', 'อะไร')], [('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('แอพ', 'แอป')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('เรย', 'เลย')], [('มั้ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('อ่ะ', 'อะ'), ('ค้ะ', 'ค่ะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('เค้าาาาาาาาาา', 'เขา')], [('หราาาาา', 'หรือ')]],
#  [[('ทำ', 'ทำ'), ('งัย', 'ไง')], [('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('เปลียน', 'เปลี่ยน'), ('เบอ', 'เบอร์')], [('มั้ย', 'ไหม')]],
#  [[('ป่ะ', 'ปะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('ดิ', 'สิ')]],
#  [[('น้ะ', 'นะ'), ('ค้ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ไม๊', 'ไหม')]],
#  [[('เห้น', 'เห็น')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('ยังงัย', 'อย่างไร'), ('ค่ะ', 'คะ')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('คอลเซนเตอร์', 'คอลเซ็นเตอร์')]],
#  [[('แอพ', 'แอป')], [('มัย', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('ด้าย', 'ได้'), ('ค่', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('เปิดบันชี', 'เปิดบัญชี')], [('คับ', 'ครับ')]],
#  [[('อ่อ', 'อ๋อ')], [('ขอบคุน', 'ขอบคุณ')]],
#  [[('ใว้', 'ไว้')], [('อยุ่', 'อยู่'), ('ไหม่', 'ไหม')]],
#  [[('โทรสัพ', 'โทรศัพท์')]],
#  [[('จร้า', 'จ้ะ')], [('สมัค', 'สมัคร'), ('ค้ะ', 'ค่ะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('พิม', 'พิมพ์')]],
#  [[], [('รึยัง', 'หรือยัง')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใหม', 'ไหม')]],
#  [[('มี', 'มี'), (' ', '.'), ('ค', 'ค'), (' ', '.')]],
#  [[('โห', 'โอ้โฮ')]],
#  [[('แอฟ', 'แอป')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('แอพ', 'แอป')]],
#  [[('ประมาน', 'ประมาณ')], [('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('คับ', 'ครับ')]],
#  [[('แบงกิ้ง', 'แบงก์กิ้ง')]],
#  [[('ใม่', 'ไม่')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('ข้อมู', 'ข้อมูล')]],
#  [[('ยาก', 'อยาก')], [('เคดิต', 'เครดิต')]],
#  [[('ยังคงอยุ่', 'ยังคงอยู่')]],
#  [[('มั้ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ตัง', 'สตางค์')], [('ดิ', 'สิ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('คร้า', 'ค่ะ')]],
#  [[('บช', 'บัญชี')]],
#  [[('คับ', 'ครับ')]],
#  [[('อยุ่', 'อยู่')],
#   [('ยังไง', 'อย่างไร'), ('ค่ะ', 'คะ')],
#   [('บันชี', 'บัญชี')]],
#  [[('แร้ว', 'แล้ว')], [('แอฟ', 'แอพ')], [('มัย', 'ไหม'), ('คับ', 'ครับ')]],
#  [[('มั่ง', 'บ้าง')]],
#  [[('คร้าบ', 'ครับ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์'), ('ไหม่', 'ใหม่'), ('ใหม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('ก้อ', 'ก็')]],
#  [[('ด้าย', 'ได้')]],
#  [[('สมัค', 'สมัคร')], [('คับ', 'ครับ')]],
#  [[('ก', 'ก'), (' ', '.')]],
#  [[('ปะ', 'เปล่า'), ('คับ', 'ครับ')]],
#  [[('เนี้ย', 'นี่')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('แอพ', 'แอป')]],
#  [[('เชค', 'เช็ค')], [('ใหม', 'ไหม')]],
#  [[('แลัว', 'แล้ว')], []],
#  [[('แอพ', 'แอป'), ('เป็นไร', 'เป็น')], [('บช', 'บัญชี')]],
#  [[('ธ', 'ธ'), (' ', '.')], []],
#  [[('อ่ะ', 'อะ')]],
#  [[('ใหน', 'ไหน')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เปลียน', 'เปลี่ยน'), ('เบอ', 'เบอร์')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('รึป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('เท่าไหร่', 'เท่าไร'), ('หรอ', 'หรือ'), ('ค้ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ'), ('ค่ะ', 'คะ')]],
#  [[('เบอ', 'เบอร์')], [('อะ', 'อ่ะ'), ('คะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์')], [('ตัง', 'สตางค์')], [('เบอ', 'เบอร์')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('คับ', 'ครับ')], [('นึง', 'หนึ่ง')]],
#  [[('ใช้', 'ใช่'), ('ไหม่', 'ไหม')]],
#  [[('สาธุฯคัพ', 'สาธุครับ')]],
#  [[('แอพ', 'แอป')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('เบอ', 'เบอร์')], [('รึ', 'หรือ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('ล็อค', 'ล็อก')],
#   [('แอพ', 'แอป')],
#   [('ไม', 'ทำไม')],
#   [('แอพ', 'แอป')],
#   [('คับ', 'ครับ')]],
#  [[('มั้ย', 'ไหม')]],
#  [[('ยังไง', 'อย่างไร')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('บช', 'บัญชี')]],
#  [[('คร้า', 'ค่ะ')]],
#  [[('เปน', 'เป็น')]],
#  [[('ตุ้', 'ตู้')]],
#  [[('แล้ส', 'แล้ว')]],
#  [[('หรือป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('เด้อ', 'นะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('บช', 'บัญชี')]],
#  [[('ก้', 'ก็')]],
#  [[('เบอร', 'เบอร์')]],
#  [[('แลัว', 'แล้ว'), ('คับ', 'ครับ')]],
#  [[('ก้', 'ก็')], [('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')], [('ให', 'ให้')], [('ไว', 'ไว้')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[], [('ไง', 'อย่างไร')]],
#  [[('ใม่', 'ไม่')]],
#  [[('อะ', 'อ่ะ')]],
#  [[('อัพ', 'อัปเดต')]],
#  [[('บช', 'บัญชี')]],
#  [[('มั๊ย', 'ไหม')]],
#  [[('แบง', 'แบงก์')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('ใด้', 'ได้')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('แล้ส', 'แล้ว')], [('มั้ย', 'ไหม')]],
#  [[('ยุ', 'อยู่')], [('งัย', 'อย่างไร')]],
#  [[('ยุ่', 'อยู่'), ('กะ', 'กับ')]],
#  [[('เคดิต', 'เครดิต')]],
#  [[('คับ', 'ครับ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('คนับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('มั๊ย', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ก้', 'ก็')], [('มั้ย', 'ไหม')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ก้', 'ก็')]],
#  [[('ยังงัย', 'ยังไง')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ครัช', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[]],
#  [[('แอพ', 'แอป')]],
#  [[('แอฟ', 'แอป')]],
#  [[('ไหม่', 'ใหม่')]],
#  [[('เครือง', 'เครื่อง')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('โทรศัพย์', 'โทรศัพท์')], [('คับ', 'ครับ')]],
#  [[('บัชชี', 'บัญชี')]],
#  [[('เปน', 'เป็น')], [('ค่ะ', 'คะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ยังไง', 'อย่างไร')], [('อ่ะ', 'อะ')]],
#  [[('แต', 'แต่')], [('บช', 'บัญชี')]],
#  [[('ค่', 'คะ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('เนาะ', 'นะ')], [('โหลด', 'ดาวน์โหลด')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('ขอโทด', 'ขอโทษ')],
#   [('คับ', 'ครับ')],
#   [('ปะ', 'เปล่า'), ('คับ', 'ครับ')],
#   [('ปะ', 'เปล่า'), ('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ'), ('ค่ะ', 'คะ')]],
#  [[('บันชี', 'บัญชี'), ('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('เนต', 'อินเทอร์เน็ต')]],
#  [[('โทรสับ', 'โทรศัพท์')], [('ค่ะ', 'คะ')]],
#  [[('เปน', 'เป็น')]],
#  [[('อะรัย', 'อะไร'), ('ใด้', 'ได้')]],
#  [[('ไช่', 'ใช่'), ('คะ', 'ค่ะ')]],
#  [[('ใด้', 'ได้')]],
#  [[('แร้ว', 'แล้ว')], [('ก้', 'ก็')]],
#  [[('อะรัย', 'อะไร')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('ยัตร', 'บัตร'), ('ใข่', 'ใช่')], [('คับ', 'ครับ')]],
#  [[('สมัค', 'สมัคร')], [('คับ', 'ครับ')]],
#  [[('ป่ะ', 'ปะ')]],
#  [[('ยังไง', 'อย่างไร')], [('คับ', 'ครับ')]],
#  [[('ใหน', 'ไหน')]],
#  [[('เบอ', 'เบอร์')], [('ละ', 'ล่ะ'), ('คับ', 'ครับ')]],
#  [[('เปน', 'เป็น')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ค้ะ', 'คะ')]],
#  [[('เปน', 'เป็น')]],
#  [[('ใม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('ได่', 'ได้')]],
#  [[('โทรสัพ', 'โทรศัพท์')], [('คับ', 'ครับ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('แอป', 'แอพ')], [('รุ้', 'รู้')], [('เเอป', 'แอพ')]],
#  [[('ก้', 'ก็')], [('คะ', 'ค่ะ')]],
#  [[('จ่ะ', 'จ้ะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('บันชี', 'บัญชี')], [('ใด้', 'ได้'), ('มั้ย', 'ไหม')]],
#  [[('ใด้', 'ได้')]],
#  [[('โทรสับ', 'โทรศัพท์')], [('อ่ะ', 'อะ')]],
#  [[('พักงาน', 'พนักงาน')], [('ใว้', 'ไว้')]],
#  [[('อะ', 'อ่ะ')]],
#  [[('อ้ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ'), ('ค่ะ', 'คะ')]],
#  [[('ใหม', 'ไหม')]],
#  [[('เคดิต', 'เครดิต')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('เคดิต', 'เครดิต')], [('ใหม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('คร้าบ', 'ครับ')]],
#  [[('ค่าาา', 'ค่ะ')]],
#  [[('เบอร์', 'หมายเลข')]],
#  [[('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ'), ('ค่า', 'ค่ะ')]],
#  [[('ไง', 'อย่างไร')]],
#  [[('ใหน', 'ไหน')], [('ค่ะ', 'คะ')]],
#  [[('อะ', 'อ่ะ'), ('คับ', 'ครับ')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('อ่อ', 'อ๋อ'), ('คับ', 'ครับ')],
#   [('ขอบคุน', 'ขอบคุณ')],
#   [('คับ', 'ครับ')]],
#  [[('คำ', 'ค้ำ'), ('ใหม', 'ไหม')]],
#  [[('เปน', 'เป็น')]],
#  [[('รีไฟแนน', 'รีไฟแนนซ์'), ('ปะ', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('สมัค', 'สมัคร')]],
#  [[('แอพ', 'แอป')]],
#  [[('ใข่', 'ใช่')], [('ค่ะ', 'คะ')]],
#  [[('ก้', 'ก็')], [('แร้ว', 'แล้ว'), ('อ่ะ', 'อะ')]],
#  [[('ล้ะ', 'ล่ะ'), ('ค่ะ', 'คะ')]],
#  [[('เปน', 'เป็น')], [('รึป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')]],
#  [[('อาทิตร์', 'อาทิตย์')]],
#  [[]],
#  [[('อ่อ', 'อ๋อ')], [('แร้ว', 'แล้ว')], [('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('นี้', 'นี่')], [('ค่ะ', 'คะ')]],
#  [[('เชค', 'เช็ค')], [('อ่ะ', 'อะ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('แบงค์', 'แบงก์')]],
#  [[('ใช่', 'ใช่'), ('ใหม', 'ไหม')]],
#  [[('เรย', 'เลย')]],
#  [[('บันชี', 'บัญชี')], [('ป่ะ', 'เปล่า')]],
#  [[('แอฟ', 'แอป')]],
#  [[('โทรศัพย์', 'โทรศัพท์')], [('งัย', 'ไง')]],
#  [[('มั้ย', 'ไหม')], [('อ่ะ', 'อะ')]],
#  [[('มั๊ย', 'ไหม'), ('อ่ะ', 'อะ')]],
#  [[('ก้', 'ก็')]],
#  [[('เน็ต', 'อินเทอร์เน็ต')],
#   [('สมัค', 'สมัคร')],
#   [('ไม', 'ไหม'), ('ค่ะ', 'คะ')]],
#  [[('สมัค', 'สมัคร'), ('ยังงัย', 'อย่างไร')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ล่ะ', 'ละ'), ('ไช่', 'ใช่'), ('ป่ะ', 'เปล่า'), ('ค่ะ', 'คะ')]],
#  [[('อินเตอร์เน็ต', 'อินเทอร์เน็ต')]],
#  [[('มั้ย', 'ไหม'), ('ค้ะ', 'คะ')]],
#  [[('คัฟ', 'ครับ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('โทรสัพ', 'โทรศัพท์'), ('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('ใช่', 'ใช้')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('ตอ้งการ', 'ต้องการ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[]],
#  [[('ใด้', 'ได้')]],
#  [[('จ้า', 'จ้ะ')]],
#  [[('กุ้', 'กู้')], [('เปน', 'เป็น')], [('ใด้', 'ได้'), ('ใหม', 'ไหม')]],
#  [[('ดิ', 'สิ')]],
#  [[('อ่ะ', 'อะ'), ('ค่า', 'ค่ะ')]],
#  [[('ลหัส', 'รหัส')]],
#  [[('พึ่ง', 'เพิ่ง')]],
#  [[('แอพที่', 'แอปที่')]],
#  [[('ม่', 'ไม่')]],
#  [[('ใม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('น่อย', 'หน่อย')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('พิม', 'พิมพ์')]],
#  [[('ไห้', 'ให้')], [('ไห้', 'ให้')], [('ก้', 'ก็')], [('อ่ะ', 'อะ')]],
#  [[('หรือป่าว', 'หรือเปล่า'), ('ค่ะ', 'คะ')],
#   [('สมัค', 'สมัคร')],
#   [('ใหน', 'ไหน')],
#   [('ค่ะ', 'คะ')]],
#  [[('ใม่', 'ไม่'), ('ใด้', 'ได้')], [('ใม่', 'ไม่'), ('ใด้', 'ได้')]],
#  [[('บ ช', 'บัญชี')]],
#  [[('ค่', 'คะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('ตุ้', 'ตู้')], [('ตุ้', 'ตู้')]],
#  [[('ก้คือ', 'ก็คือ')]],
#  [[('แอฟ', 'แอป')], [('ป่ะ', 'ปะ')]],
#  [[('ค่ะ', 'คะ')]],
#  [[('แบง', 'แบงค์')], [('อ่ะ', 'อะ')]],
#  [[('โทรศัพย์', 'โทรศัพท์')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('เปน', 'เป็น')]],
#  [[('วัน', 'วัน'), ('พีช', 'พีซ')], [('ไม๊', 'ไหม')]],
#  [[('ค้ะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์')]],
#  [[('คร่', 'ค่ะ')]],
#  [[('อ่อ', 'อ๋อ')], [('เป็นไร', 'เป็นไร')], [('คับ', 'ครับ')]],
#  [[('แร้ว', 'แล้ว')], [('สมัค', 'สมัคร')], [('ก้', 'ก็')], [('ค้ะ', 'ค่ะ')]],
#  [[('แอพ', 'แอป')], [('คะ', 'ค่ะ')]],
#  [[('ยังใง', 'ยังไง'), ('น่ะ', 'นะ'), ('ค่ะ', 'คะ')]],
#  [[('ไม่', 'ไหม'), ('คร้า', 'คะ')]],
#  [[('เปน', 'เป็น')], [('คับ', 'ครับ')]],
#  [[('คะ', 'ค่ะ')]],
#  [[('ไห้', 'ให้')]],
#  [[('ไหม่', 'ใหม่')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('สมัด', 'สมัคร')]],
#  [[('ให่', 'ให้')]],
#  [[('สามรถเชค', 'สามารถเช็ค')], [('มัย', 'ไหม')]],
#  [[('เวป', 'เว็บไซต์')]],
#  [[('ค่ะ.', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('แอพ', 'แอป')]],
#  [[('ลบกวน', 'รบกวน'), ('สมัค', 'สมัคร')], [('คับ', 'ครับ')]],
#  [[('เปน', 'เป็น')]],
#  [[('บช', 'บัญชี')]],
#  [[('ม่', 'ไม่')]],
#  [[('ตัง', 'สตางค์')], [('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('เปลียน', 'เปลี่ยน')], [('มั้ย', 'ไหม')]],
#  [[('บัชชี', 'บัญชี')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('คับ', 'ครับ')]],
#  [[('อ่อ', 'อ๋อ')]],
#  [[('ป่ะ', 'เปล่า')]],
#  [[('อ่อ', 'อ๋อ'), ('คับ', 'ครับ')]],
#  [[('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('งัย', 'ไง')]],
#  [[('อยุ่', 'อยู่'), ('มั้ย', 'ไหม')]],
#  [[('ก้', 'ก็')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อ่ะ', 'อะ'), ('คะ', 'ค่ะ')]],
#  [[('คับ', 'ครับ')]],
#  [[('มั้ย', 'ไหม'), ('ค้ะ', 'คะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[('ใช้', 'ใช่'), ('ป่ะ', 'เปล่า')]],
#  [[('คนับ', 'ครับ')]],
#  [[('ขอบคุน', 'ขอบคุณ')], [('คพ', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('คับ', 'ครับ')]],
#  [[('โทรศัพ', 'โทรศัพท์')]],
#  [[('คค่ะ', 'คะ')]],
#  [[('ยังไง', 'อย่างไร')], [('ค่ะ', 'คะ')]],
#  [[('ฮาาา', 'ฮา')]],
#  [[('ละ', 'ล่ะ')]],
#  [[('ค่', 'ค่ะ')]],
#  [[('อ่ะ', 'อะ'), ('คับ', 'ครับ')]],
#  [[]],
#  [[('ได่', 'ได้'), ('คะ', 'ค่ะ')]],
#  [[('เบอ', 'เบอร์')], [('ไง', 'อย่างไร')]],
#  [[('อ่อ', 'อ้อ')], [('ขอบคุน', 'ขอบคุณ')], [('คับ', 'ครับ')]],
#  [[('อ่ะ', 'อะ')]],
#  [[('อาทิต', 'อาทิตย์')], [('ทำไหม', 'ทำไม')], [('ค่ะ', 'คะ')]],
#  [[('อยุ่', 'อยู่')]],
#  [[('แอพ', 'แอป')], [('มั้ย', 'ไหม')]],
#  ...]

# %%
msp_type
# Out:
# [[['morphed', 10, 11]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 1, 2], ['morphed', 3, 5]],
#  [['morphed', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 3, 4], ['morphed', 5, 6]],
#  [['misspelled', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 2, 3], ['morphed', 7, 8]],
#  [['morphed', 3, 4]],
#  [['misspelled', 3, 6]],
#  [['morphed', 4, 7]],
#  [['misspelled', 1, 4]],
#  [['morphed', 6, 7], ['morphed', 13, 14], ['misspelled', 15, 16]],
#  [['misspelled', 2, 3]],
#  [['morphed', 3, 4]],
#  [['misspelled', 1, 3], ['misspelled', 4, 5]],
#  [['morphed', 3, 4]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 2], ['morphed', 12, 13]],
#  [['misspelled', 4, 9]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 3],
#   ['misspelled', 4, 5],
#   ['misspelled', 7, 9],
#   ['misspelled', 10, 11]],
#  [['misspelled', 2, 3]],
#  [['morphed', 18, 19], ['misspelled', 21, 22]],
#  [['misspelled', 1, 3], ['misspelled', 5, 6]],
#  [['misspelled', 2, 3]],
#  [['morphed', 2, 3]],
#  [['misspelled', 7, 9]],
#  [['misspelled', 5, 6], ['morphed', 7, 9]],
#  [['misspelled', 2, 3], ['misspelled', 4, 5]],
#  [['misspelled', 11, 12]],
#  [['morphed', 6, 7], ['morphed', 11, 13]],
#  [['misspelled', 2, 5], ['morphed', 8, 9]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 6]],
#  [['ws', 3, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 5, 6], ['misspelled', 9, 10]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 7, 9], ['morphed', 10, 11]],
#  [['morphed', 1, 2],
#   ['morphed', 3, 6],
#   ['morphed', 9, 10],
#   ['morphed', 12, 13],
#   ['morphed', 15, 17]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 3], ['misspelled', 4, 6]],
#  [['morphed', 6, 7]],
#  [['other', 2, 3]],
#  [['other', 2, 3]],
#  [['morphed', 6, 8]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 8, 10], ['misspelled', 14, 15], ['misspelled', 21, 23]],
#  [['morphed', 7, 8]],
#  [['morphed', 4, 5]],
#  [['misspelled', 3, 5]],
#  [['morphed', 6, 8]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 13, 15]],
#  [['misspelled', 2, 3], ['misspelled', 6, 7]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 2], ['morphed', 3, 4]],
#  [['morphed', 6, 7]],
#  [['morphed', 2, 4], ['misspelled', 5, 6]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 1, 2], ['morphed', 9, 11], ['misspelled', 13, 14]],
#  [['morphed', 13, 14], ['misspelled', 16, 17], ['morphed', 18, 20]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 3], ['misspelled', 15, 16]],
#  [['misspelled', 3, 4], ['misspelled', 7, 9]],
#  [['morphed', 4, 5]],
#  [['misspelled', 4, 6], ['misspelled', 13, 15], ['morphed', 16, 17]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 17, 18]],
#  [['misspelled', 3, 4], ['morphed', 5, 6]],
#  [['misspelled', 5, 6]],
#  [['morphed', 5, 6]],
#  [['misspelled', 2, 3], ['morphed', 7, 9]],
#  [['misspelled', 18, 20]],
#  [['misspelled', 2, 3]],
#  [['morphed', 2, 3]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 4]],
#  [['morphed', 3, 4]],
#  [['morphed', 5, 6]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4], ['misspelled', 6, 7]],
#  [['misspelled', 4, 5], ['misspelled', 6, 7]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 11, 13]],
#  [['abbreviation', 3, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 4], ['misspelled', 6, 7], ['misspelled', 9, 10]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3], ['morphed', 4, 7]],
#  [['misspelled', 15, 16]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 4, 5]],
#  [['morphed', 3, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 6], ['misspelled', 8, 9]],
#  [['misspelled', 4, 5], ['misspelled', 6, 7]],
#  [['morphed', 14, 15], ['morphed', 17, 19]],
#  [['misspelled', 1, 2], ['morphed', 4, 6], ['morphed', 7, 8]],
#  [['morphed', 3, 4], ['misspelled', 11, 13], ['morphed', 14, 15]],
#  [['misspelled', 1, 2]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 11, 13]],
#  [['misspelled', 1, 2], ['other', 4, 5]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 6]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 3, 4]],
#  [['morphed', 5, 6]],
#  [['morphed', 5, 6], ['morphed', 14, 16]],
#  [['morphed', 6, 7], ['morphed', 9, 10]],
#  [['morphed', 4, 5]],
#  [['morphed', 2, 3]],
#  [['misspelled', 20, 21]],
#  [['morphed', 1, 2], ['misspelled', 3, 6], ['misspelled', 7, 8]],
#  [['misspelled', 4, 5], ['misspelled', 9, 10], ['misspelled', 11, 12]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 2], ['misspelled', 3, 4]],
#  [['abbreviation', 3, 4]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 5]],
#  [['morphed', 13, 15]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 4]],
#  [['morphed', 3, 5], ['misspelled', 6, 8]],
#  [['misspelled', 2, 4]],
#  [['morphed', 14, 15]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 26, 27]],
#  [['morphed', 8, 9]],
#  [['abbreviation', 9, 10], ['misspelled', 12, 14]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 12, 14]],
#  [['misspelled', 4, 5]],
#  [['morphed', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 13, 15]],
#  [['morphed', 1, 2], ['misspelled', 4, 5]],
#  [['morphed', 8, 9]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 2]],
#  [['morphed', 6, 8]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 2, 3], ['morphed', 7, 8]],
#  [['misspelled', 2, 5]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 2], ['misspelled', 8, 9]],
#  [['misspelled', 5, 6], ['morphed', 7, 8]],
#  [['misspelled', 5, 6], ['misspelled', 10, 11]],
#  [['morphed', 6, 7]],
#  [['morphed', 9, 10]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['morphed', 7, 8]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 2], ['morphed', 3, 4], ['morphed', 15, 16]],
#  [['abbreviation', 1, 4]],
#  [['other', 4, 6]],
#  [['morphed', 3, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 15, 16]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 8, 11]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 3], ['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['morphed', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['morphed', 1, 2], ['misspelled', 6, 7]],
#  [['morphed', 1, 4]],
#  [['morphed', 4, 6]],
#  [['morphed', 22, 23]],
#  [['morphed', 7, 9]],
#  [['misspelled', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 2, 5], ['morphed', 6, 7]],
#  [['morphed', 6, 7], ['morphed', 8, 9]],
#  [['misspelled', 1, 4], ['morphed', 5, 6]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 6]],
#  [['misspelled', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 4], ['morphed', 5, 6]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 1, 2], ['morphed', 5, 6]],
#  [['misspelled', 1, 2], ['morphed', 4, 5], ['misspelled', 6, 9]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 3, 4]],
#  [['abbreviation', 1, 2]],
#  [['misspelled', 4, 5]],
#  [['morphed', 9, 10]],
#  [['morphed', 2, 3], ['misspelled', 6, 7]],
#  [['misspelled', 14, 15]],
#  [['misspelled', 2, 5]],
#  [['abbreviation', 19, 21]],
#  [['morphed', 1, 4]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 5], ['misspelled', 6, 8], ['morphed', 9, 10]],
#  [['misspelled', 4, 5]],
#  [['morphed', 14, 15]],
#  [['misspelled', 3, 6], ['misspelled', 7, 8]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 3], ['misspelled', 8, 9]],
#  [['misspelled', 1, 2]],
#  [['morphed', 1, 2], ['misspelled', 6, 7]],
#  [['misspelled', 8, 10]],
#  [['morphed', 13, 14]],
#  [['morphed', 4, 5], ['misspelled', 14, 15], ['misspelled', 27, 30]],
#  [['morphed', 1, 2]],
#  [['morphed', 1, 2]],
#  [['misspelled', 2, 3], ['misspelled', 4, 5]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 6, 9]],
#  [['morphed', 1, 4]],
#  [['morphed', 1, 8]],
#  [['ws', 9, 12]],
#  [['misspelled', 3, 4], ['misspelled', 9, 10]],
#  [['morphed', 2, 3]],
#  [['morphed', 7, 10]],
#  [['misspelled', 1, 2]],
#  [['morphed', 1, 2]],
#  [['misspelled', 2, 3], ['morphed', 5, 6]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 2, 3]],
#  [['abbreviation', 7, 8]],
#  [['misspelled', 3, 4], ['morphed', 6, 7]],
#  [['morphed', 6, 7]],
#  [['misspelled', 1, 2]],
#  [['morphed', 9, 11]],
#  [['misspelled', 2, 3]],
#  [['abbreviation', 6, 7]],
#  [['misspelled', 4, 5], ['morphed', 6, 7]],
#  [['morphed', 5, 6], ['misspelled', 8, 11]],
#  [['morphed', 2, 3]],
#  [['misspelled', 1, 3]],
#  [['morphed', 1, 4]],
#  [['morphed', 2, 3]],
#  [['misspelled', 1, 2]],
#  [['morphed', 1, 2]],
#  [['morphed', 1, 3]],
#  [['misspelled', 1, 2], ['misspelled', 6, 7]],
#  [['misspelled', 5, 7]],
#  [['morphed', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['morphed', 5, 6]],
#  [['morphed', 6, 7]],
#  [['misspelled', 3, 6]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 3], ['morphed', 7, 10]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 7]],
#  [['morphed', 1, 4], ['morphed', 7, 9], ['morphed', 10, 11]],
#  [['morphed', 4, 5]],
#  [['morphed', 2, 4]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 5, 6], ['misspelled', 7, 8]],
#  [['misspelled', 2, 3], ['misspelled', 7, 8]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 2, 3]],
#  [['morphed', 11, 12]],
#  [['morphed', 1, 3]],
#  [['misspelled', 3, 5]],
#  [['abbreviation', 15, 18], ['abbreviation', 26, 27]],
#  [['abbreviation', 5, 6]],
#  [['misspelled', 7, 8]],
#  [['morphed', 10, 11]],
#  [['misspelled', 6, 8]],
#  [['misspelled', 2, 3], ['misspelled', 6, 7], ['misspelled', 19, 22]],
#  [['misspelled', 2, 4]],
#  [['morphed', 1, 2]],
#  [['misspelled', 3, 6]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 5], ['morphed', 6, 7]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 2]],
#  [['abbreviation', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 6, 9], ['morphed', 11, 12]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 6, 8]],
#  [['morphed', 3, 4], ['misspelled', 12, 13]],
#  [['morphed', 9, 10]],
#  [['misspelled', 6, 8]],
#  [['ws', 4, 7]],
#  [['misspelled', 11, 12], ['misspelled', 15, 16]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 4, 6]],
#  [['morphed', 1, 4]],
#  [['misspelled', 3, 6]],
#  [['misspelled', 23, 24]],
#  [['misspelled', 3, 6], ['misspelled', 12, 13]],
#  [['misspelled', 17, 19]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 3], ['misspelled', 4, 7]],
#  [['misspelled', 2, 3]],
#  [['morphed', 6, 8]],
#  [['abbreviation', 7, 11]],
#  [['morphed', 10, 11]],
#  [['misspelled', 3, 4], ['morphed', 6, 7]],
#  [['misspelled', 6, 8]],
#  [['misspelled', 3, 7], ['morphed', 8, 9]],
#  [['ws', 5, 6], ['ws', 7, 10]],
#  [['misspelled', 1, 2]],
#  [['morphed', 6, 7]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 4, 5]],
#  [['morphed', 7, 8], ['misspelled', 9, 10]],
#  [['morphed', 2, 4]],
#  [['misspelled', 3, 5], ['morphed', 6, 8]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 10, 11], ['misspelled', 17, 20]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 3, 5], ['misspelled', 6, 7]],
#  [['morphed', 11, 13]],
#  [['morphed', 10, 12]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 5, 6], ['misspelled', 8, 12]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 5]],
#  [['morphed', 1, 3], ['morphed', 4, 5], ['misspelled', 6, 9]],
#  [['misspelled', 19, 20]],
#  [['misspelled', 7, 8], ['misspelled', 13, 14]],
#  [['misspelled', 15, 17]],
#  [['morphed', 2, 3]],
#  [['misspelled', 6, 8]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 3], ['misspelled', 7, 11]],
#  [['misspelled', 4, 5]],
#  [['morphed', 3, 4]],
#  [['morphed', 6, 7]],
#  [['misspelled', 1, 3]],
#  [['morphed', 4, 5]],
#  [['morphed', 5, 6]],
#  [['misspelled', 2, 3]],
#  [['morphed', 7, 9]],
#  [['misspelled', 1, 2], ['abbreviation', 4, 5], ['misspelled', 7, 8]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 2, 4], ['misspelled', 7, 8]],
#  [['misspelled', 1, 3], ['abbreviation', 4, 5]],
#  [['misspelled', 5, 7], ['morphed', 9, 10]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 10, 11], ['morphed', 16, 17]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 5]],
#  [['morphed', 29, 31], ['misspelled', 37, 38]],
#  [['morphed', 1, 3]],
#  [['misspelled', 1, 3],
#   ['misspelled', 16, 17],
#   ['misspelled', 24, 26],
#   ['misspelled', 31, 32]],
#  [['misspelled', 5, 9]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 7, 8], ['misspelled', 9, 10]],
#  [['misspelled', 3, 5]],
#  [['morphed', 2, 3]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 4], ['misspelled', 5, 6]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 1, 4]],
#  [['abbreviation', 1, 5]],
#  [['abbreviation', 18, 19], ['morphed', 25, 26]],
#  [['misspelled', 3, 5], ['abbreviation', 6, 7]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 6, 7]],
#  [['morphed', 10, 11]],
#  [['abbreviation', 3, 4]],
#  [['misspelled', 2, 4]],
#  [['morphed', 14, 16]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 3], ['misspelled', 5, 6]],
#  [['misspelled', 4, 5], ['misspelled', 8, 9]],
#  [['misspelled', 3, 4], ['misspelled', 6, 7]],
#  [['misspelled', 2, 4], ['misspelled', 10, 11], ['misspelled', 18, 20]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 1, 2], ['misspelled', 8, 9]],
#  [['misspelled', 14, 16], ['misspelled', 17, 19]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 7, 9]],
#  [['misspelled', 7, 10]],
#  [['misspelled', 1, 2], ['misspelled', 4, 6]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 5], ['misspelled', 7, 8]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['morphed', 1, 4]],
#  [['morphed', 2, 3], ['misspelled', 4, 5], ['misspelled', 7, 9]],
#  [['morphed', 3, 5]],
#  [['morphed', 2, 3]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 3, 4]],
#  [['morphed', 5, 6], ['morphed', 10, 11]],
#  [['morphed', 8, 9], ['morphed', 10, 11]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 9, 11]],
#  [['morphed', 14, 15]],
#  [['misspelled', 1, 2], ['morphed', 4, 6]],
#  [['misspelled', 3, 4], ['misspelled', 6, 8], ['morphed', 9, 10]],
#  [['misspelled', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 1, 4], ['misspelled', 6, 9]],
#  [['morphed', 2, 5]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 4, 5], ['misspelled', 8, 9]],
#  [['morphed', 3, 4]],
#  [['misspelled', 11, 12]],
#  [['other', 3, 4]],
#  [['misspelled', 6, 7], ['morphed', 9, 10]],
#  [['morphed', 3, 4], ['morphed', 7, 8]],
#  [['morphed', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 5], ['morphed', 6, 8]],
#  [['misspelled', 7, 8]],
#  [['morphed', 2, 3]],
#  [['misspelled', 1, 2]],
#  [['abbreviation', 2, 4]],
#  [['misspelled', 4, 5]],
#  [['morphed', 3, 4]],
#  [['misspelled', 1, 2], ['misspelled', 7, 9]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 2, 3], ['misspelled', 4, 6]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 12, 14], ['morphed', 20, 22], ['misspelled', 34, 35]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 3, 4]],
#  [['morphed', 1, 2], ['abbreviation', 7, 9]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 4, 7], ['misspelled', 8, 10], ['misspelled', 11, 12]],
#  [['misspelled', 3, 5], ['morphed', 10, 12]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 6], ['misspelled', 7, 9]],
#  [['morphed', 8, 9]],
#  [['morphed', 1, 4]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 7, 8], ['misspelled', 13, 15], ['morphed', 17, 18]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 1, 3], ['misspelled', 6, 7], ['morphed', 9, 10]],
#  [['morphed', 5, 6]],
#  [['morphed', 2, 3]],
#  [['morphed', 1, 2]],
#  [['morphed', 1, 2]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 4]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 6, 7], ['misspelled', 10, 12]],
#  [['misspelled', 2, 5]],
#  [['morphed', 4, 5]],
#  [['misspelled', 2, 3], ['morphed', 4, 5]],
#  [['misspelled', 7, 8]],
#  [['abbreviation', 4, 7], ['morphed', 19, 20]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 5], ['misspelled', 7, 8], ['morphed', 13, 14]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 3, 4]],
#  [['morphed', 8, 9]],
#  [['misspelled', 1, 3], ['misspelled', 5, 6]],
#  [['misspelled', 2, 3], ['misspelled', 7, 8]],
#  [['misspelled', 5, 6]],
#  [['morphed', 11, 12]],
#  [['misspelled', 7, 8], ['misspelled', 9, 11], ['misspelled', 12, 13]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 7, 9]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 2], ['morphed', 9, 11]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 2, 4]],
#  [['morphed', 5, 7]],
#  [['morphed', 3, 4]],
#  [['morphed', 4, 7]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 1, 2], ['misspelled', 3, 4]],
#  [['morphed', 5, 6]],
#  [['misspelled', 6, 7]],
#  [['abbreviation', 1, 2], ['morphed', 8, 9]],
#  [['morphed', 12, 13]],
#  [['morphed', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 1, 3], ['misspelled', 8, 9]],
#  [['misspelled', 2, 4]],
#  [['abbreviation', 3, 4]],
#  [['misspelled', 1, 4]],
#  [['morphed', 2, 3]],
#  [['misspelled', 2, 5], ['misspelled', 9, 10]],
#  [['morphed', 11, 13]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 1, 2]],
#  [['morphed', 4, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 3, 4], ['abbreviation', 5, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 3], ['abbreviation', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 3, 6]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 2, 3], ['misspelled', 7, 10]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 1, 2], ['misspelled', 3, 4]],
#  [['misspelled', 4, 6], ['misspelled', 13, 15]],
#  [['morphed', 5, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 6, 8]],
#  [['abbreviation', 4, 5], ['morphed', 23, 24]],
#  [['morphed', 15, 16]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 5, 11]],
#  [['misspelled', 1, 2]],
#  [['morphed', 2, 3], ['misspelled', 20, 22]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 1, 2]],
#  [['morphed', 8, 9], ['morphed', 10, 11]],
#  [['morphed', 8, 9]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 1, 3]],
#  [['morphed', 3, 5], ['misspelled', 12, 13]],
#  [['misspelled', 5, 6]],
#  [['morphed', 12, 13]],
#  [['misspelled', 10, 11]],
#  [['morphed', 2, 3]],
#  [['misspelled', 1, 4], ['misspelled', 5, 7]],
#  [['morphed', 6, 7], ['morphed', 8, 9]],
#  [['morphed', 3, 4], ['morphed', 5, 6], ['misspelled', 28, 30]],
#  [['misspelled', 1, 2], ['morphed', 5, 6]],
#  [['morphed', 6, 8]],
#  [['morphed', 6, 7]],
#  [['morphed', 1, 2], ['morphed', 6, 7]],
#  [['morphed', 1, 2], ['morphed', 5, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3], ['misspelled', 6, 8]],
#  [['misspelled', 5, 9]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 1, 2]],
#  [['morphed', 6, 8]],
#  [['misspelled', 1, 4], ['misspelled', 16, 17]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 1, 2]],
#  [['abbreviation', 7, 8]],
#  [['misspelled', 2, 4], ['misspelled', 5, 6]],
#  [['morphed', 6, 7]],
#  [['morphed', 2, 4], ['morphed', 5, 6]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 4]],
#  [['morphed', 9, 10], ['morphed', 11, 13]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 6]],
#  [['morphed', 3, 4]],
#  [['morphed', 5, 15], ['morphed', 16, 21]],
#  [['misspelled', 3, 5], ['misspelled', 6, 7]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 1, 5], ['morphed', 9, 10]],
#  [['misspelled', 1, 2]],
#  [['morphed', 2, 3]],
#  [['misspelled', 5, 7]],
#  [['morphed', 10, 11]],
#  [['misspelled', 1, 3]],
#  [['morphed', 2, 3]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 2, 3]],
#  [['morphed', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 5, 7]],
#  [['morphed', 6, 8]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 11, 13]],
#  [['misspelled', 2, 3], ['morphed', 6, 8]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 7, 8]],
#  [['morphed', 3, 4]],
#  [['misspelled', 9, 10]],
#  [['misspelled', 7, 10], ['morphed', 11, 12]],
#  [['morphed', 1, 2], ['misspelled', 4, 5]],
#  [['misspelled', 2, 3], ['misspelled', 15, 18]],
#  [['misspelled', 4, 7]],
#  [['morphed', 7, 8], ['misspelled', 12, 15]],
#  [['misspelled', 31, 32]],
#  [['misspelled', 2, 3]],
#  [['abbreviation', 3, 4], ['morphed', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['abbreviation', 6, 10]],
#  [['morphed', 1, 2]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 17, 18]],
#  [['misspelled', 2, 3], ['misspelled', 18, 19]],
#  [['misspelled', 8, 9]],
#  [['morphed', 4, 5]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 1, 2], ['misspelled', 3, 6]],
#  [['misspelled', 5, 7]],
#  [['morphed', 5, 7]],
#  [['morphed', 2, 3], ['morphed', 4, 5]],
#  [['misspelled', 4, 5]],
#  [['morphed', 2, 3]],
#  [['abbreviation', 14, 15]],
#  [['morphed', 12, 13]],
#  [['misspelled', 3, 4], ['morphed', 7, 9], ['misspelled', 12, 14]],
#  [['morphed', 1, 2], ['misspelled', 3, 4], ['morphed', 5, 7]],
#  [['morphed', 5, 6]],
#  [['morphed', 3, 4]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 7, 12]],
#  [['misspelled', 2, 3]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 3], ['morphed', 4, 5]],
#  [['abbreviation', 11, 14]],
#  [['morphed', 8, 10]],
#  [['morphed', 4, 5]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 2], ['misspelled', 5, 6]],
#  [['misspelled', 4, 6], ['morphed', 11, 12]],
#  [['misspelled', 1, 4], ['abbreviation', 9, 10]],
#  [['abbreviation', 3, 6], ['abbreviation', 12, 13]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 5]],
#  [['morphed', 19, 20]],
#  [['morphed', 3, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 5]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 3, 4], ['misspelled', 5, 7]],
#  [['misspelled', 2, 3], ['morphed', 9, 10], ['misspelled', 13, 14]],
#  [['morphed', 5, 6]],
#  [['morphed', 3, 4], ['morphed', 6, 7]],
#  [['misspelled', 5, 8]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 2, 3], ['morphed', 7, 8]],
#  [['morphed', 14, 15]],
#  [['misspelled', 3, 4],
#   ['misspelled', 5, 6],
#   ['morphed', 10, 11],
#   ['misspelled', 12, 13],
#   ['morphed', 15, 16]],
#  [['morphed', 11, 12]],
#  [['morphed', 12, 13]],
#  [['morphed', 10, 11]],
#  [['abbreviation', 12, 13]],
#  [['morphed', 1, 2]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 12, 14]],
#  [['misspelled', 2, 4]],
#  [['morphed', 14, 16]],
#  [['other', 4, 5]],
#  [['misspelled', 2, 3]],
#  [['abbreviation', 2, 3]],
#  [['morphed', 4, 5]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 4, 7]],
#  [['misspelled', 1, 2], ['misspelled', 5, 6]],
#  [['misspelled', 6, 7], ['misspelled', 11, 12], ['misspelled', 13, 14]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 5, 7], ['morphed', 9, 10]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['abbreviation', 8, 9]],
#  [['abbreviation', 5, 6]],
#  [['morphed', 10, 11]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 1, 3], ['morphed', 11, 12]],
#  [['morphed', 4, 5], ['morphed', 8, 9]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 3, 6]],
#  [['morphed', 4, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 6, 7]],
#  [['morphed', 5, 7]],
#  [['misspelled', 3, 4]],
#  [['morphed', 7, 8], ['morphed', 14, 15]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 25, 26]],
#  [['misspelled', 2, 3]],
#  [['morphed', 1, 2]],
#  [['misspelled', 5, 6]],
#  [['abbreviation', 9, 11]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 1, 5], ['misspelled', 11, 12]],
#  [['misspelled', 10, 13]],
#  [['misspelled', 1, 2], ['misspelled', 7, 8]],
#  [['morphed', 6, 7]],
#  [['morphed', 2, 3], ['misspelled', 6, 7]],
#  [['misspelled', 5, 6], ['abbreviation', 8, 9]],
#  [['misspelled', 12, 14]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 3, 5]],
#  [['morphed', 3, 4], ['abbreviation', 5, 6]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 2],
#   ['morphed', 3, 4],
#   ['morphed', 13, 15],
#   ['morphed', 22, 24]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 2, 6]],
#  [['misspelled', 2, 3]],
#  [['morphed', 4, 6], ['misspelled', 10, 11]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 1, 2]],
#  [['morphed', 1, 2], ['misspelled', 7, 8]],
#  [['morphed', 3, 5]],
#  [['morphed', 2, 3]],
#  [['misspelled', 7, 11], ['morphed', 12, 13]],
#  [['misspelled', 4, 6], ['morphed', 7, 8]],
#  [['misspelled', 1, 2]],
#  [['morphed', 2, 3], ['morphed', 4, 5]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3], ['misspelled', 4, 6]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 6], ['morphed', 8, 9]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 2, 3], ['misspelled', 4, 5], ['misspelled', 6, 8]],
#  [['misspelled', 4, 5], ['misspelled', 6, 7]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 1, 3], ['misspelled', 4, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 3, 5], ['misspelled', 6, 7]],
#  [['misspelled', 2, 4], ['misspelled', 9, 10]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 15, 16]],
#  [['misspelled', 7, 10]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 6], ['misspelled', 7, 9]],
#  [['morphed', 6, 7]],
#  [['morphed', 2, 5]],
#  [['other', 7, 8]],
#  [['misspelled', 6, 7]],
#  [['misspelled', 7, 9]],
#  [['morphed', 8, 9]],
#  [['misspelled', 2, 3], ['misspelled', 5, 6]],
#  [['misspelled', 6, 8]],
#  [['misspelled', 3, 6]],
#  [['morphed', 1, 3], ['misspelled', 4, 5], ['misspelled', 7, 8]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 1, 6]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 6], ['misspelled', 7, 8]],
#  [['misspelled', 5, 6], ['morphed', 9, 11]],
#  [['misspelled', 1, 3]],
#  [['morphed', 2, 3], ['morphed', 9, 11]],
#  [['misspelled', 3, 5]],
#  [['abbreviation', 7, 8]],
#  [['misspelled', 1, 2], ['morphed', 3, 4], ['misspelled', 6, 8]],
#  [['misspelled', 1, 2], ['misspelled', 6, 7]],
#  [['misspelled', 2, 3], ['misspelled', 17, 18]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 3, 4]],
#  [['ws', 4, 6]],
#  [['morphed', 4, 5]],
#  [['misspelled', 1, 3], ['morphed', 6, 7]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 7], ['morphed', 12, 13]],
#  [['morphed', 9, 10], ['misspelled', 12, 13]],
#  [['morphed', 3, 5]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 2, 3], ['misspelled', 5, 7], ['misspelled', 8, 10]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 3, 7]],
#  [['misspelled', 16, 18]],
#  [['morphed', 6, 8]],
#  [['morphed', 6, 7]],
#  [['misspelled', 2, 3]],
#  [['morphed', 3, 8]],
#  [['misspelled', 2, 3]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 1, 4]],
#  [['misspelled', 10, 11]],
#  [['abbreviation', 2, 3]],
#  [['misspelled', 2, 3]],
#  [['morphed', 4, 5]],
#  [['misspelled', 2, 4], ['morphed', 7, 8], ['misspelled', 9, 11]],
#  [['morphed', 2, 3]],
#  [['misspelled', 20, 22]],
#  [['misspelled', 5, 7]],
#  [['morphed', 1, 2]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 10, 11]],
#  [['misspelled', 7, 8]],
#  [['misspelled', 2, 3],
#   ['misspelled', 5, 6],
#   ['misspelled', 7, 8],
#   ['misspelled', 11, 12]],
#  [['morphed', 4, 6],
#   ['misspelled', 7, 9],
#   ['misspelled', 10, 11],
#   ['misspelled', 12, 13]],
#  [['misspelled', 2, 4], ['misspelled', 14, 16]],
#  [['abbreviation', 5, 8]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 13, 14]],
#  [['misspelled', 3, 5], ['misspelled', 9, 11]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 2, 3], ['misspelled', 9, 10]],
#  [['misspelled', 11, 12]],
#  [['misspelled', 5, 6], ['misspelled', 7, 8]],
#  [['misspelled', 1, 5]],
#  [['misspelled', 5, 7]],
#  [['morphed', 7, 8]],
#  [['misspelled', 13, 15], ['morphed', 16, 17]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 1, 2], ['ws', 3, 4], ['morphed', 5, 6]],
#  [['morphed', 1, 2],
#   ['misspelled', 3, 5],
#   ['misspelled', 7, 8],
#   ['misspelled', 10, 11]],
#  [['misspelled', 6, 7], ['misspelled', 8, 9]],
#  [['misspelled', 1, 6]],
#  [['misspelled', 4, 6]],
#  [['morphed', 1, 2], ['morphed', 4, 5]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 11, 13]],
#  [['misspelled', 1, 4], ['misspelled', 5, 6]],
#  [['misspelled', 5, 6]],
#  [['misspelled', 6, 8]],
#  [['misspelled', 3, 5]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 1, 5], ['morphed', 7, 8]],
#  [['misspelled', 2, 3]],
#  [['abbreviation', 3, 4]],
#  [['misspelled', 2, 3]],
#  [['morphed', 3, 4], ['misspelled', 5, 7]],
#  [['misspelled', 1, 4], ['morphed', 5, 6]],
#  [['misspelled', 8, 11]],
#  [['morphed', 1, 2]],
#  [['morphed', 15, 16]],
#  [['misspelled', 1, 2]],
#  [['morphed', 9, 10]],
#  [['misspelled', 1, 7]],
#  [['morphed', 5, 6]],
#  [['misspelled', 5, 6]],
#  [['morphed', 4, 5]],
#  [['misspelled', 19, 21]],
#  [['misspelled', 1, 2]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 11, 13]],
#  [['morphed', 7, 8]],
#  [['morphed', 6, 8]],
#  [['misspelled', 8, 10]],
#  [['morphed', 5, 7]],
#  [['misspelled', 5, 7]],
#  [['misspelled', 1, 2], ['misspelled', 3, 5]],
#  [['misspelled', 7, 8]],
#  [['morphed', 2, 3]],
#  [['misspelled', 6, 9]],
#  [['misspelled', 1, 3]],
#  [['morphed', 2, 3], ['misspelled', 4, 5]],
#  [['misspelled', 7, 10]],
#  [['misspelled', 3, 4]],
#  [['misspelled', 2, 4]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 1, 3]],
#  [['misspelled', 4, 6]],
#  [['misspelled', 2, 3], ['morphed', 6, 7]],
#  [['morphed', 1, 2], ['morphed', 10, 11], ['morphed', 14, 15]],
#  [['misspelled', 4, 5]],
#  [['misspelled', 7, 9], ['misspelled', 10, 12], ['misspelled', 14, 15]],
#  [['misspelled', 8, 9]],
#  [['misspelled', 15, 16], ['morphed', 17, 18]],
#  ...]

# %%
def predict(text):
    with torch.no_grad():
        input_ids = tokenizer_mt5.encode(text, return_tensors="pt", add_special_tokens=True)

        input_ids = input_ids.cuda()

        # print(input_ids)
        mt5_model.cuda()
        generated_ids = mt5_model.generate(
            input_ids=input_ids,
            num_beams=3,
            max_length=10000,
            repetition_penalty=2.5,
            length_penalty=1.0,
            early_stopping=True,
            top_p=50,
            top_k=20,
            num_return_sequences=1,
        )

        # print(generated_ids)

        preds = [
            tokenizer_mt5.decode(
                g,
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
            for g in generated_ids
        ]
    return preds

# %%
def ids_to_tokens(tokenized_text):
  a = tokenizer_mt5.convert_ids_to_tokens(tokenized_text)
  return a

# %%
msp_type_dict = {}
msp_type_dict_full = {}
msp_type_dict_fill = {}
sent_id_type = {}
msp_word_dict = {}
msp_word_dict_full = {}
msp_word_dict_fill = {}

NUM_SAMPLE = 5000
len_msp_type = len(msp_type)
# for i in range(len_msp_type):
for i in range(NUM_SAMPLE):
  len_a = len(msp_type[i])
  for j in range(len_a):
    k = msp_type[i][j][0]
    if not k in msp_type_dict:
      msp_type_dict[k] = 1
      msp_type_dict_full[k] = 0
      msp_type_dict_fill[k] = 0
      sent_id_type[k] = []
    else:
      msp_type_dict[k] += 1
    
    len_b = len(msp_word[i][j])
    for k in range(len_b):
      x = msp_word[i][j][k]
      if not x in msp_word_dict:
        msp_word_dict[x] = 1
        msp_word_dict_full[x] = 0
        msp_word_dict_fill[x] = 0
      else:
        msp_word_dict[x] += 1

msp_word_dict_wrong = msp_word_dict_fill.copy()
print(msp_type_dict)
print(msp_type_dict_fill)
print(msp_type_dict_full)
msp_word_dict = dict(sorted(msp_word_dict.items(), key=lambda item: item[1], reverse=True))
print(msp_word_dict)
print(msp_word_dict_fill)
print(msp_word_dict_full)
# Out:
# {'morphed': 1818, 'misspelled': 4509, 'ws': 36, 'other': 38, 'abbreviation': 190, 'new': 1}
# {'morphed': 0, 'misspelled': 0, 'ws': 0, 'other': 0, 'abbreviation': 0, 'new': 0}
# {'morphed': 0, 'misspelled': 0, 'ws': 0, 'other': 0, 'abbreviation': 0, 'new': 0}
# {('อ่ะ', 'อะ'): 626, ('ค่ะ', 'คะ'): 487, ('คับ', 'ครับ'): 466, ('คะ', 'ค่ะ'): 345, ('เบอ', 'เบอร์'): 315, ('มั้ย', 'ไหม'): 205, ('สมัค', 'สมัคร'): 186, ('แอพ', 'แอป'): 170, ('เปน', 'เป็น'): 153, ('ค้ะ', 'คะ'): 148, ('ค้ะ', 'ค่ะ'): 146, ('อ่อ', 'อ๋อ'): 143, ('ยังไง', 'อย่างไร'): 136, ('ก้', 'ก็'): 135, ('ใด้', 'ได้'): 106, ('คัฟ', 'ครับ'): 90, ('มั๊ย', 'ไ
อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0, ('ลิ้ง', 'ลิงค์'): 0, ('คพ', 'คะ'): 0, ('ไร', 'อะไร'): 0, ('ครัช', 'ครับ'): 0, ('เปิดบันชี', 'เปิดบัญชี'): 0, ('คร้าาา', 'ค่ะ'): 0, ('เด๋วนี้', 'เดี๋ยวนี้'): 0, ('เห้อ', 'เฮ้อ'): 0, ('ไหม่', 'ไหม'): 0, ('เปนไร', 'เป็นไร'): 0, ('ให', 'ให้'): 0, ('เบย', 'เลย'): 0, ('เน้ต', 'อินเทอร์เน็ต'): 0, ('พนง', 'พนักงาน'): 0, ('เท่าไหร่', 'เท่าไร'): 0, ('ที', 'ที่'): 0, ('ยังงัย', 'อย่างไร'): 0, ('ร้องได้อ้ะ', 'ร้องได้อะ'): 0, ('เช็ค', 'เช็ก'): 0, ('ค๊ะ', 'คะ'): 0, ('ต่ะ', 'คะ'): 0, ('คระบ', 'ครับ'): 0, ('ไช่', 'ใช่'): 0, ('อิก', 'อีก'): 0, ('คุน', 'คุณ'): 0, ('คนับ', 'ครับ'): 0, ('มี', 'มี'): 0, ('ค', 'ค'): 0, ('เวป', 'เว็บไซต์'): 0, ('ดิ', 'สิ'): 0, ('k', 'k plus'): 0, ('plusอ่ะคับ', 'อะครับ'): 0, ('มะ', 'ไม่'): 0, ('เนี่ยยย', 'เนี่ย'): 0, ('กับ', 'กัน'): 0, ('ลิ้งค์', 'ลิงค์'): 0, ('หน่ะ', 'น่ะ'): 0, ('ฮาาา', 'ฮา'): 0, ('จร้า', 'จ้ะ'): 0, ('โดนจัย', 'โดนใจ'): 0, ('โท', 'โทร'): 0, ('คีับ', 'ครับ'): 0, ('คอม', 'คอมพิวเตอร์'): 0, ('น้ะ', 'นะ'): 0, ('ใช่', 'ใช้'): 0, ('เปี่ยน', 'เปลี่ยน'): 0, ('แอพ', 'application'): 0, ('แบงค์', 'แบงก์'): 0, ('ไม่', 'ไหม'): 0, ('ทา', 'มา'): 0, ('สาธุ จร้า', 'สาธุ จ้า'): 0, ('รึยัง', 'หรือยัง'): 0, ('พึ่ง', 'เพิ่ง'): 0, ('กะตัง', 'สตางค์'): 0, ('มัย', 'ไหม'): 0, ('ยัตร', 'บัตร'): 0, ('หรือป่าว', 'หรือเปล่า'): 0,  ...

# %%
total_gs_ori = 0
total_gs_pred = 0
total_cer_ori = 0
total_cer_pred = 0

for sent_id in tqdm(range(NUM_SAMPLE)):
  chng = []
  text = ds_tag.iloc[sent_id]['text']['input_ids'].squeeze(0).tolist()
  mask = ds_mlm.iloc[sent_id]['attention_mask']
  labels = test_df.iloc[sent_id]['target_text']
  text = [k for k in text if k != 1]
  mask = [k for k in mask if k != 0]
  labels = tokenizer_mt5(labels)['input_ids']
  # print(text)
  # print(labels)
  # print(mask)
  original = "".join(tokenizer_tag.convert_ids_to_tokens(text))
  original = original.replace("<s>", "")
  original = original.replace("</s>", "")
  original = tokenizer_mt5(original)['input_ids']
  original_id = original.copy()
  original = [ids_to_tokens(original)]
  references = [[ids_to_tokens(labels)]]
  moi = ''.join(original[0])
  moi = moi.replace("▁", " ")
  # print(f"TEXT: {moi}")
  

  i_f = evaluate_one_text(tagging_model, text, mask)
  predicted_tokens = tokenizer_tag.convert_ids_to_tokens(text.copy())

  original_tokens = predicted_tokens.copy()

  i_f_len = len(i_f)
  for j in range(i_f_len):
    if(i_f[j] == 'i'):
      ph = predicted_tokens[j+1]

      predicted_tokens[j+1] = "<mask>"
      # concat_input = "".join(tokenizer_tag.convert_ids_to_tokens(predicted_id))
      concat_input = "".join(predicted_tokens)
      concat_input = concat_input.replace("<s>", "")
      concat_input = concat_input.replace("</s>", "")
      concat_input = concat_input.replace("▁", " ")
      concat_input = concat_input.strip()
      mt5_input = "แก้คำผิด: " + concat_input
      # print(f"INPUT: {concat_input}")
      
      predicted = predict(mt5_input)[0]
      # print(f"PRED: {predicted}")

      # find mask
      a = concat_input
      b = predicted
      while len(a)>0 and len(b)>0 and a[0] == b[0]:
        a = a[1:]
        b = b[1:]
      while len(a)>0 and len(b)>0 and a[-1] == b[-1]:
        a = a[:-1]
        b = b[:-1]
      # print(f"{a} = {b}")
      # a = tokenizer_mt5(predicted)
      # print(f"INPUTID: {input_mt5}")
      # print(tokenizer_mt5.convert_ids_to_tokens(input_mt5))
      # print(f"PRED ID: {a['input_ids'][0]}")
      # b = tokenizer_mt5.convert_ids_to_tokens(a['input_ids'][0])
      # print(b)
      # print(f"LEN ORI: {len(input_mt5)}, LEN PRED: {len(b)}")

      # token_logits = mlm_model(**mlm_input).logits
      # mask_token_index = torch.where(mlm_input["input_ids"] == tokenizer.mask_token_id)[1]
      # mask_token_logits = token_logits[0, mask_token_index, :]
      # top_5_tokens = torch.topk(mask_token_logits, 3, dim=1).indices[0].tolist()
      # # print(f"{tokenizer.convert_ids_to_tokens(ph)} ({ph}) => {tokenizer.convert_ids_to_tokens(top_5_tokens[0])} ({top_5_tokens[0]})")
      chng.append((j, b))
      predicted_tokens[j+1] = ph
      if (ph, b) in msp_word_dict_fill:
        msp_word_dict_fill[(ph, b)] += 1
        # print(f"({ph},{b})")

  for x,y in chng:
    predicted_tokens[x+1] = y

  labels_len = len(labels)  

  predicted_tokens = [k for k in predicted_tokens if k != "<s>"]
  predicted_tokens = [k for k in predicted_tokens if k != "</s>"]
  ans = tokenizer_mt5("".join(predicted_tokens))['input_ids']
  predicted_id = ans.copy()
  ans = tokenizer_mt5.convert_ids_to_tokens(ans)
  # if "<s>" in ans:
  #   ans.remove('<s>')
  # if "</s>" in ans:
  #   ans.remove('</s>')
  # if ans[0] == '▁':
  #   ans.pop(0)
  predictions = [ans]  
  ans = ''.join(ans)
  ans = ans.replace("▁", " ")

  references[0][0] = [k.replace("▁", " ") for k in references[0][0]]
  original[0] = [k.replace("▁", " ") for k in original[0]]
  predictions[0] = [k.replace("▁", " ") for k in predictions[0]]

  # print(f"REF: {references}")
  # print(f"PRE: {predictions}")
  # print(f"ORI: {original}")
  gleu_score = sentence_gleu(references[0], predictions[0], min_len=1, max_len=4)
  total_gs_pred += gleu_score
  gleu_score_original = sentence_gleu(references[0], original[0], min_len=1, max_len=4)
  total_gs_ori += gleu_score_original

  cer_text_ori = "".join(original[0])
  cer_text_pred = "".join(predictions[0])
  cer_text_ref = "".join(references[0][0])
  cer_text_ori = cer_text_ori.replace("_", "")
  cer_text_ori = cer_text_ori.replace("▁", "")
  cer_text_pred = cer_text_pred.replace("_", "")
  cer_text_pred = cer_text_pred.replace("▁", "")
  cer_text_ref = cer_text_ref.replace("_", "")
  cer_text_ref = cer_text_ref.replace("▁", "")
  # print(f"ORI: {cer_text_ori}")
  # print(f"PRED: {cer_text_pred}")
  # print(f"REF: {cer_text_ref}")
  cer_original = cer(cer_text_ori, cer_text_ref)
  total_cer_ori += cer_original
  cer_pred = cer(cer_text_pred, cer_text_ref)
  total_cer_pred += cer_pred

  # print(f"MSP TYPE: {msp_type[sent_id]}")
  # for i in msp_type[sent_id]:
  #   msp_type_dict_full[i[0]] += 1
  #   flag = 0
  #   a = []
  #   for j in range(i[1]+1, i[2]+1):
  #     a.append((original_id[j], predicted_id[j]))
  #     # print(tokenizer.convert_ids_to_tokens(predicted_id[j]), tokenizer.convert_ids_to_tokens(labels[j]))
  #     if predicted_id[j] != labels[j]:
  #       flag = 1
  #       break
  #   if flag == 0:
  #     msp_type_dict_fill[i[0]] += 1
  #     if sent_id not in sent_id_type[i[0]]: #it may look too little because it only takes full marks
  #       sent_id_type[i[0]].append([sent_id, a])

  # print(f"PREDICTE ID: {predicted_id}")
  # print(f"ORIGINAL ID: {original_id}")
  # print(f"LABELS   ID: {labels}")
  # print(f"PRED: {len(predicted_id)}, ORI: {len(original_id)}, LABEL: {len(labels)}")
  # for i in range(labels_len):
  #   if labels[i] != original_id[i]: #change
  #     word_original = tokenizer_mt5.convert_ids_to_tokens(original_id[i])
  #     word_original = word_original.replace("▁", "")
  #     word_predicted = tokenizer_mt5.convert_ids_to_tokens(predicted_id[i])
  #     word_predicted = word_predicted.replace("▁", "")
  #     word_labels = tokenizer_mt5.convert_ids_to_tokens(labels[i])
  #     word_labels = word_labels.replace("▁", "")
  #     # if (word_original, word_predicted) in msp_word_dict_fill: #have key
  #     if (word_original, word_labels) in msp_word_dict_fill: #have key
  #       # msp_word_dict_full[(word_original, word_predicted)] += 1
  #       msp_word_dict_full[(word_original, word_labels)] += 1
  #       if labels[i] == predicted_id[i]: #correct
  #         # msp_word_dict_fill[(word_original, word_predicted)] += 1
  #         msp_word_dict_fill[(word_original, word_labels)] += 1
  #       elif labels[i] != predicted_id[i]: #incorrect
  #         # msp_word_dict_wrong[(word_original, word_predicted)] += 1
  #         msp_word_dict_wrong[(word_original, word_labels)] += 1

 


  # print(f"GLUE PREDICTED: {gleu_score}")
  # print(f"GLUE ORIGINAL: {gleu_score_original}")
  # print(f"CER PREDICTED: {cer_pred}")
  # print(f"CER ORIGINAL: {cer_original}")
  # print("--------------------------------------------")
# print(f"AVG ACC: {float(totalacc/NUM_SAMPLE)}")
# print(f"AVG f1: {float(total_f1/NUM_SAMPLE)}")
# print(f"# HIGHER BLEU PREDICTION: {bleu_higher}")
# print(f"# LOWER BLEU PREDICTION: {bleu_lower}")
# print(f"# EQUAL BLEU PREDICTION: {bleu_equal}")
print(f"# GLEU PREDICTION: {float(total_gs_pred/NUM_SAMPLE)}")
print(f"# GLEU ORIGINAL: {float(total_gs_ori/NUM_SAMPLE)}")
print(f"# CER PREDICTION: {float(total_cer_pred/NUM_SAMPLE)}")
print(f"# CER ORIGINAL: {float(total_cer_ori/NUM_SAMPLE)}")
# print(msp_type_dict_full)
# print(msp_type_dict_fill)
# msp_word_dict_full = dict(sorted(msp_word_dict_full.items(), key=lambda item: item[1], reverse=True))
msp_word_dict_fill = dict(sorted(msp_word_dict_fill.items(), key=lambda item: item[1], reverse=True))
# msp_word_dict_wrong = dict(sorted(msp_word_dict_wrong.items(), key=lambda item: item[1], reverse=True))
# print(msp_word_dict_full)
print(msp_word_dict)
print(msp_word_dict_fill)
# print(msp_word_dict_wrong)
# print(sent_id_type)
# Out:
# 100%|██████████| 5000/5000 [1:47:35<00:00,  1.29s/it]
# # GLEU PREDICTION: 0.6518720137207179
# # GLEU ORIGINAL: 0.5054915367683877
# # CER PREDICTION: 0.16382701521622978
# # CER ORIGINAL: 0.09989535645117614
# {('อ่ะ', 'อะ'): 626, ('ค่ะ', 'คะ'): 487, ('คับ', 'ครับ'): 466, ('คะ', 'ค่ะ'): 345, ('เบอ', 'เบอร์'): 315, ('มั้ย', 'ไหม'): 205, ('สมัค', 'สมัคร'): 186, ('แอพ', 'แอป'): 170, ('เปน', 'เป็น'): 153, ('ค้ะ', 'คะ'): 148, ('ค้ะ', 'ค่ะ'): 146, ('อ่อ', 'อ๋อ'): 143, ('ยังไง', 'อย่างไร'): 136, ('ก้', 'ก็'): 135, ('ใด้', 'ได้'): 106, ('คัฟ', 'ครับ'): 90, ('มั๊ย', 'ไหม'): 88, ('เรย', 'เลย'): 70, ('โทรศัพ', 'โทรศัพท์'): 70, ('ใหม', 'ไหม'): 68, ('ไง', 'อย่างไร'): 67, ('ไม', 'ไหม'): 67, ('เคดิต', 'เครดิต'): 62, ('บช', 'บัญชี'): 56, ('แอฟ', 'แอป'): 55, ('ตัง', 'สตางค์'): 55, ('ม่', 'ไม่'): 55, ('อยุ่', 'อยู่'): 53, ('บันชี', 'บัญชี'): 53, ('ไหม่', 'ใหม่'): 51, ('อ้ะ', 'อะ'): 49, ('รุ้', 'รู้'): 48, ('ก้อ', 'ก็'): 48, ('แร้ว', 'แล้ว'): 46, ('ใหน', 'ไหน'): 43, ('หรอ', 'หรือ'): 41, ('ตุ้', 'ตู้'): 40, ('ขอบคุน', 'ขอบคุณ'): 40, ('เบอร', 'เบอร์'): 37, ('หรอ',
อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0, ('ลิ้ง', 'ลิงค์'): 0, ('คพ', 'คะ'): 0, ('เปิดบันชี', 'เปิดบัญชี'): 0, ('คร้าาา', 'ค่ะ'): 0, ('เด๋วนี้', 'เดี๋ยวนี้'): 0, ('เห้อ', 'เฮ้อ'): 0, ('ไหม่', 'ไหม'): 0, ('เปนไร', 'เป็นไร'): 0, ('ให', 'ให้'): 0, ('เบย', 'เลย'): 0,  ...

# %%
total_gs_ori = 0
total_gs_pred = 0
total_cer_ori = 0
total_cer_pred = 0

for sent_id in tqdm(range(NUM_SAMPLE)):
  # print(sent_id)
  if sent_id == 658: continue
  chng = []
  text = ds_tag.iloc[sent_id]['text']['input_ids'].squeeze(0).tolist()
  mask = ds_mlm.iloc[sent_id]['attention_mask']
  labels = test_df.iloc[sent_id]['target_text']
  text = [k for k in text if k != 1]
  mask = [k for k in mask if k != 0]
  labels = tokenizer_mt5(labels)['input_ids']
  # print(text)
  # print(labels)
  # print(mask)
  original = "".join(tokenizer_tag.convert_ids_to_tokens(text))
  original = original.replace("<s>", "")
  original = original.replace("</s>", "")
  original = tokenizer_mt5(original)['input_ids']
  original_id = original.copy()
  original = [ids_to_tokens(original)]
  references = [[ids_to_tokens(labels)]]
  moi = ''.join(original[0])
  moi = moi.replace("▁", " ")
  # print(f"TEXT: {moi}")
  

  i_f = evaluate_one_text(tagging_model, text, mask)
  predicted_tokens = tokenizer_tag.convert_ids_to_tokens(text.copy())

  original_tokens = predicted_tokens.copy()

  i_f_len = len(i_f)
  for j in range(i_f_len):
    if(i_f[j] == 'i'):
      ph = predicted_tokens[j+1]

      predicted_tokens[j+1] = "<mask>"
      # concat_input = "".join(tokenizer_tag.convert_ids_to_tokens(predicted_id))
      concat_input = "".join(predicted_tokens)
      concat_input = concat_input.replace("<s>", "")
      concat_input = concat_input.replace("</s>", "")
      concat_input = concat_input.replace("▁", " ")
      concat_input = concat_input.strip()
      mt5_input = "แก้คำผิด: " + concat_input
      # print(f"INPUT: {concat_input}")
      
      predicted = predict(mt5_input)[0]
      # print(f"PRED: {predicted}")

      # find mask
      a = concat_input
      b = predicted
      while len(a)>0 and len(b)>0 and a[0] == b[0]:
        a = a[1:]
        b = b[1:]
      while len(a)>0 and len(b)>0 and a[-1] == b[-1]:
        a = a[:-1]
        b = b[:-1]
      # print(f"{a} = {b}")
      # a = tokenizer_mt5(predicted)
      # print(f"INPUTID: {input_mt5}")
      # print(tokenizer_mt5.convert_ids_to_tokens(input_mt5))
      # print(f"PRED ID: {a['input_ids'][0]}")
      # b = tokenizer_mt5.convert_ids_to_tokens(a['input_ids'][0])
      # print(b)
      # print(f"LEN ORI: {len(input_mt5)}, LEN PRED: {len(b)}")

      # token_logits = mlm_model(**mlm_input).logits
      # mask_token_index = torch.where(mlm_input["input_ids"] == tokenizer.mask_token_id)[1]
      # mask_token_logits = token_logits[0, mask_token_index, :]
      # top_5_tokens = torch.topk(mask_token_logits, 3, dim=1).indices[0].tolist()
      # # print(f"{tokenizer.convert_ids_to_tokens(ph)} ({ph}) => {tokenizer.convert_ids_to_tokens(top_5_tokens[0])} ({top_5_tokens[0]})")
      chng.append((j, b))
      predicted_tokens[j+1] = ph
      if (ph, b) in msp_word_dict_fill:
        msp_word_dict_fill[(ph, b)] += 1
        # print(f"({ph},{b})")

  for x,y in chng:
    predicted_tokens[x+1] = y

  labels_len = len(labels)  

  predicted_tokens = [k for k in predicted_tokens if k != "<s>"]
  predicted_tokens = [k for k in predicted_tokens if k != "</s>"]
  ans = tokenizer_mt5("".join(predicted_tokens))['input_ids']
  predicted_id = ans.copy()
  ans = tokenizer_mt5.convert_ids_to_tokens(ans)
  # if "<s>" in ans:
  #   ans.remove('<s>')
  # if "</s>" in ans:
  #   ans.remove('</s>')
  # if ans[0] == '▁':
  #   ans.pop(0)
  predictions = [ans]  
  ans = ''.join(ans)
  ans = ans.replace("▁", " ")

  references[0][0] = [k.replace("▁", " ") for k in references[0][0]]
  original[0] = [k.replace("▁", " ") for k in original[0]]
  predictions[0] = [k.replace("▁", " ") for k in predictions[0]]

  # print(f"REF: {references}")
  # print(f"PRE: {predictions}")
  # print(f"ORI: {original}")
  gleu_score = sentence_gleu(references[0], predictions[0], min_len=1, max_len=4)
  total_gs_pred += gleu_score
  gleu_score_original = sentence_gleu(references[0], original[0], min_len=1, max_len=4)
  total_gs_ori += gleu_score_original

  cer_text_ori = "".join(original[0])
  cer_text_pred = "".join(predictions[0])
  cer_text_ref = "".join(references[0][0])
  cer_text_ori = cer_text_ori.replace("_", "")
  cer_text_ori = cer_text_ori.replace("▁", "")
  cer_text_pred = cer_text_pred.replace("_", "")
  cer_text_pred = cer_text_pred.replace("▁", "")
  cer_text_ref = cer_text_ref.replace("_", "")
  cer_text_ref = cer_text_ref.replace("▁", "")
  # print(f"ORI: {cer_text_ori}")
  # print(f"PRED: {cer_text_pred}")
  # print(f"REF: {cer_text_ref}")
  cer_original = cer(cer_text_ori, cer_text_ref)
  total_cer_ori += cer_original
  cer_pred = cer(cer_text_pred, cer_text_ref)
  total_cer_pred += cer_pred

  # print(f"MSP TYPE: {msp_type[sent_id]}")
  # for i in msp_type[sent_id]:
  #   msp_type_dict_full[i[0]] += 1
  #   flag = 0
  #   a = []
  #   for j in range(i[1]+1, i[2]+1):
  #     a.append((original_id[j], predicted_id[j]))
  #     # print(tokenizer.convert_ids_to_tokens(predicted_id[j]), tokenizer.convert_ids_to_tokens(labels[j]))
  #     if predicted_id[j] != labels[j]:
  #       flag = 1
  #       break
  #   if flag == 0:
  #     msp_type_dict_fill[i[0]] += 1
  #     if sent_id not in sent_id_type[i[0]]: #it may look too little because it only takes full marks
  #       sent_id_type[i[0]].append([sent_id, a])

  # print(f"PREDICTE ID: {predicted_id}")
  # print(f"ORIGINAL ID: {original_id}")
  # print(f"LABELS   ID: {labels}")
  # print(f"PRED: {len(predicted_id)}, ORI: {len(original_id)}, LABEL: {len(labels)}")
  # for i in range(labels_len):
  #   if labels[i] != original_id[i]: #change
  #     word_original = tokenizer_mt5.convert_ids_to_tokens(original_id[i])
  #     word_original = word_original.replace("▁", "")
  #     word_predicted = tokenizer_mt5.convert_ids_to_tokens(predicted_id[i])
  #     word_predicted = word_predicted.replace("▁", "")
  #     word_labels = tokenizer_mt5.convert_ids_to_tokens(labels[i])
  #     word_labels = word_labels.replace("▁", "")
  #     # if (word_original, word_predicted) in msp_word_dict_fill: #have key
  #     if (word_original, word_labels) in msp_word_dict_fill: #have key
  #       # msp_word_dict_full[(word_original, word_predicted)] += 1
  #       msp_word_dict_full[(word_original, word_labels)] += 1
  #       if labels[i] == predicted_id[i]: #correct
  #         # msp_word_dict_fill[(word_original, word_predicted)] += 1
  #         msp_word_dict_fill[(word_original, word_labels)] += 1
  #       elif labels[i] != predicted_id[i]: #incorrect
  #         # msp_word_dict_wrong[(word_original, word_predicted)] += 1
  #         msp_word_dict_wrong[(word_original, word_labels)] += 1

 


  # print(f"GLUE PREDICTED: {gleu_score}")
  # print(f"GLUE ORIGINAL: {gleu_score_original}")
  # print(f"CER PREDICTED: {cer_pred}")
  # print(f"CER ORIGINAL: {cer_original}")
  # print("--------------------------------------------")
# print(f"AVG ACC: {float(totalacc/NUM_SAMPLE)}")
# print(f"AVG f1: {float(total_f1/NUM_SAMPLE)}")
# print(f"# HIGHER BLEU PREDICTION: {bleu_higher}")
# print(f"# LOWER BLEU PREDICTION: {bleu_lower}")
# print(f"# EQUAL BLEU PREDICTION: {bleu_equal}")
print(f"# GLEU PREDICTION: {float(total_gs_pred/NUM_SAMPLE)}")
print(f"# GLEU ORIGINAL: {float(total_gs_ori/NUM_SAMPLE)}")
print(f"# CER PREDICTION: {float(total_cer_pred/NUM_SAMPLE)}")
print(f"# CER ORIGINAL: {float(total_cer_ori/NUM_SAMPLE)}")
# print(msp_type_dict_full)
# print(msp_type_dict_fill)
# msp_word_dict_full = dict(sorted(msp_word_dict_full.items(), key=lambda item: item[1], reverse=True))
msp_word_dict_fill = dict(sorted(msp_word_dict_fill.items(), key=lambda item: item[1], reverse=True))
# msp_word_dict_wrong = dict(sorted(msp_word_dict_wrong.items(), key=lambda item: item[1], reverse=True))
# print(msp_word_dict_full)
print(msp_word_dict)
print(msp_word_dict_fill)
# print(msp_word_dict_wrong)
# print(sent_id_type)
# Out:
# 100%|██████████| 5000/5000 [30:08<00:00,  2.76it/s]
# # GLEU PREDICTION: 0.6518720081547842
# # GLEU ORIGINAL: 0.5054426005981749
# # CER PREDICTION: 0.16362704025848862
# # CER ORIGINAL: 0.09980346455928424
# {('อ่ะ', 'อะ'): 626, ('ค่ะ', 'คะ'): 487, ('คับ', 'ครับ'): 466, ('คะ', 'ค่ะ'): 345, ('เบอ', 'เบอร์'): 315, ('มั้ย', 'ไหม'): 205, ('สมัค', 'สมัคร'): 186, ('แอพ', 'แอป'): 170, ('เปน', 'เป็น'): 153, ('ค้ะ', 'คะ'): 148, ('ค้ะ', 'ค่ะ
0, ('ป่ะ', 'เปล่า'): 0, ('ยังใง', 'ยังไง'): 0, ('แต', 'แต่'): 0, ('เบอยุแล้ว', 'เบอร์อยู่แล้ว'): 0, ('เตอ', 'เจอ'): 0, ('ล๊อก', 'ล็อก'): 0, ('หรัส', 'รหัส'): 0, ('เคาเตอร์', 'เคาน์เตอร์'): 0, ('สามรถ', 'สามารถ'): 0, ('คพ', 'ค่ะ'): 0, ('เนต', 'อินเทอร์เน็ต'): 0, ('ใม่', 'ไม่'): 0, ('สวัดดี', 'สวัสดี'): 0, ('เนาะ', 'นะ'): 0, ('ค่', 'คะ'): 0, ('รีไฟแนน', 'รีไฟแนนซ์'): 0, ('ใว้', 'ไว้'): 0, ('โทรศัพย์', 'โทรศัพท์'): 0, ('เคดิต', 'เครดิต'): 0, ('อะ', 'อ่ะ'): 0, ('วีธี', 'วิธี'): 0, ('ข้อมุล', 'ข้อมูล'): 0, ('เปลียน', 'เปลี่ยน'): 0, ('ใข่', 'ใช่'): 0, ('ไทยพานิชย์', 'ไทยพาณิชย์'): 0, ('เนี้ย', 'เนี่ย'): 0, ('โทรสัพ', 'โทรศัพท์'): 0, ('ค่าาาาาาา', 'ค่ะ'): 0, ('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0, ('ลิ้ง', 'ลิงค์'): 0, ('คพ', 'คะ'): 0, ('เปิดบันชี', 'เปิดบัญชี'): 0, ('คร้าาา', 'ค่ะ'): 0, ('เด๋วนี้', 'เดี๋ยวนี้'): 0, ('เห้อ', 'เฮ้อ'): 0, ('ไหม่', 'ไหม'): 0, ('เปนไร', 'เป็นไร'): 0, ('ให', 'ให้'): 0, ('เบย', 'เลย'): 0,  ...

# %%
tokenizer_mt5.convert_tokens_to_ids(["<mask>", '$'])
# tokenizer_mt5.convert_ids_to_tokens([259, 26461, 25301])
# references = [[1,2,3]]
# predictions = [1,2,3]
# print(sentence_gleu(references, predictions, min_len=1, max_len=4))

# print(cer("0123", "123"))
# Out:
# [2, 1279]

# %%
pickle_model_json = {}
pickle_model_json['msp_type_dict_full'] = msp_type_dict_full
pickle_model_json['msp_type_dict_fill'] = msp_type_dict_fill
pickle_model_json['msp_word_dict_full'] = msp_word_dict_full
pickle_model_json['msp_word_dict_fill'] = msp_word_dict_fill
pickle_model_json['msp_word_dict_wrong'] = msp_word_dict_wrong
pickle_model_json['sent_id_type'] = sent_id_type

pickle.dump(pickle_model_json, open('pickle_model_json_mt5.pkl', 'wb'))

# %%
pickle_model_json['msp_type_dict_full']
# Out:
# {'abbreviation': 190,
#  'misspelled': 4509,
#  'morphed': 1818,
#  'new': 1,
#  'other': 38,
#  'ws': 36}

# %%
for key in sent_id_type:
  print(f"=========[{key}]==========")
  for sent_id, words in sent_id_type[key]:
    text = ds_tag.iloc[sent_id]['text']['input_ids'].squeeze(0).tolist()
    labels = ds_mlm.iloc[sent_id]['labels']
    text = [k for k in text if k != 1]
    labels = [k for k in labels if k != 1]
    original = [ids_to_tokens(text)]
    references = [[ids_to_tokens(labels)]]
    for i in words:
      print(f"MSP: {tokenizer.convert_ids_to_tokens(i[0])} => {tokenizer.convert_ids_to_tokens(i[1])}")
    print(original)
    print(references)
    print("-------------------")
# Out:
# Streaming output truncated to the last 5000 lines.
# MSP: เปน => เป็น
# [['<s>', '▁ถ้า', 'เปน', 'แบบนี้', 'ทําไงดี', 'คะ', '</s>']]
# [[['<s>', '▁ถ้า', 'เป็น', 'แบบนี้', 'ทําไงดี', 'คะ', '</s>']]]
# -------------------
# MSP: เบอ => เบอร์
# [['<s>', '▁', 'เปลี่ยน', 'เบอ', 'ตรงไหน', 'หรอ', 'คะ', '▁', 'หาไม่เจอ', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'เบอร์', 'ตรงไหน', 'เหรอ', 'คะ', '▁', 'หาไม่เจอ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁พี่', 'ค่ะ', '.', '</s>']]
# [[['<s>', '▁พี่', 'คะ', '.', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁', 'เปลี่ยน', 'มือถือ', 'ละ', 'เข้า', 'แอพ', 'scb', 'ไม่ได้', '▁', 'เครียด', 'เด้อ', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'มือถือ', 'ละ', 'เข้า', 'แอป', 'scb', 'ไม่ได้', '▁', 'เครียด', 'เด้อ', '</s>']]]
# -------------------
# MSP: คะ => ค่ะ
# [['<s>', '▁', 'อยากสอบถาม', 'เรื่อง', 'โอน', 'ตัง', 'เข้า', 'พร้อมเพย์', '▁', 'คะ', '</s>']]
# [[['<s>', '▁', 'อยากสอบถาม', 'เรื่อง', 'โอน', 'สตางค์', 'เข้า', 'พร้อมเพย์', '▁', 'ค่ะ', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁ยัง', 'สามารถทํา', 'ผ่าน', 'แอพ', 'ได้', 'มั้ย', '</s>']]
# [[['<s>', '▁ยัง', 'สามารถทํา', 'ผ่าน', 'แอป', 'ได้', 'ไหม', '</s>']]]
# -------------------
# MSP: รุ้ => ▁รู้
# [['<s>', '▁', 'ไร', 'ไม่', 'รุ้', '</s>']]
# [[['<s>', '▁', 'อะไร', 'ไม่', '▁รู้', '</s>']]]
# -------------------
# MSP: เบอ => เบอร์
# [['<s>', '▁', 'เปลี่ยน', 'เบอ', 'มือถือ', '.', '▁', 'ต้องใช้', 'เอกสาร', 'รัย', 'บ้างค่ะ', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'เบอร์', 'มือถือ', '.', '▁', 'ต้องใช้', 'เอกสาร', 'รัย', 'บ้างค่ะ', '</s>']]]
# -------------------
# MSP: อ้ะ => อะ
# MSP: ค้ะ => ค่ะ
# [['<s>', '▁', 'ตัวเอง', 'โดน', 'โกง', 'อ้ะ', 'ค้ะ', '</s>']]
# [[['<s>', '▁', 'ตัวเอง', 'โดน', 'โกง', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: เชค => เช็ก
# [['<s>', '▁', 'เชค', 'ได้ไหมคะ', '</s>']]
# [[['<s>', '▁', 'เช็ก', 'ได้ไหมคะ', '</s>']]]
# -------------------
# MSP: ม่ => ▁ไม่
# [['<s>', '▁', 'เช็ค', 'ตอนนี้', 'ม่', 'เข้า', '</s>']]
# [[['<s>', '▁', 'เช็ค', 'ตอนนี้', '▁ไม่', 'เข้า', '</s>']]]
# -------------------
# MSP: รุ้ => ▁รู้
# [['<s>', '▁บอก', '▁', 'กรอก', 'ข้อมูล', 'ไม่ถูกต้อง', 'ค่ะ', '▁ไม่', 'รุ้', 'ว่า', 'ช่อง', '▁', 'เบอร์โทรศัพท์', '▁', 'ผิด', '▁', 'หรือ', '▁', 'วงเงิน', '</s>']]
# [[['<s>', '▁บอก', '▁', 'กรอก', 'ข้อมูล', 'ไม่ถูกต้อง', 'ค่ะ', '▁ไม่', '▁รู้', 'ว่า', 'ช่อง', '▁', 'เบอร์โทรศัพท์', '▁', 'ผิด', '▁', 'หรือ', '▁', 'วงเงิน', '</s>']]]
# -------------------
# MSP: ใหน => ไหน
# [['<s>', '▁', 'บัตรเครดิต', '▁', 'กสิกรไทย', '▁มี', 'แบบ', 'ใหน', 'บ้างครับ', '</s>']]
# [[['<s>', '▁', 'บัตรเครดิต', '▁', 'กสิกรไทย', '▁มี', 'แบบ', 'ไหน', 'บ้างครับ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁', 'ต้องมี', 'บัญชี', 'k', 'bank', 'ด้วย', 'ใช่มั้ย', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'ต้องมี', 'บัญชี', 'k', 'bank', 'ด้วย', 'ใช่มั้ย', 'คะ', '</s>']]]
# -------------------
# MSP: ค้ะ => คะ
# [['<s>', '▁ถ้าเรา', 'โอนเงิน', 'ผิด', 'บัญชี', 'นี่', 'ทําอะไร', 'ได้บ้าง', 'ค้ะ', '</s>']]
# [[['<s>', '▁ถ้าเรา', 'โอนเงิน', 'ผิด', 'บัญชี', 'นี่', 'ทําอะไร', 'ได้บ้าง', 'คะ', '</s>']]]
# -------------------
# MSP: ก้ => ▁ก็
# MSP: เปน => เป็น
# [['<s>', '▁ลอง', 'ใหม่', 'ก้', 'เปน', 'แบบนี้', '</s>']]
# [[['<s>', '▁ลอง', 'ใหม่', '▁ก็', 'เป็น', 'แบบนี้', '</s>']]]
# -------------------
# MSP: ใด้ => ได้
# [['<s>', '▁', 'มีให้เลือก', 'ฝาก', 'ใด้', 'กี่', 'เดือน', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'มีให้เลือก', 'ฝาก', 'ได้', 'กี่', 'เดือน', 'คะ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁', 'มีให้เลือก', 'ฝาก', 'ใด้', 'กี่', 'เดือน', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'มีให้เลือก', 'ฝาก', 'ได้', 'กี่', 'เดือน', 'คะ', '</s>']]]
# -------------------
# MSP: ไช่ => ▁ใช่
# MSP: มั้ย => ไหม
# [['<s>', '▁', 'ไช่', 'มั้ย', 'ครับ', '</s>']]
# [[['<s>', '▁', '▁ใช่', 'ไหม', 'ครับ', '</s>']]]
# -------------------
# MSP: คะ => ค่ะ
# [['<s>', '▁', 'เบอร์', 'มือถือ', 'เรา', 'โทร', 'กลับ', 'ไทย', 'ไม่ได้', 'คะ', '</s>']]
# [[['<s>', '▁', 'เบอร์', 'มือถือ', 'เรา', 'โทร', 'กลับ', 'ไทย', 'ไม่ได้', 'ค่ะ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# MSP: คะ => ค่ะ
# [['<s>', '▁คือ', 'บอกว่า', 'รหัส', 'ไม่ถูกต้อง', 'อ่ะ', 'คะ', '</s>']]
# [[['<s>', '▁คือ', 'บอกว่า', 'รหัส', 'ไม่ถูกต้อง', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: เบอ => เบอร์
# [['<s>', '▁', 'เปลี่ยน', 'เครื่อง', 'อย่างเดียว', 'ค่ะ', '▁แต่', 'ใช้', 'เบอ', 'เดิม', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'เครื่อง', 'อย่างเดียว', 'ค่ะ', '▁แต่', 'ใช้', 'เบอร์', 'เดิม', '</s>']]]
# -------------------
# MSP: อ่อ => ▁อ๋อ
# [['<s>', '▁', 'อ่อ', '▁', 'คะ', '▁แล้วถ้า', 'สมัคร', 'บัตร', 'พรุ่งนี้', 'จะ', 'สามารถใช้', 'ได้ทันที', 'เลย', 'มั้ยคะ', '</s>']]
# [[['<s>', '▁', '▁อ๋อ
# -------------------
# MSP: ใหม => ไหม
# [['<s>', '▁', 'ตรวจสอบได้', 'ใหม', 'ครับ', '</s>']]
# [[['<s>', '▁', 'ตรวจสอบได้', 'ไหม', 'ครับ', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁', 'ต้องมี', 'บัญชี', 'ของ', 'ธ', '▁', 'กรุงไทย', '▁', 'ป่าว', 'คะ', 'ถึง', 'ใช้', 'แอพ', 'นี้ได้', '</s>']]
# [[['<s>', '▁', 'ต้องมี', 'บัญชี', 'ของ', 'แบงก์กิ้ง', '▁', 'กรุงไทย', '▁', '▁เปล่า', 'ค่ะ', 'ถึง', 'ใช้', 'แอป', 'นี้ได้', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁แล้ว', 'โหลด', 'แอพ', 'มาใหม่', '</s>']]
# [[['<s>', '▁แล้ว', 'โหลด', 'แอป', 'มาใหม่', '</s>']]]
# -------------------
# MSP: ม่ => ▁ไม่
# [['<s>', '▁', 'สมัคร', 'ม่', 'ได้', 'คัฟ', '</s>']]
# [[['<s>', '▁', 'สมัคร', '▁ไม่', 'ได้', 'ครับ', '</s>']]]
# -------------------
# MSP: ใด้ => ได้
# [['<s>', '▁หนู', 'โอนเงิน', 'ไม่', 'ใด้', '</s>']]
# [[['<s>', '▁หนู', 'โอนเงิน', 'ไม่', 'ได้', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁', 'เราไป', 'ของ', 'หมด', 'อ่ะ', '</s>']]
# [[['<s>', '▁', 'เราไป', 'ของ', 'หมด', 'อะ', '</s>']]]
# -------------------
# MSP: เปน => เป็น
# [['<s>', '▁', 'เปน', 'เครื่อง', 'ตัวเอง', 'ค่ะ', 'แต่', 'ก่อนหน้า', 'นี้', 'แฟน', 'เคย', 'เอาไปใช้', 'แล้ว', 'สมัคร', 'บัญชี', 'ของ', 'แฟน', 'ไว้', '▁แล้ว', 'พอจะ', 'สมัคร', 'ของตัวเอง', 'ก้', 'เปน', 'แบบนี้', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'เป็น', 'เครื่อง', 'ตัวเอง', 'ค่ะ', 'แต่', 'ก่อนหน้า', 'นี้', 'แฟน', 'เคย', 'เอาไปใช้', 'แล้ว', 'สมัคร', 'บัญชี', 'ของ', 'แฟน', 'ไว้', '▁แล้ว', 'พอจะ', 'สมัคร', 'ของตัวเอง', '▁ก็', 'เป็น', 'แบบนี้', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ก้ => ▁ก็
# MSP: เปน => เป็น
# [['<s>', '▁', 'เปน', 'เครื่อง', 'ตัวเอง', 'ค่ะ', 'แต่', 'ก่อนหน้า', 'นี้', 'แฟน', 'เคย', 'เอาไปใช้', 'แล้ว', 'สมัคร', 'บัญชี', 'ของ', 'แฟน', 'ไว้', '▁แล้ว', 'พอจะ', 'สมัคร', 'ของตัวเอง', 'ก้', 'เปน', 'แบบนี้', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 
'</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁', 'ยอด', 'จาก', 'ธนาคาร', '▁', 'กรุงไทย', '▁', 'เข้า', '▁', 'กสิกร', '▁', 'ยอดเงิน', 'ออกจาก', 'กรุงไทย', 'แล้ว', '▁แต่', 'ใน', 'กสิกร', 'ยอด', 'ยังไม่', 'ปรับ', 'เลย', 'อ่ะ', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'ยอด', 'จาก', 'ธนาคาร', '▁', 'กรุงไทย', '▁', 'เข้า', '▁', 'กสิกร', '▁', 'ยอดเงิน', 'ออกจาก', 'กรุงไทย', 'แล้ว', '▁แต่', 'ใน', 'กสิกร', 'ยอด', 'ยังไม่', 'ปรับ', 'เลย', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ค้ะ => ค่ะ
# [['<s>', '▁', 'ตู้', 'ไม่', 'คืน', 'บัตร', 'ค้ะ', '</s>']]
# [[['<s>', '▁', 'ตู้', 'ไม่', 'คืน', 'บัตร', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁', 'ลืม', 'ร', 'หั', ' ทําิ', '▁', 'ต้องทําไง', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'ลืม', 'ร', 'หั', ' ทําิ', '▁', 'ต้องทําไง', 'คะ', '</s>']]]
# -------------------
# MSP: อ่อ => ▁อ๋อ
# [['<s>', '▁', 'อ่อ', '▁ถ้า', 'ยังไม่มี', 'บัญชี', 'กองทุน', '</s>']]
# [[['<s>', '▁', '▁อ๋อ', '▁ถ้า', 'ยังไม่มี', 'บัญชี', 'กองทุน', '</s>']]]
# -------------------
# MSP: ก้ => ▁ก็
# [['<s>', '▁', 'โอนเงิน', 'ก้', 'ไม่ได้', '</s>']]
# [[['<s>', '▁', 'โอนเงิน', '▁ก็', 'ไม่ได้', '</s>']]]
# -------------------
# MSP: รุ้ => ▁รู้
# [['<s>', '▁', 'รุ้', 'ผล', 'ตอน', 'ใหน', 'ครับผม', 'ต้อง', 'ใช้เงิน', 'วันนี้', 'นะครับ', '</s>']]
# [[['<s>', '▁', '▁รู้', 'ผล', 'ตอน', 'ไหน', 'ครับผม', 'ต้อง', 'ใช้เงิน', 'วันนี้', 'นะครับ', '</s>']]]
# -------------------
# MSP: ใหน => ไหน
# [['<s>', '▁', 'รุ้', 'ผล', 'ตอน', 'ใหน', 'ครับผม', 'ต้อง', 'ใช้เงิน', 'วันนี้', 'นะครับ', '</s>']]
# [[['<s>', '▁', '▁รู้', 'ผล', 'ตอน', 'ไหน', 'ครับผม', 'ต้อง', 'ใช้เงิน', 'วันนี้', 'นะครับ', '</s>']]]
# -------------------
# MSP: ก้อ => ▁ก็
# [['<s>', '▁เดี๋ยว', 'ติดต่อ', 'ไป', 'ใหม่', 'ก้อ', 'ได้', 'ค', 'รั', 'ปะละ', '▁', '.', 'ขอบคุน', 'ครับ', '</s>']]
# [[['<s>', '▁เดี๋ยว', 'ติดต่อ', 'ไป', 'ใหม่', '▁ก็', 'ได้', 'ค', 'รั', 'ปะละ', '▁', '.', '▁ขอบคุณ', 'ครับ', '</s>']]]
# -------------------
# MSP: ขอบคุน => ▁ขอบคุณ
# [['<s>', '▁เดี๋ยว', 'ติดต่อ', 'ไป', 'ใหม่', 'ก้อ', 'ได้', 'ค', 'รั', 'ปะละ', '▁', '.', 'ขอบคุน', 'ครับ', '</s>']]
# [[['<s>', '▁เดี๋ยว', 'ติดต่อ', 'ไป', 'ใหม่', '▁ก็', 'ได้', 'ค', 'รั', 'ปะละ', '▁', '.', '▁ขอบคุณ', 'ครับ', '</s>']]]
# -------------------
# MSP: เปน => เป็น
# [['<s>', '▁', 'เปน', 'กระดาษ', 'ได้ไหมครับ', '</s>']]
# [[['<s>', '▁', 'เป็น', 'กระดาษ', 'ได้ไหมครับ', '</s>']]]
# -------------------
# MSP: ใหม => ไหม
# [['<s>', '▁', 'เลือก', 'ลาย', 'ได้', 'ใหม', '?', '</s>']]
# [[['<s>', '▁', 'เลือก', 'ลาย', 'ได้', 'ไหม', '?', '</s>']]]
# -------------------
# MSP: ค้ะ => คะ
# [['<s>', '▁แล้วถ้า', 'เป็นแบบ', 'ใส่', 'รูป', 'หรือ', 'เลือก', 'ลาย', 'ได้', 'นี่', 'กี่บาท', 'ค้ะ', '</s>']]
# [[['<s>', '▁แล้วถ้า', 'เป็นแบบ', 'ใส่', 'รูป', 'หรือ', 'เลือก', 'ลาย', 'ได้', 'นี่', 'กี่บาท', 'คะ', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁', 'จะเพิ่ม', 'บัตร', 'อะ งง', '▁', 'ลาย', 'วัน', 'พีช', 'ที่เพิ่ง', 'ทํามา', 'เข้า', 'ใน', 'แอพ', '▁', 'k plus', '▁', 'ยังไง', '</s>']]
# [[['<s>', '▁', 'จะเพิ่ม', 'บัตร', 'อะ งง', '▁', 'ลาย', 'วัน', 'พีช', 'ที่เพิ่ง', 'ทํามา', 'เข้า', 'ใน', 'แอป', '▁', 'k plus', '▁', 'ยังไง', '</s>']]]
# -------------------
# MSP: ใม่ => ▁ไม่
# MSP: ใด้ => ได้
# [['<s>', '▁ใช่', 'คะ', '▁ลอง', 'ทําตาม', 'นี้', 'แร้ว', 'แต่มัน', 'ใม่', 'ใด้', '</s>']]
# [[['<s>', '▁ใช่', 'คะ', '▁ลอง', 'ทําตาม', 'นี้', '▁แล้ว', 'แต่มัน', '▁ไม่', 'ได้', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁ซื้อ', 'โทร', 'ศ', 'ัพ', 'ย์', 'ต่อ', 'คนรู้จัก', 'มา', 'ครับ', '▁', 'แล้วเขาก็', 'สมัคร', 'แอพ', 'นี้', 'ไว้', 'เหมือนกัน', '▁ผมจะ', 'เปลี่ยน', 'เป็น', 'มากอะ', '▁ผม', '▁', 'กด', 'อันไหน', 'ครับ', '</s>']]
# [[['<s>', '▁ซื้อ', 'โทรศัพท์', '_', '_', '_', 'ต่อ', 'คนรู้จัก', 'มา', 'ครับ', '▁', 'แล้วเขาก็', 'สมัคร', 'แอป', 'นี้', 'ไว้', 'เหมือนกัน', '▁ผมจะ', 'เปลี่ยน', 'เป็น', 'มากอะ', '▁ผม', '▁', 'กด', 'อันไหน', 'ครับ', '</s>']]]
# -------------------
# MSP: เห้น => ▁เห็น
# [['<s>', '▁เพราะ', 'เห้น', 'ใน', 'กระทู้', 'ต่างๆ', 'บอกว่า', 'ให้ไป', 'ยกเลิก', 'ที่', 'ตู้', 'เดิม', '▁มัน', 'เกี่ยว', 'กัน', 'หรือป่าว', 'คับ', '▁', '</s>']]
# [[['<s>', '▁เพราะ', '▁เห็น', 'ใน', 'กระทู้', 'ต่างๆ', 'บอกว่า', 'ให้ไป', 'ยกเลิก', 'ที่', 'ตู้', 'เดิม', '▁มัน', 'เกี่ยว', 'กัน', 'หรือป่าว', 'ครับ', '▁', '</s>']]]
# -------------------
# MSP: ค้ะ => ค่ะ
# [['<s>', '▁', 'ถึง', 'แล้ว', 'ค้ะ', '</s>']]
# [[['<s>', '▁', 
'</s>']]]
# -------------------
# MSP: บช => บัญชี
# [['<s>', '▁ขอ', 'สอบถาม', 'นิดนึง', 'นะค่ะ', '▁วันนี้', 'จะไป', 'เปิด', '▁', 'บช', '▁', 'ให้ลูก', '▁', 'พอจะ', 'แนะนําให้', 'ทํา', 'แบบไหน', 'ดีค่ะ', '</s>']]
# [[['<s>', '▁ขอ', 'สอบถาม', 'นิดนึง', 'นะค่ะ', '▁วันนี้', 'จะไป', 'เปิด', '▁', 'บัญชี', '▁', 'ให้ลูก', '▁', 'พอจะ', 'แนะนําให้', 'ทํา', 'แบบไหน', 'ดีค่ะ', '</s>']]]
# -------------------
# =========[new]==========

# %%
pickle_model_json = pickle.load(open('drive/MyDrive/AIBuilders/json/pickle_model_json_mt5.pkl', 'rb'))
msp_type_dict_full = pickle_model_json['msp_type_dict_full']
msp_type_dict_fill = pickle_model_json['msp_type_dict_fill']
msp_word_dict_full = pickle_model_json['msp_word_dict_full']
msp_word_dict_fill = pickle_model_json['msp_word_dict_fill']
msp_word_dict_wrong = pickle_model_json['msp_word_dict_wrong']
sent_id_type = pickle_model_json['sent_id_type']

# %%
cou = 0
suma = 0
sumb = 0
sumc = 0
for i in pickle_model_json['msp_word_dict_fill']:
  a = pickle_model_json['msp_word_dict_fill'][i]
  # b = pickle_model_json['msp_word_dict_full'][i]
  b = msp_word_dict[i]
  c = pickle_model_json['msp_word_dict_wrong'][i]
  # print(a,b,i)
  if b > 0:
    cou += 1
  suma += a
  sumb += b
  sumc += c
print(cou)
print(suma, sumb, sumc)
# Out:
# 608
# 3162 7574 0

# %%
pickle_model_json['msp_word_dict_fill']
# Out:
# {('อ่ะ', 'อะ'): 493,
#  ('ค่ะ', 'คะ'): 386,
#  ('เบอ', 'เบอร์'): 307,
#  ('คะ', 'ค่ะ'): 246,
#  ('มั้ย', 'ไหม'): 196,
#  ('คับ', 'ครับ'): 177,
#  ('อ่อ', 'อ๋อ'): 131,
#  ('ค้ะ', 'คะ'): 131,
#  ('เปน', 'เป็น'): 129,
#  ('ก้', 'ก็'): 113,
#  ('แอพ', 'แอป'): 110,
#  ('ยังไง', 'อย่างไร'): 108,
#  ('ค้ะ', 'ค่ะ'): 106,
#  ('ใด้', 'ได้'): 91,
#  ('มั๊ย', 'ไหม'): 80,
#  ('ไง', 'อย่างไร'): 62,
#  ('ใหม', 'ไหม'): 59,
#  ('ไม', 'ไหม'): 59,
#  ('ม่', 'ไม่'): 50,
#  ('แอฟ', 'แอป'): 46,
#  ('บช', 'บัญชี'): 43,
#  ('อยุ่', 'อยู่'): 42,
#  ('รุ้', 'รู้'): 40,
#  ('อ้ะ', 'อะ'): 39,
#  ('ตัง', 'สตางค์'): 37,
#  ('ใหน', 'ไหน'): 33,
#  ('ก้อ', 'ก็'): 32,
#  ('ขอบคุน', 'ขอบคุณ'): 30,
#  ('เรย', 'เลย'): 27,
#  ('เค้า', 'เขา'): 26,
#  ('คัฟ', 'ครับ'): 25,
#  ('ใม่', 'ไม่'): 25,
#  ('ค', 'คะ'): 24,
#  ('แร้ว', 'แล้ว'): 20,
#  ('ไช่', 'ใช่'): 20,
#  ('ได่', 'ได้'): 17,
#  ('ขอโทด', 'ขอโทษ'): 17,
#  ('คร้า', 'ค่ะ'): 16,
#  ('ยังงัย', 'อย่างไร'): 14,
#  ('ยุ่', 'อยู่'): 13,
#  ('นึง', 'หนึ่ง'): 13,
#  ('ไม', 'ไม่'): 12,
#  ('ยุ', 'อยู่'): 11,
#  ('ค่า', 'ค่ะ'): 11,
#  ('น้ะ', 'นะ'): 11,
#  ('ไม๊', 'ไหม'): 10,
#  ('ดิ', 'สิ'): 10,
#  ('เท่าไหร่', 'เท่าไร'): 9,
#  ('เด๋ว', 'เดี๋ยว'): 8,
#  ('ด้', 'ได้'): 8,
#  ('มัย', 'ไหม'): 8,
#  ('ค', 'ค่ะ'): 8,
#  ('คร้าบ', 'ครับ'): 7,
#  ('ใว้', 'ไว้'): 7,
#  ('ไห้', 'ให้'): 7,
#  ('คร้า', 'คะ'): 7,
#  ('น่ะ', 'นะ'): 6,
#  ('โท', 'โทร'): 6,
#  ('ใช่', 'ใช้'): 6,
#  ('ด้าย', 'ได้'): 6,
#  ('เปง', 'เป็น'): 6,
#  ('ม่ะ', 'ไหม'): 6,
#  ('หรอ', 'หรือ'): 5,
#  ('พึ่ง', 'เพิ่ง'): 5,
#  ('หรอ', 'เหรอ'): 4,
#  ('พิม', 'พิมพ์'): 4,
#  ('อิก', 'อีก'): 4,
#  ('เห้น', 'เห็น'): 4,
#  ('เชค', 'เช็ค'): 3,
#  ('ตังค์', 'สตางค์'): 3,
#  ('ครัช', 'ครับ'): 3,
#  ('เบย', 'เลย'): 3,
#  ('ที', 'ที่'): 3,
#  ('รึ', 'หรือ'): 3,
#  ('งัย', 'อย่างไร'): 3,
#  ('งัย', 'ไง'): 2,
#  ('จิง', 'จริง'): 2,
#  ('ใช้', 'ใช่'): 2,
#  ('นู๋', 'หนู'): 2,
#  ('เนาะ', 'นะ'): 2,
#  ('ให', 'ให้'): 2,
#  ('มะ', 'ไม่'): 2,
#  ('หรือป่าว', 'หรือเปล่า'): 2,
#  ('มั่ง', 'บ้าง'): 2,
#  ('กะ', 'กับ'): 2,
#  ('ความ', 'ความ'): 2,
#  ('ธ', 'ธนาคาร'): 2,
#  ('เนอะ', 'นะ'): 2,
#  ('แอ๊บ', 'แอป'): 2,
#  ('ล้ะ', 'ละ'): 2,
#  ('เหรอ', 'หรือ'): 2,
#  ('มะ', 'ไหม'): 2,
#  ('เชค', 'เช็ก'): 2,
#  ('ม่ะ', 'ไม่'): 2,
#  ('ยังงัย', 'ยังไง'): 1,
#  ('นี่', 'นี้'): 1,
#  ('รึป่าว', 'หรือเปล่า'): 1,
#  ('เนี้ย', 'เนี่ย'): 1,
#  ('เห้อ', 'เฮ้อ'): 1,
#  ('พนง', 'พนักงาน'): 1,
#  ('ประมาน', 'ประมาณ'): 1,
#  ('โหลด', 'ดาวน์โหลด'): 1,
#  ('โทร', 'โทรศัพท์'): 1,
#  ('ล็อค', 'ล็อก'): 1,
#  ('แบง', 'แบงก์'): 1,
#  ('ล่ะ', 'ละ'): 1,
#  ('สู้', 'สู่'): 1,
#  ('เนี้ย', 'นี้'): 1,
#  ('ไม้', 'ไม่'): 1,
#  ('เวป', 'เว็บ'): 1,
#  ('คัพ', 'ครับ'): 1,
#  ('เบอ', 'เบลอ'): 1,
#  ('กะ', 'ก็'): 1,
#  ('คราบ', 'ครับ'): 1,
#  ('ใส้', 'ไส้'): 1,
#  ('ไช่', 'ใช้'): 1,
#  ('เทอ', 'เธอ'): 1,
#  ('บาง', 'บ้าง'): 1,
#  ('คห', 'ความเห็น'): 1,
#  ('ใม่', 'ไหม'): 1,
#  ('แระ', 'แล้ว'): 1,
#  ('รับ', 'ครับ'): 1,
#  ('ล้ะ', 'แล้ว'): 1,
#  ('ค่า', 'คะ'): 1,
#  ('จ่ะ', 'คะ'): 1,
#  ('เดียว', 'เดี๋ยว'): 1,
#  ('ข้อ', 'เขา'): 1,
#  ('ตุ้', 'ตู้'): 0,
#  ('แอฟ', 'แอพ'): 0,
#  ('เบอร', 'เบอร์'): 0,
#  ('อัพเดต', 'อัปเดต'): 0,
#  ('เช้ค', 'เช็ค'): 0,
#  ('อยาก', 'ยาก'): 0,
#  ('จ้า', 'จ้ะ'): 0,
#  ('บัชชี', 'บัญชี'): 0,
#  ('ยังใง', 'อย่างไร'): 0,
#  ('คร้าบบ?', 'ครับ'): 0,
#  ('ป่าว', 'เปล่า'): 0,
#  ('อินเตอร์เน็ต', 'อินเทอร์เน็ต'): 0,
#  ('ไหม่', 'ใหม่'): 0,
#  ('ค่', 'ค่ะ'): 0,
#  ('สมัค', 'สมัคร'): 0,
#  ('อะ', 'อะไร'): 0,
#  ('โทรศัพ', 'โทรศัพท์'): 0,
#  ('คครับ', 'ครับ'): 0,
#  ('ตอ้ง', 'ต้อง'): 0,
#  ('รอง', 'ลอง'): 0,
#  ('ปะ', 'เปล่า'): 0,
#  ('สัส', 'สัตว์'): 0,
#  ('ที่อยุ่', 'ที่อยู่'): 0,
#  ('เบอร์', 'หมายเลข'): 0,
#  ('โทสับ', 'โทรศัพท์'): 0,
#  ('ออนไล', 'ออนไลน์'): 0,
#  ('อะรัย', 'อะไร'): 0,
#  ('สเตดเม้น', 'สเตทเม้นท์'): 0,
#  ('เน็ต', 'อินเทอร์เน็ต'): 0,
#  ('บันชี', 'บัญชี'): 0,
#  ('โทรสับ', 'โทรศัพท์'): 0,
#  ('ต', 'ต'): 0,
#  (' ', '.'): 0,
#  ('ค่าาา', 'ค่ะ'): 0,
#  ('น่อย', 'หน่อย'): 0,
#  ('กุ้', 'กู้'): 0,
#  ('แอป', 'แอพ'): 0,
#  ('ว่ะ', 'วะ'): 0,
#  ('ป่ะ', 'เปล่า'): 0,
#  ('ยังใง', 'ยังไง'): 0,
#  ('แต', 'แต่'): 0,
#  ('เบอยุแล้ว', 'เบอร์อยู่แล้ว'): 0,
#  ('เตอ', 'เจอ'): 0,
#  ('ล๊อก', 'ล็อก'): 0,
#  ('หรัส', 'รหัส'): 0,
#  ('เคาเตอร์', 'เคาน์เตอร์'): 0,
#  ('สามรถ', 'สามารถ'): 0,
#  ('คพ', 'ค่ะ'): 0,
#  ('เนต', 'อินเทอร์เน็ต'): 0,
#  ('สวัดดี', 'สวัสดี'): 0,
#  ('ก', 'ก'): 0,
#  ('ค่', 'คะ'): 0,
#  ('รีไฟแนน', 'รีไฟแนนซ์'): 0,
#  ('อ่อ', 'อ้อ'): 0,
#  ('โทรศัพย์', 'โทรศัพท์'): 0,
#  ('เคดิต', 'เครดิต'): 0,
#  ('อะ', 'อ่ะ'): 0,
#  ('วีธี', 'วิธี'): 0,
#  ('ข้อมุล', 'ข้อมูล'): 0,
#  ('เปลียน', 'เปลี่ยน'): 0,
#  ('ใข่', 'ใช่'): 0,
#  ('ไทยพานิชย์', 'ไทยพาณิชย์'): 0,
#  ('ละ', 'ล่ะ'): 0,
#  ('โทรสัพ', 'โทรศัพท์'): 0,
#  ('ค่าาาาาาา', 'ค่ะ'): 0,
#  ('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0,
#  ('ลิ้ง', 'ลิงค์'): 0,
#  ('คพ', 'คะ'): 0,
#  ('ไร', 'อะไร'): 0,
#  ('เปิดบันชี', 'เปิดบัญชี'): 0,
#  ('คร้าาา', 'ค่ะ'): 0,
#  ('เด๋วนี้', 'เดี๋ยวนี้'): 0,
#  ('ไหม่', 'ไหม'): 0,
#  ('เปนไร', 'เป็นไร'): 0,
#  ('เน้ต', 'อินเทอร์เน็ต'): 0,
#  ('ร้องได้อ้ะ', 'ร้องได้อะ'): 0,
#  ('เช็ค', 'เช็ก'): 0,
#  ('ค๊ะ', 'คะ'): 0,
#  ('ต่ะ', 'คะ'): 0,
#  ('คระบ', 'ครับ'): 0,
#  ('คุน', 'คุณ'): 0,
#  ('คนับ', 'ครับ'): 0,
#  ('มี', 'มี'): 0,
#  ('ค', 'ค'): 0,
#  ('เวป', 'เว็บไซต์'): 0,
#  ('k', 'k plus'): 0,
#  ('plusอ่ะคับ', 'อะครับ'): 0,
#  ('เนี่ยยย', 'เนี่ย'): 0,
#  ('กับ', 'กัน'): 0,
#  ('ลิ้งค์', 'ลิงค์'): 0,
#  ('หน่ะ', 'น่ะ'): 0,
#  ('ฮาาา', 'ฮา'): 0,
#  ('จร้า', 'จ้ะ'): 0,
#  ('โดนจัย', 'โดนใจ'): 0,
#  ('คีับ', 'ครับ'): 0,
#  ('คอม', 'คอมพิวเตอร์'): 0,
#  ('เปี่ยน', 'เปลี่ยน'): 0,
#  ('แอพ', 'application'): 0,
#  ('แบงค์', 'แบงก์'): 0,
#  ('ไม่', 'ไหม'): 0,
#  ('ทา', 'มา'): 0,
#  ('สาธุ จร้า', 'สาธุ จ้า'): 0,
#  ('รึยัง', 'หรือยัง'): 0,
#  ('กะตัง', 'สตางค์'): 0,
#  ('ยัตร', 'บัตร'): 0,
#  ('บช.', 'บัญชี'): 0,
#  ('พร้อมเพย์', 'พร้อมเพย์์'): 0,
#  ('คอลเซนเตอร์', 'คอลเซ็นเตอร์'): 0,
#  ('แลัว', 'แล้ว'): 0,
#  ('ธ', 'ธ'): 0,
#  ('ซัก', 'สัก'): 0,
#  ('วัน', 'วัน'): 0,
#  ('พีช', 'พีซ'): 0,
#  ('ฟัดดดด', 'ฟัด'): 0,
#  ('ดาวโหลด', 'ดาวน์โหลด'): 0,
#  ('กุ', 'กู'): 0,
#  ('บัญขี', 'บัญชี'): 0,
#  ('หมดดด', 'หมด'): 0,
#  ('เเร้ว', 'แล้ว'): 0,
#  ('ต่ะ', 'ค่ะ'): 0,
#  ('นิดนึง', 'นิดหนึ่ง'): 0,
#  ('คร่', 'ค่ะ'): 0,
#  ('คึดถึง', 'คิดถึง'): 0,
#  ('เป่น', 'เป็น'): 0,
#  ('ป่ะ', 'ปะ'): 0,
#  ('เค้าาาาาาาาาา', 'เขา'): 0,
#  ('หราาาาา', 'หรือ'): 0,
#  ('ทำ', 'ทำ'): 0,
#  ('โห', 'โอ้โฮ'): 0,
#  ('แบงกิ้ง', 'แบงก์กิ้ง'): 0,
#  ('ข้อมู', 'ข้อมูล'): 0,
#  ('ยาก', 'อยาก'): 0,
#  ('ยังคงอยุ่', 'ยังคงอยู่'): 0,
#  ('เนี้ย', 'นี่'): 0,
#  ('เป็นไร', 'เป็น'): 0,
#  ('สาธุฯคัพ', 'สาธุครับ'): 0,
#  ('ไม', 'ทำไม'): 0,
#  ('แล้ส', 'แล้ว'): 0,
#  ('เด้อ', 'นะ'): 0,
#  ('ไว', 'ไว้'): 0,
#  ('อัพ', 'อัปเดต'): 0,
#  ('เครือง', 'เครื่อง'): 0,
#  ('เเอป', 'แอพ'): 0,
#  ('จ่ะ', 'จ้ะ'): 0,
#  ('พักงาน', 'พนักงาน'): 0,
#  ('คำ', 'ค้ำ'): 0,
#  ('ปะ', 'หรือเปล่า'): 0,
#  ('ล้ะ', 'ล่ะ'): 0,
#  ('อาทิตร์', 'อาทิตย์'): 0,
#  ('นี้', 'นี่'): 0,
#  ('ใช่', 'ใช่'): 0,
#  ('ตอ้งการ', 'ต้องการ'): 0,
#  ('ลหัส', 'รหัส'): 0,
#  ('แอพที่', 'แอปที่'): 0,
#  ('บ ช', 'บัญชี'): 0,
#  ('ก้คือ', 'ก็คือ'): 0,
#  ('แบง', 'แบงค์'): 0,
#  ('เป็นไร', 'เป็นไร'): 0,
#  ('สมัด', 'สมัคร'): 0,
#  ('ให่', 'ให้'): 0,
#  ('สามรถเชค', 'สามารถเช็ค'): 0,
#  ('ค่ะ.', 'ค่ะ'): 0,
#  ('ลบกวน', 'รบกวน'): 0,
#  ('คค่ะ', 'คะ'): 0,
#  ('อาทิต', 'อาทิตย์'): 0,
#  ('ทำไหม', 'ทำไม'): 0,
#  ('หายอ่ะ', 'หายอะ'): 0,
#  ('ไงต่ออ่ะ', 'อย่างไรต่ออะ'): 0,
#  ('ล้าง', 'บ้าง'): 0,
#  ('เคแบงค์', 'เคแบงก์'): 0,
#  ('สุดยอดดดด', 'สุดยอด'): 0,
#  ('น๊ะ', 'นะ'): 0,
#  ('นิดเห็น', 'คิดเห็น'): 0,
#  ('ใง', 'ไง'): 0,
#  ('ภึง', 'ถึง'): 0,
#  ('เรียร้อย', 'เรียบร้อย'): 0,
#  ('เปิดบช', 'เปิดบัญชี'): 0,
#  ('คร้าาา', 'คะ'): 0,
#  ('เบราเซอร์', 'เบราว์เซอร์'): 0,
#  ('เอ่า', 'อ้าว'): 0,
#  ('เค้าเตอ', 'เคาน์เตอร์'): 0,
#  ('แอพ', 'app'): 0,
#  ('แอฟ', 'app'): 0,
#  ('แระ', 'แหละ'): 0,
#  ('โดน', 'โดย'): 0,
#  ('ตลอดดด', 'ตลอด'): 0,
#  ('โปร', 'โปรโมชั่น'): 0,
#  ('เพือน', 'เพื่อน'): 0,
#  ('k plus', 'k plus'): 0,
#  ('เฟส', 'เฟซ'): 0,
#  ('้เปลี่ยน', 'เปลี่ยน'): 0,
#  ('อัพเดท', 'อัปเดต'): 0,
#  ('ออนไลน', 'ออนไลน์'): 0,
#  ('เตรื่อง', 'เครื่อง'): 0,
#  ('เข้า', 'เขา'): 0,
#  ('อ้ะ', 'อ่ะ'): 0,
#  ('สริป', 'สลิป'): 0,
#  ('ตรงกัน', 'ตรงกัน'): 0,
#  ('คาฟฟ', 'ครับ'): 0,
#  ('เคโมบายพลาส', 'เคโมบายพลัส'): 0,
#  ('มากกกกกกกกกกกกกกกกก', 'มาก'): 0,
#  ('พร้อมเพ', 'พร้อมเพย์'): 0,
#  ('และ', 'แล้ว'): 0,
#  ('เนี่ย', 'นี่'): 0,
#  ('แอฟK+', 'แอพK+'): 0,
#  ('มัร', 'มัน'): 0,
#  ('ออม', 'ออม'): 0,
#  ('ทรัพ', 'ทรัพย์'): 0,
#  ('เสด', 'เสร็จ'): 0,
#  ('ค่เ', 'ค่ะ'): 0,
#  ('คึด', 'คิด'): 0,
#  ('ทำไม่', 'ทำไม'): 0,
#  ('เนต', 'เน็ต'): 0,
#  ('แบล็คลิส', 'แบล็คลิสต์'): 0,
#  ('ธนคาร', 'ธนาคาร'): 0,
#  ('อ่อ', 'ออ'): 0,
#  ('ใช่ไวไฟ', 'ใช้ไวไฟ'): 0,
#  ('อ่ะกู', 'อะกู'): 0,
#  ('อ่ะสิ', 'อะสิ'): 0,
#  ('อ่อ', 'หรอ'): 0,
#  ('สเตสเม้น', 'สเตทเม้นท์'): 0,
#  ('ตะกี้', 'เมื่อกี้'): 0,
#  ('ขอบตคุนคับ', 'ขอบคุณครับ'): 0,
#  ('สมัคk-plus', 'สมัครk-plus'): 0,
#  ('เว', 'เวลา'): 0,
#  ('ล๊อคอิน', 'ล็อคอิน'): 0,
#  ('จะ', 'จ้ะ'): 0,
#  ('นะ', 'นะ'): 0,
#  ('แระ', 'และ'): 0,
#  ('ได้ป', 'ได้'): 0,
#  ('ใข้', 'ใช้'): 0,
#  ('ดึก', 'ดึง'): 0,
#  ('กรุงเทพฯ', 'กรุงเทพ'): 0,
#  ('ก้วิธีการ', 'ก็วิธีการ'): 0,
#  ('เมล', 'เมล์'): 0,
#  ('เนะนำ', 'แนะนำ'): 0,
#  ('ไม่', 'ไม่'): 0,
#  ('แอพพลิเคชั่น', 'แอปพลิเคชัน'): 0,
#  ('เนาะ', 'เน้อ'): 0,
#  ('ดงิน', 'เงิน'): 0,
#  ('มือ', 'มือถือ'): 0,
#  ('ชั้น', 'ฉัน'): 0,
#  ('ครับช', 'ครับ'): 0,
#  ('แอด', 'แอดมิน'): 0,
#  ('บ/ช', 'บัญชี'): 0,
#  ('คัห', 'ครับ'): 0,
#  ('อายัด', 'อายัติ'): 0,
#  ('เน้อะ', 'นะ'): 0,
#  ('ตำ่', 'ต่ำ'): 0,
#  ('ป่ะ', 'ป้ะ'): 0,
#  ('เซน', 'เซ็น'): 0,
#  ('ช่ม่', 'ใช่'): 0,
#  ('ส่วนบุคคนคับ', 'ส่วนบุคคลครับ'): 0,
#  ('เวบ', 'เว็บไซต์'): 0,
#  ('ตัง', 'เงิน'): 0,
#  ('อ่อ', 'เหรอ'): 0,
#  ('มาอ่ะ', 'มาอะ'): 0,
#  ('อะเค', 'โอเค'): 0,
#  ('เงืน', 'เงิน'): 0,
#  ('ดิชั้น', 'ดิฉัน'): 0,
#  ('ปั้ม', 'ปั๊ม'): 0,
#  ('ป่ะ', 'หรือเปล่า'): 0,
#  ('ปัย', 'ไป'): 0,
#  ('หรอก', 'หรอ'): 0,
#  ('จร้า', 'จ้า'): 0,
#  ('ล๊อคอิน', 'ล็อกอิน'): 0,
#  ('ได้', 'ได้'): 0,
#  ('คร้ง', 'ครั้ง'): 0,
#  ('มีป่าว', 'มีเปล่า'): 0,
#  ('้ครับ', 'ครับ'): 0,
#  ('น๊อน', 'นอน'): 0,
#  ('เคอะ', 'คะ'): 0,
#  ('ฝันดีราตรี', 'ฝันดีราตรี'): 0,
#  ('หมายเลยโทรศัพย์', 'หมายเลขโทรศัพท์'): 0,
#  ('อ่อ', 'ิอ๋อ'): 0,
#  ('ขอ', 'ของ'): 0,
#  ('.', '.'): 0,
#  ('นิ', 'นี้'): 0,
#  ('รุ้จัก', 'รู้จัก'): 0,
#  ('อัติโนมัติ', 'อัตโนมัติ'): 0,
#  ('อะ', 'ล่ะ'): 0,
#  ('โปรโมชั่น', 'โปรโมชัน'): 0,
#  ('เคแบงค์กิ้ง', 'เคแบงก์กิ้ง'): 0,
#  ('บัณชี', 'บัญชี'): 0,
#  ('อินเตอเนต', 'อินเทอร์เน็ต'): 0,
#  ('ยังงัย', 'อย่างไง'): 0,
#  ('ค่ะ้', 'คะ'): 0,
#  ('ปะ', 'ไป'): 0,
#  ('กาก', 'การ'): 0,
#  ('มากกกกกกก', 'มาก'): 0,
#  ('เดยวบัตร', 'เดี๋ยว'): 0,
#  ('มาน', 'บัตร'): 0,
#  ('โม๊ดด', 'หมด'): 0,
#  ('ทำ', 'ทำไม'): 0,
#  ('เตียม', 'เตรียม'): 0,
#  ('ไมา', 'ไม่'): 0,
#  ('เปิดบัชชี', 'เปิดบัญชี'): 0,
#  ('ก้ดี', 'ก็ดี'): 0,
#  ('ช่วง', 'ช่วย'): 0,
#  ('ใง', 'อย่างไร'): 0,
#  ('ละ', 'แล้ว'): 0,
#  ('ตเอง', 'ต้อง'): 0,
#  ('คร้าบบ', 'ครับ'): 0,
#  ('กับ', 'กลับ'): 0,
#  ('มีป่าวค๊ะ', 'มีเปล่าคะ'): 0,
#  ('ป๋ม', 'ผม'): 0,
#  ('เพื่ม', 'เพิ่ม'): 0,
#  ('สเตดเม้น', 'สเตทเมนท์'): 0,
#  ('ใหมี', 'ใหม่'): 0,
#  ('ค่าาา', 'คะ'): 0,
#  ('นะ', 'น่ะ'): 0,
#  ('แพตตินัม', 'แพลทินัม'): 0,
#  ('เมื่อไหร่', 'เมื่อไร'): 0,
#  ('หรัสผ่าน', 'รหัสผ่าน'): 0,
#  ('อยุ่ดี', 'อยู่ดี'): 0,
#  ('ตัง', 'ตังค์'): 0,
#  ('กัล', 'กัน'): 0,
#  ('นั้น', 'นั่น'): 0,
#  ('ส ค บ เรยคะ', 'สคบ.เลยค่ะ'): 0,
#  ('ยังำงค่ะ', 'ยังไงคะ'): 0,
#  ('ไง', 'ไงิ'): 0,
#  ('อะ', 'อะ'): 0,
#  ('สคริป', 'สคริปต์'): 0,
#  ('ไหม่ป', 'ใหม่'): 0,
#  ('เครคิต', 'เครดิต'): 0,
#  ('ล๊อก', 'ล็อค'): 0,
#  ('คค่ะ', 'ค่ะ'): 0,
#  ('โทร', 'โทร'): 0,
#  ('รับแซ๊บ', 'รับทราบ'): 0,
#  ('ใช่จ่ายใหมค่ะ', 'ใช้จ่ายไหมคะ'): 0,
#  ('ส น', 'สน.'): 0,
#  ('เปอเซน', 'เปอร์เซ็นต์'): 0,
#  ('ป่ะ', 'ไป'): 0,
#  ('ช่ายยยย', 'ใช่'): 0,
#  ('ค๊ะ', 'ค่ะ'): 0,
#  ('อยู่อ่ะ', 'อยู่อะ'): 0,
#  ('รีด', 'อีก'): 0,
#  ('ชัว', 'ชัวร์'): 0,
#  ('ททราบ', 'ทราบ'): 0,
#  ('คับผม', 'ครับผม'): 0,
#  ('ซื้อง', 'ซื้อ'): 0,
#  ('นี่แระ', 'นี่แหละ'): 0,
#  ('เฟิสช้อย', 'เฟิร์สช้อยส์'): 0,
#  ('ค่าใช้จ่าย', 'ค่า'): 0,
#  ('ไม', 'ใช้จ่าย'): 0,
#  ('เมื่อไหร่กะเพรา', 'เมื่อไรกะเพรา'): 0,
#  ('ทีา', 'ที่'): 0,
#  ('โครตกาก', 'โคตรกาก'): 0,
#  ('สมมุติ', 'สมมติ'): 0,
#  ('หรือไป', 'หรือไป'): 0,
#  ('เปนอ่ะ', 'เป็นอะ'): 0,
#  ('รึยัง', 'รึยัง'): 0,
#  ('เงื้อนไข', 'เงื่อนไข'): 0,
#  ('อ่ะคับผม', 'อะครับผม'): 0,
#  ('ใหม่', 'ไหม'): 0,
#  ('อ่อ', '๋อ๋อ'): 0,
#  ('ตลอดดดด', 'ตลอด'): 0,
#  ('เพื่อ', 'เพิ่ม'): 0,
#  ('้เจ้าหน้าที่', 'เจ้าหน้าที่'): 0,
#  ('ธ.', 'ธนาคาร'): 0,
#  ('เดี่ยว', 'เดี๋ยว'): 0,
#  ('ม่', 'ไหม'): 0,
#  ('ยัง', 'ยังไง'): 0,
#  ('้เมื่อ', 'เมื่อ'): 0,
#  ('เน้', 'นี้'): 0,
#  ('อ่ะภาพ', 'อะภาพ'): 0,
#  ('หักบช', 'หักบัญชี'): 0,
#  ('ดี', 'สวัสดี'): 0,
#  ('สิบถาม', 'สอบถาม'): 0,
#  ('ต้อง', 'ตรง'): 0,
#  ('มากอ่ะ', 'มากอะ'): 0,
#  ('สมัคk', 'สมัคร'): 0,
#  ('plus', 'k plus'): 0,
#  ('เคแบงเติม', 'เคแบงก์'): 0,
#  ('เว็ป', 'เว็บ'): 0,
#  ('คใคร', 'ใคร'): 0,
#  ('เก๊า', 'เรา'): 0,
#  ('แบงค์กรุงเทพ', 'แบงก์กรุงเทพ'): 0,
#  ('จ่ะ', 'จ๊ะ'): 0,
#  ('รึป่าว', 'รึเปล่า'): 0,
#  ('ยิม', 'ยิ้ม'): 0,
#  ('ก กรุงไทย', 'กรุงไทย'): 0,
#  ('ครับบ', 'ครับ'): 0,
#  ('คร้าบผม', 'ครับผม'): 0,
#  ('อย่างรัย', 'อย่างไร'): 0,
#  ('เปนรัยคะ', 'เป็นไรค่ะ'): 0,
#  ('อะป่าวคับ', 'อะเปล่าครับ'): 0,
#  ('ยุแล้ว', 'อยู่แล้ว'): 0,
#  ('อ๊าววว', 'อ้าว'): 0,
#  ('ๆด้', 'ได้'): 0,
#  ('สมัคKBank', 'สมัครKBank'): 0,
#  ('ไป', 'ไม่'): 0,
#  ('ฮื้อออแแ', 'ฮือ'): 0,
#  ('ทวีทรัพย์เอ็กตร้า', 'ทวีทรัพย์เอ็กซ์ตร้า'): 0,
#  ('ยัยช้างด้า', 'ยายช้างด้า'): 0,
#  ('แอปฯ', 'application'): 0,
#  ('เค้า', 'เข้า'): 0,
#  ('คนับ', 'ครับี่'): 0,
#  ('นิ', 'นี่'): 0,
#  ('ฟฤหัส', 'พฤหัสบดี'): 0,
#  ('ป้ายบาร์โค้ดยังไงอ่ะ', 'ป้ายบาร์โค้ดอย่างไรอะ'): 0,
#  ('เว็ป', 'เว็บไซต์'): 0,
#  ('ก้เลย', 'ก็เลย'): 0,
#  ('แล้ง', 'แล้ว'): 0,
#  ('อยู้', 'อยู่'): 0,
#  ('สิ้', 'สิ'): 0,
#  ('ดด', 'กด'): 0,
#  ('ทันที่ไม', 'ทันทีไม่'): 0,
#  ('ชะ', 'ซะ'): 0,
#  ('เปลั่ยน', 'เปลี่ยน'): 0,
#  ('คคะ', 'ค่ะ'): 0,
#  ('เข้า', 'ข้า'): 0,
#  ('เด๊๋ยว', 'เดี๋ยว'): 0,
#  ('ใหมาไมา', 'ใหม่ไม่'): 0,
#  ('ปิดบันชี', 'ปิดบัญชี'): 0,
#  ('ไฟแนน', 'ไฟแนนซ์'): 0,
#  ('กสิกรช', 'กสิกร'): 0,
#  ('แกไข', 'แก้ไข'): 0,
#  ('อย่า', 'อยาก'): 0,
#  ('ใข่', 'ใช้'): 0,
#  ('ม้ย', 'ไหม'): 0,
#  ('เพาะ', 'เพราะ'): 0,
#  ('บริหาร', 'บริการ'): 0,
#  ('เขา', 'เข้า'): 0,
#  ('ทราบถามอ่ะ', 'สอบถามอะ'): 0,
#  ('ช้อป', 'ชอป'): 0,
#  ('ยุแร้วอ่ะ', 'อยู่แล้วอะ'): 0,
#  ('กอีก', 'อีก'): 0,
#  ('มิ', 'มิ'): 0,
#  ('เดี่ยว', 'เดียว'): 0,
#  ('ก็เรย', 'ก็เลย'): 0,
#  ('ทำไรค้ะ', 'ทำไรคะ'): 0,
#  ('รอดดดดดด', 'รอด'): 0,
#  ('เบอ', 'number'): 0,
#  ('ทำไม่สมัค', 'ทำไมสมัคร'): 0,
#  ('แบ็งกิ้ง', 'แบงก์กิ้ง'): 0,
#  ('แหละ', 'และ'): 0,
#  ('เบอร์ึ่ะ', 'เบอร์'): 0,
#  ('ป่าว', 'หรือเปล่า'): 0,
#  ('อะค่ะ', 'อะ'): 0,
#  ('จร้า', 'จ๊ะ'): 0,
#  ('คอลเซ็น', 'คอลเซ็นเตอร์'): 0,
#  ('ไวไฟอ่ะคับ', 'ไวไฟอะครับ'): 0,
#  ('รุ้ที่ยุ', 'รู้ที่อยู่'): 0,
#  ('ที่ยุ', 'ที่อยู่'): 0,
#  ('ลงอิน', 'ล็อคอิน'): 0,
#  ('อ่อคับบบ', 'อ้อครับ'): 0,
#  ('ๆม่', 'ไม่'): 0,
#  ('ขึ้นยุ', 'ขึ้นอยู่'): 0,
#  ('เช้ค', 'เช็ก'): 0,
#  ('เฟสบุ้ค', 'เฟซบุ๊ค'): 0,
#  ('ค้พ', 'ค่ะ'): 0,
#  ('เคแบงค์', 'promptpay'): 0,
#  ('เข้าจัย', 'เข้าใจ'): 0,
#  ('ม่มัน', 'มัน'): 0,
#  ('ใช้', 'ใช้'): 0,
#  ('ตรวจเชค', 'ตรวจเช็ค'): 0,
#  ('ศัทพ์', 'โทรศัพท์'): 0,
#  ('ครับพ้ม', 'ครับผม'): 0,
#  ('คำแนะนำค้ะ', 'คำแนะนำค่ะ'): 0,
#  ('ล้อคอิน', 'ล็อคอิน'): 0,
#  ('ค่ะ', 'ค่ะ'): 0,
#  ('ระบ', 'รับ'): 0,
#  ('K My play', 'K My pay'): 0,
#  ('คร่', 'คะ'): 0,
#  ('ใส้', 'ใส่'): 0,
#  ('อิ', 'อี'): 0,
#  ('ล้อคอิน', 'ล็อกอิน'): 0,
#  ('อ่ะ', 'อ่อะ'): 0,
#  ('เน้ต', 'เน็ต'): 0,
#  ('สเตสเม้น', 'สเตทเมนท์'): 0,
#  ('ก่า', 'กว่า'): 0,
#  ('เบอร์', 'number'): 0,
#  ('ยุ่ไกล', 'อยู่ไกล'): 0,
#  ('คร้าทำไม่', 'คะทำไม'): 0,
#  ('แบงค์กรุงไทย', 'แบงก์กรุงไทย'): 0,
#  ('สมัครอะคับ', 'สมัครอะครับ'): 0,
#  ('คับ', 'ครับบ'): 0,
#  ('ปัจุบัน', 'ปัจจุบัน'): 0,
#  ('อิกเสียได้', 'อีกเสียดาย'): 0,
#  ('จ่ะ', 'จะ'): 0}

# %%
pickle_model_json
# Out:
# {'msp_type_dict_full': {'morphed': 1818,
#   'misspelled': 4509,
#   'ws': 36,
#   'other': 38,
#   'abbreviation': 190,
#   'new': 1},
#  'msp_type_dict_fill': {'morphed': 868,
#   'misspelled': 2147,
#   'ws': 6,
#   'other': 14,
#   'abbreviation': 54,
#   'new': 0},
#  'msp_word_dict_full': {('อ่ะ', 'อะ'): 626,
#   ('ค่ะ', 'คะ'): 489,
#   ('คับ', 'ครับ'): 467,
#   ('เบอ', 'เบอร์'): 352,
#   ('คะ', 'ค่ะ'): 345,
#   ('มั้ย', 'ไหม'): 205,
#   ('แอพ', 'แอป'): 170,
#   ('เปน', 'เป็น'): 153,
#   ('โทร', 'โทรศัพท์'): 150,
#   ('ค้ะ', 'คะ'): 148,
#   ('ค้ะ', 'ค่ะ'): 146,
#   ('อ่อ', 'อ๋อ'): 143,
#   ('ยังไง', 'อย่างไร'): 137,
#   ('ก้', 'ก็'): 135,
#   ('ใด้', 'ได้'): 106,
#   ('คัฟ', 'ครับ'): 90,
#   ('มั๊ย', 'ไหม'): 88,
#   ('เรย', 'เลย'): 70,
#   ('ใหม', 'ไหม'): 68,
#   ('ไง', 'อย่างไร'): 67,
#   ('ไม', 'ไหม'): 67,
#   ('บช', 'บัญชี'): 56,
#   ('แอฟ', 'แอป'): 55,
#   ('ตัง', 'สตางค์'): 55,
#   ('ม่', 'ไม่'): 55,
#   ('ค', 'ค่ะ'): 55,
#   ('อยุ่', 'อยู่'): 53,
#   ('อ้ะ', 'อะ'): 49,
#   ('รุ้', 'รู้'): 48,
#   ('ก้อ', 'ก็'): 48,
#   ('แร้ว', 'แล้ว'): 46,
#   ('ใหน', 'ไหน'): 43,
#   ('หรอ', 'หรือ'): 41,
#   ('ขอบคุน', 'ขอบคุณ'): 40,
#   ('ค', 'คะ'): 40,
#   ('เค้า', 'เขา'): 38,
#   ('หรอ', 'เหรอ'): 37,
#   ('อะ', 'อ่ะ'): 35,
#   ('ป่ะ', 'เปล่า'): 33,
#   ('ใม่', 'ไม่'): 32,
#   ('ใช่', 'ใช้'): 32,
#   ('ป่าว', 'เปล่า'): 31,
#   ('ค่า', 'ค่ะ'): 31,
#   ('ไช่', 'ใช่'): 31,
#   ('แอฟ', 'แอพ'): 30,
#   ('ยังงัย', 'ยังไง'): 29,
#   ('ดิ', 'สิ'): 28,
#   ('รึป่าว', 'หรือเปล่า'): 27,
#   ('เท่าไหร่', 'เท่าไร'): 27,
#   ('คร้า', 'ค่ะ'): 25,
#   ('หรือป่าว', 'หรือเปล่า'): 25,
#   ('ได่', 'ได้'): 24,
#   ('เชค', 'เช็ค'): 23,
#   ('อะ', 'อะไร'): 22,
#   ('งัย', 'ไง'): 22,
#   ('ขอโทด', 'ขอโทษ'): 22,
#   ('โท', 'โทร'): 22,
#   ('น้ะ', 'นะ'): 22,
#   ('ป่ะ', 'ปะ'): 20,
#   ('ยังงัย', 'อย่างไร'): 19,
#   ('คร้าบ', 'ครับ'): 18,
#   ('ไม', 'ไม่'): 18,
#   ('ครัช', 'ครับ'): 18,
#   ('จร้า', 'จ้ะ'): 16,
#   ('นึง', 'หนึ่ง'): 16,
#   ('น่ะ', 'นะ'): 15,
#   ('ใว้', 'ไว้'): 15,
#   ('ใช้', 'ใช่'): 14,
#   ('นู๋', 'หนู'): 14,
#   ('ยุ่', 'อยู่'): 14,
#   ('ไห้', 'ให้'): 14,
#   ('ยุ', 'อยู่'): 13,
#   ('แอป', 'แอพ'): 13,
#   ('พิม', 'พิมพ์'): 13,
#   ('ยัง', 'ยังไง'): 13,
#   ('ไม๊', 'ไหม'): 12,
#   ('เด๋ว', 'เดี๋ยว'): 12,
#   ('มัย', 'ไหม'): 12,
#   ('คร้า', 'คะ'): 12,
#   ('ด้', 'ได้'): 11,
#   ('ปะ', 'เปล่า'): 10,
#   ('ให', 'ให้'): 10,
#   ('เวป', 'เว็บไซต์'): 10,
#   ('เห้น', 'เห็น'): 10,
#   ('เนอะ', 'นะ'): 10,
#   ('จร้า', 'จ้า'): 10,
#   ('จ้า', 'จ้ะ'): 9,
#   ('เบอร์', 'หมายเลข'): 9,
#   ('เบย', 'เลย'): 9,
#   ('ที', 'ที่'): 9,
#   ('โหลด', 'ดาวน์โหลด'): 9,
#   ('เนาะ', 'นะ'): 8,
#   ('ไม่', 'ไหม'): 8,
#   ('พึ่ง', 'เพิ่ง'): 8,
#   ('ด้าย', 'ได้'): 8,
#   ('จิง', 'จริง'): 7,
#   ('มี', 'มี'): 7,
#   ('แบงค์', 'แบงก์'): 7,
#   ('รึ', 'หรือ'): 7,
#   ('เปง', 'เป็น'): 7,
#   ('เหรอ', 'หรือ'): 7,
#   ('นี่', 'นี้'): 6,
#   ('สัส', 'สัตว์'): 6,
#   ('ละ', 'ล่ะ'): 6,
#   ('ม่ะ', 'ไหม'): 6,
#   ('เชค', 'เช็ก'): 6,
#   ('ไร', 'อะไร'): 5,
#   ('พนง', 'พนักงาน'): 5,
#   ('อิก', 'อีก'): 5,
#   ('คุน', 'คุณ'): 5,
#   ('หน่ะ', 'น่ะ'): 5,
#   ('เนี้ย', 'นี่'): 5,
#   ('ล่ะ', 'ละ'): 5,
#   ('อัพเดท', 'อัปเดต'): 5,
#   ('เนต', 'เน็ต'): 5,
#   ('เวป', 'เว็บ'): 5,
#   ('แต', 'แต่'): 4,
#   ('อ่อ', 'อ้อ'): 4,
#   ('เช็ค', 'เช็ก'): 4,
#   ('รึยัง', 'หรือยัง'): 4,
#   ('ประมาน', 'ประมาณ'): 4,
#   ('มั่ง', 'บ้าง'): 4,
#   ('งัย', 'อย่างไร'): 4,
#   ('กะ', 'กับ'): 4,
#   ('ธ', 'ธนาคาร'): 4,
#   ('ล้ะ', 'ละ'): 4,
#   ('ไม่', 'ไม่'): 4,
#   ('เมื่อไหร่', 'เมื่อไร'): 4,
#   ('อัพเดต', 'อัปเดต'): 3,
#   ('ว่ะ', 'วะ'): 3,
#   ('ตังค์', 'สตางค์'): 3,
#   ('เนี้ย', 'เนี่ย'): 3,
#   ('ลิ้ง', 'ลิงค์'): 3,
#   ('ยาก', 'อยาก'): 3,
#   ('ล็อค', 'ล็อก'): 3,
#   ('ล้ะ', 'ล่ะ'): 3,
#   ('ความ', 'ความ'): 3,
#   ('อ้ะ', 'อ่ะ'): 3,
#   ('เนี่ย', 'นี่'): 3,
#   ('แอ๊บ', 'แอป'): 3,
#   ('แระ', 'และ'): 3,
#   ('เนี้ย', 'นี้'): 3,
#   ('อ่อ', 'เหรอ'): 3,
#   ('ป่ะ', 'หรือเปล่า'): 3,
#   ('มะ', 'ไหม'): 3,
#   ('กับ', 'กลับ'): 3,
#   ('นะ', 'น่ะ'): 3,
#   ('ป่ะ', 'ไป'): 3,
#   ('บาง', 'บ้าง'): 3,
#   ('รอง', 'ลอง'): 2,
#   ('เห้อ', 'เฮ้อ'): 2,
#   ('มะ', 'ไม่'): 2,
#   ('บช.', 'บัญชี'): 2,
#   ('พีช', 'พีซ'): 2,
#   ('ดาวโหลด', 'ดาวน์โหลด'): 2,
#   ('กุ', 'กู'): 2,
#   ('อัพ', 'อัปเดต'): 2,
#   ('แบง', 'แบงก์'): 2,
#   ('จ่ะ', 'จ้ะ'): 2,
#   ('ปะ', 'หรือเปล่า'): 2,
#   ('นี้', 'นี่'): 2,
#   ('สู้', 'สู่'): 2,
#   ('แอฟ', 'app'): 2,
#   ('โดน', 'โดย'): 2,
#   ('เฟส', 'เฟซ'): 2,
#   ('และ', 'แล้ว'): 2,
#   ('เสด', 'เสร็จ'): 2,
#   ('อ่อ', 'ออ'): 2,
#   ('ไม้', 'ไม่'): 2,
#   ('คัพ', 'ครับ'): 2,
#   ('ขอ', 'ของ'): 2,
#   ('นิ', 'นี้'): 2,
#   ('ม่ะ', 'ไม่'): 2,
#   ('ละ', 'แล้ว'): 2,
#   ('ไช่', 'ใช้'): 2,
#   ('เทอ', 'เธอ'): 2,
#   ('คห', 'ความเห็น'): 2,
#   ('ใม่', 'ไหม'): 2,
#   ('เน้', 'นี้'): 2,
#   ('แระ', 'แล้ว'): 2,
#   ('นิ', 'นี่'): 2,
#   ('ค่า', 'คะ'): 2,
#   ('อยาก', 'ยาก'): 1,
#   ('เตอ', 'เจอ'): 1,
#   ('k', 'k plus'): 1,
#   ('กับ', 'กัน'): 1,
#   ('ลิ้งค์', 'ลิงค์'): 1,
#   ('ซัก', 'สัก'): 1,
#   ('นิดนึง', 'นิดหนึ่ง'): 1,
#   ('เป็นไร', 'เป็น'): 1,
#   ('เด้อ', 'นะ'): 1,
#   ('ไว', 'ไว้'): 1,
#   ('ใช่', 'ใช่'): 1,
#   ('แบง', 'แบงค์'): 1,
#   ('ล้าง', 'บ้าง'): 1,
#   ('แอพ', 'app'): 1,
#   ('แระ', 'แหละ'): 1,
#   ('โปร', 'โปรโมชั่น'): 1,
#   ('เข้า', 'เขา'): 1,
#   ('อ่อ', 'หรอ'): 1,
#   ('เว', 'เวลา'): 1,
#   ('จะ', 'จ้ะ'): 1,
#   ('ดึก', 'ดึง'): 1,
#   ('กรุงเทพฯ', 'กรุงเทพ'): 1,
#   ('เมล', 'เมล์'): 1,
#   ('เนาะ', 'เน้อ'): 1,
#   ('มือ', 'มือถือ'): 1,
#   ('ชั้น', 'ฉัน'): 1,
#   ('แอด', 'แอดมิน'): 1,
#   ('ป่ะ', 'ป้ะ'): 1,
#   ('เซน', 'เซ็น'): 1,
#   ('เวบ', 'เว็บไซต์'): 1,
#   ('ตัง', 'เงิน'): 1,
#   ('ปั้ม', 'ปั๊ม'): 1,
#   ('หรอก', 'หรอ'): 1,
#   ('เบอ', 'เบลอ'): 1,
#   ('อะ', 'ล่ะ'): 1,
#   ('โปรโมชั่น', 'โปรโมชัน'): 1,
#   ('ปะ', 'ไป'): 1,
#   ('กาก', 'การ'): 1,
#   ('มาน', 'บัตร'): 1,
#   ('ช่วง', 'ช่วย'): 1,
#   ('ตัง', 'ตังค์'): 1,
#   ('กะ', 'ก็'): 1,
#   ('กัล', 'กัน'): 1,
#   ('นั้น', 'นั่น'): 1,
#   ('คราบ', 'ครับ'): 1,
#   ('ใส้', 'ไส้'): 1,
#   ('รีด', 'อีก'): 1,
#   ('ชัว', 'ชัวร์'): 1,
#   ('ค่าใช้จ่าย', 'ค่า'): 1,
#   ('ไม', 'ใช้จ่าย'): 1,
#   ('สมมุติ', 'สมมติ'): 1,
#   ('ใหม่', 'ไหม'): 1,
#   ('เพื่อ', 'เพิ่ม'): 1,
#   ('ม่', 'ไหม'): 1,
#   ('ดี', 'สวัสดี'): 1,
#   ('ต้อง', 'ตรง'): 1,
#   ('plus', 'k plus'): 1,
#   ('รับ', 'ครับ'): 1,
#   ('เว็ป', 'เว็บ'): 1,
#   ('จ่ะ', 'จ๊ะ'): 1,
#   ('รึป่าว', 'รึเปล่า'): 1,
#   ('ยิม', 'ยิ้ม'): 1,
#   ('ล้ะ', 'แล้ว'): 1,
#   ('ไป', 'ไม่'): 1,
#   ('เค้า', 'เข้า'): 1,
#   ('เว็ป', 'เว็บไซต์'): 1,
#   ('แล้ง', 'แล้ว'): 1,
#   ('ดด', 'กด'): 1,
#   ('ชะ', 'ซะ'): 1,
#   ('เข้า', 'ข้า'): 1,
#   ('อย่า', 'อยาก'): 1,
#   ('เพาะ', 'เพราะ'): 1,
#   ('บริหาร', 'บริการ'): 1,
#   ('เขา', 'เข้า'): 1,
#   ('เบอ', 'number'): 1,
#   ('แหละ', 'และ'): 1,
#   ('ป่าว', 'หรือเปล่า'): 1,
#   ('อะค่ะ', 'อะ'): 1,
#   ('จร้า', 'จ๊ะ'): 1,
#   ('ใช้', 'ใช้'): 1,
#   ('จ่ะ', 'คะ'): 1,
#   ('เดียว', 'เดี๋ยว'): 1,
#   ('ใส้', 'ใส่'): 1,
#   ('อิ', 'อี'): 1,
#   ('ข้อ', 'เขา'): 1,
#   ('เบอร์', 'number'): 1,
#   ('จ่ะ', 'จะ'): 1,
#   ('ตุ้', 'ตู้'): 0,
#   ('เบอร', 'เบอร์'): 0,
#   ('เช้ค', 'เช็ค'): 0,
#   ('บัชชี', 'บัญชี'): 0,
#   ('ยังใง', 'อย่างไร'): 0,
#   ('คร้าบบ?', 'ครับ'): 0,
#   ('อินเตอร์เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('ไหม่', 'ใหม่'): 0,
#   ('ค่', 'ค่ะ'): 0,
#   ('สมัค', 'สมัคร'): 0,
#   ('โทรศัพ', 'โทรศัพท์'): 0,
#   ('คครับ', 'ครับ'): 0,
#   ('ตอ้ง', 'ต้อง'): 0,
#   ('ที่อยุ่', 'ที่อยู่'): 0,
#   ('โทสับ', 'โทรศัพท์'): 0,
#   ('ออนไล', 'ออนไลน์'): 0,
#   ('อะรัย', 'อะไร'): 0,
#   ('สเตดเม้น', 'สเตทเม้นท์'): 0,
#   ('เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('บันชี', 'บัญชี'): 0,
#   ('โทรสับ', 'โทรศัพท์'): 0,
#   ('ต', 'ต'): 0,
#   (' ', '.'): 0,
#   ('ค่าาา', 'ค่ะ'): 0,
#   ('น่อย', 'หน่อย'): 0,
#   ('กุ้', 'กู้'): 0,
#   ('ยังใง', 'ยังไง'): 0,
#   ('เบอยุแล้ว', 'เบอร์อยู่แล้ว'): 0,
#   ('ล๊อก', 'ล็อก'): 0,
#   ('หรัส', 'รหัส'): 0,
#   ('เคาเตอร์', 'เคาน์เตอร์'): 0,
#   ('สามรถ', 'สามารถ'): 0,
#   ('คพ', 'ค่ะ'): 0,
#   ('เนต', 'อินเทอร์เน็ต'): 0,
#   ('สวัดดี', 'สวัสดี'): 0,
#   ('ก', 'ก'): 0,
#   ('ค่', 'คะ'): 0,
#   ('รีไฟแนน', 'รีไฟแนนซ์'): 0,
#   ('โทรศัพย์', 'โทรศัพท์'): 0,
#   ('เคดิต', 'เครดิต'): 0,
#   ('วีธี', 'วิธี'): 0,
#   ('ข้อมุล', 'ข้อมูล'): 0,
#   ('เปลียน', 'เปลี่ยน'): 0,
#   ('ใข่', 'ใช่'): 0,
#   ('ไทยพานิชย์', 'ไทยพาณิชย์'): 0,
#   ('โทรสัพ', 'โทรศัพท์'): 0,
#   ('ค่าาาาาาา', 'ค่ะ'): 0,
#   ('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0,
#   ('คพ', 'คะ'): 0,
#   ('เปิดบันชี', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'ค่ะ'): 0,
#   ('เด๋วนี้', 'เดี๋ยวนี้'): 0,
#   ('ไหม่', 'ไหม'): 0,
#   ('เปนไร', 'เป็นไร'): 0,
#   ('เน้ต', 'อินเทอร์เน็ต'): 0,
#   ('ร้องได้อ้ะ', 'ร้องได้อะ'): 0,
#   ('ค๊ะ', 'คะ'): 0,
#   ('ต่ะ', 'คะ'): 0,
#   ('คระบ', 'ครับ'): 0,
#   ('คนับ', 'ครับ'): 0,
#   ('ค', 'ค'): 0,
#   ('plusอ่ะคับ', 'อะครับ'): 0,
#   ('เนี่ยยย', 'เนี่ย'): 0,
#   ('ฮาาา', 'ฮา'): 0,
#   ('โดนจัย', 'โดนใจ'): 0,
#   ('คีับ', 'ครับ'): 0,
#   ('คอม', 'คอมพิวเตอร์'): 0,
#   ('เปี่ยน', 'เปลี่ยน'): 0,
#   ('แอพ', 'application'): 0,
#   ('ทา', 'มา'): 0,
#   ('สาธุ จร้า', 'สาธุ จ้า'): 0,
#   ('กะตัง', 'สตางค์'): 0,
#   ('ยัตร', 'บัตร'): 0,
#   ('พร้อมเพย์', 'พร้อมเพย์์'): 0,
#   ('คอลเซนเตอร์', 'คอลเซ็นเตอร์'): 0,
#   ('แลัว', 'แล้ว'): 0,
#   ('ธ', 'ธ'): 0,
#   ('วัน', 'วัน'): 0,
#   ('ฟัดดดด', 'ฟัด'): 0,
#   ('บัญขี', 'บัญชี'): 0,
#   ('หมดดด', 'หมด'): 0,
#   ('เเร้ว', 'แล้ว'): 0,
#   ('ต่ะ', 'ค่ะ'): 0,
#   ('คร่', 'ค่ะ'): 0,
#   ('คึดถึง', 'คิดถึง'): 0,
#   ('เป่น', 'เป็น'): 0,
#   ('เค้าาาาาาาาาา', 'เขา'): 0,
#   ('หราาาาา', 'หรือ'): 0,
#   ('ทำ', 'ทำ'): 0,
#   ('โห', 'โอ้โฮ'): 0,
#   ('แบงกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('ข้อมู', 'ข้อมูล'): 0,
#   ('ยังคงอยุ่', 'ยังคงอยู่'): 0,
#   ('สาธุฯคัพ', 'สาธุครับ'): 0,
#   ('ไม', 'ทำไม'): 0,
#   ('แล้ส', 'แล้ว'): 0,
#   ('เครือง', 'เครื่อง'): 0,
#   ('เเอป', 'แอพ'): 0,
#   ('พักงาน', 'พนักงาน'): 0,
#   ('คำ', 'ค้ำ'): 0,
#   ('อาทิตร์', 'อาทิตย์'): 0,
#   ('ตอ้งการ', 'ต้องการ'): 0,
#   ('ลหัส', 'รหัส'): 0,
#   ('แอพที่', 'แอปที่'): 0,
#   ('บ ช', 'บัญชี'): 0,
#   ('ก้คือ', 'ก็คือ'): 0,
#   ('เป็นไร', 'เป็นไร'): 0,
#   ('สมัด', 'สมัคร'): 0,
#   ('ให่', 'ให้'): 0,
#   ('สามรถเชค', 'สามารถเช็ค'): 0,
#   ('ค่ะ.', 'ค่ะ'): 0,
#   ('ลบกวน', 'รบกวน'): 0,
#   ('คค่ะ', 'คะ'): 0,
#   ('อาทิต', 'อาทิตย์'): 0,
#   ('ทำไหม', 'ทำไม'): 0,
#   ('หายอ่ะ', 'หายอะ'): 0,
#   ('ไงต่ออ่ะ', 'อย่างไรต่ออะ'): 0,
#   ('เคแบงค์', 'เคแบงก์'): 0,
#   ('สุดยอดดดด', 'สุดยอด'): 0,
#   ('น๊ะ', 'นะ'): 0,
#   ('นิดเห็น', 'คิดเห็น'): 0,
#   ('ใง', 'ไง'): 0,
#   ('ภึง', 'ถึง'): 0,
#   ('เรียร้อย', 'เรียบร้อย'): 0,
#   ('เปิดบช', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'คะ'): 0,
#   ('เบราเซอร์', 'เบราว์เซอร์'): 0,
#   ('เอ่า', 'อ้าว'): 0,
#   ('เค้าเตอ', 'เคาน์เตอร์'): 0,
#   ('ตลอดดด', 'ตลอด'): 0,
#   ('เพือน', 'เพื่อน'): 0,
#   ('k plus', 'k plus'): 0,
#   ('้เปลี่ยน', 'เปลี่ยน'): 0,
#   ('ออนไลน', 'ออนไลน์'): 0,
#   ('เตรื่อง', 'เครื่อง'): 0,
#   ('สริป', 'สลิป'): 0,
#   ('ตรงกัน', 'ตรงกัน'): 0,
#   ('คาฟฟ', 'ครับ'): 0,
#   ('เคโมบายพลาส', 'เคโมบายพลัส'): 0,
#   ('มากกกกกกกกกกกกกกกกก', 'มาก'): 0,
#   ('พร้อมเพ', 'พร้อมเพย์'): 0,
#   ('แอฟK+', 'แอพK+'): 0,
#   ('มัร', 'มัน'): 0,
#   ('ออม', 'ออม'): 0,
#   ('ทรัพ', 'ทรัพย์'): 0,
#   ('ค่เ', 'ค่ะ'): 0,
#   ('คึด', 'คิด'): 0,
#   ('ทำไม่', 'ทำไม'): 0,
#   ('แบล็คลิส', 'แบล็คลิสต์'): 0,
#   ('ธนคาร', 'ธนาคาร'): 0,
#   ('ใช่ไวไฟ', 'ใช้ไวไฟ'): 0,
#   ('อ่ะกู', 'อะกู'): 0,
#   ('อ่ะสิ', 'อะสิ'): 0,
#   ('สเตสเม้น', 'สเตทเม้นท์'): 0,
#   ('ตะกี้', 'เมื่อกี้'): 0,
#   ('ขอบตคุนคับ', 'ขอบคุณครับ'): 0,
#   ('สมัคk-plus', 'สมัครk-plus'): 0,
#   ('ล๊อคอิน', 'ล็อคอิน'): 0,
#   ('นะ', 'นะ'): 0,
#   ('ได้ป', 'ได้'): 0,
#   ('ใข้', 'ใช้'): 0,
#   ('ก้วิธีการ', 'ก็วิธีการ'): 0,
#   ('เนะนำ', 'แนะนำ'): 0,
#   ('แอพพลิเคชั่น', 'แอปพลิเคชัน'): 0,
#   ('ดงิน', 'เงิน'): 0,
#   ('ครับช', 'ครับ'): 0,
#   ('บ/ช', 'บัญชี'): 0,
#   ('คัห', 'ครับ'): 0,
#   ('อายัด', 'อายัติ'): 0,
#   ('เน้อะ', 'นะ'): 0,
#   ('ตำ่', 'ต่ำ'): 0,
#   ('ช่ม่', 'ใช่'): 0,
#   ('ส่วนบุคคนคับ', 'ส่วนบุคคลครับ'): 0,
#   ('มาอ่ะ', 'มาอะ'): 0,
#   ('อะเค', 'โอเค'): 0,
#   ('เงืน', 'เงิน'): 0,
#   ('ดิชั้น', 'ดิฉัน'): 0,
#   ('ปัย', 'ไป'): 0,
#   ('ล๊อคอิน', 'ล็อกอิน'): 0,
#   ('ได้', 'ได้'): 0,
#   ('คร้ง', 'ครั้ง'): 0,
#   ('มีป่าว', 'มีเปล่า'): 0,
#   ('้ครับ', 'ครับ'): 0,
#   ('น๊อน', 'นอน'): 0,
#   ('เคอะ', 'คะ'): 0,
#   ('ฝันดีราตรี', 'ฝันดีราตรี'): 0,
#   ('หมายเลยโทรศัพย์', 'หมายเลขโทรศัพท์'): 0,
#   ('อ่อ', 'ิอ๋อ'): 0,
#   ('.', '.'): 0,
#   ('รุ้จัก', 'รู้จัก'): 0,
#   ('อัติโนมัติ', 'อัตโนมัติ'): 0,
#   ('เคแบงค์กิ้ง', 'เคแบงก์กิ้ง'): 0,
#   ('บัณชี', 'บัญชี'): 0,
#   ('อินเตอเนต', 'อินเทอร์เน็ต'): 0,
#   ('ยังงัย', 'อย่างไง'): 0,
#   ('ค่ะ้', 'คะ'): 0,
#   ('มากกกกกกก', 'มาก'): 0,
#   ('เดยวบัตร', 'เดี๋ยว'): 0,
#   ('โม๊ดด', 'หมด'): 0,
#   ('ทำ', 'ทำไม'): 0,
#   ('เตียม', 'เตรียม'): 0,
#   ('ไมา', 'ไม่'): 0,
#   ('เปิดบัชชี', 'เปิดบัญชี'): 0,
#   ('ก้ดี', 'ก็ดี'): 0,
#   ('ใง', 'อย่างไร'): 0,
#   ('ตเอง', 'ต้อง'): 0,
#   ('คร้าบบ', 'ครับ'): 0,
#   ('มีป่าวค๊ะ', 'มีเปล่าคะ'): 0,
#   ('ป๋ม', 'ผม'): 0,
#   ('เพื่ม', 'เพิ่ม'): 0,
#   ('สเตดเม้น', 'สเตทเมนท์'): 0,
#   ('ใหมี', 'ใหม่'): 0,
#   ('ค่าาา', 'คะ'): 0,
#   ('แพตตินัม', 'แพลทินัม'): 0,
#   ('หรัสผ่าน', 'รหัสผ่าน'): 0,
#   ('อยุ่ดี', 'อยู่ดี'): 0,
#   ('ส ค บ เรยคะ', 'สคบ.เลยค่ะ'): 0,
#   ('ยังำงค่ะ', 'ยังไงคะ'): 0,
#   ('ไง', 'ไงิ'): 0,
#   ('อะ', 'อะ'): 0,
#   ('สคริป', 'สคริปต์'): 0,
#   ('ไหม่ป', 'ใหม่'): 0,
#   ('เครคิต', 'เครดิต'): 0,
#   ('ล๊อก', 'ล็อค'): 0,
#   ('คค่ะ', 'ค่ะ'): 0,
#   ('โทร', 'โทร'): 0,
#   ('รับแซ๊บ', 'รับทราบ'): 0,
#   ('ใช่จ่ายใหมค่ะ', 'ใช้จ่ายไหมคะ'): 0,
#   ('ส น', 'สน.'): 0,
#   ('เปอเซน', 'เปอร์เซ็นต์'): 0,
#   ('ช่ายยยย', 'ใช่'): 0,
#   ('ค๊ะ', 'ค่ะ'): 0,
#   ('อยู่อ่ะ', 'อยู่อะ'): 0,
#   ('ททราบ', 'ทราบ'): 0,
#   ('คับผม', 'ครับผม'): 0,
#   ('ซื้อง', 'ซื้อ'): 0,
#   ('นี่แระ', 'นี่แหละ'): 0,
#   ('เฟิสช้อย', 'เฟิร์สช้อยส์'): 0,
#   ('เมื่อไหร่กะเพรา', 'เมื่อไรกะเพรา'): 0,
#   ('ทีา', 'ที่'): 0,
#   ('โครตกาก', 'โคตรกาก'): 0,
#   ('หรือไป', 'หรือไป'): 0,
#   ('เปนอ่ะ', 'เป็นอะ'): 0,
#   ('รึยัง', 'รึยัง'): 0,
#   ('เงื้อนไข', 'เงื่อนไข'): 0,
#   ('อ่ะคับผม', 'อะครับผม'): 0,
#   ('อ่อ', '๋อ๋อ'): 0,
#   ('ตลอดดดด', 'ตลอด'): 0,
#   ('้เจ้าหน้าที่', 'เจ้าหน้าที่'): 0,
#   ('ธ.', 'ธนาคาร'): 0,
#   ('เดี่ยว', 'เดี๋ยว'): 0,
#   ('้เมื่อ', 'เมื่อ'): 0,
#   ('อ่ะภาพ', 'อะภาพ'): 0,
#   ('หักบช', 'หักบัญชี'): 0,
#   ('สิบถาม', 'สอบถาม'): 0,
#   ('มากอ่ะ', 'มากอะ'): 0,
#   ('สมัคk', 'สมัคร'): 0,
#   ('เคแบงเติม', 'เคแบงก์'): 0,
#   ('คใคร', 'ใคร'): 0,
#   ('เก๊า', 'เรา'): 0,
#   ('แบงค์กรุงเทพ', 'แบงก์กรุงเทพ'): 0,
#   ('ก กรุงไทย', 'กรุงไทย'): 0,
#   ('ครับบ', 'ครับ'): 0,
#   ('คร้าบผม', 'ครับผม'): 0,
#   ('อย่างรัย', 'อย่างไร'): 0,
#   ('เปนรัยคะ', 'เป็นไรค่ะ'): 0,
#   ('อะป่าวคับ', 'อะเปล่าครับ'): 0,
#   ('ยุแล้ว', 'อยู่แล้ว'): 0,
#   ('อ๊าววว', 'อ้าว'): 0,
#   ('ๆด้', 'ได้'): 0,
#   ('สมัคKBank', 'สมัครKBank'): 0,
#   ('ฮื้อออแแ', 'ฮือ'): 0,
#   ('ทวีทรัพย์เอ็กตร้า', 'ทวีทรัพย์เอ็กซ์ตร้า'): 0,
#   ('ยัยช้างด้า', 'ยายช้างด้า'): 0,
#   ('แอปฯ', 'application'): 0,
#   ('คนับ', 'ครับี่'): 0,
#   ('ฟฤหัส', 'พฤหัสบดี'): 0,
#   ('ป้ายบาร์โค้ดยังไงอ่ะ', 'ป้ายบาร์โค้ดอย่างไรอะ'): 0,
#   ('ก้เลย', 'ก็เลย'): 0,
#   ('อยู้', 'อยู่'): 0,
#   ('สิ้', 'สิ'): 0,
#   ('ทันที่ไม', 'ทันทีไม่'): 0,
#   ('เปลั่ยน', 'เปลี่ยน'): 0,
#   ('คคะ', 'ค่ะ'): 0,
#   ('เด๊๋ยว', 'เดี๋ยว'): 0,
#   ('ใหมาไมา', 'ใหม่ไม่'): 0,
#   ('ปิดบันชี', 'ปิดบัญชี'): 0,
#   ('ไฟแนน', 'ไฟแนนซ์'): 0,
#   ('กสิกรช', 'กสิกร'): 0,
#   ('แกไข', 'แก้ไข'): 0,
#   ('ใข่', 'ใช้'): 0,
#   ('ม้ย', 'ไหม'): 0,
#   ('ทราบถามอ่ะ', 'สอบถามอะ'): 0,
#   ('ช้อป', 'ชอป'): 0,
#   ('ยุแร้วอ่ะ', 'อยู่แล้วอะ'): 0,
#   ('กอีก', 'อีก'): 0,
#   ('มิ', 'มิ'): 0,
#   ('เดี่ยว', 'เดียว'): 0,
#   ('ก็เรย', 'ก็เลย'): 0,
#   ('ทำไรค้ะ', 'ทำไรคะ'): 0,
#   ('รอดดดดดด', 'รอด'): 0,
#   ('ทำไม่สมัค', 'ทำไมสมัคร'): 0,
#   ('แบ็งกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('เบอร์ึ่ะ', 'เบอร์'): 0,
#   ('คอลเซ็น', 'คอลเซ็นเตอร์'): 0,
#   ('ไวไฟอ่ะคับ', 'ไวไฟอะครับ'): 0,
#   ('รุ้ที่ยุ', 'รู้ที่อยู่'): 0,
#   ('ที่ยุ', 'ที่อยู่'): 0,
#   ('ลงอิน', 'ล็อคอิน'): 0,
#   ('อ่อคับบบ', 'อ้อครับ'): 0,
#   ('ๆม่', 'ไม่'): 0,
#   ('ขึ้นยุ', 'ขึ้นอยู่'): 0,
#   ('เช้ค', 'เช็ก'): 0,
#   ('เฟสบุ้ค', 'เฟซบุ๊ค'): 0,
#   ('ค้พ', 'ค่ะ'): 0,
#   ('เคแบงค์', 'promptpay'): 0,
#   ('เข้าจัย', 'เข้าใจ'): 0,
#   ('ม่มัน', 'มัน'): 0,
#   ('ตรวจเชค', 'ตรวจเช็ค'): 0,
#   ('ศัทพ์', 'โทรศัพท์'): 0,
#   ('ครับพ้ม', 'ครับผม'): 0,
#   ('คำแนะนำค้ะ', 'คำแนะนำค่ะ'): 0,
#   ('ล้อคอิน', 'ล็อคอิน'): 0,
#   ('ค่ะ', 'ค่ะ'): 0,
#   ('ระบ', 'รับ'): 0,
#   ('K My play', 'K My pay'): 0,
#   ('คร่', 'คะ'): 0,
#   ('ล้อคอิน', 'ล็อกอิน'): 0,
#   ('อ่ะ', 'อ่อะ'): 0,
#   ('เน้ต', 'เน็ต'): 0,
#   ('สเตสเม้น', 'สเตทเมนท์'): 0,
#   ('ก่า', 'กว่า'): 0,
#   ('ยุ่ไกล', 'อยู่ไกล'): 0,
#   ('คร้าทำไม่', 'คะทำไม'): 0,
#   ('แบงค์กรุงไทย', 'แบงก์กรุงไทย'): 0,
#   ('สมัครอะคับ', 'สมัครอะครับ'): 0,
#   ('คับ', 'ครับบ'): 0,
#   ('ปัจุบัน', 'ปัจจุบัน'): 0,
#   ('อิกเสียได้', 'อีกเสียดาย'): 0},
#  'msp_word_dict_fill': {('อ่ะ', 'อะ'): 493,
#   ('ค่ะ', 'คะ'): 386,
#   ('เบอ', 'เบอร์'): 307,
#   ('คะ', 'ค่ะ'): 246,
#   ('มั้ย', 'ไหม'): 196,
#   ('คับ', 'ครับ'): 177,
#   ('อ่อ', 'อ๋อ'): 131,
#   ('ค้ะ', 'คะ'): 131,
#   ('เปน', 'เป็น'): 129,
#   ('ก้', 'ก็'): 113,
#   ('แอพ', 'แอป'): 110,
#   ('ยังไง', 'อย่างไร'): 108,
#   ('ค้ะ', 'ค่ะ'): 106,
#   ('ใด้', 'ได้'): 91,
#   ('มั๊ย', 'ไหม'): 80,
#   ('ไง', 'อย่างไร'): 62,
#   ('ใหม', 'ไหม'): 59,
#   ('ไม', 'ไหม'): 59,
#   ('ม่', 'ไม่'): 50,
#   ('แอฟ', 'แอป'): 46,
#   ('บช', 'บัญชี'): 43,
#   ('อยุ่', 'อยู่'): 42,
#   ('รุ้', 'รู้'): 40,
#   ('อ้ะ', 'อะ'): 39,
#   ('ตัง', 'สตางค์'): 37,
#   ('ใหน', 'ไหน'): 33,
#   ('ก้อ', 'ก็'): 32,
#   ('ขอบคุน', 'ขอบคุณ'): 30,
#   ('เรย', 'เลย'): 27,
#   ('เค้า', 'เขา'): 26,
#   ('คัฟ', 'ครับ'): 25,
#   ('ใม่', 'ไม่'): 25,
#   ('ค', 'คะ'): 24,
#   ('แร้ว', 'แล้ว'): 20,
#   ('ไช่', 'ใช่'): 20,
#   ('ได่', 'ได้'): 17,
#   ('ขอโทด', 'ขอโทษ'): 17,
#   ('คร้า', 'ค่ะ'): 16,
#   ('ยังงัย', 'อย่างไร'): 14,
#   ('ยุ่', 'อยู่'): 13,
#   ('นึง', 'หนึ่ง'): 13,
#   ('ไม', 'ไม่'): 12,
#   ('ยุ', 'อยู่'): 11,
#   ('ค่า', 'ค่ะ'): 11,
#   ('น้ะ', 'นะ'): 11,
#   ('ไม๊', 'ไหม'): 10,
#   ('ดิ', 'สิ'): 10,
#   ('เท่าไหร่', 'เท่าไร'): 9,
#   ('เด๋ว', 'เดี๋ยว'): 8,
#   ('ด้', 'ได้'): 8,
#   ('มัย', 'ไหม'): 8,
#   ('ค', 'ค่ะ'): 8,
#   ('คร้าบ', 'ครับ'): 7,
#   ('ใว้', 'ไว้'): 7,
#   ('ไห้', 'ให้'): 7,
#   ('คร้า', 'คะ'): 7,
#   ('น่ะ', 'นะ'): 6,
#   ('โท', 'โทร'): 6,
#   ('ใช่', 'ใช้'): 6,
#   ('ด้าย', 'ได้'): 6,
#   ('เปง', 'เป็น'): 6,
#   ('ม่ะ', 'ไหม'): 6,
#   ('หรอ', 'หรือ'): 5,
#   ('พึ่ง', 'เพิ่ง'): 5,
#   ('หรอ', 'เหรอ'): 4,
#   ('พิม', 'พิมพ์'): 4,
#   ('อิก', 'อีก'): 4,
#   ('เห้น', 'เห็น'): 4,
#   ('เชค', 'เช็ค'): 3,
#   ('ตังค์', 'สตางค์'): 3,
#   ('ครัช', 'ครับ'): 3,
#   ('เบย', 'เลย'): 3,
#   ('ที', 'ที่'): 3,
#   ('รึ', 'หรือ'): 3,
#   ('งัย', 'อย่างไร'): 3,
#   ('งัย', 'ไง'): 2,
#   ('จิง', 'จริง'): 2,
#   ('ใช้', 'ใช่'): 2,
#   ('นู๋', 'หนู'): 2,
#   ('เนาะ', 'นะ'): 2,
#   ('ให', 'ให้'): 2,
#   ('มะ', 'ไม่'): 2,
#   ('หรือป่าว', 'หรือเปล่า'): 2,
#   ('มั่ง', 'บ้าง'): 2,
#   ('กะ', 'กับ'): 2,
#   ('ความ', 'ความ'): 2,
#   ('ธ', 'ธนาคาร'): 2,
#   ('เนอะ', 'นะ'): 2,
#   ('แอ๊บ', 'แอป'): 2,
#   ('ล้ะ', 'ละ'): 2,
#   ('เหรอ', 'หรือ'): 2,
#   ('มะ', 'ไหม'): 2,
#   ('เชค', 'เช็ก'): 2,
#   ('ม่ะ', 'ไม่'): 2,
#   ('ยังงัย', 'ยังไง'): 1,
#   ('นี่', 'นี้'): 1,
#   ('รึป่าว', 'หรือเปล่า'): 1,
#   ('เนี้ย', 'เนี่ย'): 1,
#   ('เห้อ', 'เฮ้อ'): 1,
#   ('พนง', 'พนักงาน'): 1,
#   ('ประมาน', 'ประมาณ'): 1,
#   ('โหลด', 'ดาวน์โหลด'): 1,
#   ('โทร', 'โทรศัพท์'): 1,
#   ('ล็อค', 'ล็อก'): 1,
#   ('แบง', 'แบงก์'): 1,
#   ('ล่ะ', 'ละ'): 1,
#   ('สู้', 'สู่'): 1,
#   ('เนี้ย', 'นี้'): 1,
#   ('ไม้', 'ไม่'): 1,
#   ('เวป', 'เว็บ'): 1,
#   ('คัพ', 'ครับ'): 1,
#   ('เบอ', 'เบลอ'): 1,
#   ('กะ', 'ก็'): 1,
#   ('คราบ', 'ครับ'): 1,
#   ('ใส้', 'ไส้'): 1,
#   ('ไช่', 'ใช้'): 1,
#   ('เทอ', 'เธอ'): 1,
#   ('บาง', 'บ้าง'): 1,
#   ('คห', 'ความเห็น'): 1,
#   ('ใม่', 'ไหม'): 1,
#   ('แระ', 'แล้ว'): 1,
#   ('รับ', 'ครับ'): 1,
#   ('ล้ะ', 'แล้ว'): 1,
#   ('ค่า', 'คะ'): 1,
#   ('จ่ะ', 'คะ'): 1,
#   ('เดียว', 'เดี๋ยว'): 1,
#   ('ข้อ', 'เขา'): 1,
#   ('ตุ้', 'ตู้'): 0,
#   ('แอฟ', 'แอพ'): 0,
#   ('เบอร', 'เบอร์'): 0,
#   ('อัพเดต', 'อัปเดต'): 0,
#   ('เช้ค', 'เช็ค'): 0,
#   ('อยาก', 'ยาก'): 0,
#   ('จ้า', 'จ้ะ'): 0,
#   ('บัชชี', 'บัญชี'): 0,
#   ('ยังใง', 'อย่างไร'): 0,
#   ('คร้าบบ?', 'ครับ'): 0,
#   ('ป่าว', 'เปล่า'): 0,
#   ('อินเตอร์เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('ไหม่', 'ใหม่'): 0,
#   ('ค่', 'ค่ะ'): 0,
#   ('สมัค', 'สมัคร'): 0,
#   ('อะ', 'อะไร'): 0,
#   ('โทรศัพ', 'โทรศัพท์'): 0,
#   ('คครับ', 'ครับ'): 0,
#   ('ตอ้ง', 'ต้อง'): 0,
#   ('รอง', 'ลอง'): 0,
#   ('ปะ', 'เปล่า'): 0,
#   ('สัส', 'สัตว์'): 0,
#   ('ที่อยุ่', 'ที่อยู่'): 0,
#   ('เบอร์', 'หมายเลข'): 0,
#   ('โทสับ', 'โทรศัพท์'): 0,
#   ('ออนไล', 'ออนไลน์'): 0,
#   ('อะรัย', 'อะไร'): 0,
#   ('สเตดเม้น', 'สเตทเม้นท์'): 0,
#   ('เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('บันชี', 'บัญชี'): 0,
#   ('โทรสับ', 'โทรศัพท์'): 0,
#   ('ต', 'ต'): 0,
#   (' ', '.'): 0,
#   ('ค่าาา', 'ค่ะ'): 0,
#   ('น่อย', 'หน่อย'): 0,
#   ('กุ้', 'กู้'): 0,
#   ('แอป', 'แอพ'): 0,
#   ('ว่ะ', 'วะ'): 0,
#   ('ป่ะ', 'เปล่า'): 0,
#   ('ยังใง', 'ยังไง'): 0,
#   ('แต', 'แต่'): 0,
#   ('เบอยุแล้ว', 'เบอร์อยู่แล้ว'): 0,
#   ('เตอ', 'เจอ'): 0,
#   ('ล๊อก', 'ล็อก'): 0,
#   ('หรัส', 'รหัส'): 0,
#   ('เคาเตอร์', 'เคาน์เตอร์'): 0,
#   ('สามรถ', 'สามารถ'): 0,
#   ('คพ', 'ค่ะ'): 0,
#   ('เนต', 'อินเทอร์เน็ต'): 0,
#   ('สวัดดี', 'สวัสดี'): 0,
#   ('ก', 'ก'): 0,
#   ('ค่', 'คะ'): 0,
#   ('รีไฟแนน', 'รีไฟแนนซ์'): 0,
#   ('อ่อ', 'อ้อ'): 0,
#   ('โทรศัพย์', 'โทรศัพท์'): 0,
#   ('เคดิต', 'เครดิต'): 0,
#   ('อะ', 'อ่ะ'): 0,
#   ('วีธี', 'วิธี'): 0,
#   ('ข้อมุล', 'ข้อมูล'): 0,
#   ('เปลียน', 'เปลี่ยน'): 0,
#   ('ใข่', 'ใช่'): 0,
#   ('ไทยพานิชย์', 'ไทยพาณิชย์'): 0,
#   ('ละ', 'ล่ะ'): 0,
#   ('โทรสัพ', 'โทรศัพท์'): 0,
#   ('ค่าาาาาาา', 'ค่ะ'): 0,
#   ('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0,
#   ('ลิ้ง', 'ลิงค์'): 0,
#   ('คพ', 'คะ'): 0,
#   ('ไร', 'อะไร'): 0,
#   ('เปิดบันชี', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'ค่ะ'): 0,
#   ('เด๋วนี้', 'เดี๋ยวนี้'): 0,
#   ('ไหม่', 'ไหม'): 0,
#   ('เปนไร', 'เป็นไร'): 0,
#   ('เน้ต', 'อินเทอร์เน็ต'): 0,
#   ('ร้องได้อ้ะ', 'ร้องได้อะ'): 0,
#   ('เช็ค', 'เช็ก'): 0,
#   ('ค๊ะ', 'คะ'): 0,
#   ('ต่ะ', 'คะ'): 0,
#   ('คระบ', 'ครับ'): 0,
#   ('คุน', 'คุณ'): 0,
#   ('คนับ', 'ครับ'): 0,
#   ('มี', 'มี'): 0,
#   ('ค', 'ค'): 0,
#   ('เวป', 'เว็บไซต์'): 0,
#   ('k', 'k plus'): 0,
#   ('plusอ่ะคับ', 'อะครับ'): 0,
#   ('เนี่ยยย', 'เนี่ย'): 0,
#   ('กับ', 'กัน'): 0,
#   ('ลิ้งค์', 'ลิงค์'): 0,
#   ('หน่ะ', 'น่ะ'): 0,
#   ('ฮาาา', 'ฮา'): 0,
#   ('จร้า', 'จ้ะ'): 0,
#   ('โดนจัย', 'โดนใจ'): 0,
#   ('คีับ', 'ครับ'): 0,
#   ('คอม', 'คอมพิวเตอร์'): 0,
#   ('เปี่ยน', 'เปลี่ยน'): 0,
#   ('แอพ', 'application'): 0,
#   ('แบงค์', 'แบงก์'): 0,
#   ('ไม่', 'ไหม'): 0,
#   ('ทา', 'มา'): 0,
#   ('สาธุ จร้า', 'สาธุ จ้า'): 0,
#   ('รึยัง', 'หรือยัง'): 0,
#   ('กะตัง', 'สตางค์'): 0,
#   ('ยัตร', 'บัตร'): 0,
#   ('บช.', 'บัญชี'): 0,
#   ('พร้อมเพย์', 'พร้อมเพย์์'): 0,
#   ('คอลเซนเตอร์', 'คอลเซ็นเตอร์'): 0,
#   ('แลัว', 'แล้ว'): 0,
#   ('ธ', 'ธ'): 0,
#   ('ซัก', 'สัก'): 0,
#   ('วัน', 'วัน'): 0,
#   ('พีช', 'พีซ'): 0,
#   ('ฟัดดดด', 'ฟัด'): 0,
#   ('ดาวโหลด', 'ดาวน์โหลด'): 0,
#   ('กุ', 'กู'): 0,
#   ('บัญขี', 'บัญชี'): 0,
#   ('หมดดด', 'หมด'): 0,
#   ('เเร้ว', 'แล้ว'): 0,
#   ('ต่ะ', 'ค่ะ'): 0,
#   ('นิดนึง', 'นิดหนึ่ง'): 0,
#   ('คร่', 'ค่ะ'): 0,
#   ('คึดถึง', 'คิดถึง'): 0,
#   ('เป่น', 'เป็น'): 0,
#   ('ป่ะ', 'ปะ'): 0,
#   ('เค้าาาาาาาาาา', 'เขา'): 0,
#   ('หราาาาา', 'หรือ'): 0,
#   ('ทำ', 'ทำ'): 0,
#   ('โห', 'โอ้โฮ'): 0,
#   ('แบงกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('ข้อมู', 'ข้อมูล'): 0,
#   ('ยาก', 'อยาก'): 0,
#   ('ยังคงอยุ่', 'ยังคงอยู่'): 0,
#   ('เนี้ย', 'นี่'): 0,
#   ('เป็นไร', 'เป็น'): 0,
#   ('สาธุฯคัพ', 'สาธุครับ'): 0,
#   ('ไม', 'ทำไม'): 0,
#   ('แล้ส', 'แล้ว'): 0,
#   ('เด้อ', 'นะ'): 0,
#   ('ไว', 'ไว้'): 0,
#   ('อัพ', 'อัปเดต'): 0,
#   ('เครือง', 'เครื่อง'): 0,
#   ('เเอป', 'แอพ'): 0,
#   ('จ่ะ', 'จ้ะ'): 0,
#   ('พักงาน', 'พนักงาน'): 0,
#   ('คำ', 'ค้ำ'): 0,
#   ('ปะ', 'หรือเปล่า'): 0,
#   ('ล้ะ', 'ล่ะ'): 0,
#   ('อาทิตร์', 'อาทิตย์'): 0,
#   ('นี้', 'นี่'): 0,
#   ('ใช่', 'ใช่'): 0,
#   ('ตอ้งการ', 'ต้องการ'): 0,
#   ('ลหัส', 'รหัส'): 0,
#   ('แอพที่', 'แอปที่'): 0,
#   ('บ ช', 'บัญชี'): 0,
#   ('ก้คือ', 'ก็คือ'): 0,
#   ('แบง', 'แบงค์'): 0,
#   ('เป็นไร', 'เป็นไร'): 0,
#   ('สมัด', 'สมัคร'): 0,
#   ('ให่', 'ให้'): 0,
#   ('สามรถเชค', 'สามารถเช็ค'): 0,
#   ('ค่ะ.', 'ค่ะ'): 0,
#   ('ลบกวน', 'รบกวน'): 0,
#   ('คค่ะ', 'คะ'): 0,
#   ('อาทิต', 'อาทิตย์'): 0,
#   ('ทำไหม', 'ทำไม'): 0,
#   ('หายอ่ะ', 'หายอะ'): 0,
#   ('ไงต่ออ่ะ', 'อย่างไรต่ออะ'): 0,
#   ('ล้าง', 'บ้าง'): 0,
#   ('เคแบงค์', 'เคแบงก์'): 0,
#   ('สุดยอดดดด', 'สุดยอด'): 0,
#   ('น๊ะ', 'นะ'): 0,
#   ('นิดเห็น', 'คิดเห็น'): 0,
#   ('ใง', 'ไง'): 0,
#   ('ภึง', 'ถึง'): 0,
#   ('เรียร้อย', 'เรียบร้อย'): 0,
#   ('เปิดบช', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'คะ'): 0,
#   ('เบราเซอร์', 'เบราว์เซอร์'): 0,
#   ('เอ่า', 'อ้าว'): 0,
#   ('เค้าเตอ', 'เคาน์เตอร์'): 0,
#   ('แอพ', 'app'): 0,
#   ('แอฟ', 'app'): 0,
#   ('แระ', 'แหละ'): 0,
#   ('โดน', 'โดย'): 0,
#   ('ตลอดดด', 'ตลอด'): 0,
#   ('โปร', 'โปรโมชั่น'): 0,
#   ('เพือน', 'เพื่อน'): 0,
#   ('k plus', 'k plus'): 0,
#   ('เฟส', 'เฟซ'): 0,
#   ('้เปลี่ยน', 'เปลี่ยน'): 0,
#   ('อัพเดท', 'อัปเดต'): 0,
#   ('ออนไลน', 'ออนไลน์'): 0,
#   ('เตรื่อง', 'เครื่อง'): 0,
#   ('เข้า', 'เขา'): 0,
#   ('อ้ะ', 'อ่ะ'): 0,
#   ('สริป', 'สลิป'): 0,
#   ('ตรงกัน', 'ตรงกัน'): 0,
#   ('คาฟฟ', 'ครับ'): 0,
#   ('เคโมบายพลาส', 'เคโมบายพลัส'): 0,
#   ('มากกกกกกกกกกกกกกกกก', 'มาก'): 0,
#   ('พร้อมเพ', 'พร้อมเพย์'): 0,
#   ('และ', 'แล้ว'): 0,
#   ('เนี่ย', 'นี่'): 0,
#   ('แอฟK+', 'แอพK+'): 0,
#   ('มัร', 'มัน'): 0,
#   ('ออม', 'ออม'): 0,
#   ('ทรัพ', 'ทรัพย์'): 0,
#   ('เสด', 'เสร็จ'): 0,
#   ('ค่เ', 'ค่ะ'): 0,
#   ('คึด', 'คิด'): 0,
#   ('ทำไม่', 'ทำไม'): 0,
#   ('เนต', 'เน็ต'): 0,
#   ('แบล็คลิส', 'แบล็คลิสต์'): 0,
#   ('ธนคาร', 'ธนาคาร'): 0,
#   ('อ่อ', 'ออ'): 0,
#   ('ใช่ไวไฟ', 'ใช้ไวไฟ'): 0,
#   ('อ่ะกู', 'อะกู'): 0,
#   ('อ่ะสิ', 'อะสิ'): 0,
#   ('อ่อ', 'หรอ'): 0,
#   ('สเตสเม้น', 'สเตทเม้นท์'): 0,
#   ('ตะกี้', 'เมื่อกี้'): 0,
#   ('ขอบตคุนคับ', 'ขอบคุณครับ'): 0,
#   ('สมัคk-plus', 'สมัครk-plus'): 0,
#   ('เว', 'เวลา'): 0,
#   ('ล๊อคอิน', 'ล็อคอิน'): 0,
#   ('จะ', 'จ้ะ'): 0,
#   ('นะ', 'นะ'): 0,
#   ('แระ', 'และ'): 0,
#   ('ได้ป', 'ได้'): 0,
#   ('ใข้', 'ใช้'): 0,
#   ('ดึก', 'ดึง'): 0,
#   ('กรุงเทพฯ', 'กรุงเทพ'): 0,
#   ('ก้วิธีการ', 'ก็วิธีการ'): 0,
#   ('เมล', 'เมล์'): 0,
#   ('เนะนำ', 'แนะนำ'): 0,
#   ('ไม่', 'ไม่'): 0,
#   ('แอพพลิเคชั่น', 'แอปพลิเคชัน'): 0,
#   ('เนาะ', 'เน้อ'): 0,
#   ('ดงิน', 'เงิน'): 0,
#   ('มือ', 'มือถือ'): 0,
#   ('ชั้น', 'ฉัน'): 0,
#   ('ครับช', 'ครับ'): 0,
#   ('แอด', 'แอดมิน'): 0,
#   ('บ/ช', 'บัญชี'): 0,
#   ('คัห', 'ครับ'): 0,
#   ('อายัด', 'อายัติ'): 0,
#   ('เน้อะ', 'นะ'): 0,
#   ('ตำ่', 'ต่ำ'): 0,
#   ('ป่ะ', 'ป้ะ'): 0,
#   ('เซน', 'เซ็น'): 0,
#   ('ช่ม่', 'ใช่'): 0,
#   ('ส่วนบุคคนคับ', 'ส่วนบุคคลครับ'): 0,
#   ('เวบ', 'เว็บไซต์'): 0,
#   ('ตัง', 'เงิน'): 0,
#   ('อ่อ', 'เหรอ'): 0,
#   ('มาอ่ะ', 'มาอะ'): 0,
#   ('อะเค', 'โอเค'): 0,
#   ('เงืน', 'เงิน'): 0,
#   ('ดิชั้น', 'ดิฉัน'): 0,
#   ('ปั้ม', 'ปั๊ม'): 0,
#   ('ป่ะ', 'หรือเปล่า'): 0,
#   ('ปัย', 'ไป'): 0,
#   ('หรอก', 'หรอ'): 0,
#   ('จร้า', 'จ้า'): 0,
#   ('ล๊อคอิน', 'ล็อกอิน'): 0,
#   ('ได้', 'ได้'): 0,
#   ('คร้ง', 'ครั้ง'): 0,
#   ('มีป่าว', 'มีเปล่า'): 0,
#   ('้ครับ', 'ครับ'): 0,
#   ('น๊อน', 'นอน'): 0,
#   ('เคอะ', 'คะ'): 0,
#   ('ฝันดีราตรี', 'ฝันดีราตรี'): 0,
#   ('หมายเลยโทรศัพย์', 'หมายเลขโทรศัพท์'): 0,
#   ('อ่อ', 'ิอ๋อ'): 0,
#   ('ขอ', 'ของ'): 0,
#   ('.', '.'): 0,
#   ('นิ', 'นี้'): 0,
#   ('รุ้จัก', 'รู้จัก'): 0,
#   ('อัติโนมัติ', 'อัตโนมัติ'): 0,
#   ('อะ', 'ล่ะ'): 0,
#   ('โปรโมชั่น', 'โปรโมชัน'): 0,
#   ('เคแบงค์กิ้ง', 'เคแบงก์กิ้ง'): 0,
#   ('บัณชี', 'บัญชี'): 0,
#   ('อินเตอเนต', 'อินเทอร์เน็ต'): 0,
#   ('ยังงัย', 'อย่างไง'): 0,
#   ('ค่ะ้', 'คะ'): 0,
#   ('ปะ', 'ไป'): 0,
#   ('กาก', 'การ'): 0,
#   ('มากกกกกกก', 'มาก'): 0,
#   ('เดยวบัตร', 'เดี๋ยว'): 0,
#   ('มาน', 'บัตร'): 0,
#   ('โม๊ดด', 'หมด'): 0,
#   ('ทำ', 'ทำไม'): 0,
#   ('เตียม', 'เตรียม'): 0,
#   ('ไมา', 'ไม่'): 0,
#   ('เปิดบัชชี', 'เปิดบัญชี'): 0,
#   ('ก้ดี', 'ก็ดี'): 0,
#   ('ช่วง', 'ช่วย'): 0,
#   ('ใง', 'อย่างไร'): 0,
#   ('ละ', 'แล้ว'): 0,
#   ('ตเอง', 'ต้อง'): 0,
#   ('คร้าบบ', 'ครับ'): 0,
#   ('กับ', 'กลับ'): 0,
#   ('มีป่าวค๊ะ', 'มีเปล่าคะ'): 0,
#   ('ป๋ม', 'ผม'): 0,
#   ('เพื่ม', 'เพิ่ม'): 0,
#   ('สเตดเม้น', 'สเตทเมนท์'): 0,
#   ('ใหมี', 'ใหม่'): 0,
#   ('ค่าาา', 'คะ'): 0,
#   ('นะ', 'น่ะ'): 0,
#   ('แพตตินัม', 'แพลทินัม'): 0,
#   ('เมื่อไหร่', 'เมื่อไร'): 0,
#   ('หรัสผ่าน', 'รหัสผ่าน'): 0,
#   ('อยุ่ดี', 'อยู่ดี'): 0,
#   ('ตัง', 'ตังค์'): 0,
#   ('กัล', 'กัน'): 0,
#   ('นั้น', 'นั่น'): 0,
#   ('ส ค บ เรยคะ', 'สคบ.เลยค่ะ'): 0,
#   ('ยังำงค่ะ', 'ยังไงคะ'): 0,
#   ('ไง', 'ไงิ'): 0,
#   ('อะ', 'อะ'): 0,
#   ('สคริป', 'สคริปต์'): 0,
#   ('ไหม่ป', 'ใหม่'): 0,
#   ('เครคิต', 'เครดิต'): 0,
#   ('ล๊อก', 'ล็อค'): 0,
#   ('คค่ะ', 'ค่ะ'): 0,
#   ('โทร', 'โทร'): 0,
#   ('รับแซ๊บ', 'รับทราบ'): 0,
#   ('ใช่จ่ายใหมค่ะ', 'ใช้จ่ายไหมคะ'): 0,
#   ('ส น', 'สน.'): 0,
#   ('เปอเซน', 'เปอร์เซ็นต์'): 0,
#   ('ป่ะ', 'ไป'): 0,
#   ('ช่ายยยย', 'ใช่'): 0,
#   ('ค๊ะ', 'ค่ะ'): 0,
#   ('อยู่อ่ะ', 'อยู่อะ'): 0,
#   ('รีด', 'อีก'): 0,
#   ('ชัว', 'ชัวร์'): 0,
#   ('ททราบ', 'ทราบ'): 0,
#   ('คับผม', 'ครับผม'): 0,
#   ('ซื้อง', 'ซื้อ'): 0,
#   ('นี่แระ', 'นี่แหละ'): 0,
#   ('เฟิสช้อย', 'เฟิร์สช้อยส์'): 0,
#   ('ค่าใช้จ่าย', 'ค่า'): 0,
#   ('ไม', 'ใช้จ่าย'): 0,
#   ('เมื่อไหร่กะเพรา', 'เมื่อไรกะเพรา'): 0,
#   ('ทีา', 'ที่'): 0,
#   ('โครตกาก', 'โคตรกาก'): 0,
#   ('สมมุติ', 'สมมติ'): 0,
#   ('หรือไป', 'หรือไป'): 0,
#   ('เปนอ่ะ', 'เป็นอะ'): 0,
#   ('รึยัง', 'รึยัง'): 0,
#   ('เงื้อนไข', 'เงื่อนไข'): 0,
#   ('อ่ะคับผม', 'อะครับผม'): 0,
#   ('ใหม่', 'ไหม'): 0,
#   ('อ่อ', '๋อ๋อ'): 0,
#   ('ตลอดดดด', 'ตลอด'): 0,
#   ('เพื่อ', 'เพิ่ม'): 0,
#   ('้เจ้าหน้าที่', 'เจ้าหน้าที่'): 0,
#   ('ธ.', 'ธนาคาร'): 0,
#   ('เดี่ยว', 'เดี๋ยว'): 0,
#   ('ม่', 'ไหม'): 0,
#   ('ยัง', 'ยังไง'): 0,
#   ('้เมื่อ', 'เมื่อ'): 0,
#   ('เน้', 'นี้'): 0,
#   ('อ่ะภาพ', 'อะภาพ'): 0,
#   ('หักบช', 'หักบัญชี'): 0,
#   ('ดี', 'สวัสดี'): 0,
#   ('สิบถาม', 'สอบถาม'): 0,
#   ('ต้อง', 'ตรง'): 0,
#   ('มากอ่ะ', 'มากอะ'): 0,
#   ('สมัคk', 'สมัคร'): 0,
#   ('plus', 'k plus'): 0,
#   ('เคแบงเติม', 'เคแบงก์'): 0,
#   ('เว็ป', 'เว็บ'): 0,
#   ('คใคร', 'ใคร'): 0,
#   ('เก๊า', 'เรา'): 0,
#   ('แบงค์กรุงเทพ', 'แบงก์กรุงเทพ'): 0,
#   ('จ่ะ', 'จ๊ะ'): 0,
#   ('รึป่าว', 'รึเปล่า'): 0,
#   ('ยิม', 'ยิ้ม'): 0,
#   ('ก กรุงไทย', 'กรุงไทย'): 0,
#   ('ครับบ', 'ครับ'): 0,
#   ('คร้าบผม', 'ครับผม'): 0,
#   ('อย่างรัย', 'อย่างไร'): 0,
#   ('เปนรัยคะ', 'เป็นไรค่ะ'): 0,
#   ('อะป่าวคับ', 'อะเปล่าครับ'): 0,
#   ('ยุแล้ว', 'อยู่แล้ว'): 0,
#   ('อ๊าววว', 'อ้าว'): 0,
#   ('ๆด้', 'ได้'): 0,
#   ('สมัคKBank', 'สมัครKBank'): 0,
#   ('ไป', 'ไม่'): 0,
#   ('ฮื้อออแแ', 'ฮือ'): 0,
#   ('ทวีทรัพย์เอ็กตร้า', 'ทวีทรัพย์เอ็กซ์ตร้า'): 0,
#   ('ยัยช้างด้า', 'ยายช้างด้า'): 0,
#   ('แอปฯ', 'application'): 0,
#   ('เค้า', 'เข้า'): 0,
#   ('คนับ', 'ครับี่'): 0,
#   ('นิ', 'นี่'): 0,
#   ('ฟฤหัส', 'พฤหัสบดี'): 0,
#   ('ป้ายบาร์โค้ดยังไงอ่ะ', 'ป้ายบาร์โค้ดอย่างไรอะ'): 0,
#   ('เว็ป', 'เว็บไซต์'): 0,
#   ('ก้เลย', 'ก็เลย'): 0,
#   ('แล้ง', 'แล้ว'): 0,
#   ('อยู้', 'อยู่'): 0,
#   ('สิ้', 'สิ'): 0,
#   ('ดด', 'กด'): 0,
#   ('ทันที่ไม', 'ทันทีไม่'): 0,
#   ('ชะ', 'ซะ'): 0,
#   ('เปลั่ยน', 'เปลี่ยน'): 0,
#   ('คคะ', 'ค่ะ'): 0,
#   ('เข้า', 'ข้า'): 0,
#   ('เด๊๋ยว', 'เดี๋ยว'): 0,
#   ('ใหมาไมา', 'ใหม่ไม่'): 0,
#   ('ปิดบันชี', 'ปิดบัญชี'): 0,
#   ('ไฟแนน', 'ไฟแนนซ์'): 0,
#   ('กสิกรช', 'กสิกร'): 0,
#   ('แกไข', 'แก้ไข'): 0,
#   ('อย่า', 'อยาก'): 0,
#   ('ใข่', 'ใช้'): 0,
#   ('ม้ย', 'ไหม'): 0,
#   ('เพาะ', 'เพราะ'): 0,
#   ('บริหาร', 'บริการ'): 0,
#   ('เขา', 'เข้า'): 0,
#   ('ทราบถามอ่ะ', 'สอบถามอะ'): 0,
#   ('ช้อป', 'ชอป'): 0,
#   ('ยุแร้วอ่ะ', 'อยู่แล้วอะ'): 0,
#   ('กอีก', 'อีก'): 0,
#   ('มิ', 'มิ'): 0,
#   ('เดี่ยว', 'เดียว'): 0,
#   ('ก็เรย', 'ก็เลย'): 0,
#   ('ทำไรค้ะ', 'ทำไรคะ'): 0,
#   ('รอดดดดดด', 'รอด'): 0,
#   ('เบอ', 'number'): 0,
#   ('ทำไม่สมัค', 'ทำไมสมัคร'): 0,
#   ('แบ็งกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('แหละ', 'และ'): 0,
#   ('เบอร์ึ่ะ', 'เบอร์'): 0,
#   ('ป่าว', 'หรือเปล่า'): 0,
#   ('อะค่ะ', 'อะ'): 0,
#   ('จร้า', 'จ๊ะ'): 0,
#   ('คอลเซ็น', 'คอลเซ็นเตอร์'): 0,
#   ('ไวไฟอ่ะคับ', 'ไวไฟอะครับ'): 0,
#   ('รุ้ที่ยุ', 'รู้ที่อยู่'): 0,
#   ('ที่ยุ', 'ที่อยู่'): 0,
#   ('ลงอิน', 'ล็อคอิน'): 0,
#   ('อ่อคับบบ', 'อ้อครับ'): 0,
#   ('ๆม่', 'ไม่'): 0,
#   ('ขึ้นยุ', 'ขึ้นอยู่'): 0,
#   ('เช้ค', 'เช็ก'): 0,
#   ('เฟสบุ้ค', 'เฟซบุ๊ค'): 0,
#   ('ค้พ', 'ค่ะ'): 0,
#   ('เคแบงค์', 'promptpay'): 0,
#   ('เข้าจัย', 'เข้าใจ'): 0,
#   ('ม่มัน', 'มัน'): 0,
#   ('ใช้', 'ใช้'): 0,
#   ('ตรวจเชค', 'ตรวจเช็ค'): 0,
#   ('ศัทพ์', 'โทรศัพท์'): 0,
#   ('ครับพ้ม', 'ครับผม'): 0,
#   ('คำแนะนำค้ะ', 'คำแนะนำค่ะ'): 0,
#   ('ล้อคอิน', 'ล็อคอิน'): 0,
#   ('ค่ะ', 'ค่ะ'): 0,
#   ('ระบ', 'รับ'): 0,
#   ('K My play', 'K My pay'): 0,
#   ('คร่', 'คะ'): 0,
#   ('ใส้', 'ใส่'): 0,
#   ('อิ', 'อี'): 0,
#   ('ล้อคอิน', 'ล็อกอิน'): 0,
#   ('อ่ะ', 'อ่อะ'): 0,
#   ('เน้ต', 'เน็ต'): 0,
#   ('สเตสเม้น', 'สเตทเมนท์'): 0,
#   ('ก่า', 'กว่า'): 0,
#   ('เบอร์', 'number'): 0,
#   ('ยุ่ไกล', 'อยู่ไกล'): 0,
#   ('คร้าทำไม่', 'คะทำไม'): 0,
#   ('แบงค์กรุงไทย', 'แบงก์กรุงไทย'): 0,
#   ('สมัครอะคับ', 'สมัครอะครับ'): 0,
#   ('คับ', 'ครับบ'): 0,
#   ('ปัจุบัน', 'ปัจจุบัน'): 0,
#   ('อิกเสียได้', 'อีกเสียดาย'): 0,
#   ('จ่ะ', 'จะ'): 0},
#  'msp_word_dict_wrong': {('คับ', 'ครับ'): 290,
#   ('โทร', 'โทรศัพท์'): 149,
#   ('อ่ะ', 'อะ'): 133,
#   ('ค่ะ', 'คะ'): 103,
#   ('คะ', 'ค่ะ'): 99,
#   ('คัฟ', 'ครับ'): 65,
#   ('แอพ', 'แอป'): 60,
#   ('ค', 'ค่ะ'): 47,
#   ('เบอ', 'เบอร์'): 45,
#   ('เรย', 'เลย'): 43,
#   ('ค้ะ', 'ค่ะ'): 40,
#   ('หรอ', 'หรือ'): 36,
#   ('อะ', 'อ่ะ'): 35,
#   ('หรอ', 'เหรอ'): 33,
#   ('ป่ะ', 'เปล่า'): 33,
#   ('ป่าว', 'เปล่า'): 31,
#   ('แอฟ', 'แอพ'): 30,
#   ('ยังไง', 'อย่างไร'): 29,
#   ('ยังงัย', 'ยังไง'): 28,
#   ('แร้ว', 'แล้ว'): 26,
#   ('รึป่าว', 'หรือเปล่า'): 26,
#   ('ใช่', 'ใช้'): 26,
#   ('เปน', 'เป็น'): 24,
#   ('หรือป่าว', 'หรือเปล่า'): 23,
#   ('ก้', 'ก็'): 22,
#   ('อะ', 'อะไร'): 22,
#   ('เชค', 'เช็ค'): 20,
#   ('งัย', 'ไง'): 20,
#   ('ค่า', 'ค่ะ'): 20,
#   ('ป่ะ', 'ปะ'): 20,
#   ('ตัง', 'สตางค์'): 18,
#   ('เท่าไหร่', 'เท่าไร'): 18,
#   ('ดิ', 'สิ'): 18,
#   ('ค้ะ', 'คะ'): 17,
#   ('ก้อ', 'ก็'): 16,
#   ('จร้า', 'จ้ะ'): 16,
#   ('โท', 'โทร'): 16,
#   ('ค', 'คะ'): 16,
#   ('ใด้', 'ได้'): 15,
#   ('ครัช', 'ครับ'): 15,
#   ('แอป', 'แอพ'): 13,
#   ('บช', 'บัญชี'): 13,
#   ('ยัง', 'ยังไง'): 13,
#   ('อ่อ', 'อ๋อ'): 12,
#   ('เค้า', 'เขา'): 12,
#   ('ใช้', 'ใช่'): 12,
#   ('นู๋', 'หนู'): 12,
#   ('อยุ่', 'อยู่'): 11,
#   ('คร้าบ', 'ครับ'): 11,
#   ('ไช่', 'ใช่'): 11,
#   ('น้ะ', 'นะ'): 11,
#   ('ใหน', 'ไหน'): 10,
#   ('อ้ะ', 'อะ'): 10,
#   ('ปะ', 'เปล่า'): 10,
#   ('ขอบคุน', 'ขอบคุณ'): 10,
#   ('เวป', 'เว็บไซต์'): 10,
#   ('จร้า', 'จ้า'): 10,
#   ('แอฟ', 'แอป'): 9,
#   ('จ้า', 'จ้ะ'): 9,
#   ('คร้า', 'ค่ะ'): 9,
#   ('ใหม', 'ไหม'): 9,
#   ('มั้ย', 'ไหม'): 9,
#   ('น่ะ', 'นะ'): 9,
#   ('เบอร์', 'หมายเลข'): 9,
#   ('พิม', 'พิมพ์'): 9,
#   ('มั๊ย', 'ไหม'): 8,
#   ('รุ้', 'รู้'): 8,
#   ('ไม', 'ไหม'): 8,
#   ('ใว้', 'ไว้'): 8,
#   ('ให', 'ให้'): 8,
#   ('ไม่', 'ไหม'): 8,
#   ('โหลด', 'ดาวน์โหลด'): 8,
#   ('เนอะ', 'นะ'): 8,
#   ('ได่', 'ได้'): 7,
#   ('ใม่', 'ไม่'): 7,
#   ('ไห้', 'ให้'): 7,
#   ('มี', 'มี'): 7,
#   ('แบงค์', 'แบงก์'): 7,
#   ('สัส', 'สัตว์'): 6,
#   ('เนาะ', 'นะ'): 6,
#   ('ไม', 'ไม่'): 6,
#   ('ละ', 'ล่ะ'): 6,
#   ('เบย', 'เลย'): 6,
#   ('ที', 'ที่'): 6,
#   ('เห้น', 'เห็น'): 6,
#   ('ไง', 'อย่างไร'): 5,
#   ('นี่', 'นี้'): 5,
#   ('จิง', 'จริง'): 5,
#   ('ม่', 'ไม่'): 5,
#   ('ขอโทด', 'ขอโทษ'): 5,
#   ('ไร', 'อะไร'): 5,
#   ('ยังงัย', 'อย่างไร'): 5,
#   ('คุน', 'คุณ'): 5,
#   ('หน่ะ', 'น่ะ'): 5,
#   ('คร้า', 'คะ'): 5,
#   ('เนี้ย', 'นี่'): 5,
#   ('อัพเดท', 'อัปเดต'): 5,
#   ('เนต', 'เน็ต'): 5,
#   ('เหรอ', 'หรือ'): 5,
#   ('แต', 'แต่'): 4,
#   ('เด๋ว', 'เดี๋ยว'): 4,
#   ('อ่อ', 'อ้อ'): 4,
#   ('พนง', 'พนักงาน'): 4,
#   ('เช็ค', 'เช็ก'): 4,
#   ('รึยัง', 'หรือยัง'): 4,
#   ('มัย', 'ไหม'): 4,
#   ('รึ', 'หรือ'): 4,
#   ('ล่ะ', 'ละ'): 4,
#   ('ไม่', 'ไม่'): 4,
#   ('เวป', 'เว็บ'): 4,
#   ('เชค', 'เช็ก'): 4,
#   ('เมื่อไหร่', 'เมื่อไร'): 4,
#   ('อัพเดต', 'อัปเดต'): 3,
#   ('ว่ะ', 'วะ'): 3,
#   ('ด้', 'ได้'): 3,
#   ('ลิ้ง', 'ลิงค์'): 3,
#   ('พึ่ง', 'เพิ่ง'): 3,
#   ('นึง', 'หนึ่ง'): 3,
#   ('ประมาน', 'ประมาณ'): 3,
#   ('ยาก', 'อยาก'): 3,
#   ('ล้ะ', 'ล่ะ'): 3,
#   ('อ้ะ', 'อ่ะ'): 3,
#   ('เนี่ย', 'นี่'): 3,
#   ('แระ', 'และ'): 3,
#   ('อ่อ', 'เหรอ'): 3,
#   ('ป่ะ', 'หรือเปล่า'): 3,
#   ('กับ', 'กลับ'): 3,
#   ('นะ', 'น่ะ'): 3,
#   ('ป่ะ', 'ไป'): 3,
#   ('ยุ', 'อยู่'): 2,
#   ('รอง', 'ลอง'): 2,
#   ('ไม๊', 'ไหม'): 2,
#   ('เนี้ย', 'เนี่ย'): 2,
#   ('บช.', 'บัญชี'): 2,
#   ('พีช', 'พีซ'): 2,
#   ('ดาวโหลด', 'ดาวน์โหลด'): 2,
#   ('กุ', 'กู'): 2,
#   ('ด้าย', 'ได้'): 2,
#   ('มั่ง', 'บ้าง'): 2,
#   ('ล็อค', 'ล็อก'): 2,
#   ('อัพ', 'อัปเดต'): 2,
#   ('กะ', 'กับ'): 2,
#   ('จ่ะ', 'จ้ะ'): 2,
#   ('ปะ', 'หรือเปล่า'): 2,
#   ('นี้', 'นี่'): 2,
#   ('แอฟ', 'app'): 2,
#   ('โดน', 'โดย'): 2,
#   ('เฟส', 'เฟซ'): 2,
#   ('และ', 'แล้ว'): 2,
#   ('เสด', 'เสร็จ'): 2,
#   ('ธ', 'ธนาคาร'): 2,
#   ('อ่อ', 'ออ'): 2,
#   ('ล้ะ', 'ละ'): 2,
#   ('เนี้ย', 'นี้'): 2,
#   ('ขอ', 'ของ'): 2,
#   ('นิ', 'นี้'): 2,
#   ('ละ', 'แล้ว'): 2,
#   ('บาง', 'บ้าง'): 2,
#   ('เน้', 'นี้'): 2,
#   ('นิ', 'นี่'): 2,
#   ('อยาก', 'ยาก'): 1,
#   ('เตอ', 'เจอ'): 1,
#   ('ยุ่', 'อยู่'): 1,
#   ('เห้อ', 'เฮ้อ'): 1,
#   ('อิก', 'อีก'): 1,
#   ('k', 'k plus'): 1,
#   ('กับ', 'กัน'): 1,
#   ('ลิ้งค์', 'ลิงค์'): 1,
#   ('ซัก', 'สัก'): 1,
#   ('นิดนึง', 'นิดหนึ่ง'): 1,
#   ('เป็นไร', 'เป็น'): 1,
#   ('เด้อ', 'นะ'): 1,
#   ('ไว', 'ไว้'): 1,
#   ('แบง', 'แบงก์'): 1,
#   ('งัย', 'อย่างไร'): 1,
#   ('ใช่', 'ใช่'): 1,
#   ('แบง', 'แบงค์'): 1,
#   ('ล้าง', 'บ้าง'): 1,
#   ('ความ', 'ความ'): 1,
#   ('สู้', 'สู่'): 1,
#   ('แอพ', 'app'): 1,
#   ('แระ', 'แหละ'): 1,
#   ('โปร', 'โปรโมชั่น'): 1,
#   ('เข้า', 'เขา'): 1,
#   ('เปง', 'เป็น'): 1,
#   ('อ่อ', 'หรอ'): 1,
#   ('แอ๊บ', 'แอป'): 1,
#   ('เว', 'เวลา'): 1,
#   ('จะ', 'จ้ะ'): 1,
#   ('ดึก', 'ดึง'): 1,
#   ('กรุงเทพฯ', 'กรุงเทพ'): 1,
#   ('เมล', 'เมล์'): 1,
#   ('เนาะ', 'เน้อ'): 1,
#   ('มือ', 'มือถือ'): 1,
#   ('ชั้น', 'ฉัน'): 1,
#   ('ไม้', 'ไม่'): 1,
#   ('แอด', 'แอดมิน'): 1,
#   ('ป่ะ', 'ป้ะ'): 1,
#   ('เซน', 'เซ็น'): 1,
#   ('เวบ', 'เว็บไซต์'): 1,
#   ('ตัง', 'เงิน'): 1,
#   ('ปั้ม', 'ปั๊ม'): 1,
#   ('หรอก', 'หรอ'): 1,
#   ('คัพ', 'ครับ'): 1,
#   ('อะ', 'ล่ะ'): 1,
#   ('โปรโมชั่น', 'โปรโมชัน'): 1,
#   ('ปะ', 'ไป'): 1,
#   ('มะ', 'ไหม'): 1,
#   ('กาก', 'การ'): 1,
#   ('มาน', 'บัตร'): 1,
#   ('ช่วง', 'ช่วย'): 1,
#   ('ตัง', 'ตังค์'): 1,
#   ('กัล', 'กัน'): 1,
#   ('นั้น', 'นั่น'): 1,
#   ('ไช่', 'ใช้'): 1,
#   ('เทอ', 'เธอ'): 1,
#   ('รีด', 'อีก'): 1,
#   ('ชัว', 'ชัวร์'): 1,
#   ('ค่าใช้จ่าย', 'ค่า'): 1,
#   ('ไม', 'ใช้จ่าย'): 1,
#   ('สมมุติ', 'สมมติ'): 1,
#   ('ใหม่', 'ไหม'): 1,
#   ('คห', 'ความเห็น'): 1,
#   ('เพื่อ', 'เพิ่ม'): 1,
#   ('ใม่', 'ไหม'): 1,
#   ('ม่', 'ไหม'): 1,
#   ('แระ', 'แล้ว'): 1,
#   ('ดี', 'สวัสดี'): 1,
#   ('ต้อง', 'ตรง'): 1,
#   ('plus', 'k plus'): 1,
#   ('เว็ป', 'เว็บ'): 1,
#   ('จ่ะ', 'จ๊ะ'): 1,
#   ('รึป่าว', 'รึเปล่า'): 1,
#   ('ยิม', 'ยิ้ม'): 1,
#   ('ไป', 'ไม่'): 1,
#   ('เค้า', 'เข้า'): 1,
#   ('เว็ป', 'เว็บไซต์'): 1,
#   ('แล้ง', 'แล้ว'): 1,
#   ('ดด', 'กด'): 1,
#   ('ชะ', 'ซะ'): 1,
#   ('เข้า', 'ข้า'): 1,
#   ('อย่า', 'อยาก'): 1,
#   ('เพาะ', 'เพราะ'): 1,
#   ('บริหาร', 'บริการ'): 1,
#   ('เขา', 'เข้า'): 1,
#   ('ค่า', 'คะ'): 1,
#   ('เบอ', 'number'): 1,
#   ('แหละ', 'และ'): 1,
#   ('ป่าว', 'หรือเปล่า'): 1,
#   ('อะค่ะ', 'อะ'): 1,
#   ('จร้า', 'จ๊ะ'): 1,
#   ('ใช้', 'ใช้'): 1,
#   ('ใส้', 'ใส่'): 1,
#   ('อิ', 'อี'): 1,
#   ('เบอร์', 'number'): 1,
#   ('จ่ะ', 'จะ'): 1,
#   ('ตุ้', 'ตู้'): 0,
#   ('เบอร', 'เบอร์'): 0,
#   ('เช้ค', 'เช็ค'): 0,
#   ('บัชชี', 'บัญชี'): 0,
#   ('ยังใง', 'อย่างไร'): 0,
#   ('คร้าบบ?', 'ครับ'): 0,
#   ('อินเตอร์เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('ไหม่', 'ใหม่'): 0,
#   ('ค่', 'ค่ะ'): 0,
#   ('สมัค', 'สมัคร'): 0,
#   ('โทรศัพ', 'โทรศัพท์'): 0,
#   ('คครับ', 'ครับ'): 0,
#   ('ตอ้ง', 'ต้อง'): 0,
#   ('ที่อยุ่', 'ที่อยู่'): 0,
#   ('โทสับ', 'โทรศัพท์'): 0,
#   ('ออนไล', 'ออนไลน์'): 0,
#   ('อะรัย', 'อะไร'): 0,
#   ('สเตดเม้น', 'สเตทเม้นท์'): 0,
#   ('เน็ต', 'อินเทอร์เน็ต'): 0,
#   ('บันชี', 'บัญชี'): 0,
#   ('โทรสับ', 'โทรศัพท์'): 0,
#   ('ต', 'ต'): 0,
#   (' ', '.'): 0,
#   ('ค่าาา', 'ค่ะ'): 0,
#   ('น่อย', 'หน่อย'): 0,
#   ('กุ้', 'กู้'): 0,
#   ('ยังใง', 'ยังไง'): 0,
#   ('เบอยุแล้ว', 'เบอร์อยู่แล้ว'): 0,
#   ('ล๊อก', 'ล็อก'): 0,
#   ('หรัส', 'รหัส'): 0,
#   ('เคาเตอร์', 'เคาน์เตอร์'): 0,
#   ('สามรถ', 'สามารถ'): 0,
#   ('คพ', 'ค่ะ'): 0,
#   ('เนต', 'อินเทอร์เน็ต'): 0,
#   ('สวัดดี', 'สวัสดี'): 0,
#   ('ก', 'ก'): 0,
#   ('ค่', 'คะ'): 0,
#   ('รีไฟแนน', 'รีไฟแนนซ์'): 0,
#   ('โทรศัพย์', 'โทรศัพท์'): 0,
#   ('เคดิต', 'เครดิต'): 0,
#   ('วีธี', 'วิธี'): 0,
#   ('ข้อมุล', 'ข้อมูล'): 0,
#   ('ตังค์', 'สตางค์'): 0,
#   ('เปลียน', 'เปลี่ยน'): 0,
#   ('ใข่', 'ใช่'): 0,
#   ('ไทยพานิชย์', 'ไทยพาณิชย์'): 0,
#   ('โทรสัพ', 'โทรศัพท์'): 0,
#   ('ค่าาาาาาา', 'ค่ะ'): 0,
#   ('อย่างนี้รึป่าวคัฟ', 'อย่างนี้หรือเปล่าครับ'): 0,
#   ('คพ', 'คะ'): 0,
#   ('เปิดบันชี', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'ค่ะ'): 0,
#   ('เด๋วนี้', 'เดี๋ยวนี้'): 0,
#   ('ไหม่', 'ไหม'): 0,
#   ('เปนไร', 'เป็นไร'): 0,
#   ('เน้ต', 'อินเทอร์เน็ต'): 0,
#   ('ร้องได้อ้ะ', 'ร้องได้อะ'): 0,
#   ('ค๊ะ', 'คะ'): 0,
#   ('ต่ะ', 'คะ'): 0,
#   ('คระบ', 'ครับ'): 0,
#   ('คนับ', 'ครับ'): 0,
#   ('ค', 'ค'): 0,
#   ('plusอ่ะคับ', 'อะครับ'): 0,
#   ('มะ', 'ไม่'): 0,
#   ('เนี่ยยย', 'เนี่ย'): 0,
#   ('ฮาาา', 'ฮา'): 0,
#   ('โดนจัย', 'โดนใจ'): 0,
#   ('คีับ', 'ครับ'): 0,
#   ('คอม', 'คอมพิวเตอร์'): 0,
#   ('เปี่ยน', 'เปลี่ยน'): 0,
#   ('แอพ', 'application'): 0,
#   ('ทา', 'มา'): 0,
#   ('สาธุ จร้า', 'สาธุ จ้า'): 0,
#   ('กะตัง', 'สตางค์'): 0,
#   ('ยัตร', 'บัตร'): 0,
#   ('พร้อมเพย์', 'พร้อมเพย์์'): 0,
#   ('คอลเซนเตอร์', 'คอลเซ็นเตอร์'): 0,
#   ('แลัว', 'แล้ว'): 0,
#   ('ธ', 'ธ'): 0,
#   ('วัน', 'วัน'): 0,
#   ('ฟัดดดด', 'ฟัด'): 0,
#   ('บัญขี', 'บัญชี'): 0,
#   ('หมดดด', 'หมด'): 0,
#   ('เเร้ว', 'แล้ว'): 0,
#   ('ต่ะ', 'ค่ะ'): 0,
#   ('คร่', 'ค่ะ'): 0,
#   ('คึดถึง', 'คิดถึง'): 0,
#   ('เป่น', 'เป็น'): 0,
#   ('เค้าาาาาาาาาา', 'เขา'): 0,
#   ('หราาาาา', 'หรือ'): 0,
#   ('ทำ', 'ทำ'): 0,
#   ('โห', 'โอ้โฮ'): 0,
#   ('แบงกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('ข้อมู', 'ข้อมูล'): 0,
#   ('ยังคงอยุ่', 'ยังคงอยู่'): 0,
#   ('สาธุฯคัพ', 'สาธุครับ'): 0,
#   ('ไม', 'ทำไม'): 0,
#   ('แล้ส', 'แล้ว'): 0,
#   ('เครือง', 'เครื่อง'): 0,
#   ('เเอป', 'แอพ'): 0,
#   ('พักงาน', 'พนักงาน'): 0,
#   ('คำ', 'ค้ำ'): 0,
#   ('อาทิตร์', 'อาทิตย์'): 0,
#   ('ตอ้งการ', 'ต้องการ'): 0,
#   ('ลหัส', 'รหัส'): 0,
#   ('แอพที่', 'แอปที่'): 0,
#   ('บ ช', 'บัญชี'): 0,
#   ('ก้คือ', 'ก็คือ'): 0,
#   ('เป็นไร', 'เป็นไร'): 0,
#   ('สมัด', 'สมัคร'): 0,
#   ('ให่', 'ให้'): 0,
#   ('สามรถเชค', 'สามารถเช็ค'): 0,
#   ('ค่ะ.', 'ค่ะ'): 0,
#   ('ลบกวน', 'รบกวน'): 0,
#   ('คค่ะ', 'คะ'): 0,
#   ('อาทิต', 'อาทิตย์'): 0,
#   ('ทำไหม', 'ทำไม'): 0,
#   ('หายอ่ะ', 'หายอะ'): 0,
#   ('ไงต่ออ่ะ', 'อย่างไรต่ออะ'): 0,
#   ('เคแบงค์', 'เคแบงก์'): 0,
#   ('สุดยอดดดด', 'สุดยอด'): 0,
#   ('น๊ะ', 'นะ'): 0,
#   ('นิดเห็น', 'คิดเห็น'): 0,
#   ('ใง', 'ไง'): 0,
#   ('ภึง', 'ถึง'): 0,
#   ('เรียร้อย', 'เรียบร้อย'): 0,
#   ('เปิดบช', 'เปิดบัญชี'): 0,
#   ('คร้าาา', 'คะ'): 0,
#   ('เบราเซอร์', 'เบราว์เซอร์'): 0,
#   ('เอ่า', 'อ้าว'): 0,
#   ('เค้าเตอ', 'เคาน์เตอร์'): 0,
#   ('ตลอดดด', 'ตลอด'): 0,
#   ('เพือน', 'เพื่อน'): 0,
#   ('k plus', 'k plus'): 0,
#   ('้เปลี่ยน', 'เปลี่ยน'): 0,
#   ('ออนไลน', 'ออนไลน์'): 0,
#   ('เตรื่อง', 'เครื่อง'): 0,
#   ('สริป', 'สลิป'): 0,
#   ('ตรงกัน', 'ตรงกัน'): 0,
#   ('คาฟฟ', 'ครับ'): 0,
#   ('เคโมบายพลาส', 'เคโมบายพลัส'): 0,
#   ('มากกกกกกกกกกกกกกกกก', 'มาก'): 0,
#   ('พร้อมเพ', 'พร้อมเพย์'): 0,
#   ('แอฟK+', 'แอพK+'): 0,
#   ('มัร', 'มัน'): 0,
#   ('ออม', 'ออม'): 0,
#   ('ทรัพ', 'ทรัพย์'): 0,
#   ('ค่เ', 'ค่ะ'): 0,
#   ('คึด', 'คิด'): 0,
#   ('ทำไม่', 'ทำไม'): 0,
#   ('แบล็คลิส', 'แบล็คลิสต์'): 0,
#   ('ธนคาร', 'ธนาคาร'): 0,
#   ('ใช่ไวไฟ', 'ใช้ไวไฟ'): 0,
#   ('อ่ะกู', 'อะกู'): 0,
#   ('อ่ะสิ', 'อะสิ'): 0,
#   ('สเตสเม้น', 'สเตทเม้นท์'): 0,
#   ('ตะกี้', 'เมื่อกี้'): 0,
#   ('ขอบตคุนคับ', 'ขอบคุณครับ'): 0,
#   ('สมัคk-plus', 'สมัครk-plus'): 0,
#   ('ล๊อคอิน', 'ล็อคอิน'): 0,
#   ('นะ', 'นะ'): 0,
#   ('ได้ป', 'ได้'): 0,
#   ('ใข้', 'ใช้'): 0,
#   ('ก้วิธีการ', 'ก็วิธีการ'): 0,
#   ('เนะนำ', 'แนะนำ'): 0,
#   ('แอพพลิเคชั่น', 'แอปพลิเคชัน'): 0,
#   ('ดงิน', 'เงิน'): 0,
#   ('ครับช', 'ครับ'): 0,
#   ('บ/ช', 'บัญชี'): 0,
#   ('คัห', 'ครับ'): 0,
#   ('อายัด', 'อายัติ'): 0,
#   ('เน้อะ', 'นะ'): 0,
#   ('ตำ่', 'ต่ำ'): 0,
#   ('ช่ม่', 'ใช่'): 0,
#   ('ส่วนบุคคนคับ', 'ส่วนบุคคลครับ'): 0,
#   ('ม่ะ', 'ไหม'): 0,
#   ('มาอ่ะ', 'มาอะ'): 0,
#   ('อะเค', 'โอเค'): 0,
#   ('เงืน', 'เงิน'): 0,
#   ('ดิชั้น', 'ดิฉัน'): 0,
#   ('ปัย', 'ไป'): 0,
#   ('ล๊อคอิน', 'ล็อกอิน'): 0,
#   ('ได้', 'ได้'): 0,
#   ('คร้ง', 'ครั้ง'): 0,
#   ('มีป่าว', 'มีเปล่า'): 0,
#   ('้ครับ', 'ครับ'): 0,
#   ('น๊อน', 'นอน'): 0,
#   ('เคอะ', 'คะ'): 0,
#   ('ฝันดีราตรี', 'ฝันดีราตรี'): 0,
#   ('หมายเลยโทรศัพย์', 'หมายเลขโทรศัพท์'): 0,
#   ('อ่อ', 'ิอ๋อ'): 0,
#   ('.', '.'): 0,
#   ('รุ้จัก', 'รู้จัก'): 0,
#   ('อัติโนมัติ', 'อัตโนมัติ'): 0,
#   ('เบอ', 'เบลอ'): 0,
#   ('เคแบงค์กิ้ง', 'เคแบงก์กิ้ง'): 0,
#   ('บัณชี', 'บัญชี'): 0,
#   ('อินเตอเนต', 'อินเทอร์เน็ต'): 0,
#   ('ยังงัย', 'อย่างไง'): 0,
#   ('ค่ะ้', 'คะ'): 0,
#   ('มากกกกกกก', 'มาก'): 0,
#   ('เดยวบัตร', 'เดี๋ยว'): 0,
#   ('โม๊ดด', 'หมด'): 0,
#   ('ทำ', 'ทำไม'): 0,
#   ('เตียม', 'เตรียม'): 0,
#   ('ไมา', 'ไม่'): 0,
#   ('เปิดบัชชี', 'เปิดบัญชี'): 0,
#   ('ก้ดี', 'ก็ดี'): 0,
#   ('ม่ะ', 'ไม่'): 0,
#   ('ใง', 'อย่างไร'): 0,
#   ('ตเอง', 'ต้อง'): 0,
#   ('คร้าบบ', 'ครับ'): 0,
#   ('มีป่าวค๊ะ', 'มีเปล่าคะ'): 0,
#   ('ป๋ม', 'ผม'): 0,
#   ('เพื่ม', 'เพิ่ม'): 0,
#   ('สเตดเม้น', 'สเตทเมนท์'): 0,
#   ('ใหมี', 'ใหม่'): 0,
#   ('ค่าาา', 'คะ'): 0,
#   ('แพตตินัม', 'แพลทินัม'): 0,
#   ('หรัสผ่าน', 'รหัสผ่าน'): 0,
#   ('อยุ่ดี', 'อยู่ดี'): 0,
#   ('กะ', 'ก็'): 0,
#   ('ส ค บ เรยคะ', 'สคบ.เลยค่ะ'): 0,
#   ('ยังำงค่ะ', 'ยังไงคะ'): 0,
#   ('ไง', 'ไงิ'): 0,
#   ('อะ', 'อะ'): 0,
#   ('สคริป', 'สคริปต์'): 0,
#   ('ไหม่ป', 'ใหม่'): 0,
#   ('เครคิต', 'เครดิต'): 0,
#   ('ล๊อก', 'ล็อค'): 0,
#   ('คค่ะ', 'ค่ะ'): 0,
#   ('คราบ', 'ครับ'): 0,
#   ('โทร', 'โทร'): 0,
#   ('ใส้', 'ไส้'): 0,
#   ('รับแซ๊บ', 'รับทราบ'): 0,
#   ('ใช่จ่ายใหมค่ะ', 'ใช้จ่ายไหมคะ'): 0,
#   ('ส น', 'สน.'): 0,
#   ('เปอเซน', 'เปอร์เซ็นต์'): 0,
#   ('ช่ายยยย', 'ใช่'): 0,
#   ('ค๊ะ', 'ค่ะ'): 0,
#   ('อยู่อ่ะ', 'อยู่อะ'): 0,
#   ('ททราบ', 'ทราบ'): 0,
#   ('คับผม', 'ครับผม'): 0,
#   ('ซื้อง', 'ซื้อ'): 0,
#   ('นี่แระ', 'นี่แหละ'): 0,
#   ('เฟิสช้อย', 'เฟิร์สช้อยส์'): 0,
#   ('เมื่อไหร่กะเพรา', 'เมื่อไรกะเพรา'): 0,
#   ('ทีา', 'ที่'): 0,
#   ('โครตกาก', 'โคตรกาก'): 0,
#   ('หรือไป', 'หรือไป'): 0,
#   ('เปนอ่ะ', 'เป็นอะ'): 0,
#   ('รึยัง', 'รึยัง'): 0,
#   ('เงื้อนไข', 'เงื่อนไข'): 0,
#   ('อ่ะคับผม', 'อะครับผม'): 0,
#   ('อ่อ', '๋อ๋อ'): 0,
#   ('ตลอดดดด', 'ตลอด'): 0,
#   ('้เจ้าหน้าที่', 'เจ้าหน้าที่'): 0,
#   ('ธ.', 'ธนาคาร'): 0,
#   ('เดี่ยว', 'เดี๋ยว'): 0,
#   ('้เมื่อ', 'เมื่อ'): 0,
#   ('อ่ะภาพ', 'อะภาพ'): 0,
#   ('หักบช', 'หักบัญชี'): 0,
#   ('สิบถาม', 'สอบถาม'): 0,
#   ('มากอ่ะ', 'มากอะ'): 0,
#   ('สมัคk', 'สมัคร'): 0,
#   ('เคแบงเติม', 'เคแบงก์'): 0,
#   ('รับ', 'ครับ'): 0,
#   ('คใคร', 'ใคร'): 0,
#   ('เก๊า', 'เรา'): 0,
#   ('แบงค์กรุงเทพ', 'แบงก์กรุงเทพ'): 0,
#   ('ก กรุงไทย', 'กรุงไทย'): 0,
#   ('ครับบ', 'ครับ'): 0,
#   ('คร้าบผม', 'ครับผม'): 0,
#   ('อย่างรัย', 'อย่างไร'): 0,
#   ('เปนรัยคะ', 'เป็นไรค่ะ'): 0,
#   ('อะป่าวคับ', 'อะเปล่าครับ'): 0,
#   ('ล้ะ', 'แล้ว'): 0,
#   ('ยุแล้ว', 'อยู่แล้ว'): 0,
#   ('อ๊าววว', 'อ้าว'): 0,
#   ('ๆด้', 'ได้'): 0,
#   ('สมัคKBank', 'สมัครKBank'): 0,
#   ('ฮื้อออแแ', 'ฮือ'): 0,
#   ('ทวีทรัพย์เอ็กตร้า', 'ทวีทรัพย์เอ็กซ์ตร้า'): 0,
#   ('ยัยช้างด้า', 'ยายช้างด้า'): 0,
#   ('แอปฯ', 'application'): 0,
#   ('คนับ', 'ครับี่'): 0,
#   ('ฟฤหัส', 'พฤหัสบดี'): 0,
#   ('ป้ายบาร์โค้ดยังไงอ่ะ', 'ป้ายบาร์โค้ดอย่างไรอะ'): 0,
#   ('ก้เลย', 'ก็เลย'): 0,
#   ('อยู้', 'อยู่'): 0,
#   ('สิ้', 'สิ'): 0,
#   ('ทันที่ไม', 'ทันทีไม่'): 0,
#   ('เปลั่ยน', 'เปลี่ยน'): 0,
#   ('คคะ', 'ค่ะ'): 0,
#   ('เด๊๋ยว', 'เดี๋ยว'): 0,
#   ('ใหมาไมา', 'ใหม่ไม่'): 0,
#   ('ปิดบันชี', 'ปิดบัญชี'): 0,
#   ('ไฟแนน', 'ไฟแนนซ์'): 0,
#   ('กสิกรช', 'กสิกร'): 0,
#   ('แกไข', 'แก้ไข'): 0,
#   ('ใข่', 'ใช้'): 0,
#   ('ม้ย', 'ไหม'): 0,
#   ('ทราบถามอ่ะ', 'สอบถามอะ'): 0,
#   ('ช้อป', 'ชอป'): 0,
#   ('ยุแร้วอ่ะ', 'อยู่แล้วอะ'): 0,
#   ('กอีก', 'อีก'): 0,
#   ('มิ', 'มิ'): 0,
#   ('เดี่ยว', 'เดียว'): 0,
#   ('ก็เรย', 'ก็เลย'): 0,
#   ('ทำไรค้ะ', 'ทำไรคะ'): 0,
#   ('รอดดดดดด', 'รอด'): 0,
#   ('ทำไม่สมัค', 'ทำไมสมัคร'): 0,
#   ('แบ็งกิ้ง', 'แบงก์กิ้ง'): 0,
#   ('เบอร์ึ่ะ', 'เบอร์'): 0,
#   ('คอลเซ็น', 'คอลเซ็นเตอร์'): 0,
#   ('ไวไฟอ่ะคับ', 'ไวไฟอะครับ'): 0,
#   ('รุ้ที่ยุ', 'รู้ที่อยู่'): 0,
#   ('ที่ยุ', 'ที่อยู่'): 0,
#   ('ลงอิน', 'ล็อคอิน'): 0,
#   ('อ่อคับบบ', 'อ้อครับ'): 0,
#   ('ๆม่', 'ไม่'): 0,
#   ('ขึ้นยุ', 'ขึ้นอยู่'): 0,
#   ('เช้ค', 'เช็ก'): 0,
#   ('เฟสบุ้ค', 'เฟซบุ๊ค'): 0,
#   ('ค้พ', 'ค่ะ'): 0,
#   ('เคแบงค์', 'promptpay'): 0,
#   ('เข้าจัย', 'เข้าใจ'): 0,
#   ('ม่มัน', 'มัน'): 0,
#   ('จ่ะ', 'คะ'): 0,
#   ('เดียว', 'เดี๋ยว'): 0,
#   ('ตรวจเชค', 'ตรวจเช็ค'): 0,
#   ('ศัทพ์', 'โทรศัพท์'): 0,
#   ('ครับพ้ม', 'ครับผม'): 0,
#   ('คำแนะนำค้ะ', 'คำแนะนำค่ะ'): 0,
#   ('ล้อคอิน', 'ล็อคอิน'): 0,
#   ('ค่ะ', 'ค่ะ'): 0,
#   ('ระบ', 'รับ'): 0,
#   ('K My play', 'K My pay'): 0,
#   ('คร่', 'คะ'): 0,
#   ('ล้อคอิน', 'ล็อกอิน'): 0,
#   ('อ่ะ', 'อ่อะ'): 0,
#   ('เน้ต', 'เน็ต'): 0,
#   ('สเตสเม้น', 'สเตทเมนท์'): 0,
#   ('ก่า', 'กว่า'): 0,
#   ('ข้อ', 'เขา'): 0,
#   ('ยุ่ไกล', 'อยู่ไกล'): 0,
#   ('คร้าทำไม่', 'คะทำไม'): 0,
#   ('แบงค์กรุงไทย', 'แบงก์กรุงไทย'): 0,
#   ('สมัครอะคับ', 'สมัครอะครับ'): 0,
#   ('คับ', 'ครับบ'): 0,
#   ('ปัจุบัน', 'ปัจจุบัน'): 0,
#   ('อิกเสียได้', 'อีกเสียดาย'): 0},
#  'sent_id_type': {'morphed': [[0, [(4254, 335)]],
#    [5, [(801, 73)]],
#    [14, [(608, 415)]],
#    [1143, [(103, 1551)]],
#    [1144, [(11787, 907)]],
#    [1147, [(4230, 8704)]],
#    [1147, [(260, 70)]],
#    [1152, [(14237, 70)]],
#    [1155, [(9596, 335), (801, 73)]],
#    [1158, [(70, 260)]],
#    [1158, [(70, 260)]],
#    [1161, [(6704, 15), (2048, 335), (801, 73)]],
#    [1162, [(1203, 1917)]],
#    [1162, [(11787, 907)]],
#    [1165, [(1203, 1917)]],
#    [1169, [(406, 300)]],
#    [1172, [(7968, 14014)]],
#    [1172, [(21497, 3047)]],
#    [1175, [(70, 260)]],
#    [1179, [(14237, 260)]],
#    [1185, [(406, 300), (260, 70)]],
#    [1187, [(1203, 1917)]],
#    [1198, [(11787, 907)]],
#    [1199, [(19969, 729), (6704, 15)]],
#    [1199, [(5614, 335), (70, 260)]],
#    [1202, [(406, 300)]],
#    [1203, [(70, 260)]],
#    [1205, [(1955, 17)]],
#    [1205, [(70, 260)]],
#    [1206, [(5861, 729)]],
#    [1210, [(14237, 260)]],
#    [1211, [(19969, 729)]],
#    [1212, [(260, 70)]],
#    [1217, [(260, 70)]],
#    [1220, [(406, 300)]],
#    [1223, [(14237, 70)]],
#    [1225, [(406, 300)]],
#    [1228, [(406, 300)]],
#    [1231, [(406, 300)]],
#    [1235, [(406, 300)]],
#    [1239, [(11787, 907)]],
#    [1240, [(11640, 8704)]],
#    [1244, [(7968, 14014)]],
#    [1247, [(21352, 1551)]],
#    [1248, [(7968, 14014)]],
#    [1249, [(4230, 8704)]],
#    [1251, [(406, 300)]],
#    [1253, [(6704, 15), (556, 335), (801, 73)]],
#    [1255, [(5861, 729)]],
#    [1255, [(6704, 15)]],
#    [1256, [(10733, 300)]],
#    [1261, [(10733, 300)]],
#    [1262, [(70, 260)]],
#    [1264, [(406, 300)]],
#    [1266, [(11787, 907)]],
#    [1267, [(3569, 55)]],
#    [1268, [(7273, 12355)]],
#    [1269, [(4230, 8704)]],
#    [1269, [(260, 70)]],
#    [1270, [(11787, 907)]],
#    [1270, [(406, 300), (801, 73)]],
#    [1271, [(70, 260)]],
#    [1274, [(1203, 1917)]],
#    [1276, [(70, 260)]],
#    [1277, [(406, 300)]],
#    [1279, [(1203, 1917)]],
#    [1281, [(406, 300)]],
#    [1282, [(406, 300)]],
#    [1283, [(11640, 8704)]],
#    [1284, [(7968, 14014)]],
#    [1285, [(406, 300)]],
#    [1286, [(556, 335)]],
#    [1287, [(70, 260)]],
#    [1288, [(7968, 14014)]],
#    [1290, [(1203, 1917)]],
#    [1294, [(4230, 8704)]],
#    [1295, [(70, 260)]],
#    [1297, [(406, 300)]],
#    [1298, [(14237, 260)]],
#    [1305, [(406, 300), (801, 73)]],
#    [1306, [(260, 70)]],
#    [1307, [(21352, 1551)]],
#    [1307, [(801, 73)]],
#    [1312, [(4230, 8704)]],
#    [1315, [(11787, 907)]],
#    [1323, [(14237, 70)]],
#    [1341, [(260, 70)]],
#    [1346, [(11787, 907), (406, 300)]],
#    [1350, [(406, 300), (260, 70)]],
#    [1351, [(22404, 8704)]],
#    [1354, [(11787, 907)]],
#    [1355, [(1352, 1145)]],
#    [1355, [(1214, 1917)]],
#    [1356, [(2048, 729)]],
#    [1357, [(1203, 1917)]],
#    [1358, [(260, 70)]],
#    [1359, [(11787, 907)]],
#    [1361, [(1955, 17)]],
#    [1362, [(4254, 335)]],
#    [1364, [(11640, 8704)]],
#    [1365, [(14237, 260)]],
#    [1366, [(14237, 260)]],
#    [1368, [(4230, 8704)]],
#    [1375, [(11787, 907)]],
#    [1379, [(406, 300)]],
#    [1380, [(11787, 907)]],
#    [1380, [(5746, 648)]],
#    [1381, [(260, 70)]],
#    [1383, [(7968, 14014)]],
#    [1384, [(14237, 70)]],
#    [1385, [(70, 260)]],
#    [1389, [(18477, 3386)]],
#    [1394, [(406, 300)]],
#    [1395, [(12862, 130), (406, 300), (260, 70)]],
#    [1396, [(70, 260)]],
#    [1397, [(11640, 8704)]],
#    [1401, [(4230, 8704)]],
#    [1403, [(260, 70)]],
#    [1405, [(4230, 8704)]],
#    [1408, [(21352, 1551)]],
#    [1411, [(7968, 14014)]],
#    [1412, [(406, 300)]],
#    [1417, [(6704, 15)]],
#    [1417, [(70, 260)]],
#    [1419, [(74, 74), (70, 260)]],
#    [1420, [(11787, 907)]],
#    [1422, [(406, 300)]],
#    [1423, [(11787, 907)]],
#    [1425, [(406, 300), (14237, 260)]],
#    [1426, [(70, 260)]],
#    [1430, [(14237, 70)]],
#    [1436, [(4230, 8704)]],
#    [1440, [(14237, 70)]],
#    [1441, [(406, 300)]],
#    [1442, [(11640, 8704)]],
#    [1445, [(70, 260)]],
#    [1447, [(22133, 153)]],
#    [1449, [(14237, 70)]],
#    [1450, [(406, 300)]],
#    [1452, [(406, 300)]],
#    [1455, [(14237, 260)]],
#    [1458, [(406, 300)]],
#    [1461, [(260, 70)]],
#    [1464, [(1955, 17)]],
#    [1470, [(11787, 907)]],
#    [1473, [(260, 70)]],
#    [1474, [(11787, 907)]],
#    [1479, [(1203, 1917)]],
#    [1481, [(406, 300)]],
#    [1486, [(1214, 1917)]],
#    [1488, [(260, 70)]],
#    [1494, [(70, 260)]],
#    [1496, [(4230, 8704)]],
#    [1497, [(3569, 55)]],
#    [1502, [(7968, 14014)]],
#    [1505, [(6069, 483)]],
#    [1508, [(406, 300)]],
#    [1510, [(406, 300)]],
#    [1514, [(11787, 907)]],
#    [1515, [(11787, 907)]],
#    [1516, [(406, 300)]],
#    [1517, [(260, 70)]],
#    [1522, [(406, 300)]],
#    [1525, [(11787, 907)]],
#    [1526, [(260, 70)]],
#    [1528, [(406, 300)]],
#    [1531, [(6704, 15)]],
#    [1532, [(7968, 14014)]],
#    [1534, [(11787, 907)]],
#    [1534, [(260, 70)]],
#    [1537, [(11787, 907)]],
#    [1538, [(406, 300)]],
#    [1546, [(1955, 17)]],
#    [1548, [(11787, 907)]],
#    [1550, [(14237, 70)]],
#    [1550, [(1955, 17)]],
#    [1550, [(14237, 70)]],
#    [1554, [(406, 300)]],
#    [1555, [(19969, 729)]],
#    [1558, [(11787, 907)]],
#    [1559, [(1203, 1917), (1955, 17)]],
#    [1560, [(3569, 55)]],
#    [1561, [(11787, 907), (801, 73)]],
#    [1567, [(2048, 335), (70, 260)]],
#    [1568, [(14237, 260)]],
#    [1571, [(1352, 1145)]],
#    [1571, [(11787, 907)]],
#    [1571, [(801, 73)]],
#    [1572, [(14237, 70)]],
#    [1573, [(762, 5678)]],
#    [1576, [(11787, 907)]],
#    [1577, [(406, 300)]],
#    [1582, [(406, 300)]],
#    [1584, [(11787, 907)]],
#    [1585, [(260, 70)]],
#    [1586, [(260, 70)]],
#    [1587, [(6069, 483), (70, 260)]],
#    [1590, [(4230, 8704)]],
#    [1593, [(6704, 15)]],
#    [1594, [(124, 44), (406, 300)]],
#    [1595, [(19969, 729), (6704, 15)]],
#    [1596, [(70, 260)]],
#    [1597, [(14237, 70)]],
#    [1602, [(4230, 8704)]],
#    [1603, [(717, 729)]],
#    [1606, [(406, 300)]],
#    [1607, [(5861, 729)]],
#    [1608, [(14237, 260)]],
#    [1612, [(7968, 14014)]],
#    [1613, [(406, 300)]],
#    [1615, [(1955, 17)]],
#    [1619, [(70, 260)]],
#    [1624, [(11787, 907)]],
#    [1624, [(11787, 907)]],
#    [1628, [(14237, 260)]],
#    [1632, [(1955, 17)]],
#    [1633, [(2048, 335)]],
#    [1636, [(260, 70)]],
#    [1637, [(260, 70)]],
#    [1638, [(14237, 70)]],
#    [1639, [(260, 70)]],
#    [1641, [(1203, 1917)]],
#    [1642, [(406, 300)]],
#    [1645, [(70, 260)]],
#    [1649, [(406, 300)]],
#    [1654, [(260, 70)]],
#    [1662, [(406, 300), (260, 70)]],
#    [1664, [(260, 70)]],
#    [1666, [(406, 300)]],
#    [1676, [(260, 70)]],
#    [1682, [(406, 300)]],
#    [1685, [(10733, 300), (14237, 70)]],
#    [1687, [(7273, 12355)]],
#    [1688, [(14237, 70)]],
#    [1692, [(14237, 260)]],
#    [1693, [(21352, 1551)]],
#    [1695, [(7968, 14014)]],
#    [1698, [(14237, 70)]],
#    [1701, [(11787, 907)]],
#    [1703, [(406, 300)]],
#    [1704, [(14237, 70)]],
#    [1708, [(7968, 14014)]],
#    [1709, [(7273, 12355)]],
#    [1710, [(406, 300)]],
#    [1711, [(406, 300)]],
#    [1715, [(70, 260)]],
#    [1716, [(11787, 907)]],
#    [1718, [(406, 300)]],
#    [1722, [(14237, 70)]],
#    [1726, [(11787, 907)]],
#    [1729, [(406, 300)]],
#    [1733, [(10733, 300), (14237, 260)]],
#    [1740, [(406, 300)]],
#    [1742, [(406, 300)]],
#    [1743, [(556, 335)]],
#    [1749, [(11787, 907)]],
#    [1750, [(406, 300)]],
#    [1753, [(1203, 1917)]],
#    [1753, [(260, 70)]],
#    [1754, [(260, 70)]],
#    [1757, [(3569, 55)]],
#    [1758, [(406, 300)]],
#    [1765, [(406, 300)]],
#    [1766, [(70, 260)]],
#    [1769, [(11787, 907)]],
#    [1769, [(406, 300), (801, 73)]],
#    [1776, [(70, 260)]],
#    [1778, [(7273, 12355)]],
#    [1780, [(9596, 335)]],
#    [1783, [(21352, 1551)]],
#    [1786, [(11787, 907)]],
#    [1787, [(3569, 55)]],
#    [1792, [(1046, 2459)]],
#    [1794, [(13056, 93)]],
#    [1795, [(1203, 1917)]],
#    [1799, [(406, 300)]],
#    [1801, [(11787, 907)]],
#    [1802, [(8335, 894)]],
#    [1803, [(70, 260)]],
#    [1805, [(11787, 907)]],
#    [1809, [(406, 300)]],
#    [1810, [(9596, 335)]],
#    [1812, [(7968, 14014)]],
#    [1814, [(4230, 8704)]],
#    [1817, [(1955, 17)]],
#    [1818, [(63, 3342), (7273, 12355)]],
#    [1819, [(11787, 907)]],
#    [1824, [(70, 260)]],
#    [1826, [(11787, 907)]],
#    [1827, [(70, 260)]],
#    [1828, [(14237, 70)]],
#    [1831, [(406, 300)]],
#    [1834, [(1352, 1145)]],
#    [1841, [(406, 300)]],
#    [1842, [(406, 300)]],
#    [1843, [(21497, 3047)]],
#    [1843, [(14237, 70)]],
#    [1844, [(70, 260)]],
#    [1852, [(4230, 8704)]],
#    [1854, [(11787, 907), (406, 300)]],
#    [1855, [(1955, 17)]],
#    [1856, [(11787, 907)]],
#    [1857, [(70, 260)]],
#    [1862, [(11640, 8704)]],
#    [1862, [(260, 70)]],
#    [1863, [(443, 153)]],
#    [1863, [(70, 260)]],
#    [1867, [(12712, 415), (70, 260)]],
#    [1873, [(7968, 14014)]],
#    [1873, [(21497, 3047)]],
#    [1874, [(406, 300)]],
#    [1875, [(18477, 3386)]],
#    [1883, [(70, 260)]],
#    [1893, [(14237, 70)]],
#    [1895, [(70, 260)]],
#    [1896, [(70, 260)]],
#    [1897, [(11787, 907)]],
#    [1897, [(70, 260)]],
#    [1898, [(11787, 907)]],
#    [1903, [(21352, 1551)]],
#    [1903, [(70, 260)]],
#    [1904, [(406, 300)]],
#    [1906, [(11787, 907)]],
#    [1906, [(260, 70)]],
#    [1910, [(6704, 15)]],
#    [1914, [(14237, 70)]],
#    [1921, [(7273, 12355)]],
#    [1930, [(70, 260)]],
#    [1933, [(406, 300)]],
#    [1934, [(21352, 1551)]],
#    [1936, [(11787, 907)]],
#    [1937, [(11787, 907)]],
#    [1938, [(70, 260)]],
#    [1940, [(70, 260)]],
#    [1945, [(11787, 907)]],
#    [1948, [(406, 300)]],
#    [1954, [(11787, 907)]],
#    [1955, [(260, 70)]],
#    [1959, [(24796, 7217)]],
#    [1963, [(260, 70)]],
#    [1964, [(4230, 8704)]],
#    [1967, [(7968, 14014)]],
#    [1971, [(1955, 17)]],
#    [1973, [(406, 300)]],
#    [1974, [(1203, 1917)]],
#    [1975, [(406, 300)]],
#    [1977, [(11787, 907)]],
#    [1978, [(9596, 335), (70, 260)]],
#    [1979, [(371, 12)]],
#    [1980, [(1203, 1917)]],
#    [1982, [(260, 70)]],
#    [1985, [(406, 300)]],
#    [1986, [(1203, 1917)]],
#    [1988, [(2048, 335), (70, 260)]],
#    [1993, [(11787, 907)]],
#    [1994, [(11787, 907)]],
#    [2208, [(14237, 70)]],
#    [2209, [(406, 300)]],
#    [2212, [(10733, 300)]],
#    [2214, [(406, 300)]],
#    [2226, [(9596, 335)]],
#    [2227, [(406, 300)]],
#    [2228, [(1955, 17)]],
#    [2229, [(406, 300)]],
#    [2232, [(13056, 93)]],
#    [2234, [(406, 300)]],
#    [2236, [(7968, 14014)]],
#    [2237, [(2048, 335)]],
#    [2238, [(6069, 483)]],
#    [2241, [(5861, 729)]],
#    [2243, [(70, 260)]],
#    [2245, [(5301, 3672)]],
#    [2247, [(1955, 17)]],
#    [2250, [(6704, 15)]],
#    [2254, [(4230, 8704)]],
#    [2255, [(1203, 1917)]],
#    [2256, [(4230, 8704)]],
#    [2257, [(41, 260)]],
#    [2259, [(70, 260)]],
#    [2260, [(11787, 907)]],
#    [2261, [(6704, 15), (9596, 335)]],
#    [2263, [(11787, 907)]],
#    [2263, [(70, 260)]],
#    [2264, [(1203, 1917)]],
#    [2266, [(406, 300)]],
#    [2267, [(260, 70)]],
#    [2268, [(70, 260)]],
#    [2269, [(6069, 483)]],
#    [2270, [(17754, 15)]],
#    [2282, [(3569, 55)]],
#    [2285, [(21352, 1551)]],
#    [2287, [(1955, 17)]],
#    [2288, [(11787, 907)]],
#    [2291, [(7273, 12355)]],
#    [2293, [(1203, 1917)]],
#    [2295, [(11787, 907)]],
#    [2298, [(260, 70)]],
#    [2299, [(4230, 8704)]],
#    [2303, [(70, 260)]],
#    [2304, [(14237, 70)]],
#    [2304, [(14237, 260)]],
#    [2306, [(11787, 907)]],
#    [2309, [(11640, 8704)]],
#    [2310, [(6704, 15)]],
#    [2312, [(6069, 483)]],
#    [2317, [(1203, 1917)]],
#    [2317, [(260, 70)]],
#    [2319, [(1955, 17)]],
#    [2323, [(9596, 335)]],
#    [2326, [(406, 300)]],
#    [2334, [(406, 300)]],
#    [2336, [(7273, 12355)]],
#    [2338, [(11787, 907)]],
#    [2339, [(10733, 300), (14237, 70)]],
#    [2340, [(7273, 12355)]],
#    [2343, [(7273, 12355)]],
#    [2343, [(70, 260)]],
#    [2344, [(1955, 17)]],
#    [2348, [(11787, 907)]],
#    ...],
#   'ws': [[941, [(12360, 12360)]],
#    [1188, [(9264, 9264)]],
#    [1958, [(19969, 729), (15, 15)]],
#    [2595, [(11787, 907), (1145, 1145)]],
#    [3899, [(6268, 6268)]],
#    [4660, [(406, 300), (70, 70)]]],
#   'other': [[135, [(10733, 300)]],
#    [484, [(406, 300)]],
#    [1263, [(406, 300)]],
#    [1391, [(406, 300), (801, 73)]],
#    [1475, [(406, 300)]],
#    [1751, [(406, 300)]],
#    [2013, [(406, 300)]],
#    [2028, [(406, 300)]],
#    [2181, [(406, 300)]],
#    [3579, [(406, 300), (801, 73)]],
#    [3782, [(406, 300)]],
#    [3801, [(406, 300), (260, 70)]],
#    [4088, [(406, 300)]],
#    [4356, [(406, 300), (801, 73)]]],
#   'abbreviation': [[160, [(8105, 1063)]],
#    [173, [(8105, 1063)]],
#    [278, [(8105, 1063)]],
#    [284, [(406, 300)]],
#    [321, [(13957, 454)]],
#    [322, [(19373, 518)]],
#    [570, [(1145, 726)]],
#    [604, [(8105, 1063)]],
#    [712, [(8105, 1063)]],
#    [730, [(8105, 1063)]],
#    [756, [(8105, 1063)]],
#    [764, [(8105, 1063)]],
#    [777, [(8105, 1063)]],
#    [813, [(8105, 1063)]],
#    [960, [(8105, 1063)]],
#    [1081, [(8105, 1063)]],
#    [1141, [(8105, 1063)]],
#    [1164, [(8105, 1063)]],
#    [1299, [(8105, 1063)]],
#    [1441, [(8105, 1063)]],
#    [1524, [(8105, 1063)]],
#    [1743, [(19373, 518)]],
#    [2149, [(8105, 1063)]],
#    [2161, [(19373, 518)]],
#    [2273, [(8105, 1063)]],
#    [2331, [(8105, 1063)]],
#    [2366, [(8105, 1063)]],
#    [2774, [(8105, 1063)]],
#    [2942, [(8105, 1063)]],
#    [2953, [(8105, 1063)]],
#    [3033, [(8105, 1063)]],
#    [3114, [(5904, 1351)]],
#    [3131, [(8105, 1063)]],
#    [3201, [(8105, 1063)]],
#    [3266, [(417, 1045)]],
#    [3279, [(8105, 1063)]],
#    [3441, [(8105, 1063)]],
#    [3508, [(8105, 1063)]],
#    [3593, [(417, 1045)]],
#    [3605, [(8105, 1063)]],
#    [3683, [(8105, 1063)]],
#    [3935, [(8105, 1063)]],
#    [3955, [(8105, 1063)]],
#    [3959, [(19373, 518)]],
#    [4310, [(8105, 1063)]],
#    [4312, [(8105, 1063)]],
#    [4380, [(19373, 518)]],
#    [4584, [(8105, 1063)]],
#    [4624, [(8105, 1063)]],
#    [4799, [(8105, 1063)]],
#    [4847, [(8105, 1063)]],
#    [4874, [(8105, 1063)]],
#    [4897, [(8105, 1063)]],
#    [4937, [(8105, 1063)]]],
#   'new': []}}

# %%
percent_correct = {}
for key in msp_word_dict_full:
  fill = msp_word_dict_fill[key]
  full = msp_word_dict_full[key]
  if full == 0 or full < 30:
    percent_correct[key] = 0
  else:
    percent_correct[key] = fill/full
a = dict(sorted(percent_correct.items(), key=lambda item: item[1], reverse=True))
print(a)
# Out:
# {('มั้ย', 'ไหม'): 0.9560975609756097, ('ไง', 'อย่างไร'): 0.9253731343283582, ('อ่อ', 'อ๋อ'): 0.916083916083916, ('มั๊ย', 'ไหม'): 0.9090909090909091, ('ม่', 'ไม่'): 0.9090909090909091, ('ค้ะ', 'คะ'): 0.8851351351351351, ('ไม', 'ไหม'): 0.8805970149253731, ('เบอ', 'เบอร์'): 0.8721590909090909, ('ใหม', 'ไหม'): 0.8676470588235294, ('ใด้', 'ได้'): 0.8584905660377359, ('เปน', 'เป็น'): 0.8431372549019608, ('ก้', 'ก็'): 0.837037037037037, ('แอฟ', 'แอป'): 0.8363636363636363, ('รุ้', 'รู้'): 0.8333333333333334, ('อ้ะ', 'อะ'): 0.7959183673469388, ('อยุ่', 'อยู่'): 0.7924528301886793, ('ค่ะ', 'คะ'): 0.7893660531697342, ('ยังไง', 'อย่างไร'): 0.7883211678832117, ('อ่ะ', 'อะ'): 0.
 0, ('บาง', 'บ้าง'): 0, ('รอง', 'ลอง'): 0, ('เห้อ', 'เฮ้อ'): 0, ('มะ', 'ไม่'): 0, ('บช.', 'บัญชี'): 0, ('พีช', 'พีซ'): 0, ('ดาวโหลด', 'ดาวน์โหลด'): 0, ('กุ', 'กู'): 0, ('อัพ', 'อัปเดต'): 0, ('แบง', 'แบงก์'): 0, ('จ่ะ', 'จ้ะ'): 0, ('ปะ', 'หรือเปล่า'): 0, ('นี้', 'นี่'): 0, ('สู้', 'สู่'): 0, ('แอฟ', 'app'): 0, ('โดน', 'โดย'): 0, ('เ ...

# %%
for key in sent_id_type:
  cou = 0
  print(f"=========[{key}]==========")
  for sent_id, words in sent_id_type[key]:
    cou += 1
    if cou == 20: break
    text = ds_tag.iloc[sent_id]['text']['input_ids'].squeeze(0).tolist()
    labels = ds_mlm.iloc[sent_id]['labels']
    text = [k for k in text if k != 1]
    labels = [k for k in labels if k != 1]
    original = [ids_to_tokens(text)]
    references = [[ids_to_tokens(labels)]]
    for i in words:
      print(f"MSP: {tokenizer.convert_ids_to_tokens(i[0])} => {tokenizer.convert_ids_to_tokens(i[1])}")
    print(original)
    print(references)
    print("-------------------")
# Out:
# =========[morphed]==========
# MSP: มั๊ย => ไหม
# [['<s>', '▁', 'จําเป็น', 'ต้อง', 'เปิดบริการ', 'กับ', 'สาขา', 'ที่', 'เ', 'ปิดบัญชี', '▁', 'มั๊ย', 'ครับ', '▁', 'หรือ', 'สาขา', 'ไหนก็ได้', '</s>']]
# [[['<s>', '▁', 'จําเป็น', 'ต้อง', 'เปิดบริการ', 'กับ', 'สาขา', 'ที่', 'เ', 'ปิดบัญชี', '▁', 'ไหม', 'ครับ', '▁', 'หรือ', 'สาขา', 'ไหนก็ได้', '</s>']]]
# -------------------
# MSP: คับ => ครับ
# [['<s>', '▁พี่', 'คับ', 'ผมอยาก', 'รุ้', 'ว่า', '</s>']]
# [[['<s>', '▁พี่', 'ครับ', 'ผมอยาก', '▁รู้', 'ว่า', '</s>']]]
# -------------------
# MSP: ยังไง => อย่างไร
# [['<s>', '▁แล้วถ้า', 'อยาก', 'เชค', 'ยอด', 'การใช้งาน', 'บัตรเครดิต', 'ต้องทํา', 'ยังไง', 'อะคะ', '</s>']]
# [[['<s>', '▁แล้วถ้า', 'อยาก', 'เช็ค', 'ยอด', 'การใช้งาน', 'บัตรเครดิต', 'ต้องทํา', 'อย่างไร', 'อะคะ', '</s>']]]
# -------------------
# MSP: ตัง => สตางค์
# [['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'ตัง', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เปน', 'เพราะอะไร', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'สตางค์', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เป็น', 'เพราะอะไร', 'คะ', '</s>']]]
# -------------------
# MSP: เปน => เป็น
# [['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'ตัง', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เปน', 'เพราะอะไร', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'สตางค์', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เป็น', 'เพราะอะไร', 'คะ', '</s>']]]
# -------------------
# MSP: ยังไง => อย่างไร
# [['<s>', '▁', 'มีค่า', 'ธรรมเนียม', 'ยังไง', 'บ้าง', 'อ่อ', 'คะ', '</s>']]
# [[['<s>', '▁', 'มีค่า', 'ธรรมเนียม', 'อย่างไร', 'บ้าง', 'อ่อ', 'คะ', '</s>']]]
# -------------------
# MSP: คร้า => ค่ะ
# [['<s>', '▁', 'รหัส', 'จําได้', 'คร้า', '</s>']]
# [[['<s>', '▁', 'รหัส', 'จําได้', 'ค่ะ', '</s>']]]
# -------------------
# MSP: มั้ย => ไหม
# [['<s>', '▁', 'อ่อ', 'โอเค', 'ค่ะ', 'ยกเลิก', 'ทันที', '▁แล้วก็', 'สมัคร', 'ใหม่', 'ได้ทันที', 'เลย', 'ใช่', 'มั้ย', 'คะ', '</s>']]
# [[['<s>', '▁', '▁อ๋อ', 'โอเค', 'ค่ะ', 'ยกเลิก', 'ทันที', '▁แล้วก็', 'สมัคร', 'ใหม่', 'ได้ทันที', 'เลย', 'ใช่', 'ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: ยังไง => อย่างไร
# [['<s>', '▁ไม่', 'ครับผม', 'เปลี่ยน', 'ใช้', 'ซิม', 'ใหม่', 'และจะ', 'เข้าบัญชี', 'ใหม่', 'ครับ', 'แต่มัน', 'ติด', 'อันนี้', 'ผม', 'ไม่เข้าใจ', 'ว่ามัน', 'ติด', 'มาได้', 'ยังไง', 'ผม', 'ลบ', 'แอพ', 'แล้ว', '</s>']]
# [[['<s>', '▁ไม่', 'ครับผม', 'เปลี่ยน', 'ใช้', 'ซิม', 'ใหม่', 'และจะ', 'เข้าบัญชี', 'ใหม่', 'ครับ', 'แต่มัน', 'ติด', 'อันนี้', 'ผม', 'ไม่เข้าใจ', 'ว่ามัน', 'ติด', 'มาได้', 'อย่างไร', 'ผม', 'ลบ', 'แอป', 'แล้ว', '</s>']]]
# -------------------
# MSP: ไง => อย่างไร
# [['<s>', '▁มัน', 'ต้องทํา', 'ไง', 'อะครับ', '</s>']]
# [[['<s>', '▁มัน', 'ต้องทํา', 'อย่างไร', 'อะครับ', '</s>']]]
# -------------------
# MSP: มั๊ย => ไหม
# [['<s>', '▁', 'เปลี่ยน', 'โทร', 'ศ', 'ัพ', 'แต่ต้อง', 'สมัคร', 'ใหม่', 'มั๊ย', 'คะ', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'โทรศัพท์', '_', '_', 'แต่ต้อง', 'สมัคร', 'ใหม่', 'ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: ก้อ => ▁ก็
# [['<s>', '▁', 'ไปให้', 'ที่', 'ธนาคาร', 'ขอ', 'รหัส', 'ใหม่ที่', 'ตุ', '้', '<unk>', 'ก้อ', 'ทําไม่ได้', '</s>']]
# [[['<s>', '▁', 'ไปให้', 'ที่', 'ธนาคาร', 'ขอ', 'รหัส', 'ใหม่ที่', 'ตู้', '_', '<unk>', '▁ก็', 'ทําไม่ได้', '</s>']]]
# -------------------
# MSP: คับ => ครับ
# [['<s>', '▁', 'คับ', 'เดี๋ยวจะ', 'รอง', 'ส', 'มัค', 'ผ่าน', 'มือถือ', 'นะ', 'คับ', '.', '▁', 'แร้ว', 'ต้องทําไง', 'อีก', 'ปะ', 'คับ', '</s>']]
# [[['<s>', '▁', 'ครับ', 'เดี๋ยวจะ', '▁ลอง', 'สมัคร', '_', 'ผ่าน', 'มือถือ', 'นะ', 'ครับ', '.', '▁', '▁แล้ว', 'ต้องทําไง', 'อีก', '▁เปล่า', 'ครับ', '</s>']]]
# -------------------
# MSP: แร้ว => ▁แล้ว
# [['<s>', '▁', 'คับ', 'เดี๋ยวจะ', 'รอง', 'ส', 'มัค', 'ผ่าน', 'มือถือ', 'นะ', 'คับ', '.', '▁', 'แร้ว', 'ต้องทําไง', 'อีก', 'ปะ', 'คับ', '</s>']]
# [[['<s>', '▁', 'ครับ', 'เดี๋ยวจะ', '▁ลอง', 'สมัคร', '_', 'ผ่าน', 'มือถือ', 'นะ', 'ครับ', '.', '▁', '▁แล้ว', 'ต้องทําไง', 'อีก', '▁เปล่า', 'ครับ', '</s>']]]
# -------------------
# MSP: คับ => ครับ
# [['<s>', '▁คือผม', 'ต้องการ', '▁', 'กู้เงิน', 'ธนาคาร', 'อะ', 'คับ', '</s>']]
# [[['<s>', '▁คือผม', 'ต้องการ', '▁', 'กู้เงิน', 'ธนาคาร', 'อะ', 'ครับ', '</s>']]]
# -------------------
# MSP: มั้ย => ไหม
# [['<s>', '▁', 'ขอบคุณนะคะ', 'ต้อง', 'แจ้ง', 'ไปใน', 'อีเมล', 'ใช่', 'มั้ย', 'คะ', '</s>']]
# [[['<s>', '▁', 'ขอบคุณนะคะ', 'ต้อง', 'แจ้ง', 'ไปใน', 'อีเมล', 'ใช่', 'ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: ไม๊ => ไหม
# [['<s>', '▁', 'สามารถ', 'ยื่น', 'ใหม่', 'ได้', 'ใช่', 'ไม๊', 'คะ', '▁แล้ว', 'จะต้อง', 'ใช้เวลา', 'กี่วัน', 'ถึงจะ', 'ได้รับเงิน', '</s>']]
# [[['<s>', '▁', 'สามารถ', 'ยื่น', 'ใหม่', 'ได้', 'ใช่', 'ไหม', 'คะ', '▁แล้ว', 'จะต้อง', 'ใช้เวลา', 'กี่วัน', 'ถึงจะ', 'ได้รับเงิน', '</s>']]]
# -------------------
# MSP: ตัง => สตางค์
# MSP: อยุ่ => อยู่
# [['<s>', '▁พี่', 'ค่ะ', 'หนู', 'ไม่มี', 'สมุดบัญชี', 'ไม่มี', 'บัตร', 'เอทีเอ็ม', 'แต่', 'ตัง', 'อยุ่', 'ในบัญชี', 'ทําไงดี', 'ค่ะ', '</s>']]
# [[['<s>', '▁พี่', 'คะ', 'หนู', 'ไม่มี', 'สมุดบัญชี', 'ไม่มี', 'บัตร', 'เอทีเอ็ม', 'แต่', 'สตางค์', 'อยู่', 'ในบัญชี', 'ทําไงดี', 'คะ', '</s>']]]
# -------------------
# MSP: คับ => ครับ
# [['<s>', '▁พี่', 'คับ', '▁พอดี', 'เปลี่ยน', 'โทร', 'สับ', 'ใหม่', 'จะ', 'เข้าสู่', 'ระบบ', 'เดิม', 'ใน', 'เครื่อง', 'บลจ.', '▁', 'จะทําไง', 'คับ', '</s>']]
# [[['<s>', '▁พี่', 'คับ', '▁พอดี', 'เปลี่ยน', 'โทรศัพท์', '_', 'ใหม่', 'จะ', 'เข้าสู่', 'ระบบ', 'เดิม', 'ใน', 'เครื่อง', 'ใหม่', '_', 'จะทําไง', 'ครับ', '</s>']]]
# -------------------
# =========[misspelled]==========
# MSP: ก้ => ▁ก็
# [['<s>', '▁เมื่อวาน', 'ก้', 'ยัง', 'เข้า', 'ได้', '</s>']]
# [[['<s>', '▁เมื่อวาน', '▁ก็', 'ยัง', 'เข้า', 'ได้', '</s>']]]
# -------------------
# MSP: อยุ่ => อยู่
# [['<s>', '▁ผม', 'อยุ่', 'ต่างประเทศ', 'ครับ', '</s>']]
# [[['<s>', '▁ผม', 'อยู่', 'ต่างประเทศ', 'ครับ', '</s>']]]
# -------------------
# MSP: รุ้ => ▁รู้
# [['<s>', '▁พี่', 'คับ', 'ผมอยาก', 'รุ้', 'ว่า', '</s>']]
# [[['<s>', '▁พี่', 'ครับ', 'ผมอยาก', '▁รู้', 'ว่า', '</s>']]]
# -------------------
# MSP: ใหน => ไหน
# [['<s>', '▁', 'เข้าไป', 'โหลด', 'ตรง', 'ใหน', 'ครับ', '</s>']]
# [[['<s>', '▁', 'เข้าไป', 'โหลด', 'ตรง', 'ไหน', 'ครับ', '</s>']]]
# -------------------
# MSP: เบอ => เบอร์
# [['<s>', '▁', 'โอน', 'โดยใช้', 'เบอ', 'มือถือ', 'คับ', '</s>']]
# [[['<s>', '▁', 'โอน', 'โดยใช้', 'เบอร์', 'มือถือ', 'ครับ', '</s>']]]
# -------------------
# MSP: แอฟ => แอป
# [['<s>', '▁แต่', 'แอฟ', 'ธนาคาร', 'เข้า', 'อยาก', 'ค่ะ', '</s>']]
# [[['<s>', '▁แต่', 'แอป', 'ธนาคาร', 'เข้า', 'ยาก', 'ค่ะ', '</s>']]]
# -------------------
# MSP: แอพ => แอป
# [['<s>', '▁', 'สมัคร', 'ผ่าน', 'แอพ', 'ไปแล้ว', '▁', 'แต่ยัง', 'ใช้ไม่ได้', 'เลยค่ะ', '</s>']]
# [[['<s>', '▁', 'สมัคร', 'ผ่าน', 'แอป', 'ไปแล้ว', '▁', 'แต่ยัง', 'ใช้ไม่ได้', 'เลยค่ะ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'ตัง', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เปน', 'เพราะอะไร', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'สอบถาม', 'หน่อยค่ะ', '▁', 'บางทีก็', 'โอน', 'สตางค์', 'ได้', '▁', 'บางทีก็', 'โอน', 'ไม่ได้', '▁', 'เป็น', 'เพราะอะไร', 'คะ', '</s>']]]
# -------------------
# MSP: คะ => ค่ะ
# [['<s>', '▁', 'อ่อ', 'คะ', 'ขอบคุณ', 'คะ', 'แล้วถ้า', 'สมัคร', 'บัตร', 'อะ งง', '▁', 'นี้', 'ต้องเสีย', 'รายเดือน', 'ไหมคะ', '</s>']]
# [[['<s>', '▁', '▁อ๋อ', 'ค่ะ', 'ขอบคุณ', 'ค่ะ', 'แล้วถ้า', 'สมัคร', 'บัตร', 'อะ งง', '▁', 'นี้', 'ต้องเสีย', 'รายเดือน', 'ไหมคะ', '</s>']]]
# -------------------
# MSP: ใหม => ไหม
# [['<s>', '▁เวลา', 'ต้อง', 'หัก', 'ค่า', 'อะไร', 'เพิ่ม', 'ใหม', 'ครับ', '</s>']]
# [[['<s>', '▁เวลา', 'ต้อง', 'หัก', 'ค่า', 'อะไร', 'เพิ่ม', 'ไหม', 'ครับ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁ต้อง', '▁การ', '▁ใช้', '▁', 'บัตร', 'อะ งง', '▁', 'อ่ะ', 'ครับ', '</s>']]
# [[['<s>', '▁ต้อง', '▁การ', '▁ใช้', '▁', 'บัตร', 'อะ งง', '▁', 'อะ', 'ครับ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁', 'ไม่ทัน', 'อ่ะ', '</s>']]
# [[['<s>', '▁', 'ไม่ทัน', 'อะ', '</s>']]]
# -------------------
# MSP: ก้ => ▁ก็
# [['<s>', '▁จะ', 'บสย.', '▁', 'ไร', 'ก้', 'เติม', 'ไม่ได้', '</s>']]
# [[['<s>', '▁จะ', 'บสย.', '▁', 'ไร', '▁ก็', 'เติม', 'ไม่ได้', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁แล้ว', 'บัตร', 'เก่า', 'อ่ะ', 'ครับ', '</s>']]
# [[['<s>', '▁แล้ว', 'บัตร', 'เก่า', 'อะ', 'ครับ', '</s>']]]
# -------------------
# MSP: อ่อ => ▁อ๋อ
# [['<s>', '▁', 'อ่อ', 'โอเค', 'ค่ะ', 'ยกเลิก', 'ทันที', '▁แล้วก็', 'สมัคร', 'ใหม่', 'ได้ทันที', 'เลย', 'ใช่', 'มั้ย', 'คะ', '</s>']]
# [[['<s>', '▁', '▁อ๋อ', 'โอเค', 'ค่ะ', 'ยกเลิก', 'ทันที', '▁แล้วก็', 'สมัคร', 'ใหม่', 'ได้ทันที', 'เลย', 'ใช่', 'ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: อยุ่ => อยู่
# [['<s>', '▁เมื่อวาน', 'ยัง', 'กด', 'ได้', 'อยุ่', 'ค่ะ', '</s>']]
# [[['<s>', '▁เมื่อวาน', 'ยัง', 'กด', 'ได้', 'อยู่', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ยุ => อยู่
# [['<s>', '▁อยาก', 'ส', 'มัค', 'ค่ะ', 'ยุ', 'ต่างประเทศ', 'จะ', 'ส', 'มัค', 'ได้ไหม', 'ค่ะ', '</s>']]
# [[['<s>', '▁อยาก', 'สมัคร', '_', 'ค่ะ', 'อยู่', 'ต่างประเทศ', 'จะ', 'สมัคร', '_', 'ได้ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: ค่ะ => คะ
# [['<s>', '▁อยาก', 'ส', 'มัค', 'ค่ะ', 'ยุ', 'ต่างประเทศ', 'จะ', 'ส', 'มัค', 'ได้ไหม', 'ค่ะ', '</s>']]
# [[['<s>', '▁อยาก', 'สมัคร', '_', 'ค่ะ', 'อยู่', 'ต่างประเทศ', 'จะ', 'สมัคร', '_', 'ได้ไหม', 'คะ', '</s>']]]
# -------------------
# MSP: อ้ะ => อะ
# [['<s>', '▁', 'เหมือนเดิม', 'อ้ะ', 'ครับ', '</s>']]
# [[['<s>', '▁', 'เหมือนเดิม', 'อะ', 'ครับ', '</s>']]]
# -------------------
# =========[ws]==========
# MSP: เป็นไร => เป็นไร
# [['<s>', '▁', 'อ่อ', 'ไม่', 'เป็นไร', 'แล้ว', 'คับ', '</s>']]
# [[['<s>', '▁', '▁อ๋อ', 'ไม่', 'เป็นไร', 'แล้ว', 'ครับ', '</s>']]]
# -------------------
# MSP: ตรงกัน => ตรงกัน
# [['<s>', '▁', 'เบอ', '▁', 'ตรงกัน', 'ครับ', '</s>']]
# [[['<s>', '▁', 'เบอร์', '▁', 'ตรงกัน', 'ครับ', '</s>']]]
# -------------------
# MSP: ใม่ => ▁ไม่
# MSP: ได้ => ได้
# [['<s>', '▁', 'ตรวจดู', 'ทุกอย่าง', 'ไม่ผิด', '▁', 'แต่ยัง', 'โอน', 'ใม่', 'ได้', 'ต้องทํา', 'ยัง', 'ใ', 'ง', 'คับ', '</s>']]
# [[['<s>', '▁', 'ตรวจดู', 'ทุกอย่าง', 'ไม่ผิด', '▁', 'แต่ยัง', 'โอน', '▁ไม่', 'ได้', 'ต้องทํา', 'ยังไง', '_', '_', 'ครับ', '</s>']]]
# -------------------
# MSP: เบอ => เบอร์
# MSP: โทร => โทร
# [['<s>', '▁', 'เปลี่ยน', 'เบอ', 'โทร', 'ที่', 'เชื่อม', 'กับ', 'บัญชี', 'อะ', 'คะ', '</s>']]
# [[['<s>', '▁', 'เปลี่ยน', 'เบอร์', 'โทร', 'ที่', 'เชื่อม', 'กับ', 'บัญชี', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: ก้อง => ก้อง
# [['<s>', '▁เออ', 'เรา', 'ก้อง', 'ง', '▁', 'สิ', '้', 'ค้ะ', '</s>']]
# [[['<s>', '▁เออ', 'เรา', 'ก้อง', 'ง', '▁', 'สิ', '_', 'คะ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# MSP: ค่ะ => ค่ะ
# [['<s>', '▁คือ', 'เข้า', 'ไม่ได้', 'อ่ะ', 'ค่ะ', '</s>']]
# [[['<s>', '▁คือ', 'เข้า', 'ไม่ได้', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# =========[other]==========
# MSP: อ้ะ => อะ
# [['<s>', '▁', 'แอป', 'ของ', 'กสิกร', 'อ้ะ', 'ค่ะ', '▁', 'จะยกเลิก', 'เบอร์', 'เดิม', 'แล้ว', 'สมัคร', 'เบอร์', 'ใหม่', '</s>']]
# [[['<s>', '▁', 'แอพ', 'ของ', 'กสิกร', 'อะ', 'ค่ะ', '▁', 'จะยกเลิก', 'เบอร์', 'เดิม', 'แล้ว', 'สมัคร', 'เบอร์', 'ใหม่', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁พอดี', 'อยู่ชั้นไหน', '▁', 'อ่ะ', 'ค่ะ', '</s>']]
# [[['<s>', '▁พอดี', 'อยู่ชั้นไหน', '▁', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁', 'ยอดเงิน', 'หัก', 'แล้วแต่', 'ป', 'ลายทาง', '▁', 'ไม่ได้รับ', 'อ่ะ', 'ครับ', '</s>']]
# [[['<s>', '▁', 'ยอดเงิน', 'หัก', 'แล้วแต่', 'ป', 'ลายทาง', '▁', 'ไม่ได้รับ', 'อะ', 'ครับ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# MSP: คับ => ครับ
# [['<s>', '▁ถ้า', 'ยังไม่', 'เพิ่ม', 'อ่ะ', 'คับ', '</s>']]
# [[['<s>', '▁ถ้า', 'ยังไม่', 'เพิ่ม', 'อะ', 'ครับ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '�
', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁', '\\', 'ผมว่า', 'ผู้', 'การ', 'เค้า', '▁', '\\', '\\', 'อยู่', 'ไม่เป็น', '\\', '\\', '▁', 'อ่ะ', '\\', '</s>']]
# [[['<s>', '▁', '\\', 'ผมว่า', 'ผู้', 'การ', 'เค้า', '▁', '\\', '\\', 'อยู่', 'ไม่เป็น', '\\', '\\', '▁', 'อะ', '\\', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# MSP: คับ => ครับ
# [['<s>', '▁', 'เบอ', 'ใช้', 'อยู่', 'อ่ะ', 'คับ', '</s>']]
# [[['<s>', '▁', 'เบอร์', 'ใช้', 'อยู่', 'อะ', 'ครับ', '</s>']]]
# -------------------
# =========[abbreviation]==========
# MSP: บช => บัญชี
# [['<s>', '▁', 'เพิ่ม', 'เพิ่ม', 'บช', '▁', 'มา', 'เมื่อวาน', 'นี้', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'เพิ่ม', 'เพิ่ม', 'บัญชี', '▁', 'มา', 'เมื่อวาน', 'นี้', 'ค่ะ', '</s>']]]
# -------------------
# MSP: บช => บัญชี
# [['<s>', '▁เ', 'ปิดบัญชี', '▁', 'แล้วครับ', '▁', 'เป็น', 'บัญชี', 'โดย', '▁', 'บช', '▁', 'นี้', 'สาม', 'รถ', 'โอนเงิน', 'ให้คนอื่น', 'ได้ไหม', '</s>']]
# [[['<s>', '▁เ', 'ปิดบัญชี', '▁', 'แล้วครับ', '▁', 'เป็น', 'บัญชี', 'โดย', '▁', 'บัญชี', '▁', 'นี้', 'สามารถ', '_', 'โอนเงิน', 'ให้คนอื่น', 'ได้ไหม', '</s>']]]
# -------------------
# MSP: บช => บัญชี
# [['<s>', '▁', 'สอบถาม', 'เรื่อง', '▁', 'เงิน', 'ใน', '▁', 'บช', '▁โดน', 'หัก', 'ไป', 'โดยไม่', 'ทราบสาเหตุ', 'ค่ะ', '</s>']]
# [[['<s>', '▁', 'สอบถาม', 'เรื่อง', '▁', 'เงิน', 'ใน', '▁', 'บัญชี', '▁โดน', 'หัก', 'ไป', 'โดยไม่', 'ทราบสาเหตุ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: อ่ะ => อะ
# [['<s>', '▁คือ', 'ว่า', 'ซิม', 'ใช้', 'ที่นี่', 'ไม่ได้', 'อ่ะ', 'ค่ะ', '</s>']]
# [[['<s>', '▁คือ', 'ว่า', 'ซิม', 'ใช้', 'ที่นี่', 'ไม่ได้', 'อะ', 'ค่ะ', '</s>']]]
# -------------------
# MSP: พนง => พนักงาน
# [['<s>', '▁', '<unk>', 'a', 'tic', 'hon', '<unk>', 'n', 'line', '▁', 'อธิบดี', 'ดีเอสไอ', '▁', 'ขอดู', 'มติ', '▁', 'ก', 'ค', 'พ', '▁', 'คดี', 'ปล่อยกู้', 'กรุงไทย', 'ก่อน', '▁เพราะ', 'ช่วงนั้น', 'ไม่ได้เป็น', 'พนง', '▁', 'สอบสวน', '▁', '</s>']]
# [[['<s>', '▁', '<unk>', 'a', 'tic', 'hon', '<unk>', 'n', 'line', '▁', 'อธิบดี', 'ดีเอสไอ', '▁', 'ขอดู', 'มติ', '▁', 'คปภ.', '_', '_', '▁', 'คดี', 'ปล่อยกู้', 'กรุงไทย', 'ก่อน', '▁เพราะ', 'ช่วงนั้น', 'ไม่ได้เป็น', 'พนักงาน', '▁', 'สอบสวน', '▁', '</s>']]]
# -------------------
# MSP: ตปท => ต่างประเทศ
# [['<s>', '▁เพราะ', 'ตัว', 'ดิฉัน', 'อยู่', '▁', 'ตปท', '▁', 'ด้วย', '</s>']]
